# %% [markdown]
# # Deep Learning: Laparoscopic segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
import cv2
import tensorflow as tf
import keras.backend as K
from skimage import exposure
from skimage.color import rgb2gray
from sklearn.model_selection import train_test_split
from glob import glob
import pickle
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
CLASS_WEIGHTS = [2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
 1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
 3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
 4.36967906e-03]

# %%
# https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape, 
                    padding_color = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size, interpolation=cv2.INTER_NEAREST)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 120:-120,:]
    img = resize_with_pad(img, (HEIGHT, WIDTH))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 120:-120,:]
    mask = resize_with_pad(mask, (HEIGHT, WIDTH), (50, 50, 50))
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx], cmap='magma')
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
# dump_data(X, y)
# X, y = load_data()
np.unique(y_encoded[idx])
# Out:
# array([ 0,  1,  2,  3,  4,  5, 10], dtype=uint8)

# %%
plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1), cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## U-Net

# %%
def double_conv_block(x, n_filters):

   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)

   return x

def downsample_block(x, n_filters):
   f = double_conv_block(x, n_filters)
   p = tf.keras.layers.MaxPool2D(2)(f)
   p = tf.keras.layers.BatchNormalization()(p)
   p = tf.keras.layers.Dropout(0.2)(p)

   return f, p

def upsample_block(x, conv_features, n_filters):
   # upsample
   x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
   # concatenate
   x = tf.keras.layers.concatenate([x, conv_features])
   # dropout
   x = tf.keras.layers.BatchNormalization()(x)
   x = tf.keras.layers.Dropout(0.2)(x)
   # Conv2D twice with ReLU activation
   x = double_conv_block(x, n_filters)

   return x

def build_unet_model(n_filters=64, n_classes=2):
   # inputs
   inputs = tf.keras.layers.Input(shape=(HEIGHT,WIDTH,3))

   # encoder: contracting path - downsample
   # 1 - downsample
   f1, p1 = downsample_block(inputs, n_filters)
   # 2 - downsample
   f2, p2 = downsample_block(p1, n_filters*2)
   # 3 - downsample
   f3, p3 = downsample_block(p2, n_filters*4)
   # 4 - downsample
   f4, p4 = downsample_block(p3, n_filters*8)

   # 5 - bottleneck
   bottleneck = double_conv_block(p4, n_filters*16)

   # decoder: expanding path - upsample
   # 6 - upsample
   u6 = upsample_block(bottleneck, f4, n_filters*8)
   # 7 - upsample
   u7 = upsample_block(u6, f3, n_filters*4)
   # 8 - upsample
   u8 = upsample_block(u7, f2, n_filters*2)
   # 9 - upsample
   u9 = upsample_block(u8, f1, n_filters)

   # outputs
   
   activation = 'sigmoid' if n_classes == 2 else 'softmax'
   outputs = tf.keras.layers.Conv2D(n_classes, 1, padding="same", activation=activation)(u9)

   # unet model with Keras Functional API
   unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

   return unet_model

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tv = tversky(y_true, y_pred)
    return tf.keras.backend.pow((1 - tv), gamma)

def generalized_dice_coeff(y_true, y_pred, smooth=1e-9):
    Ncl = y_pred.shape[-1]
    w = np.zeros((Ncl,))
    w = K.sum(y_true, (0,1,2))
    w = 1 / (w ** 2 + smooth)

    y_pred = tf.nn.softmax(y_pred)

    # Compute gen dice coef:
    numerator = y_true * y_pred
    numerator = w * K.sum(numerator, (0,1,2))
    numerator = K.sum(numerator)

    denominator = y_true + y_pred
    denominator = w * K.sum(denominator, (0,1,2))
    denominator = K.sum(denominator)

    return 2. * (numerator + smooth) / (denominator + smooth)


def generalized_dice_loss(y_true, y_pred):
    return 1. - generalized_dice_coeff(y_true, y_pred)

# %%
unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.load_weights('../models/u-net_39-0.22_tversky_loss.hdf5')
unet_model.compile(
    optimizer=tf.keras.optimizers.Adam(5e-4), 
    loss=sm.losses.DiceLoss(class_weights=CLASS_WEIGHTS),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)

unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   896         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 32)  128         ['max_pooling2d[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 32, 32, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   18496       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 64)  256         ['max_pooling2d_1[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_5[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 128)   512         ['max_pooling2d_2[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 8, 8, 128)    0           ['batch_normalization_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 256)    295168      ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)   0           ['conv2d_7[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 4, 4, 256)   1024        ['max_pooling2d_3[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 4, 4, 256)    0           ['batch_normalization_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 512)    1180160     ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 4, 4, 512)    2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 8, 8, 256)   1179904     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 8, 8, 512)    0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 512)   2048        ['concatenate[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 8, 8, 512)    0           ['batch_normalization_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 256)    1179904     ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 16, 16, 128)  295040     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 256)  1024       ['concatenate_1[0][0]']
#  rmalization)
#
#  dropout_5 (Dropout)            (None, 16, 16, 256)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 32, 32, 64)  73792       ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 128)  512        ['concatenate_2[0][0]']
#  rmalization)
#
#  dropout_6 (Dropout)            (None, 32, 32, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_15[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 64)  256         ['concatenate_3[0][0]']
#  rmalization)
#
#  dropout_7 (Dropout)            (None, 64, 64, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 13)   429         ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 8,636,653
# Trainable params: 8,633,773
# Non-trainable params: 2,880
# __________________________________________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/u-net-BN_diceLoss.hdf5',
    verbose=1,
    monitor='val_mean_io_u',
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)

print('\n\t TRAINING\n')

model_history = unet_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9596 - mean_io_u: 0.4680 - dice_coeficient: 0.5616
# Epoch 1: val_mean_io_u improved from -inf to 0.46753, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 22s 236ms/step - loss: 0.9596 - mean_io_u: 0.4680 - dice_coeficient: 0.5616 - val_loss: 0.9809 - val_mean_io_u: 0.4675 - val_dice_coeficient: 0.2690
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9373 - mean_io_u: 0.5345 - dice_coeficient: 0.8589
# Epoch 2: val_mean_io_u did not improve from 0.46753
# 51/51 [==============================] - 8s 165ms/step - loss: 0.9373 - mean_io_u: 0.5345 - dice_coeficient: 0.8589 - val_loss: 0.9692 - val_mean_io_u: 0.4623 - val_dice_coeficient: 0.4188
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9341 - mean_io_u: 0.5812 - dice_coeficient: 0.8914
# Epoch 3: val_mean_io_u did not improve from 0.46753
# 51/51 [==============================] - 8s 165ms/step - loss: 0.9341 - mean_io_u: 0.5812 - dice_coeficient: 0.8914 - val_loss: 0.9608 - val_mean_io_u: 0.4615 - val_dice_coeficient: 0.5387
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9326 - mean_io_u: 0.6328 - dice_coeficient: 0.9061
# Epoch 4: val_mean_io_u did not improve from 0.46753
# 51/51 [==============================] - 9s 167ms/step - loss: 0.9326 - mean_io_u: 0.6328 - dice_coeficient: 0.9061 - val_loss: 0.9544 - val_mean_io_u: 0.4615 - val_dice_coeficient: 0.6394
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9304 - mean_io_u: 0.6840 - dice_coeficient: 0.9260
# Epoch 5: val_mean_io_u did not improve from 0.46753
# 51/51 [==============================] - 8s 166ms/step - loss: 0.9304 - mean_io_u: 0.6840 - dice_coeficient: 0.9260 - val_loss: 0.9447 - val_mean_io_u: 0.4663 - val_dice_coeficient: 0.7547
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9295 - mean_io_u: 0.7438 - dice_coeficient: 0.9367
# Epoch 6: val_mean_io_u improved from 0.46753 to 0.49869, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 168ms/step - loss: 0.9295 - mean_io_u: 0.7438 - dice_coeficient: 0.9367 - val_loss: 0.9369 - val_mean_io_u: 0.4987 - val_dice_coeficient: 0.8470
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9292 - mean_io_u: 0.7722 - dice_coeficient: 0.9396
# Epoch 7: val_mean_io_u improved from 0.49869 to 0.57275, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 171ms/step - loss: 0.9292 - mean_io_u: 0.7722 - dice_coeficient: 0.9396 - val_loss: 0.9320 - val_mean_io_u: 0.5728 - val_dice_coeficient: 0.9063
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9290 - mean_io_u: 0.7934 - dice_coeficient: 0.9419
# Epoch 8: val_mean_io_u improved from 0.57275 to 0.65781, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 170ms/step - loss: 0.9290 - mean_io_u: 0.7934 - dice_coeficient: 0.9419 - val_loss: 0.9303 - val_mean_io_u: 0.6578 - val_dice_coeficient: 0.9260
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9289 - mean_io_u: 0.8157 - dice_coeficient: 0.9436
# Epoch 9: val_mean_io_u improved from 0.65781 to 0.71806, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 169ms/step - loss: 0.9289 - mean_io_u: 0.8157 - dice_coeficient: 0.9436 - val_loss: 0.9295 - val_mean_io_u: 0.7181 - val_dice_coeficient: 0.9355
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9287 - mean_io_u: 0.8286 - dice_coeficient: 0.9454
# Epoch 10: val_mean_io_u improved from 0.71806 to 0.77967, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 169ms/step - loss: 0.9287 - mean_io_u: 0.8286 - dice_coeficient: 0.9454 - val_loss: 0.9289 - val_mean_io_u: 0.7797 - val_dice_coeficient: 0.9432
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9286 - mean_io_u: 0.8426 - dice_coeficient: 0.9458
# Epoch 11: val_mean_io_u improved from 0.77967 to 0.81462, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 169ms/step - loss: 0.9286 - mean_io_u: 0.8426 - dice_coeficient: 0.9458 - val_loss: 0.9287 - val_mean_io_u: 0.8146 - val_dice_coeficient: 0.9449
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9285 - mean_io_u: 0.8527 - dice_coeficient: 0.9471
# Epoch 12: val_mean_io_u improved from 0.81462 to 0.82999, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 169ms/step - loss: 0.9285 - mean_io_u: 0.8527 - dice_coeficient: 0.9471 - val_loss: 0.9285 - val_mean_io_u: 0.8300 - val_dice_coeficient: 0.9468
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9284 - mean_io_u: 0.8605 - dice_coeficient: 0.9481
# Epoch 13: val_mean_io_u improved from 0.82999 to 0.85273, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 169ms/step - loss: 0.9284 - mean_io_u: 0.8605 - dice_coeficient: 0.9481 - val_loss: 0.9284 - val_mean_io_u: 0.8527 - val_dice_coeficient: 0.9484
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9282 - mean_io_u: 0.8630 - dice_coeficient: 0.9505
# Epoch 14: val_mean_io_u improved from 0.85273 to 0.87084, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 170ms/step - loss: 0.9282 - mean_io_u: 0.8630 - dice_coeficient: 0.9505 - val_loss: 0.9280 - val_mean_io_u: 0.8708 - val_dice_coeficient: 0.9538
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9280 - mean_io_u: 0.8774 - dice_coeficient: 0.9524
# Epoch 15: val_mean_io_u improved from 0.87084 to 0.87146, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 170ms/step - loss: 0.9280 - mean_io_u: 0.8774 - dice_coeficient: 0.9524 - val_loss: 0.9279 - val_mean_io_u: 0.8715 - val_dice_coeficient: 0.9540
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9279 - mean_io_u: 0.8826 - dice_coeficient: 0.9530
# Epoch 16: val_mean_io_u improved from 0.87146 to 0.88832, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 171ms/step - loss: 0.9279 - mean_io_u: 0.8826 - dice_coeficient: 0.9530 - val_loss: 0.9278 - val_mean_io_u: 0.8883 - val_dice_coeficient: 0.9557
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9279 - mean_io_u: 0.8869 - dice_coeficient: 0.9537
# Epoch 17: val_mean_io_u improved from 0.88832 to 0.89594, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 173ms/step - loss: 0.9279 - mean_io_u: 0.8869 - dice_coeficient: 0.9537 - val_loss: 0.9277 - val_mean_io_u: 0.8959 - val_dice_coeficient: 0.9562
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9278 - mean_io_u: 0.8921 - dice_coeficient: 0.9539
# Epoch 18: val_mean_io_u improved from 0.89594 to 0.90491, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 172ms/step - loss: 0.9278 - mean_io_u: 0.8921 - dice_coeficient: 0.9539 - val_loss: 0.9277 - val_mean_io_u: 0.9049 - val_dice_coeficient: 0.9565
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9278 - mean_io_u: 0.8979 - dice_coeficient: 0.9543
# Epoch 19: val_mean_io_u improved from 0.90491 to 0.90628, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 173ms/step - loss: 0.9278 - mean_io_u: 0.8979 - dice_coeficient: 0.9543 - val_loss: 0.9277 - val_mean_io_u: 0.9063 - val_dice_coeficient: 0.9566
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9278 - mean_io_u: 0.9008 - dice_coeficient: 0.9546
# Epoch 20: val_mean_io_u improved from 0.90628 to 0.91166, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 173ms/step - loss: 0.9278 - mean_io_u: 0.9008 - dice_coeficient: 0.9546 - val_loss: 0.9276 - val_mean_io_u: 0.9117 - val_dice_coeficient: 0.9573
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9277 - mean_io_u: 0.9031 - dice_coeficient: 0.9548
# Epoch 21: val_mean_io_u improved from 0.91166 to 0.91236, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 173ms/step - loss: 0.9277 - mean_io_u: 0.9031 - dice_coeficient: 0.9548 - val_loss: 0.9276 - val_mean_io_u: 0.9124 - val_dice_coeficient: 0.9573
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9277 - mean_io_u: 0.9068 - dice_coeficient: 0.9552
# Epoch 22: val_mean_io_u improved from 0.91236 to 0.91319, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 174ms/step - loss: 0.9277 - mean_io_u: 0.9068 - dice_coeficient: 0.9552 - val_loss: 0.9276 - val_mean_io_u: 0.9132 - val_dice_coeficient: 0.9565
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9277 - mean_io_u: 0.9087 - dice_coeficient: 0.9554
# Epoch 23: val_mean_io_u improved from 0.91319 to 0.91665, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 176ms/step - loss: 0.9277 - mean_io_u: 0.9087 - dice_coeficient: 0.9554 - val_loss: 0.9275 - val_mean_io_u: 0.9166 - val_dice_coeficient: 0.9578
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9276 - mean_io_u: 0.9111 - dice_coeficient: 0.9556
# Epoch 24: val_mean_io_u improved from 0.91665 to 0.91712, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 174ms/step - loss: 0.9276 - mean_io_u: 0.9111 - dice_coeficient: 0.9556 - val_loss: 0.9275 - val_mean_io_u: 0.9171 - val_dice_coeficient: 0.9579
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9276 - mean_io_u: 0.9127 - dice_coeficient: 0.9558
# Epoch 25: val_mean_io_u improved from 0.91712 to 0.92048, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 175ms/step - loss: 0.9276 - mean_io_u: 0.9127 - dice_coeficient: 0.9558 - val_loss: 0.9275 - val_mean_io_u: 0.9205 - val_dice_coeficient: 0.9576
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9276 - mean_io_u: 0.9164 - dice_coeficient: 0.9559
# Epoch 26: val_mean_io_u improved from 0.92048 to 0.92230, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 176ms/step - loss: 0.9276 - mean_io_u: 0.9164 - dice_coeficient: 0.9559 - val_loss: 0.9275 - val_mean_io_u: 0.9223 - val_dice_coeficient: 0.9576
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9276 - mean_io_u: 0.9177 - dice_coeficient: 0.9561
# Epoch 27: val_mean_io_u improved from 0.92230 to 0.92294, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 176ms/step - loss: 0.9276 - mean_io_u: 0.9177 - dice_coeficient: 0.9561 - val_loss: 0.9275 - val_mean_io_u: 0.9229 - val_dice_coeficient: 0.9580
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9275 - mean_io_u: 0.9191 - dice_coeficient: 0.9562
# Epoch 28: val_mean_io_u improved from 0.92294 to 0.92773, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 177ms/step - loss: 0.9275 - mean_io_u: 0.9191 - dice_coeficient: 0.9562 - val_loss: 0.9274 - val_mean_io_u: 0.9277 - val_dice_coeficient: 0.9586
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9275 - mean_io_u: 0.9211 - dice_coeficient: 0.9566
# Epoch 29: val_mean_io_u did not improve from 0.92773
# 51/51 [==============================] - 9s 173ms/step - loss: 0.9275 - mean_io_u: 0.9211 - dice_coeficient: 0.9566 - val_loss: 0.9274 - val_mean_io_u: 0.9266 - val_dice_coeficient: 0.9584
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9275 - mean_io_u: 0.9221 - dice_coeficient: 0.9566
# Epoch 30: val_mean_io_u improved from 0.92773 to 0.93097, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 175ms/step - loss: 0.9275 - mean_io_u: 0.9221 - dice_coeficient: 0.9566 - val_loss: 0.9274 - val_mean_io_u: 0.9310 - val_dice_coeficient: 0.9588
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9275 - mean_io_u: 0.9245 - dice_coeficient: 0.9567
# Epoch 31: val_mean_io_u did not improve from 0.93097
# 51/51 [==============================] - 9s 175ms/step - loss: 0.9275 - mean_io_u: 0.9245 - dice_coeficient: 0.9567 - val_loss: 0.9274 - val_mean_io_u: 0.9294 - val_dice_coeficient: 0.9589
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9275 - mean_io_u: 0.9266 - dice_coeficient: 0.9569
# Epoch 32: val_mean_io_u improved from 0.93097 to 0.93225, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 177ms/step - loss: 0.9275 - mean_io_u: 0.9266 - dice_coeficient: 0.9569 - val_loss: 0.9274 - val_mean_io_u: 0.9322 - val_dice_coeficient: 0.9589
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9274 - mean_io_u: 0.9273 - dice_coeficient: 0.9570
# Epoch 33: val_mean_io_u improved from 0.93225 to 0.93362, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 177ms/step - loss: 0.9274 - mean_io_u: 0.9273 - dice_coeficient: 0.9570 - val_loss: 0.9274 - val_mean_io_u: 0.9336 - val_dice_coeficient: 0.9586
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9274 - mean_io_u: 0.9278 - dice_coeficient: 0.9570
# Epoch 34: val_mean_io_u did not improve from 0.93362
# 51/51 [==============================] - 9s 176ms/step - loss: 0.9274 - mean_io_u: 0.9278 - dice_coeficient: 0.9570 - val_loss: 0.9274 - val_mean_io_u: 0.9319 - val_dice_coeficient: 0.9586
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9274 - mean_io_u: 0.9298 - dice_coeficient: 0.9574
# Epoch 35: val_mean_io_u improved from 0.93362 to 0.93487, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 177ms/step - loss: 0.9274 - mean_io_u: 0.9298 - dice_coeficient: 0.9574 - val_loss: 0.9273 - val_mean_io_u: 0.9349 - val_dice_coeficient: 0.9590
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9274 - mean_io_u: 0.9302 - dice_coeficient: 0.9574
# Epoch 36: val_mean_io_u improved from 0.93487 to 0.93644, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 177ms/step - loss: 0.9274 - mean_io_u: 0.9302 - dice_coeficient: 0.9574 - val_loss: 0.9273 - val_mean_io_u: 0.9364 - val_dice_coeficient: 0.9594
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9274 - mean_io_u: 0.9324 - dice_coeficient: 0.9575
# Epoch 37: val_mean_io_u improved from 0.93644 to 0.93671, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 179ms/step - loss: 0.9274 - mean_io_u: 0.9324 - dice_coeficient: 0.9575 - val_loss: 0.9273 - val_mean_io_u: 0.9367 - val_dice_coeficient: 0.9590
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9274 - mean_io_u: 0.9322 - dice_coeficient: 0.9577
# Epoch 38: val_mean_io_u improved from 0.93671 to 0.93960, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 179ms/step - loss: 0.9274 - mean_io_u: 0.9322 - dice_coeficient: 0.9577 - val_loss: 0.9273 - val_mean_io_u: 0.9396 - val_dice_coeficient: 0.9596
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9274 - mean_io_u: 0.9329 - dice_coeficient: 0.9577
# Epoch 39: val_mean_io_u improved from 0.93960 to 0.93975, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9274 - mean_io_u: 0.9329 - dice_coeficient: 0.9577 - val_loss: 0.9273 - val_mean_io_u: 0.9398 - val_dice_coeficient: 0.9598
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9274 - mean_io_u: 0.9344 - dice_coeficient: 0.9578
# Epoch 40: val_mean_io_u improved from 0.93975 to 0.94120, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 180ms/step - loss: 0.9274 - mean_io_u: 0.9344 - dice_coeficient: 0.9578 - val_loss: 0.9273 - val_mean_io_u: 0.9412 - val_dice_coeficient: 0.9596
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9347 - dice_coeficient: 0.9580
# Epoch 41: val_mean_io_u did not improve from 0.94120
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9273 - mean_io_u: 0.9347 - dice_coeficient: 0.9580 - val_loss: 0.9273 - val_mean_io_u: 0.9393 - val_dice_coeficient: 0.9598
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9358 - dice_coeficient: 0.9581
# Epoch 42: val_mean_io_u improved from 0.94120 to 0.94269, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 180ms/step - loss: 0.9273 - mean_io_u: 0.9358 - dice_coeficient: 0.9581 - val_loss: 0.9273 - val_mean_io_u: 0.9427 - val_dice_coeficient: 0.9595
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9365 - dice_coeficient: 0.9582
# Epoch 43: val_mean_io_u did not improve from 0.94269
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9273 - mean_io_u: 0.9365 - dice_coeficient: 0.9582 - val_loss: 0.9273 - val_mean_io_u: 0.9420 - val_dice_coeficient: 0.9599
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9367 - dice_coeficient: 0.9579
# Epoch 44: val_mean_io_u improved from 0.94269 to 0.94292, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 194ms/step - loss: 0.9273 - mean_io_u: 0.9367 - dice_coeficient: 0.9579 - val_loss: 0.9273 - val_mean_io_u: 0.9429 - val_dice_coeficient: 0.9599
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9381 - dice_coeficient: 0.9582
# Epoch 45: val_mean_io_u did not improve from 0.94292
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9273 - mean_io_u: 0.9381 - dice_coeficient: 0.9582 - val_loss: 0.9273 - val_mean_io_u: 0.9402 - val_dice_coeficient: 0.9598
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9383 - dice_coeficient: 0.9583
# Epoch 46: val_mean_io_u improved from 0.94292 to 0.94485, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 181ms/step - loss: 0.9273 - mean_io_u: 0.9383 - dice_coeficient: 0.9583 - val_loss: 0.9273 - val_mean_io_u: 0.9449 - val_dice_coeficient: 0.9599
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9380 - dice_coeficient: 0.9583
# Epoch 47: val_mean_io_u did not improve from 0.94485
# 51/51 [==============================] - 9s 179ms/step - loss: 0.9273 - mean_io_u: 0.9380 - dice_coeficient: 0.9583 - val_loss: 0.9273 - val_mean_io_u: 0.9436 - val_dice_coeficient: 0.9600
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9400 - dice_coeficient: 0.9585
# Epoch 48: val_mean_io_u improved from 0.94485 to 0.94665, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 180ms/step - loss: 0.9273 - mean_io_u: 0.9400 - dice_coeficient: 0.9585 - val_loss: 0.9273 - val_mean_io_u: 0.9467 - val_dice_coeficient: 0.9597
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9394 - dice_coeficient: 0.9585
# Epoch 49: val_mean_io_u did not improve from 0.94665
# 51/51 [==============================] - 9s 179ms/step - loss: 0.9273 - mean_io_u: 0.9394 - dice_coeficient: 0.9585 - val_loss: 0.9273 - val_mean_io_u: 0.9417 - val_dice_coeficient: 0.9599
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9395 - dice_coeficient: 0.9586
# Epoch 50: val_mean_io_u did not improve from 0.94665
# 51/51 [==============================] - 9s 181ms/step - loss: 0.9273 - mean_io_u: 0.9395 - dice_coeficient: 0.9586 - val_loss: 0.9273 - val_mean_io_u: 0.9399 - val_dice_coeficient: 0.9595
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9388 - dice_coeficient: 0.9587
# Epoch 51: val_mean_io_u did not improve from 0.94665
# 51/51 [==============================] - 9s 182ms/step - loss: 0.9273 - mean_io_u: 0.9388 - dice_coeficient: 0.9587 - val_loss: 0.9272 - val_mean_io_u: 0.9412 - val_dice_coeficient: 0.9601
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9270 - mean_io_u: 0.9313 - dice_coeficient: 0.9604
# Epoch 52: val_mean_io_u did not improve from 0.94665
# 51/51 [==============================] - 9s 181ms/step - loss: 0.9270 - mean_io_u: 0.9313 - dice_coeficient: 0.9604 - val_loss: 0.9260 - val_mean_io_u: 0.9333 - val_dice_coeficient: 0.9679
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9440 - dice_coeficient: 0.9763
# Epoch 53: val_mean_io_u improved from 0.94665 to 0.95869, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 181ms/step - loss: 0.9252 - mean_io_u: 0.9440 - dice_coeficient: 0.9763 - val_loss: 0.9251 - val_mean_io_u: 0.9587 - val_dice_coeficient: 0.9772
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9523 - dice_coeficient: 0.9783
# Epoch 54: val_mean_io_u improved from 0.95869 to 0.96003, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9251 - mean_io_u: 0.9523 - dice_coeficient: 0.9783 - val_loss: 0.9250 - val_mean_io_u: 0.9600 - val_dice_coeficient: 0.9788
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9250 - mean_io_u: 0.9558 - dice_coeficient: 0.9788
# Epoch 55: val_mean_io_u improved from 0.96003 to 0.96023, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 182ms/step - loss: 0.9250 - mean_io_u: 0.9558 - dice_coeficient: 0.9788 - val_loss: 0.9250 - val_mean_io_u: 0.9602 - val_dice_coeficient: 0.9792
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9250 - mean_io_u: 0.9567 - dice_coeficient: 0.9791
# Epoch 56: val_mean_io_u improved from 0.96023 to 0.96065, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 183ms/step - loss: 0.9250 - mean_io_u: 0.9567 - dice_coeficient: 0.9791 - val_loss: 0.9250 - val_mean_io_u: 0.9607 - val_dice_coeficient: 0.9786
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9581 - dice_coeficient: 0.9793
# Epoch 57: val_mean_io_u improved from 0.96065 to 0.96183, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 182ms/step - loss: 0.9249 - mean_io_u: 0.9581 - dice_coeficient: 0.9793 - val_loss: 0.9249 - val_mean_io_u: 0.9618 - val_dice_coeficient: 0.9796
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9588 - dice_coeficient: 0.9795
# Epoch 58: val_mean_io_u improved from 0.96183 to 0.96292, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 184ms/step - loss: 0.9249 - mean_io_u: 0.9588 - dice_coeficient: 0.9795 - val_loss: 0.9249 - val_mean_io_u: 0.9629 - val_dice_coeficient: 0.9795
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9598 - dice_coeficient: 0.9796
# Epoch 59: val_mean_io_u improved from 0.96292 to 0.96388, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 184ms/step - loss: 0.9249 - mean_io_u: 0.9598 - dice_coeficient: 0.9796 - val_loss: 0.9249 - val_mean_io_u: 0.9639 - val_dice_coeficient: 0.9798
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9607 - dice_coeficient: 0.9798
# Epoch 60: val_mean_io_u improved from 0.96388 to 0.96390, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9249 - mean_io_u: 0.9607 - dice_coeficient: 0.9798 - val_loss: 0.9250 - val_mean_io_u: 0.9639 - val_dice_coeficient: 0.9793
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9618 - dice_coeficient: 0.9796
# Epoch 61: val_mean_io_u improved from 0.96390 to 0.96463, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9249 - mean_io_u: 0.9618 - dice_coeficient: 0.9796 - val_loss: 0.9250 - val_mean_io_u: 0.9646 - val_dice_coeficient: 0.9792
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9625 - dice_coeficient: 0.9798
# Epoch 62: val_mean_io_u improved from 0.96463 to 0.96519, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9249 - mean_io_u: 0.9625 - dice_coeficient: 0.9798 - val_loss: 0.9249 - val_mean_io_u: 0.9652 - val_dice_coeficient: 0.9797
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9632 - dice_coeficient: 0.9800
# Epoch 63: val_mean_io_u improved from 0.96519 to 0.96660, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9249 - mean_io_u: 0.9632 - dice_coeficient: 0.9800 - val_loss: 0.9249 - val_mean_io_u: 0.9666 - val_dice_coeficient: 0.9800
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9637 - dice_coeficient: 0.9801
# Epoch 64: val_mean_io_u improved from 0.96660 to 0.96715, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 184ms/step - loss: 0.9249 - mean_io_u: 0.9637 - dice_coeficient: 0.9801 - val_loss: 0.9249 - val_mean_io_u: 0.9671 - val_dice_coeficient: 0.9802
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9638 - dice_coeficient: 0.9802
# Epoch 65: val_mean_io_u did not improve from 0.96715
# 51/51 [==============================] - 9s 182ms/step - loss: 0.9249 - mean_io_u: 0.9638 - dice_coeficient: 0.9802 - val_loss: 0.9249 - val_mean_io_u: 0.9660 - val_dice_coeficient: 0.9800
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9647 - dice_coeficient: 0.9803
# Epoch 66: val_mean_io_u did not improve from 0.96715
# 51/51 [==============================] - 9s 183ms/step - loss: 0.9249 - mean_io_u: 0.9647 - dice_coeficient: 0.9803 - val_loss: 0.9249 - val_mean_io_u: 0.9663 - val_dice_coeficient: 0.9798
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9654 - dice_coeficient: 0.9804
# Epoch 67: val_mean_io_u improved from 0.96715 to 0.96838, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 183ms/step - loss: 0.9249 - mean_io_u: 0.9654 - dice_coeficient: 0.9804 - val_loss: 0.9249 - val_mean_io_u: 0.9684 - val_dice_coeficient: 0.9800
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9659 - dice_coeficient: 0.9805
# Epoch 68: val_mean_io_u did not improve from 0.96838
# 51/51 [==============================] - 9s 183ms/step - loss: 0.9249 - mean_io_u: 0.9659 - dice_coeficient: 0.9805 - val_loss: 0.9249 - val_mean_io_u: 0.9683 - val_dice_coeficient: 0.9803
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9665 - dice_coeficient: 0.9806
# Epoch 69: val_mean_io_u improved from 0.96838 to 0.96902, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9248 - mean_io_u: 0.9665 - dice_coeficient: 0.9806 - val_loss: 0.9249 - val_mean_io_u: 0.9690 - val_dice_coeficient: 0.9804
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9668 - dice_coeficient: 0.9808
# Epoch 70: val_mean_io_u improved from 0.96902 to 0.96954, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9248 - mean_io_u: 0.9668 - dice_coeficient: 0.9808 - val_loss: 0.9249 - val_mean_io_u: 0.9695 - val_dice_coeficient: 0.9805
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9674 - dice_coeficient: 0.9808
# Epoch 71: val_mean_io_u did not improve from 0.96954
# 51/51 [==============================] - 9s 184ms/step - loss: 0.9249 - mean_io_u: 0.9674 - dice_coeficient: 0.9808 - val_loss: 0.9249 - val_mean_io_u: 0.9695 - val_dice_coeficient: 0.9804
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9678 - dice_coeficient: 0.9807
# Epoch 72: val_mean_io_u did not improve from 0.96954
# 51/51 [==============================] - 9s 184ms/step - loss: 0.9248 - mean_io_u: 0.9678 - dice_coeficient: 0.9807 - val_loss: 0.9249 - val_mean_io_u: 0.9695 - val_dice_coeficient: 0.9802
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9679 - dice_coeficient: 0.9807
# Epoch 73: val_mean_io_u improved from 0.96954 to 0.96996, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9248 - mean_io_u: 0.9679 - dice_coeficient: 0.9807 - val_loss: 0.9249 - val_mean_io_u: 0.9700 - val_dice_coeficient: 0.9804
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9249 - mean_io_u: 0.9682 - dice_coeficient: 0.9808
# Epoch 74: val_mean_io_u improved from 0.96996 to 0.97036, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9249 - mean_io_u: 0.9682 - dice_coeficient: 0.9808 - val_loss: 0.9249 - val_mean_io_u: 0.9704 - val_dice_coeficient: 0.9802
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9688 - dice_coeficient: 0.9810
# Epoch 75: val_mean_io_u improved from 0.97036 to 0.97079, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9248 - mean_io_u: 0.9688 - dice_coeficient: 0.9810 - val_loss: 0.9248 - val_mean_io_u: 0.9708 - val_dice_coeficient: 0.9806
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9695 - dice_coeficient: 0.9811
# Epoch 76: val_mean_io_u did not improve from 0.97079
# 51/51 [==============================] - 9s 184ms/step - loss: 0.9248 - mean_io_u: 0.9695 - dice_coeficient: 0.9811 - val_loss: 0.9249 - val_mean_io_u: 0.9706 - val_dice_coeficient: 0.9805
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9696 - dice_coeficient: 0.9811
# Epoch 77: val_mean_io_u improved from 0.97079 to 0.97108, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9248 - mean_io_u: 0.9696 - dice_coeficient: 0.9811 - val_loss: 0.9249 - val_mean_io_u: 0.9711 - val_dice_coeficient: 0.9805
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9700 - dice_coeficient: 0.9812
# Epoch 78: val_mean_io_u improved from 0.97108 to 0.97141, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 191ms/step - loss: 0.9248 - mean_io_u: 0.9700 - dice_coeficient: 0.9812 - val_loss: 0.9248 - val_mean_io_u: 0.9714 - val_dice_coeficient: 0.9807
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9701 - dice_coeficient: 0.9813
# Epoch 79: val_mean_io_u improved from 0.97141 to 0.97182, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 193ms/step - loss: 0.9248 - mean_io_u: 0.9701 - dice_coeficient: 0.9813 - val_loss: 0.9248 - val_mean_io_u: 0.9718 - val_dice_coeficient: 0.9807
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9704 - dice_coeficient: 0.9813
# Epoch 80: val_mean_io_u did not improve from 0.97182
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9248 - mean_io_u: 0.9704 - dice_coeficient: 0.9813 - val_loss: 0.9248 - val_mean_io_u: 0.9718 - val_dice_coeficient: 0.9807
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9707 - dice_coeficient: 0.9814
# Epoch 81: val_mean_io_u did not improve from 0.97182
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9248 - mean_io_u: 0.9707 - dice_coeficient: 0.9814 - val_loss: 0.9249 - val_mean_io_u: 0.9718 - val_dice_coeficient: 0.9806
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9708 - dice_coeficient: 0.9813
# Epoch 82: val_mean_io_u did not improve from 0.97182
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9248 - mean_io_u: 0.9708 - dice_coeficient: 0.9813 - val_loss: 0.9249 - val_mean_io_u: 0.9717 - val_dice_coeficient: 0.9800
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9713 - dice_coeficient: 0.9815
# Epoch 83: val_mean_io_u improved from 0.97182 to 0.97195, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9248 - mean_io_u: 0.9713 - dice_coeficient: 0.9815 - val_loss: 0.9248 - val_mean_io_u: 0.9719 - val_dice_coeficient: 0.9808
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9715 - dice_coeficient: 0.9816
# Epoch 84: val_mean_io_u improved from 0.97195 to 0.97235, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 187ms/step - loss: 0.9248 - mean_io_u: 0.9715 - dice_coeficient: 0.9816 - val_loss: 0.9248 - val_mean_io_u: 0.9724 - val_dice_coeficient: 0.9808
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9716 - dice_coeficient: 0.9816
# Epoch 85: val_mean_io_u improved from 0.97235 to 0.97275, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9248 - mean_io_u: 0.9716 - dice_coeficient: 0.9816 - val_loss: 0.9248 - val_mean_io_u: 0.9727 - val_dice_coeficient: 0.9807
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9718 - dice_coeficient: 0.9816
# Epoch 86: val_mean_io_u did not improve from 0.97275
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9248 - mean_io_u: 0.9718 - dice_coeficient: 0.9816 - val_loss: 0.9248 - val_mean_io_u: 0.9722 - val_dice_coeficient: 0.9807
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9717 - dice_coeficient: 0.9815
# Epoch 87: val_mean_io_u did not improve from 0.97275
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9248 - mean_io_u: 0.9717 - dice_coeficient: 0.9815 - val_loss: 0.9248 - val_mean_io_u: 0.9725 - val_dice_coeficient: 0.9809
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9719 - dice_coeficient: 0.9815
# Epoch 88: val_mean_io_u improved from 0.97275 to 0.97326, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9248 - mean_io_u: 0.9719 - dice_coeficient: 0.9815 - val_loss: 0.9248 - val_mean_io_u: 0.9733 - val_dice_coeficient: 0.9809
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9722 - dice_coeficient: 0.9816
# Epoch 89: val_mean_io_u did not improve from 0.97326
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9248 - mean_io_u: 0.9722 - dice_coeficient: 0.9816 - val_loss: 0.9248 - val_mean_io_u: 0.9732 - val_dice_coeficient: 0.9810
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9725 - dice_coeficient: 0.9817
# Epoch 90: val_mean_io_u did not improve from 0.97326
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9248 - mean_io_u: 0.9725 - dice_coeficient: 0.9817 - val_loss: 0.9248 - val_mean_io_u: 0.9728 - val_dice_coeficient: 0.9809
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9725 - dice_coeficient: 0.9817
# Epoch 91: val_mean_io_u did not improve from 0.97326
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9248 - mean_io_u: 0.9725 - dice_coeficient: 0.9817 - val_loss: 0.9248 - val_mean_io_u: 0.9730 - val_dice_coeficient: 0.9809
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9729 - dice_coeficient: 0.9818
# Epoch 92: val_mean_io_u improved from 0.97326 to 0.97381, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9248 - mean_io_u: 0.9729 - dice_coeficient: 0.9818 - val_loss: 0.9248 - val_mean_io_u: 0.9738 - val_dice_coeficient: 0.9812
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9247 - mean_io_u: 0.9732 - dice_coeficient: 0.9820
# Epoch 93: val_mean_io_u did not improve from 0.97381
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9247 - mean_io_u: 0.9732 - dice_coeficient: 0.9820 - val_loss: 0.9248 - val_mean_io_u: 0.9737 - val_dice_coeficient: 0.9810
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9248 - mean_io_u: 0.9733 - dice_coeficient: 0.9819
# Epoch 94: val_mean_io_u did not improve from 0.97381
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9248 - mean_io_u: 0.9733 - dice_coeficient: 0.9819 - val_loss: 0.9248 - val_mean_io_u: 0.9738 - val_dice_coeficient: 0.9812
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9247 - mean_io_u: 0.9734 - dice_coeficient: 0.9819
# Epoch 95: val_mean_io_u improved from 0.97381 to 0.97415, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9247 - mean_io_u: 0.9734 - dice_coeficient: 0.9819 - val_loss: 0.9248 - val_mean_io_u: 0.9742 - val_dice_coeficient: 0.9812
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9247 - mean_io_u: 0.9736 - dice_coeficient: 0.9820
# Epoch 96: val_mean_io_u improved from 0.97415 to 0.97442, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9247 - mean_io_u: 0.9736 - dice_coeficient: 0.9820 - val_loss: 0.9248 - val_mean_io_u: 0.9744 - val_dice_coeficient: 0.9811
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9247 - mean_io_u: 0.9737 - dice_coeficient: 0.9820
# Epoch 97: val_mean_io_u improved from 0.97442 to 0.97444, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9247 - mean_io_u: 0.9737 - dice_coeficient: 0.9820 - val_loss: 0.9248 - val_mean_io_u: 0.9744 - val_dice_coeficient: 0.9812
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9247 - mean_io_u: 0.9739 - dice_coeficient: 0.9819
# Epoch 98: val_mean_io_u did not improve from 0.97444
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9247 - mean_io_u: 0.9739 - dice_coeficient: 0.9819 - val_loss: 0.9248 - val_mean_io_u: 0.9744 - val_dice_coeficient: 0.9813
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9247 - mean_io_u: 0.9740 - dice_coeficient: 0.9820
# Epoch 99: val_mean_io_u improved from 0.97444 to 0.97455, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 190ms/step - loss: 0.9247 - mean_io_u: 0.9740 - dice_coeficient: 0.9820 - val_loss: 0.9248 - val_mean_io_u: 0.9746 - val_dice_coeficient: 0.9812
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9247 - mean_io_u: 0.9742 - dice_coeficient: 0.9822
# Epoch 100: val_mean_io_u did not improve from 0.97455
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9247 - mean_io_u: 0.9742 - dice_coeficient: 0.9822 - val_loss: 0.9248 - val_mean_io_u: 0.9745 - val_dice_coeficient: 0.9812

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='lower right')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/u-net_100epochs.hdf5')

# %%
pred = unet_model.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 2s 24ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1), cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx], cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
