# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8157

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

# def dice_loss(y_true, y_pred):
#     return 1 - dice_coeficient(y_true, y_pred)

# def tversky(y_true, y_pred, smooth=1, alpha=0.8):
#     T = tf.keras.backend.flatten(y_true)
#     P = tf.keras.backend.flatten(y_pred)
#     TP = tf.keras.backend.sum(T * P)
#     FN = tf.keras.backend.sum(T * (1 - P))
#     FP = tf.keras.backend.sum((1 - T) * P)
#     return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


# def tversky_loss(y_true, y_pred):
#     return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, decay=1e-4), 
    loss=sm.losses.DiceLoss(),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_train_Weights.hdf5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto'
)

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.7894 - mean_io_u: 0.4723 - dice_coeficient: 0.4599
# Epoch 1: val_loss improved from inf to 0.66333, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 37s 361ms/step - loss: 0.7894 - mean_io_u: 0.4723 - dice_coeficient: 0.4599 - val_loss: 0.6633 - val_mean_io_u: 0.5109 - val_dice_coeficient: 0.6913
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5575 - mean_io_u: 0.5588 - dice_coeficient: 0.7422
# Epoch 2: val_loss improved from 0.66333 to 0.47521, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 15s 289ms/step - loss: 0.5575 - mean_io_u: 0.5588 - dice_coeficient: 0.7422 - val_loss: 0.4752 - val_mean_io_u: 0.6014 - val_dice_coeficient: 0.7715
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4324 - mean_io_u: 0.6264 - dice_coeficient: 0.7925
# Epoch 3: val_loss improved from 0.47521 to 0.40176, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 15s 291ms/step - loss: 0.4324 - mean_io_u: 0.6264 - dice_coeficient: 0.7925 - val_loss: 0.4018 - val_mean_io_u: 0.6502 - val_dice_coeficient: 0.8074
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3844 - mean_io_u: 0.6544 - dice_coeficient: 0.8159
# Epoch 4: val_loss improved from 0.40176 to 0.37071, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 15s 295ms/step - loss: 0.3844 - mean_io_u: 0.6544 - dice_coeficient: 0.8159 - val_loss: 0.3707 - val_mean_io_u: 0.6653 - val_dice_coeficient: 0.8228
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3636 - mean_io_u: 0.6728 - dice_coeficient: 0.8304
# Epoch 5: val_loss improved from 0.37071 to 0.35419, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 15s 300ms/step - loss: 0.3636 - mean_io_u: 0.6728 - dice_coeficient: 0.8304 - val_loss: 0.3542 - val_mean_io_u: 0.6786 - val_dice_coeficient: 0.8345
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3400 - mean_io_u: 0.6841 - dice_coeficient: 0.8400
# Epoch 6: val_loss improved from 0.35419 to 0.33243, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 15s 303ms/step - loss: 0.3400 - mean_io_u: 0.6841 - dice_coeficient: 0.8400 - val_loss: 0.3324 - val_mean_io_u: 0.6924 - val_dice_coeficient: 0.8443
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3232 - mean_io_u: 0.6992 - dice_coeficient: 0.8488
# Epoch 7: val_loss improved from 0.33243 to 0.32069, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 15s 304ms/step - loss: 0.3232 - mean_io_u: 0.6992 - dice_coeficient: 0.8488 - val_loss: 0.3207 - val_mean_io_u: 0.7076 - val_dice_coeficient: 0.8511
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3074 - mean_io_u: 0.7154 - dice_coeficient: 0.8554
# Epoch 8: val_loss improved from 0.32069 to 0.30107, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 308ms/step - loss: 0.3074 - mean_io_u: 0.7154 - dice_coeficient: 0.8554 - val_loss: 0.3011 - val_mean_io_u: 0.7208 - val_dice_coeficient: 0.8572
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2977 - mean_io_u: 0.7254 - dice_coeficient: 0.8611
# Epoch 9: val_loss improved from 0.30107 to 0.28950, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 311ms/step - loss: 0.2977 - mean_io_u: 0.7254 - dice_coeficient: 0.8611 - val_loss: 0.2895 - val_mean_io_u: 0.7298 - val_dice_coeficient: 0.8618
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2789 - mean_io_u: 0.7333 - dice_coeficient: 0.8659
# Epoch 10: val_loss improved from 0.28950 to 0.27551, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 314ms/step - loss: 0.2789 - mean_io_u: 0.7333 - dice_coeficient: 0.8659 - val_loss: 0.2755 - val_mean_io_u: 0.7384 - val_dice_coeficient: 0.8670
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2719 - mean_io_u: 0.7425 - dice_coeficient: 0.8698
# Epoch 11: val_loss improved from 0.27551 to 0.27087, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 317ms/step - loss: 0.2719 - mean_io_u: 0.7425 - dice_coeficient: 0.8698 - val_loss: 0.2709 - val_mean_io_u: 0.7455 - val_dice_coeficient: 0.8684
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2681 - mean_io_u: 0.7505 - dice_coeficient: 0.8720
# Epoch 12: val_loss improved from 0.27087 to 0.25794, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 317ms/step - loss: 0.2681 - mean_io_u: 0.7505 - dice_coeficient: 0.8720 - val_loss: 0.2579 - val_mean_io_u: 0.7574 - val_dice_coeficient: 0.8758
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2505 - mean_io_u: 0.7634 - dice_coeficient: 0.8847
# Epoch 13: val_loss improved from 0.25794 to 0.24691, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 320ms/step - loss: 0.2505 - mean_io_u: 0.7634 - dice_coeficient: 0.8847 - val_loss: 0.2469 - val_mean_io_u: 0.7686 - val_dice_coeficient: 0.8861
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2425 - mean_io_u: 0.7685 - dice_coeficient: 0.8891
# Epoch 14: val_loss improved from 0.24691 to 0.23834, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 321ms/step - loss: 0.2425 - mean_io_u: 0.7685 - dice_coeficient: 0.8891 - val_loss: 0.2383 - val_mean_io_u: 0.7719 - val_dice_coeficient: 0.8888
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2359 - mean_io_u: 0.7744 - dice_coeficient: 0.8914
# Epoch 15: val_loss improved from 0.23834 to 0.23097, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 323ms/step - loss: 0.2359 - mean_io_u: 0.7744 - dice_coeficient: 0.8914 - val_loss: 0.2310 - val_mean_io_u: 0.7751 - val_dice_coeficient: 0.8905
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2258 - mean_io_u: 0.7743 - dice_coeficient: 0.8923
# Epoch 16: val_loss improved from 0.23097 to 0.21208, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 323ms/step - loss: 0.2258 - mean_io_u: 0.7743 - dice_coeficient: 0.8923 - val_loss: 0.2121 - val_mean_io_u: 0.7721 - val_dice_coeficient: 0.8901
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2042 - mean_io_u: 0.7776 - dice_coeficient: 0.8972
# Epoch 17: val_loss improved from 0.21208 to 0.19276, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 325ms/step - loss: 0.2042 - mean_io_u: 0.7776 - dice_coeficient: 0.8972 - val_loss: 0.1928 - val_mean_io_u: 0.7779 - val_dice_coeficient: 0.8985
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1901 - mean_io_u: 0.7850 - dice_coeficient: 0.9042
# Epoch 18: val_loss improved from 0.19276 to 0.18537, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 326ms/step - loss: 0.1901 - mean_io_u: 0.7850 - dice_coeficient: 0.9042 - val_loss: 0.1854 - val_mean_io_u: 0.7836 - val_dice_coeficient: 0.9031
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1798 - mean_io_u: 0.7883 - dice_coeficient: 0.9070
# Epoch 19: val_loss improved from 0.18537 to 0.18082, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 327ms/step - loss: 0.1798 - mean_io_u: 0.7883 - dice_coeficient: 0.9070 - val_loss: 0.1808 - val_mean_io_u: 0.7907 - val_dice_coeficient: 0.9055
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1738 - mean_io_u: 0.7936 - dice_coeficient: 0.9091
# Epoch 20: val_loss improved from 0.18082 to 0.17838, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 327ms/step - loss: 0.1738 - mean_io_u: 0.7936 - dice_coeficient: 0.9091 - val_loss: 0.1784 - val_mean_io_u: 0.7949 - val_dice_coeficient: 0.9069
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1835 - mean_io_u: 0.7915 - dice_coeficient: 0.9059
# Epoch 21: val_loss did not improve from 0.17838
# 51/51 [==============================] - 16s 324ms/step - loss: 0.1835 - mean_io_u: 0.7915 - dice_coeficient: 0.9059 - val_loss: 0.1830 - val_mean_io_u: 0.7901 - val_dice_coeficient: 0.9005
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1712 - mean_io_u: 0.8023 - dice_coeficient: 0.9092
# Epoch 22: val_loss improved from 0.17838 to 0.16730, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.1712 - mean_io_u: 0.8023 - dice_coeficient: 0.9092 - val_loss: 0.1673 - val_mean_io_u: 0.8060 - val_dice_coeficient: 0.9103
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1584 - mean_io_u: 0.8094 - dice_coeficient: 0.9147
# Epoch 23: val_loss improved from 0.16730 to 0.15985, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.1584 - mean_io_u: 0.8094 - dice_coeficient: 0.9147 - val_loss: 0.1599 - val_mean_io_u: 0.8125 - val_dice_coeficient: 0.9138
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1590 - mean_io_u: 0.8142 - dice_coeficient: 0.9175
# Epoch 24: val_loss improved from 0.15985 to 0.15617, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.1590 - mean_io_u: 0.8142 - dice_coeficient: 0.9175 - val_loss: 0.1562 - val_mean_io_u: 0.8149 - val_dice_coeficient: 0.9156
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1534 - mean_io_u: 0.8165 - dice_coeficient: 0.9188
# Epoch 25: val_loss improved from 0.15617 to 0.15518, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 331ms/step - loss: 0.1534 - mean_io_u: 0.8165 - dice_coeficient: 0.9188 - val_loss: 0.1552 - val_mean_io_u: 0.8160 - val_dice_coeficient: 0.9163
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1533 - mean_io_u: 0.8179 - dice_coeficient: 0.9190
# Epoch 26: val_loss improved from 0.15518 to 0.15385, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 331ms/step - loss: 0.1533 - mean_io_u: 0.8179 - dice_coeficient: 0.9190 - val_loss: 0.1539 - val_mean_io_u: 0.8191 - val_dice_coeficient: 0.9169
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1517 - mean_io_u: 0.8215 - dice_coeficient: 0.9206
# Epoch 27: val_loss improved from 0.15385 to 0.15268, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.1517 - mean_io_u: 0.8215 - dice_coeficient: 0.9206 - val_loss: 0.1527 - val_mean_io_u: 0.8213 - val_dice_coeficient: 0.9188
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1435 - mean_io_u: 0.8247 - dice_coeficient: 0.9217
# Epoch 28: val_loss improved from 0.15268 to 0.15089, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.1435 - mean_io_u: 0.8247 - dice_coeficient: 0.9217 - val_loss: 0.1509 - val_mean_io_u: 0.8250 - val_dice_coeficient: 0.9193
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1511 - mean_io_u: 0.8274 - dice_coeficient: 0.9227
# Epoch 29: val_loss improved from 0.15089 to 0.14994, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 334ms/step - loss: 0.1511 - mean_io_u: 0.8274 - dice_coeficient: 0.9227 - val_loss: 0.1499 - val_mean_io_u: 0.8270 - val_dice_coeficient: 0.9200
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1477 - mean_io_u: 0.8301 - dice_coeficient: 0.9237
# Epoch 30: val_loss improved from 0.14994 to 0.14739, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.1477 - mean_io_u: 0.8301 - dice_coeficient: 0.9237 - val_loss: 0.1474 - val_mean_io_u: 0.8307 - val_dice_coeficient: 0.9211
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1443 - mean_io_u: 0.8325 - dice_coeficient: 0.9244
# Epoch 31: val_loss did not improve from 0.14739
# 51/51 [==============================] - 17s 329ms/step - loss: 0.1443 - mean_io_u: 0.8325 - dice_coeficient: 0.9244 - val_loss: 0.1475 - val_mean_io_u: 0.8314 - val_dice_coeficient: 0.9209
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1442 - mean_io_u: 0.8333 - dice_coeficient: 0.9245
# Epoch 32: val_loss did not improve from 0.14739
# 51/51 [==============================] - 17s 332ms/step - loss: 0.1442 - mean_io_u: 0.8333 - dice_coeficient: 0.9245 - val_loss: 0.1486 - val_mean_io_u: 0.8346 - val_dice_coeficient: 0.9220
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1398 - mean_io_u: 0.8360 - dice_coeficient: 0.9250
# Epoch 33: val_loss improved from 0.14739 to 0.14670, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 335ms/step - loss: 0.1398 - mean_io_u: 0.8360 - dice_coeficient: 0.9250 - val_loss: 0.1467 - val_mean_io_u: 0.8363 - val_dice_coeficient: 0.9226
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1424 - mean_io_u: 0.8383 - dice_coeficient: 0.9260
# Epoch 34: val_loss improved from 0.14670 to 0.14601, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 335ms/step - loss: 0.1424 - mean_io_u: 0.8383 - dice_coeficient: 0.9260 - val_loss: 0.1460 - val_mean_io_u: 0.8362 - val_dice_coeficient: 0.9230
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1437 - mean_io_u: 0.8389 - dice_coeficient: 0.9259
# Epoch 35: val_loss improved from 0.14601 to 0.14536, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.1437 - mean_io_u: 0.8389 - dice_coeficient: 0.9259 - val_loss: 0.1454 - val_mean_io_u: 0.8388 - val_dice_coeficient: 0.9227
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1400 - mean_io_u: 0.8421 - dice_coeficient: 0.9267
# Epoch 36: val_loss did not improve from 0.14536
# 51/51 [==============================] - 17s 333ms/step - loss: 0.1400 - mean_io_u: 0.8421 - dice_coeficient: 0.9267 - val_loss: 0.1462 - val_mean_io_u: 0.8422 - val_dice_coeficient: 0.9237
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1404 - mean_io_u: 0.8441 - dice_coeficient: 0.9275
# Epoch 37: val_loss did not improve from 0.14536
# 51/51 [==============================] - 17s 333ms/step - loss: 0.1404 - mean_io_u: 0.8441 - dice_coeficient: 0.9275 - val_loss: 0.1472 - val_mean_io_u: 0.8431 - val_dice_coeficient: 0.9240
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1382 - mean_io_u: 0.8458 - dice_coeficient: 0.9280
# Epoch 38: val_loss improved from 0.14536 to 0.14286, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 343ms/step - loss: 0.1382 - mean_io_u: 0.8458 - dice_coeficient: 0.9280 - val_loss: 0.1429 - val_mean_io_u: 0.8464 - val_dice_coeficient: 0.9245
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1359 - mean_io_u: 0.8475 - dice_coeficient: 0.9285
# Epoch 39: val_loss did not improve from 0.14286
# 51/51 [==============================] - 17s 334ms/step - loss: 0.1359 - mean_io_u: 0.8475 - dice_coeficient: 0.9285 - val_loss: 0.1438 - val_mean_io_u: 0.8464 - val_dice_coeficient: 0.9248
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1359 - mean_io_u: 0.8480 - dice_coeficient: 0.9281
# Epoch 40: val_loss improved from 0.14286 to 0.14159, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.1359 - mean_io_u: 0.8480 - dice_coeficient: 0.9281 - val_loss: 0.1416 - val_mean_io_u: 0.8480 - val_dice_coeficient: 0.9255
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1365 - mean_io_u: 0.8500 - dice_coeficient: 0.9293
# Epoch 41: val_loss improved from 0.14159 to 0.14039, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 341ms/step - loss: 0.1365 - mean_io_u: 0.8500 - dice_coeficient: 0.9293 - val_loss: 0.1404 - val_mean_io_u: 0.8496 - val_dice_coeficient: 0.9260
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1324 - mean_io_u: 0.8513 - dice_coeficient: 0.9298
# Epoch 42: val_loss did not improve from 0.14039
# 51/51 [==============================] - 17s 337ms/step - loss: 0.1324 - mean_io_u: 0.8513 - dice_coeficient: 0.9298 - val_loss: 0.1413 - val_mean_io_u: 0.8496 - val_dice_coeficient: 0.9261
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1353 - mean_io_u: 0.8516 - dice_coeficient: 0.9295
# Epoch 43: val_loss did not improve from 0.14039
# 51/51 [==============================] - 17s 340ms/step - loss: 0.1353 - mean_io_u: 0.8516 - dice_coeficient: 0.9295 - val_loss: 0.1436 - val_mean_io_u: 0.8504 - val_dice_coeficient: 0.9260
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1328 - mean_io_u: 0.8536 - dice_coeficient: 0.9300
# Epoch 44: val_loss improved from 0.14039 to 0.13988, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 345ms/step - loss: 0.1328 - mean_io_u: 0.8536 - dice_coeficient: 0.9300 - val_loss: 0.1399 - val_mean_io_u: 0.8543 - val_dice_coeficient: 0.9269
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1369 - mean_io_u: 0.8557 - dice_coeficient: 0.9308
# Epoch 45: val_loss improved from 0.13988 to 0.13951, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 345ms/step - loss: 0.1369 - mean_io_u: 0.8557 - dice_coeficient: 0.9308 - val_loss: 0.1395 - val_mean_io_u: 0.8550 - val_dice_coeficient: 0.9271
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1332 - mean_io_u: 0.8574 - dice_coeficient: 0.9312
# Epoch 46: val_loss did not improve from 0.13951
# 51/51 [==============================] - 17s 341ms/step - loss: 0.1332 - mean_io_u: 0.8574 - dice_coeficient: 0.9312 - val_loss: 0.1400 - val_mean_io_u: 0.8546 - val_dice_coeficient: 0.9270
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1311 - mean_io_u: 0.8580 - dice_coeficient: 0.9310
# Epoch 47: val_loss improved from 0.13951 to 0.13871, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 345ms/step - loss: 0.1311 - mean_io_u: 0.8580 - dice_coeficient: 0.9310 - val_loss: 0.1387 - val_mean_io_u: 0.8564 - val_dice_coeficient: 0.9270
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1278 - mean_io_u: 0.8596 - dice_coeficient: 0.9317
# Epoch 48: val_loss improved from 0.13871 to 0.13803, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 352ms/step - loss: 0.1278 - mean_io_u: 0.8596 - dice_coeficient: 0.9317 - val_loss: 0.1380 - val_mean_io_u: 0.8578 - val_dice_coeficient: 0.9278
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1301 - mean_io_u: 0.8608 - dice_coeficient: 0.9320
# Epoch 49: val_loss improved from 0.13803 to 0.13617, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 338ms/step - loss: 0.1301 - mean_io_u: 0.8608 - dice_coeficient: 0.9320 - val_loss: 0.1362 - val_mean_io_u: 0.8598 - val_dice_coeficient: 0.9282
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1292 - mean_io_u: 0.8620 - dice_coeficient: 0.9325
# Epoch 50: val_loss did not improve from 0.13617
# 51/51 [==============================] - 17s 341ms/step - loss: 0.1292 - mean_io_u: 0.8620 - dice_coeficient: 0.9325 - val_loss: 0.1374 - val_mean_io_u: 0.8616 - val_dice_coeficient: 0.9284
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1256 - mean_io_u: 0.8627 - dice_coeficient: 0.9323
# Epoch 51: val_loss did not improve from 0.13617
# 51/51 [==============================] - 18s 345ms/step - loss: 0.1256 - mean_io_u: 0.8627 - dice_coeficient: 0.9323 - val_loss: 0.1375 - val_mean_io_u: 0.8628 - val_dice_coeficient: 0.9286
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1281 - mean_io_u: 0.8643 - dice_coeficient: 0.9330
# Epoch 52: val_loss did not improve from 0.13617
# 51/51 [==============================] - 17s 341ms/step - loss: 0.1281 - mean_io_u: 0.8643 - dice_coeficient: 0.9330 - val_loss: 0.1362 - val_mean_io_u: 0.8632 - val_dice_coeficient: 0.9291
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1247 - mean_io_u: 0.8651 - dice_coeficient: 0.9333
# Epoch 53: val_loss did not improve from 0.13617
# 51/51 [==============================] - 18s 344ms/step - loss: 0.1247 - mean_io_u: 0.8651 - dice_coeficient: 0.9333 - val_loss: 0.1369 - val_mean_io_u: 0.8645 - val_dice_coeficient: 0.9290
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1294 - mean_io_u: 0.8644 - dice_coeficient: 0.9318
# Epoch 54: val_loss did not improve from 0.13617
# 51/51 [==============================] - 17s 342ms/step - loss: 0.1294 - mean_io_u: 0.8644 - dice_coeficient: 0.9318 - val_loss: 0.1381 - val_mean_io_u: 0.8645 - val_dice_coeficient: 0.9282
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1221 - mean_io_u: 0.8665 - dice_coeficient: 0.9329
# Epoch 55: val_loss did not improve from 0.13617
# 51/51 [==============================] - 17s 344ms/step - loss: 0.1221 - mean_io_u: 0.8665 - dice_coeficient: 0.9329 - val_loss: 0.1376 - val_mean_io_u: 0.8652 - val_dice_coeficient: 0.9283
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1301 - mean_io_u: 0.8669 - dice_coeficient: 0.9327
# Epoch 56: val_loss did not improve from 0.13617
# 51/51 [==============================] - 18s 344ms/step - loss: 0.1301 - mean_io_u: 0.8669 - dice_coeficient: 0.9327 - val_loss: 0.1363 - val_mean_io_u: 0.8664 - val_dice_coeficient: 0.9293
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1271 - mean_io_u: 0.8686 - dice_coeficient: 0.9339
# Epoch 57: val_loss improved from 0.13617 to 0.13572, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 352ms/step - loss: 0.1271 - mean_io_u: 0.8686 - dice_coeficient: 0.9339 - val_loss: 0.1357 - val_mean_io_u: 0.8676 - val_dice_coeficient: 0.9300
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1235 - mean_io_u: 0.8695 - dice_coeficient: 0.9340
# Epoch 58: val_loss improved from 0.13572 to 0.13467, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 351ms/step - loss: 0.1235 - mean_io_u: 0.8695 - dice_coeficient: 0.9340 - val_loss: 0.1347 - val_mean_io_u: 0.8682 - val_dice_coeficient: 0.9300
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1239 - mean_io_u: 0.8707 - dice_coeficient: 0.9346
# Epoch 59: val_loss did not improve from 0.13467
# 51/51 [==============================] - 18s 347ms/step - loss: 0.1239 - mean_io_u: 0.8707 - dice_coeficient: 0.9346 - val_loss: 0.1374 - val_mean_io_u: 0.8692 - val_dice_coeficient: 0.9300
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1252 - mean_io_u: 0.8709 - dice_coeficient: 0.9342
# Epoch 60: val_loss did not improve from 0.13467
# 51/51 [==============================] - 18s 349ms/step - loss: 0.1252 - mean_io_u: 0.8709 - dice_coeficient: 0.9342 - val_loss: 0.1359 - val_mean_io_u: 0.8697 - val_dice_coeficient: 0.9298
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1251 - mean_io_u: 0.8719 - dice_coeficient: 0.9348
# Epoch 61: val_loss improved from 0.13467 to 0.13410, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 355ms/step - loss: 0.1251 - mean_io_u: 0.8719 - dice_coeficient: 0.9348 - val_loss: 0.1341 - val_mean_io_u: 0.8707 - val_dice_coeficient: 0.9305
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1331 - mean_io_u: 0.8708 - dice_coeficient: 0.9333
# Epoch 62: val_loss did not improve from 0.13410
# 51/51 [==============================] - 18s 350ms/step - loss: 0.1331 - mean_io_u: 0.8708 - dice_coeficient: 0.9333 - val_loss: 0.1358 - val_mean_io_u: 0.8714 - val_dice_coeficient: 0.9294
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1228 - mean_io_u: 0.8732 - dice_coeficient: 0.9349
# Epoch 63: val_loss did not improve from 0.13410
# 51/51 [==============================] - 18s 348ms/step - loss: 0.1228 - mean_io_u: 0.8732 - dice_coeficient: 0.9349 - val_loss: 0.1355 - val_mean_io_u: 0.8699 - val_dice_coeficient: 0.9292
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1269 - mean_io_u: 0.8704 - dice_coeficient: 0.9314
# Epoch 64: val_loss improved from 0.13410 to 0.13096, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 356ms/step - loss: 0.1269 - mean_io_u: 0.8704 - dice_coeficient: 0.9314 - val_loss: 0.1310 - val_mean_io_u: 0.8727 - val_dice_coeficient: 0.9307
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1262 - mean_io_u: 0.8731 - dice_coeficient: 0.9340
# Epoch 65: val_loss improved from 0.13096 to 0.12883, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 355ms/step - loss: 0.1262 - mean_io_u: 0.8731 - dice_coeficient: 0.9340 - val_loss: 0.1288 - val_mean_io_u: 0.8746 - val_dice_coeficient: 0.9314
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1211 - mean_io_u: 0.8758 - dice_coeficient: 0.9355
# Epoch 66: val_loss improved from 0.12883 to 0.12869, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 355ms/step - loss: 0.1211 - mean_io_u: 0.8758 - dice_coeficient: 0.9355 - val_loss: 0.1287 - val_mean_io_u: 0.8734 - val_dice_coeficient: 0.9304
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1297 - mean_io_u: 0.8733 - dice_coeficient: 0.9305
# Epoch 67: val_loss did not improve from 0.12869
# 51/51 [==============================] - 18s 351ms/step - loss: 0.1297 - mean_io_u: 0.8733 - dice_coeficient: 0.9305 - val_loss: 0.1295 - val_mean_io_u: 0.8758 - val_dice_coeficient: 0.9300
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1173 - mean_io_u: 0.8785 - dice_coeficient: 0.9355
# Epoch 68: val_loss improved from 0.12869 to 0.12751, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 356ms/step - loss: 0.1173 - mean_io_u: 0.8785 - dice_coeficient: 0.9355 - val_loss: 0.1275 - val_mean_io_u: 0.8771 - val_dice_coeficient: 0.9316
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1140 - mean_io_u: 0.8794 - dice_coeficient: 0.9359
# Epoch 69: val_loss did not improve from 0.12751
# 51/51 [==============================] - 18s 350ms/step - loss: 0.1140 - mean_io_u: 0.8794 - dice_coeficient: 0.9359 - val_loss: 0.1282 - val_mean_io_u: 0.8782 - val_dice_coeficient: 0.9316
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1400 - mean_io_u: 0.8664 - dice_coeficient: 0.9208
# Epoch 70: val_loss did not improve from 0.12751
# 51/51 [==============================] - 18s 351ms/step - loss: 0.1400 - mean_io_u: 0.8664 - dice_coeficient: 0.9208 - val_loss: 0.1350 - val_mean_io_u: 0.8749 - val_dice_coeficient: 0.9261
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1235 - mean_io_u: 0.8795 - dice_coeficient: 0.9328
# Epoch 71: val_loss did not improve from 0.12751
# 51/51 [==============================] - 18s 352ms/step - loss: 0.1235 - mean_io_u: 0.8795 - dice_coeficient: 0.9328 - val_loss: 0.1308 - val_mean_io_u: 0.8787 - val_dice_coeficient: 0.9297
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1191 - mean_io_u: 0.8811 - dice_coeficient: 0.9347
# Epoch 72: val_loss did not improve from 0.12751
# 51/51 [==============================] - 18s 355ms/step - loss: 0.1191 - mean_io_u: 0.8811 - dice_coeficient: 0.9347 - val_loss: 0.1296 - val_mean_io_u: 0.8804 - val_dice_coeficient: 0.9311
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1117 - mean_io_u: 0.8828 - dice_coeficient: 0.9364
# Epoch 73: val_loss did not improve from 0.12751
# 51/51 [==============================] - 18s 353ms/step - loss: 0.1117 - mean_io_u: 0.8828 - dice_coeficient: 0.9364 - val_loss: 0.1282 - val_mean_io_u: 0.8815 - val_dice_coeficient: 0.9322
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1193 - mean_io_u: 0.8837 - dice_coeficient: 0.9368
# Epoch 74: val_loss improved from 0.12751 to 0.12721, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1193 - mean_io_u: 0.8837 - dice_coeficient: 0.9368 - val_loss: 0.1272 - val_mean_io_u: 0.8818 - val_dice_coeficient: 0.9327
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1156 - mean_io_u: 0.8825 - dice_coeficient: 0.9357
# Epoch 75: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 356ms/step - loss: 0.1156 - mean_io_u: 0.8825 - dice_coeficient: 0.9357 - val_loss: 0.1280 - val_mean_io_u: 0.8820 - val_dice_coeficient: 0.9318
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1184 - mean_io_u: 0.8835 - dice_coeficient: 0.9358
# Epoch 76: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 356ms/step - loss: 0.1184 - mean_io_u: 0.8835 - dice_coeficient: 0.9358 - val_loss: 0.1280 - val_mean_io_u: 0.8823 - val_dice_coeficient: 0.9319
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1234 - mean_io_u: 0.8780 - dice_coeficient: 0.9295
# Epoch 77: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 353ms/step - loss: 0.1234 - mean_io_u: 0.8780 - dice_coeficient: 0.9295 - val_loss: 0.1359 - val_mean_io_u: 0.8764 - val_dice_coeficient: 0.9250
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1240 - mean_io_u: 0.8760 - dice_coeficient: 0.9263
# Epoch 78: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1240 - mean_io_u: 0.8760 - dice_coeficient: 0.9263 - val_loss: 0.1484 - val_mean_io_u: 0.8645 - val_dice_coeficient: 0.9130
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1288 - mean_io_u: 0.8793 - dice_coeficient: 0.9278
# Epoch 79: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 354ms/step - loss: 0.1288 - mean_io_u: 0.8793 - dice_coeficient: 0.9278 - val_loss: 0.1299 - val_mean_io_u: 0.8823 - val_dice_coeficient: 0.9289
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1312 - mean_io_u: 0.8749 - dice_coeficient: 0.9237
# Epoch 80: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1312 - mean_io_u: 0.8749 - dice_coeficient: 0.9237 - val_loss: 0.1413 - val_mean_io_u: 0.8768 - val_dice_coeficient: 0.9214
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1293 - mean_io_u: 0.8787 - dice_coeficient: 0.9259
# Epoch 81: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1293 - mean_io_u: 0.8787 - dice_coeficient: 0.9259 - val_loss: 0.1543 - val_mean_io_u: 0.8663 - val_dice_coeficient: 0.9096
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1557 - mean_io_u: 0.8615 - dice_coeficient: 0.9036
# Epoch 82: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 361ms/step - loss: 0.1557 - mean_io_u: 0.8615 - dice_coeficient: 0.9036 - val_loss: 0.1504 - val_mean_io_u: 0.8687 - val_dice_coeficient: 0.9090
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1318 - mean_io_u: 0.8810 - dice_coeficient: 0.9221
# Epoch 83: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1318 - mean_io_u: 0.8810 - dice_coeficient: 0.9221 - val_loss: 0.1331 - val_mean_io_u: 0.8831 - val_dice_coeficient: 0.9237
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1192 - mean_io_u: 0.8867 - dice_coeficient: 0.9296
# Epoch 84: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1192 - mean_io_u: 0.8867 - dice_coeficient: 0.9296 - val_loss: 0.1313 - val_mean_io_u: 0.8857 - val_dice_coeficient: 0.9273
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1165 - mean_io_u: 0.8871 - dice_coeficient: 0.9309
# Epoch 85: val_loss did not improve from 0.12721
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1165 - mean_io_u: 0.8871 - dice_coeficient: 0.9309 - val_loss: 0.1303 - val_mean_io_u: 0.8858 - val_dice_coeficient: 0.9278
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1157 - mean_io_u: 0.8886 - dice_coeficient: 0.9330
# Epoch 86: val_loss improved from 0.12721 to 0.12652, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1157 - mean_io_u: 0.8886 - dice_coeficient: 0.9330 - val_loss: 0.1265 - val_mean_io_u: 0.8879 - val_dice_coeficient: 0.9299
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1209 - mean_io_u: 0.8894 - dice_coeficient: 0.9330
# Epoch 87: val_loss did not improve from 0.12652
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1209 - mean_io_u: 0.8894 - dice_coeficient: 0.9330 - val_loss: 0.1268 - val_mean_io_u: 0.8885 - val_dice_coeficient: 0.9301
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1170 - mean_io_u: 0.8911 - dice_coeficient: 0.9350
# Epoch 88: val_loss improved from 0.12652 to 0.12552, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 365ms/step - loss: 0.1170 - mean_io_u: 0.8911 - dice_coeficient: 0.9350 - val_loss: 0.1255 - val_mean_io_u: 0.8893 - val_dice_coeficient: 0.9311
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1338 - mean_io_u: 0.8822 - dice_coeficient: 0.9245
# Epoch 89: val_loss did not improve from 0.12552
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1338 - mean_io_u: 0.8822 - dice_coeficient: 0.9245 - val_loss: 0.1335 - val_mean_io_u: 0.8861 - val_dice_coeficient: 0.9264
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1203 - mean_io_u: 0.8894 - dice_coeficient: 0.9320
# Epoch 90: val_loss did not improve from 0.12552
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1203 - mean_io_u: 0.8894 - dice_coeficient: 0.9320 - val_loss: 0.1286 - val_mean_io_u: 0.8882 - val_dice_coeficient: 0.9294
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1249 - mean_io_u: 0.8871 - dice_coeficient: 0.9293
# Epoch 91: val_loss did not improve from 0.12552
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1249 - mean_io_u: 0.8871 - dice_coeficient: 0.9293 - val_loss: 0.1519 - val_mean_io_u: 0.8739 - val_dice_coeficient: 0.9124
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1326 - mean_io_u: 0.8827 - dice_coeficient: 0.9239
# Epoch 92: val_loss did not improve from 0.12552
# 51/51 [==============================] - 19s 365ms/step - loss: 0.1326 - mean_io_u: 0.8827 - dice_coeficient: 0.9239 - val_loss: 0.1438 - val_mean_io_u: 0.8767 - val_dice_coeficient: 0.9152
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1278 - mean_io_u: 0.8866 - dice_coeficient: 0.9264
# Epoch 93: val_loss did not improve from 0.12552
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1278 - mean_io_u: 0.8866 - dice_coeficient: 0.9264 - val_loss: 0.1293 - val_mean_io_u: 0.8893 - val_dice_coeficient: 0.9276
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1263 - mean_io_u: 0.8890 - dice_coeficient: 0.9290
# Epoch 94: val_loss did not improve from 0.12552
# 51/51 [==============================] - 19s 367ms/step - loss: 0.1263 - mean_io_u: 0.8890 - dice_coeficient: 0.9290 - val_loss: 0.1377 - val_mean_io_u: 0.8839 - val_dice_coeficient: 0.9212
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1300 - mean_io_u: 0.8870 - dice_coeficient: 0.9263
# Epoch 95: val_loss did not improve from 0.12552
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1300 - mean_io_u: 0.8870 - dice_coeficient: 0.9263 - val_loss: 0.1532 - val_mean_io_u: 0.8768 - val_dice_coeficient: 0.9150
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1323 - mean_io_u: 0.8877 - dice_coeficient: 0.9266
# Epoch 96: val_loss did not improve from 0.12552
# 51/51 [==============================] - 19s 368ms/step - loss: 0.1323 - mean_io_u: 0.8877 - dice_coeficient: 0.9266 - val_loss: 0.1325 - val_mean_io_u: 0.8896 - val_dice_coeficient: 0.9269
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1218 - mean_io_u: 0.8928 - dice_coeficient: 0.9320
# Epoch 97: val_loss did not improve from 0.12552
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1218 - mean_io_u: 0.8928 - dice_coeficient: 0.9320 - val_loss: 0.1302 - val_mean_io_u: 0.8903 - val_dice_coeficient: 0.9273
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1457 - mean_io_u: 0.8811 - dice_coeficient: 0.9167
# Epoch 98: val_loss did not improve from 0.12552
# 51/51 [==============================] - 19s 372ms/step - loss: 0.1457 - mean_io_u: 0.8811 - dice_coeficient: 0.9167 - val_loss: 0.1563 - val_mean_io_u: 0.8731 - val_dice_coeficient: 0.9063
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1318 - mean_io_u: 0.8883 - dice_coeficient: 0.9226
# Epoch 99: val_loss did not improve from 0.12552
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1318 - mean_io_u: 0.8883 - dice_coeficient: 0.9226 - val_loss: 0.1344 - val_mean_io_u: 0.8901 - val_dice_coeficient: 0.9242
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1297 - mean_io_u: 0.8920 - dice_coeficient: 0.9275
# Epoch 100: val_loss did not improve from 0.12552
# 51/51 [==============================] - 19s 375ms/step - loss: 0.1297 - mean_io_u: 0.8920 - dice_coeficient: 0.9275 - val_loss: 0.1366 - val_mean_io_u: 0.8905 - val_dice_coeficient: 0.9242

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 5s 48ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx])
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
