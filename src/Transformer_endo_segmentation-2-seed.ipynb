# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 433310222
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8162

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

# def dice_loss(y_true, y_pred):
#     return 1 - dice_coeficient(y_true, y_pred)

# def tversky(y_true, y_pred, smooth=1, alpha=0.8):
#     T = tf.keras.backend.flatten(y_true)
#     P = tf.keras.backend.flatten(y_pred)
#     TP = tf.keras.backend.sum(T * P)
#     FN = tf.keras.backend.sum(T * (1 - P))
#     FP = tf.keras.backend.sum((1 - T) * P)
#     return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


# def tversky_loss(y_true, y_pred):
#     return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, decay=1e-4), 
    loss=sm.losses.DiceLoss(),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_train_Weights.hdf5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto'
)

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.7991 - mean_io_u: 0.4635 - dice_coeficient: 0.3933
# Epoch 1: val_loss improved from inf to 0.65604, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 40s 375ms/step - loss: 0.7991 - mean_io_u: 0.4635 - dice_coeficient: 0.3933 - val_loss: 0.6560 - val_mean_io_u: 0.4738 - val_dice_coeficient: 0.5821
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5358 - mean_io_u: 0.5097 - dice_coeficient: 0.6697
# Epoch 2: val_loss improved from 0.65604 to 0.44229, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 15s 300ms/step - loss: 0.5358 - mean_io_u: 0.5097 - dice_coeficient: 0.6697 - val_loss: 0.4423 - val_mean_io_u: 0.5439 - val_dice_coeficient: 0.7229
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4054 - mean_io_u: 0.5682 - dice_coeficient: 0.7515
# Epoch 3: val_loss improved from 0.44229 to 0.36741, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 310ms/step - loss: 0.4054 - mean_io_u: 0.5682 - dice_coeficient: 0.7515 - val_loss: 0.3674 - val_mean_io_u: 0.5883 - val_dice_coeficient: 0.7786
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3563 - mean_io_u: 0.6072 - dice_coeficient: 0.7972
# Epoch 4: val_loss improved from 0.36741 to 0.33964, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 313ms/step - loss: 0.3563 - mean_io_u: 0.6072 - dice_coeficient: 0.7972 - val_loss: 0.3396 - val_mean_io_u: 0.6287 - val_dice_coeficient: 0.8085
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3339 - mean_io_u: 0.6399 - dice_coeficient: 0.8151
# Epoch 5: val_loss improved from 0.33964 to 0.32157, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 321ms/step - loss: 0.3339 - mean_io_u: 0.6399 - dice_coeficient: 0.8151 - val_loss: 0.3216 - val_mean_io_u: 0.6507 - val_dice_coeficient: 0.8192
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3162 - mean_io_u: 0.6599 - dice_coeficient: 0.8233
# Epoch 6: val_loss improved from 0.32157 to 0.31083, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 329ms/step - loss: 0.3162 - mean_io_u: 0.6599 - dice_coeficient: 0.8233 - val_loss: 0.3108 - val_mean_io_u: 0.6709 - val_dice_coeficient: 0.8261
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3046 - mean_io_u: 0.6785 - dice_coeficient: 0.8300
# Epoch 7: val_loss improved from 0.31083 to 0.29851, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.3046 - mean_io_u: 0.6785 - dice_coeficient: 0.8300 - val_loss: 0.2985 - val_mean_io_u: 0.6886 - val_dice_coeficient: 0.8320
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2955 - mean_io_u: 0.6965 - dice_coeficient: 0.8357
# Epoch 8: val_loss improved from 0.29851 to 0.29080, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 337ms/step - loss: 0.2955 - mean_io_u: 0.6965 - dice_coeficient: 0.8357 - val_loss: 0.2908 - val_mean_io_u: 0.7039 - val_dice_coeficient: 0.8366
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2846 - mean_io_u: 0.7109 - dice_coeficient: 0.8393
# Epoch 9: val_loss improved from 0.29080 to 0.28312, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.2846 - mean_io_u: 0.7109 - dice_coeficient: 0.8393 - val_loss: 0.2831 - val_mean_io_u: 0.7173 - val_dice_coeficient: 0.8401
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2779 - mean_io_u: 0.7228 - dice_coeficient: 0.8427
# Epoch 10: val_loss improved from 0.28312 to 0.27855, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 338ms/step - loss: 0.2779 - mean_io_u: 0.7228 - dice_coeficient: 0.8427 - val_loss: 0.2785 - val_mean_io_u: 0.7287 - val_dice_coeficient: 0.8431
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2708 - mean_io_u: 0.7330 - dice_coeficient: 0.8477
# Epoch 11: val_loss improved from 0.27855 to 0.27252, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 339ms/step - loss: 0.2708 - mean_io_u: 0.7330 - dice_coeficient: 0.8477 - val_loss: 0.2725 - val_mean_io_u: 0.7409 - val_dice_coeficient: 0.8485
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2681 - mean_io_u: 0.7435 - dice_coeficient: 0.8506
# Epoch 12: val_loss improved from 0.27252 to 0.26835, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.2681 - mean_io_u: 0.7435 - dice_coeficient: 0.8506 - val_loss: 0.2683 - val_mean_io_u: 0.7482 - val_dice_coeficient: 0.8501
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2627 - mean_io_u: 0.7511 - dice_coeficient: 0.8529
# Epoch 13: val_loss improved from 0.26835 to 0.26561, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 343ms/step - loss: 0.2627 - mean_io_u: 0.7511 - dice_coeficient: 0.8529 - val_loss: 0.2656 - val_mean_io_u: 0.7544 - val_dice_coeficient: 0.8519
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2587 - mean_io_u: 0.7564 - dice_coeficient: 0.8547
# Epoch 14: val_loss improved from 0.26561 to 0.26223, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 346ms/step - loss: 0.2587 - mean_io_u: 0.7564 - dice_coeficient: 0.8547 - val_loss: 0.2622 - val_mean_io_u: 0.7596 - val_dice_coeficient: 0.8542
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2587 - mean_io_u: 0.7627 - dice_coeficient: 0.8566
# Epoch 15: val_loss improved from 0.26223 to 0.26111, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 349ms/step - loss: 0.2587 - mean_io_u: 0.7627 - dice_coeficient: 0.8566 - val_loss: 0.2611 - val_mean_io_u: 0.7658 - val_dice_coeficient: 0.8555
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2539 - mean_io_u: 0.7682 - dice_coeficient: 0.8581
# Epoch 16: val_loss improved from 0.26111 to 0.25952, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 350ms/step - loss: 0.2539 - mean_io_u: 0.7682 - dice_coeficient: 0.8581 - val_loss: 0.2595 - val_mean_io_u: 0.7704 - val_dice_coeficient: 0.8565
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2537 - mean_io_u: 0.7733 - dice_coeficient: 0.8591
# Epoch 17: val_loss improved from 0.25952 to 0.25773, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 353ms/step - loss: 0.2537 - mean_io_u: 0.7733 - dice_coeficient: 0.8591 - val_loss: 0.2577 - val_mean_io_u: 0.7756 - val_dice_coeficient: 0.8582
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2548 - mean_io_u: 0.7784 - dice_coeficient: 0.8606
# Epoch 18: val_loss improved from 0.25773 to 0.25670, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 352ms/step - loss: 0.2548 - mean_io_u: 0.7784 - dice_coeficient: 0.8606 - val_loss: 0.2567 - val_mean_io_u: 0.7790 - val_dice_coeficient: 0.8588
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2472 - mean_io_u: 0.7822 - dice_coeficient: 0.8624
# Epoch 19: val_loss improved from 0.25670 to 0.25062, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 354ms/step - loss: 0.2472 - mean_io_u: 0.7822 - dice_coeficient: 0.8624 - val_loss: 0.2506 - val_mean_io_u: 0.7816 - val_dice_coeficient: 0.8616
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2462 - mean_io_u: 0.7866 - dice_coeficient: 0.8651
# Epoch 20: val_loss improved from 0.25062 to 0.24857, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 355ms/step - loss: 0.2462 - mean_io_u: 0.7866 - dice_coeficient: 0.8651 - val_loss: 0.2486 - val_mean_io_u: 0.7862 - val_dice_coeficient: 0.8626
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2417 - mean_io_u: 0.7903 - dice_coeficient: 0.8661
# Epoch 21: val_loss improved from 0.24857 to 0.24751, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 357ms/step - loss: 0.2417 - mean_io_u: 0.7903 - dice_coeficient: 0.8661 - val_loss: 0.2475 - val_mean_io_u: 0.7913 - val_dice_coeficient: 0.8640
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2412 - mean_io_u: 0.7940 - dice_coeficient: 0.8674
# Epoch 22: val_loss improved from 0.24751 to 0.24584, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 357ms/step - loss: 0.2412 - mean_io_u: 0.7940 - dice_coeficient: 0.8674 - val_loss: 0.2458 - val_mean_io_u: 0.7939 - val_dice_coeficient: 0.8648
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2385 - mean_io_u: 0.7968 - dice_coeficient: 0.8684
# Epoch 23: val_loss improved from 0.24584 to 0.24458, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 359ms/step - loss: 0.2385 - mean_io_u: 0.7968 - dice_coeficient: 0.8684 - val_loss: 0.2446 - val_mean_io_u: 0.7975 - val_dice_coeficient: 0.8662
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2378 - mean_io_u: 0.7996 - dice_coeficient: 0.8690
# Epoch 24: val_loss did not improve from 0.24458
# 51/51 [==============================] - 18s 354ms/step - loss: 0.2378 - mean_io_u: 0.7996 - dice_coeficient: 0.8690 - val_loss: 0.2446 - val_mean_io_u: 0.7997 - val_dice_coeficient: 0.8662
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2401 - mean_io_u: 0.8021 - dice_coeficient: 0.8696
# Epoch 25: val_loss improved from 0.24458 to 0.24358, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 359ms/step - loss: 0.2401 - mean_io_u: 0.8021 - dice_coeficient: 0.8696 - val_loss: 0.2436 - val_mean_io_u: 0.8023 - val_dice_coeficient: 0.8670
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2340 - mean_io_u: 0.8044 - dice_coeficient: 0.8706
# Epoch 26: val_loss improved from 0.24358 to 0.24245, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 360ms/step - loss: 0.2340 - mean_io_u: 0.8044 - dice_coeficient: 0.8706 - val_loss: 0.2424 - val_mean_io_u: 0.8037 - val_dice_coeficient: 0.8675
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2360 - mean_io_u: 0.8068 - dice_coeficient: 0.8711
# Epoch 27: val_loss did not improve from 0.24245
# 51/51 [==============================] - 18s 359ms/step - loss: 0.2360 - mean_io_u: 0.8068 - dice_coeficient: 0.8711 - val_loss: 0.2425 - val_mean_io_u: 0.8072 - val_dice_coeficient: 0.8683
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2353 - mean_io_u: 0.8091 - dice_coeficient: 0.8717
# Epoch 28: val_loss improved from 0.24245 to 0.24131, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 360ms/step - loss: 0.2353 - mean_io_u: 0.8091 - dice_coeficient: 0.8717 - val_loss: 0.2413 - val_mean_io_u: 0.8087 - val_dice_coeficient: 0.8687
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2345 - mean_io_u: 0.8107 - dice_coeficient: 0.8718
# Epoch 29: val_loss improved from 0.24131 to 0.24118, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 361ms/step - loss: 0.2345 - mean_io_u: 0.8107 - dice_coeficient: 0.8718 - val_loss: 0.2412 - val_mean_io_u: 0.8108 - val_dice_coeficient: 0.8688
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2308 - mean_io_u: 0.8134 - dice_coeficient: 0.8728
# Epoch 30: val_loss improved from 0.24118 to 0.24004, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 362ms/step - loss: 0.2308 - mean_io_u: 0.8134 - dice_coeficient: 0.8728 - val_loss: 0.2400 - val_mean_io_u: 0.8130 - val_dice_coeficient: 0.8693
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2331 - mean_io_u: 0.8150 - dice_coeficient: 0.8732
# Epoch 31: val_loss improved from 0.24004 to 0.23969, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 362ms/step - loss: 0.2331 - mean_io_u: 0.8150 - dice_coeficient: 0.8732 - val_loss: 0.2397 - val_mean_io_u: 0.8149 - val_dice_coeficient: 0.8699
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2323 - mean_io_u: 0.8169 - dice_coeficient: 0.8733
# Epoch 32: val_loss improved from 0.23969 to 0.23905, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 362ms/step - loss: 0.2323 - mean_io_u: 0.8169 - dice_coeficient: 0.8733 - val_loss: 0.2391 - val_mean_io_u: 0.8157 - val_dice_coeficient: 0.8699
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2305 - mean_io_u: 0.8184 - dice_coeficient: 0.8738
# Epoch 33: val_loss improved from 0.23905 to 0.23835, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.2305 - mean_io_u: 0.8184 - dice_coeficient: 0.8738 - val_loss: 0.2383 - val_mean_io_u: 0.8171 - val_dice_coeficient: 0.8706
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2354 - mean_io_u: 0.8200 - dice_coeficient: 0.8745
# Epoch 34: val_loss improved from 0.23835 to 0.23765, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 368ms/step - loss: 0.2354 - mean_io_u: 0.8200 - dice_coeficient: 0.8745 - val_loss: 0.2376 - val_mean_io_u: 0.8191 - val_dice_coeficient: 0.8712
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2303 - mean_io_u: 0.8214 - dice_coeficient: 0.8749
# Epoch 35: val_loss did not improve from 0.23765
# 51/51 [==============================] - 18s 362ms/step - loss: 0.2303 - mean_io_u: 0.8214 - dice_coeficient: 0.8749 - val_loss: 0.2378 - val_mean_io_u: 0.8206 - val_dice_coeficient: 0.8712
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2284 - mean_io_u: 0.8229 - dice_coeficient: 0.8752
# Epoch 36: val_loss improved from 0.23765 to 0.23726, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 367ms/step - loss: 0.2284 - mean_io_u: 0.8229 - dice_coeficient: 0.8752 - val_loss: 0.2373 - val_mean_io_u: 0.8222 - val_dice_coeficient: 0.8715
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2283 - mean_io_u: 0.8242 - dice_coeficient: 0.8757
# Epoch 37: val_loss improved from 0.23726 to 0.23613, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2283 - mean_io_u: 0.8242 - dice_coeficient: 0.8757 - val_loss: 0.2361 - val_mean_io_u: 0.8244 - val_dice_coeficient: 0.8724
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2279 - mean_io_u: 0.8272 - dice_coeficient: 0.8792
# Epoch 38: val_loss improved from 0.23613 to 0.23434, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 367ms/step - loss: 0.2279 - mean_io_u: 0.8272 - dice_coeficient: 0.8792 - val_loss: 0.2343 - val_mean_io_u: 0.8275 - val_dice_coeficient: 0.8758
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2289 - mean_io_u: 0.8291 - dice_coeficient: 0.8801
# Epoch 39: val_loss improved from 0.23434 to 0.23373, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 369ms/step - loss: 0.2289 - mean_io_u: 0.8291 - dice_coeficient: 0.8801 - val_loss: 0.2337 - val_mean_io_u: 0.8281 - val_dice_coeficient: 0.8759
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2268 - mean_io_u: 0.8303 - dice_coeficient: 0.8806
# Epoch 40: val_loss improved from 0.23373 to 0.23343, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2268 - mean_io_u: 0.8303 - dice_coeficient: 0.8806 - val_loss: 0.2334 - val_mean_io_u: 0.8290 - val_dice_coeficient: 0.8766
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2251 - mean_io_u: 0.8314 - dice_coeficient: 0.8807
# Epoch 41: val_loss improved from 0.23343 to 0.23310, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2251 - mean_io_u: 0.8314 - dice_coeficient: 0.8807 - val_loss: 0.2331 - val_mean_io_u: 0.8307 - val_dice_coeficient: 0.8769
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2214 - mean_io_u: 0.8328 - dice_coeficient: 0.8811
# Epoch 42: val_loss improved from 0.23310 to 0.23303, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2214 - mean_io_u: 0.8328 - dice_coeficient: 0.8811 - val_loss: 0.2330 - val_mean_io_u: 0.8317 - val_dice_coeficient: 0.8770
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2216 - mean_io_u: 0.8336 - dice_coeficient: 0.8812
# Epoch 43: val_loss improved from 0.23303 to 0.23270, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2216 - mean_io_u: 0.8336 - dice_coeficient: 0.8812 - val_loss: 0.2327 - val_mean_io_u: 0.8329 - val_dice_coeficient: 0.8773
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2253 - mean_io_u: 0.8350 - dice_coeficient: 0.8816
# Epoch 44: val_loss improved from 0.23270 to 0.23212, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2253 - mean_io_u: 0.8350 - dice_coeficient: 0.8816 - val_loss: 0.2321 - val_mean_io_u: 0.8344 - val_dice_coeficient: 0.8779
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2232 - mean_io_u: 0.8362 - dice_coeficient: 0.8821
# Epoch 45: val_loss improved from 0.23212 to 0.23182, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2232 - mean_io_u: 0.8362 - dice_coeficient: 0.8821 - val_loss: 0.2318 - val_mean_io_u: 0.8349 - val_dice_coeficient: 0.8779
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2204 - mean_io_u: 0.8370 - dice_coeficient: 0.8823
# Epoch 46: val_loss did not improve from 0.23182
# 51/51 [==============================] - 19s 366ms/step - loss: 0.2204 - mean_io_u: 0.8370 - dice_coeficient: 0.8823 - val_loss: 0.2320 - val_mean_io_u: 0.8357 - val_dice_coeficient: 0.8779
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2222 - mean_io_u: 0.8378 - dice_coeficient: 0.8826
# Epoch 47: val_loss improved from 0.23182 to 0.23178, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 369ms/step - loss: 0.2222 - mean_io_u: 0.8378 - dice_coeficient: 0.8826 - val_loss: 0.2318 - val_mean_io_u: 0.8364 - val_dice_coeficient: 0.8780
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2202 - mean_io_u: 0.8389 - dice_coeficient: 0.8828
# Epoch 48: val_loss improved from 0.23178 to 0.23137, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2202 - mean_io_u: 0.8389 - dice_coeficient: 0.8828 - val_loss: 0.2314 - val_mean_io_u: 0.8380 - val_dice_coeficient: 0.8783
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2199 - mean_io_u: 0.8398 - dice_coeficient: 0.8831
# Epoch 49: val_loss improved from 0.23137 to 0.23066, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2199 - mean_io_u: 0.8398 - dice_coeficient: 0.8831 - val_loss: 0.2307 - val_mean_io_u: 0.8384 - val_dice_coeficient: 0.8786
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2185 - mean_io_u: 0.8405 - dice_coeficient: 0.8835
# Epoch 50: val_loss improved from 0.23066 to 0.23050, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2185 - mean_io_u: 0.8405 - dice_coeficient: 0.8835 - val_loss: 0.2305 - val_mean_io_u: 0.8396 - val_dice_coeficient: 0.8788
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2173 - mean_io_u: 0.8414 - dice_coeficient: 0.8838
# Epoch 51: val_loss improved from 0.23050 to 0.23025, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2173 - mean_io_u: 0.8414 - dice_coeficient: 0.8838 - val_loss: 0.2302 - val_mean_io_u: 0.8396 - val_dice_coeficient: 0.8787
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2183 - mean_io_u: 0.8421 - dice_coeficient: 0.8840
# Epoch 52: val_loss improved from 0.23025 to 0.23021, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2183 - mean_io_u: 0.8421 - dice_coeficient: 0.8840 - val_loss: 0.2302 - val_mean_io_u: 0.8407 - val_dice_coeficient: 0.8792
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2180 - mean_io_u: 0.8430 - dice_coeficient: 0.8842
# Epoch 53: val_loss improved from 0.23021 to 0.22976, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2180 - mean_io_u: 0.8430 - dice_coeficient: 0.8842 - val_loss: 0.2298 - val_mean_io_u: 0.8413 - val_dice_coeficient: 0.8794
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2178 - mean_io_u: 0.8436 - dice_coeficient: 0.8844
# Epoch 54: val_loss improved from 0.22976 to 0.22960, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2178 - mean_io_u: 0.8436 - dice_coeficient: 0.8844 - val_loss: 0.2296 - val_mean_io_u: 0.8424 - val_dice_coeficient: 0.8796
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2159 - mean_io_u: 0.8444 - dice_coeficient: 0.8847
# Epoch 55: val_loss improved from 0.22960 to 0.22938, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2159 - mean_io_u: 0.8444 - dice_coeficient: 0.8847 - val_loss: 0.2294 - val_mean_io_u: 0.8431 - val_dice_coeficient: 0.8797
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2186 - mean_io_u: 0.8452 - dice_coeficient: 0.8848
# Epoch 56: val_loss did not improve from 0.22938
# 51/51 [==============================] - 19s 369ms/step - loss: 0.2186 - mean_io_u: 0.8452 - dice_coeficient: 0.8848 - val_loss: 0.2299 - val_mean_io_u: 0.8440 - val_dice_coeficient: 0.8797
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2157 - mean_io_u: 0.8457 - dice_coeficient: 0.8848
# Epoch 57: val_loss improved from 0.22938 to 0.22918, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2157 - mean_io_u: 0.8457 - dice_coeficient: 0.8848 - val_loss: 0.2292 - val_mean_io_u: 0.8445 - val_dice_coeficient: 0.8798
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2169 - mean_io_u: 0.8465 - dice_coeficient: 0.8850
# Epoch 58: val_loss improved from 0.22918 to 0.22900, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2169 - mean_io_u: 0.8465 - dice_coeficient: 0.8850 - val_loss: 0.2290 - val_mean_io_u: 0.8453 - val_dice_coeficient: 0.8799
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2164 - mean_io_u: 0.8471 - dice_coeficient: 0.8853
# Epoch 59: val_loss did not improve from 0.22900
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2164 - mean_io_u: 0.8471 - dice_coeficient: 0.8853 - val_loss: 0.2291 - val_mean_io_u: 0.8456 - val_dice_coeficient: 0.8801
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2149 - mean_io_u: 0.8475 - dice_coeficient: 0.8853
# Epoch 60: val_loss improved from 0.22900 to 0.22896, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2149 - mean_io_u: 0.8475 - dice_coeficient: 0.8853 - val_loss: 0.2290 - val_mean_io_u: 0.8474 - val_dice_coeficient: 0.8804
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2156 - mean_io_u: 0.8483 - dice_coeficient: 0.8857
# Epoch 61: val_loss improved from 0.22896 to 0.22860, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2156 - mean_io_u: 0.8483 - dice_coeficient: 0.8857 - val_loss: 0.2286 - val_mean_io_u: 0.8467 - val_dice_coeficient: 0.8805
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2137 - mean_io_u: 0.8489 - dice_coeficient: 0.8859
# Epoch 62: val_loss improved from 0.22860 to 0.22804, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.2137 - mean_io_u: 0.8489 - dice_coeficient: 0.8859 - val_loss: 0.2280 - val_mean_io_u: 0.8476 - val_dice_coeficient: 0.8807
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2134 - mean_io_u: 0.8496 - dice_coeficient: 0.8862
# Epoch 63: val_loss did not improve from 0.22804
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2134 - mean_io_u: 0.8496 - dice_coeficient: 0.8862 - val_loss: 0.2281 - val_mean_io_u: 0.8480 - val_dice_coeficient: 0.8808
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2165 - mean_io_u: 0.8501 - dice_coeficient: 0.8863
# Epoch 64: val_loss did not improve from 0.22804
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2165 - mean_io_u: 0.8501 - dice_coeficient: 0.8863 - val_loss: 0.2281 - val_mean_io_u: 0.8484 - val_dice_coeficient: 0.8807
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2138 - mean_io_u: 0.8506 - dice_coeficient: 0.8865
# Epoch 65: val_loss did not improve from 0.22804
# 51/51 [==============================] - 19s 369ms/step - loss: 0.2138 - mean_io_u: 0.8506 - dice_coeficient: 0.8865 - val_loss: 0.2282 - val_mean_io_u: 0.8487 - val_dice_coeficient: 0.8808
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2186 - mean_io_u: 0.8511 - dice_coeficient: 0.8867
# Epoch 66: val_loss improved from 0.22804 to 0.22787, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2186 - mean_io_u: 0.8511 - dice_coeficient: 0.8867 - val_loss: 0.2279 - val_mean_io_u: 0.8502 - val_dice_coeficient: 0.8813
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2170 - mean_io_u: 0.8515 - dice_coeficient: 0.8866
# Epoch 67: val_loss did not improve from 0.22787
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2170 - mean_io_u: 0.8515 - dice_coeficient: 0.8866 - val_loss: 0.2280 - val_mean_io_u: 0.8500 - val_dice_coeficient: 0.8810
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2155 - mean_io_u: 0.8521 - dice_coeficient: 0.8868
# Epoch 68: val_loss improved from 0.22787 to 0.22786, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 375ms/step - loss: 0.2155 - mean_io_u: 0.8521 - dice_coeficient: 0.8868 - val_loss: 0.2279 - val_mean_io_u: 0.8507 - val_dice_coeficient: 0.8813
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2128 - mean_io_u: 0.8526 - dice_coeficient: 0.8870
# Epoch 69: val_loss improved from 0.22786 to 0.22714, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2128 - mean_io_u: 0.8526 - dice_coeficient: 0.8870 - val_loss: 0.2271 - val_mean_io_u: 0.8514 - val_dice_coeficient: 0.8817
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2103 - mean_io_u: 0.8539 - dice_coeficient: 0.8880
# Epoch 70: val_loss improved from 0.22714 to 0.22501, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.2103 - mean_io_u: 0.8539 - dice_coeficient: 0.8880 - val_loss: 0.2250 - val_mean_io_u: 0.8522 - val_dice_coeficient: 0.8824
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2140 - mean_io_u: 0.8544 - dice_coeficient: 0.8885
# Epoch 71: val_loss improved from 0.22501 to 0.22475, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2140 - mean_io_u: 0.8544 - dice_coeficient: 0.8885 - val_loss: 0.2248 - val_mean_io_u: 0.8529 - val_dice_coeficient: 0.8826
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2104 - mean_io_u: 0.8549 - dice_coeficient: 0.8888
# Epoch 72: val_loss improved from 0.22475 to 0.22470, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.2104 - mean_io_u: 0.8549 - dice_coeficient: 0.8888 - val_loss: 0.2247 - val_mean_io_u: 0.8531 - val_dice_coeficient: 0.8829
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2126 - mean_io_u: 0.8554 - dice_coeficient: 0.8889
# Epoch 73: val_loss improved from 0.22470 to 0.22441, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 380ms/step - loss: 0.2126 - mean_io_u: 0.8554 - dice_coeficient: 0.8889 - val_loss: 0.2244 - val_mean_io_u: 0.8537 - val_dice_coeficient: 0.8830
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2113 - mean_io_u: 0.8558 - dice_coeficient: 0.8891
# Epoch 74: val_loss improved from 0.22441 to 0.22431, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 378ms/step - loss: 0.2113 - mean_io_u: 0.8558 - dice_coeficient: 0.8891 - val_loss: 0.2243 - val_mean_io_u: 0.8538 - val_dice_coeficient: 0.8831
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2115 - mean_io_u: 0.8562 - dice_coeficient: 0.8891
# Epoch 75: val_loss did not improve from 0.22431
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2115 - mean_io_u: 0.8562 - dice_coeficient: 0.8891 - val_loss: 0.2244 - val_mean_io_u: 0.8540 - val_dice_coeficient: 0.8830
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2111 - mean_io_u: 0.8566 - dice_coeficient: 0.8892
# Epoch 76: val_loss improved from 0.22431 to 0.22426, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2111 - mean_io_u: 0.8566 - dice_coeficient: 0.8892 - val_loss: 0.2243 - val_mean_io_u: 0.8549 - val_dice_coeficient: 0.8833
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2092 - mean_io_u: 0.8570 - dice_coeficient: 0.8894
# Epoch 77: val_loss improved from 0.22426 to 0.22406, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2092 - mean_io_u: 0.8570 - dice_coeficient: 0.8894 - val_loss: 0.2241 - val_mean_io_u: 0.8556 - val_dice_coeficient: 0.8835
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2088 - mean_io_u: 0.8575 - dice_coeficient: 0.8896
# Epoch 78: val_loss improved from 0.22406 to 0.22379, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2088 - mean_io_u: 0.8575 - dice_coeficient: 0.8896 - val_loss: 0.2238 - val_mean_io_u: 0.8553 - val_dice_coeficient: 0.8832
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2101 - mean_io_u: 0.8578 - dice_coeficient: 0.8898
# Epoch 79: val_loss improved from 0.22379 to 0.22346, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.2101 - mean_io_u: 0.8578 - dice_coeficient: 0.8898 - val_loss: 0.2235 - val_mean_io_u: 0.8563 - val_dice_coeficient: 0.8835
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2111 - mean_io_u: 0.8583 - dice_coeficient: 0.8900
# Epoch 80: val_loss did not improve from 0.22346
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2111 - mean_io_u: 0.8583 - dice_coeficient: 0.8900 - val_loss: 0.2235 - val_mean_io_u: 0.8565 - val_dice_coeficient: 0.8836
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2095 - mean_io_u: 0.8586 - dice_coeficient: 0.8902
# Epoch 81: val_loss did not improve from 0.22346
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2095 - mean_io_u: 0.8586 - dice_coeficient: 0.8902 - val_loss: 0.2235 - val_mean_io_u: 0.8567 - val_dice_coeficient: 0.8837
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2065 - mean_io_u: 0.8589 - dice_coeficient: 0.8901
# Epoch 82: val_loss improved from 0.22346 to 0.22331, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2065 - mean_io_u: 0.8589 - dice_coeficient: 0.8901 - val_loss: 0.2233 - val_mean_io_u: 0.8571 - val_dice_coeficient: 0.8839
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2111 - mean_io_u: 0.8593 - dice_coeficient: 0.8901
# Epoch 83: val_loss did not improve from 0.22331
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2111 - mean_io_u: 0.8593 - dice_coeficient: 0.8901 - val_loss: 0.2234 - val_mean_io_u: 0.8573 - val_dice_coeficient: 0.8837
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2076 - mean_io_u: 0.8597 - dice_coeficient: 0.8903
# Epoch 84: val_loss improved from 0.22331 to 0.22314, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2076 - mean_io_u: 0.8597 - dice_coeficient: 0.8903 - val_loss: 0.2231 - val_mean_io_u: 0.8580 - val_dice_coeficient: 0.8839
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2059 - mean_io_u: 0.8600 - dice_coeficient: 0.8904
# Epoch 85: val_loss improved from 0.22314 to 0.22311, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2059 - mean_io_u: 0.8600 - dice_coeficient: 0.8904 - val_loss: 0.2231 - val_mean_io_u: 0.8584 - val_dice_coeficient: 0.8841
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2055 - mean_io_u: 0.8604 - dice_coeficient: 0.8907
# Epoch 86: val_loss improved from 0.22311 to 0.22285, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2055 - mean_io_u: 0.8604 - dice_coeficient: 0.8907 - val_loss: 0.2229 - val_mean_io_u: 0.8582 - val_dice_coeficient: 0.8840
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2062 - mean_io_u: 0.8607 - dice_coeficient: 0.8907
# Epoch 87: val_loss improved from 0.22285 to 0.22279, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.2062 - mean_io_u: 0.8607 - dice_coeficient: 0.8907 - val_loss: 0.2228 - val_mean_io_u: 0.8583 - val_dice_coeficient: 0.8839
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2067 - mean_io_u: 0.8610 - dice_coeficient: 0.8909
# Epoch 88: val_loss did not improve from 0.22279
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2067 - mean_io_u: 0.8610 - dice_coeficient: 0.8909 - val_loss: 0.2230 - val_mean_io_u: 0.8590 - val_dice_coeficient: 0.8841
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2080 - mean_io_u: 0.8614 - dice_coeficient: 0.8909
# Epoch 89: val_loss did not improve from 0.22279
# 51/51 [==============================] - 19s 375ms/step - loss: 0.2080 - mean_io_u: 0.8614 - dice_coeficient: 0.8909 - val_loss: 0.2231 - val_mean_io_u: 0.8592 - val_dice_coeficient: 0.8840
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2077 - mean_io_u: 0.8617 - dice_coeficient: 0.8911
# Epoch 90: val_loss improved from 0.22279 to 0.22260, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 378ms/step - loss: 0.2077 - mean_io_u: 0.8617 - dice_coeficient: 0.8911 - val_loss: 0.2226 - val_mean_io_u: 0.8597 - val_dice_coeficient: 0.8842
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2089 - mean_io_u: 0.8621 - dice_coeficient: 0.8912
# Epoch 91: val_loss did not improve from 0.22260
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2089 - mean_io_u: 0.8621 - dice_coeficient: 0.8912 - val_loss: 0.2226 - val_mean_io_u: 0.8602 - val_dice_coeficient: 0.8844
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2075 - mean_io_u: 0.8623 - dice_coeficient: 0.8912
# Epoch 92: val_loss improved from 0.22260 to 0.22255, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.2075 - mean_io_u: 0.8623 - dice_coeficient: 0.8912 - val_loss: 0.2226 - val_mean_io_u: 0.8606 - val_dice_coeficient: 0.8846
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2067 - mean_io_u: 0.8627 - dice_coeficient: 0.8914
# Epoch 93: val_loss did not improve from 0.22255
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2067 - mean_io_u: 0.8627 - dice_coeficient: 0.8914 - val_loss: 0.2227 - val_mean_io_u: 0.8603 - val_dice_coeficient: 0.8843
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2072 - mean_io_u: 0.8630 - dice_coeficient: 0.8914
# Epoch 94: val_loss improved from 0.22255 to 0.22236, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 380ms/step - loss: 0.2072 - mean_io_u: 0.8630 - dice_coeficient: 0.8914 - val_loss: 0.2224 - val_mean_io_u: 0.8606 - val_dice_coeficient: 0.8845
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2056 - mean_io_u: 0.8632 - dice_coeficient: 0.8916
# Epoch 95: val_loss improved from 0.22236 to 0.22212, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2056 - mean_io_u: 0.8632 - dice_coeficient: 0.8916 - val_loss: 0.2221 - val_mean_io_u: 0.8609 - val_dice_coeficient: 0.8845
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2035 - mean_io_u: 0.8636 - dice_coeficient: 0.8917
# Epoch 96: val_loss improved from 0.22212 to 0.22211, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.2035 - mean_io_u: 0.8636 - dice_coeficient: 0.8917 - val_loss: 0.2221 - val_mean_io_u: 0.8616 - val_dice_coeficient: 0.8848
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2093 - mean_io_u: 0.8638 - dice_coeficient: 0.8919
# Epoch 97: val_loss did not improve from 0.22211
# 51/51 [==============================] - 19s 368ms/step - loss: 0.2093 - mean_io_u: 0.8638 - dice_coeficient: 0.8919 - val_loss: 0.2222 - val_mean_io_u: 0.8617 - val_dice_coeficient: 0.8847
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2046 - mean_io_u: 0.8641 - dice_coeficient: 0.8919
# Epoch 98: val_loss improved from 0.22211 to 0.22205, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 380ms/step - loss: 0.2046 - mean_io_u: 0.8641 - dice_coeficient: 0.8919 - val_loss: 0.2220 - val_mean_io_u: 0.8619 - val_dice_coeficient: 0.8847
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2041 - mean_io_u: 0.8643 - dice_coeficient: 0.8920
# Epoch 99: val_loss did not improve from 0.22205
# 51/51 [==============================] - 19s 375ms/step - loss: 0.2041 - mean_io_u: 0.8643 - dice_coeficient: 0.8920 - val_loss: 0.2221 - val_mean_io_u: 0.8620 - val_dice_coeficient: 0.8848
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2052 - mean_io_u: 0.8645 - dice_coeficient: 0.8919
# Epoch 100: val_loss improved from 0.22205 to 0.22198, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 382ms/step - loss: 0.2052 - mean_io_u: 0.8645 - dice_coeficient: 0.8919 - val_loss: 0.2220 - val_mean_io_u: 0.8622 - val_dice_coeficient: 0.8846

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 5s 54ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx])
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
