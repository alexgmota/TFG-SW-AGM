# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
import cv2
import tensorflow as tf
import keras.backend as K
from skimage import exposure
from skimage.color import rgb2gray
from sklearn.model_selection import train_test_split
from glob import glob
import pickle
import segmentation_models as sm
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
CLASS_WEIGHTS = [2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
 1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
 3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
 4.36967906e-03]

# %%
# https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape, 
                    padding_color = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size, interpolation=cv2.INTER_NEAREST)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 120:-120,:]
    img = resize_with_pad(img, (HEIGHT, WIDTH))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 120:-120,:]
    mask = resize_with_pad(mask, (HEIGHT, WIDTH), (50, 50, 50))
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx], cmap='magma')
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
# dump_data(X, y)
# X, y = load_data()
np.unique(y_encoded[idx])
# Out:
# array([ 0,  1,  2,  3,  4,  5, 10], dtype=uint8)

# %%
plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1), cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## U-Net

# %%
def double_conv_block(x, n_filters):

   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
   # Conv2D then ReLU activation
   x = tf.keras.layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)

   return x

def downsample_block(x, n_filters):
   f = double_conv_block(x, n_filters)
   p = tf.keras.layers.MaxPool2D(2)(f)
   p = tf.keras.layers.Dropout(0.2)(p)

   return f, p

def upsample_block(x, conv_features, n_filters):
   # upsample
   x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
   # concatenate
   x = tf.keras.layers.concatenate([x, conv_features])
   # dropout
   x = tf.keras.layers.Dropout(0.2)(x)
   # Conv2D twice with ReLU activation
   x = double_conv_block(x, n_filters)

   return x

def build_unet_model(n_filters=64, n_classes=2):
   # inputs
   inputs = tf.keras.layers.Input(shape=(HEIGHT,WIDTH,3))

   # encoder: contracting path - downsample
   # 1 - downsample
   f1, p1 = downsample_block(inputs, n_filters)
   # 2 - downsample
   f2, p2 = downsample_block(p1, n_filters*2)
   # 3 - downsample
   f3, p3 = downsample_block(p2, n_filters*4)
   # 4 - downsample
   f4, p4 = downsample_block(p3, n_filters*8)

   # 5 - bottleneck
   bottleneck = double_conv_block(p4, n_filters*16)

   # decoder: expanding path - upsample
   # 6 - upsample
   u6 = upsample_block(bottleneck, f4, n_filters*8)
   # 7 - upsample
   u7 = upsample_block(u6, f3, n_filters*4)
   # 8 - upsample
   u8 = upsample_block(u7, f2, n_filters*2)
   # 9 - upsample
   u9 = upsample_block(u8, f1, n_filters)

   # outputs
   
   activation = 'sigmoid' if n_classes == 2 else 'softmax'
   outputs = tf.keras.layers.Conv2D(n_classes, 1, padding="same", activation=activation)(u9)

   # unet model with Keras Functional API
   unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

   return unet_model

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tv = tversky(y_true, y_pred)
    return tf.keras.backend.pow((1 - tv), gamma)

def generalized_dice_coeff(y_true, y_pred, smooth=1e-9):
    Ncl = y_pred.shape[-1]
    w = np.zeros((Ncl,))
    w = K.sum(y_true, (0,1,2))
    w = 1 / (w ** 2 + smooth)

    y_pred = tf.nn.softmax(y_pred)

    # Compute gen dice coef:
    numerator = y_true * y_pred
    numerator = w * K.sum(numerator, (0,1,2))
    numerator = K.sum(numerator)

    denominator = y_true + y_pred
    denominator = w * K.sum(denominator, (0,1,2))
    denominator = K.sum(denominator)

    return 2. * (numerator + smooth) / (denominator + smooth)


def generalized_dice_loss(y_true, y_pred):
    return 1. - generalized_dice_coeff(y_true, y_pred)

# %%
unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.load_weights('../models/u-net_39-0.22_tversky_loss.hdf5')
unet_model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4), 
    loss=sm.losses.DiceLoss(class_weights=CLASS_WEIGHTS),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)

unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   896         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 32, 32, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   18496       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 16, 16, 64)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 8, 8, 128)    0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 256)    295168      ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)   0           ['conv2d_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 4, 4, 256)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 512)    1180160     ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 4, 4, 512)    2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 8, 8, 256)   1179904     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 8, 8, 512)    0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 512)    0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 256)    1179904     ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 16, 16, 128)  295040     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 16, 16, 256)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 32, 32, 64)  73792       ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 32, 32, 128)  0           ['concatenate_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_15[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 64)   0           ['concatenate_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 13)   429         ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 8,630,893
# Trainable params: 8,630,893
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/u-net_diceLoss.hdf5',
    verbose=1,
    monitor='val_mean_io_u',
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)

print('\n\t TRAINING\n')

model_history = unet_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9856 - mean_io_u: 0.4806 - dice_coeficient: 0.1873
# Epoch 1: val_mean_io_u improved from -inf to 0.60128, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 22s 233ms/step - loss: 0.9856 - mean_io_u: 0.4806 - dice_coeficient: 0.1873 - val_loss: 0.9669 - val_mean_io_u: 0.6013 - val_dice_coeficient: 0.4926
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9640 - mean_io_u: 0.6455 - dice_coeficient: 0.5372
# Epoch 2: val_mean_io_u improved from 0.60128 to 0.67037, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 8s 161ms/step - loss: 0.9640 - mean_io_u: 0.6455 - dice_coeficient: 0.5372 - val_loss: 0.9617 - val_mean_io_u: 0.6704 - val_dice_coeficient: 0.5725
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9609 - mean_io_u: 0.6618 - dice_coeficient: 0.5681
# Epoch 3: val_mean_io_u did not improve from 0.67037
# 51/51 [==============================] - 8s 160ms/step - loss: 0.9609 - mean_io_u: 0.6618 - dice_coeficient: 0.5681 - val_loss: 0.9604 - val_mean_io_u: 0.6500 - val_dice_coeficient: 0.5752
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9595 - mean_io_u: 0.6395 - dice_coeficient: 0.5822
# Epoch 4: val_mean_io_u did not improve from 0.67037
# 51/51 [==============================] - 8s 160ms/step - loss: 0.9595 - mean_io_u: 0.6395 - dice_coeficient: 0.5822 - val_loss: 0.9592 - val_mean_io_u: 0.5802 - val_dice_coeficient: 0.5843
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9570 - mean_io_u: 0.6367 - dice_coeficient: 0.5961
# Epoch 5: val_mean_io_u did not improve from 0.67037
# 51/51 [==============================] - 8s 163ms/step - loss: 0.9570 - mean_io_u: 0.6367 - dice_coeficient: 0.5961 - val_loss: 0.9555 - val_mean_io_u: 0.6368 - val_dice_coeficient: 0.6096
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9531 - mean_io_u: 0.6638 - dice_coeficient: 0.6354
# Epoch 6: val_mean_io_u did not improve from 0.67037
# 51/51 [==============================] - 8s 165ms/step - loss: 0.9531 - mean_io_u: 0.6638 - dice_coeficient: 0.6354 - val_loss: 0.9519 - val_mean_io_u: 0.6538 - val_dice_coeficient: 0.6509
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9513 - mean_io_u: 0.6786 - dice_coeficient: 0.6565
# Epoch 7: val_mean_io_u did not improve from 0.67037
# 51/51 [==============================] - 9s 167ms/step - loss: 0.9513 - mean_io_u: 0.6786 - dice_coeficient: 0.6565 - val_loss: 0.9511 - val_mean_io_u: 0.6628 - val_dice_coeficient: 0.6617
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9458 - mean_io_u: 0.7323 - dice_coeficient: 0.7648
# Epoch 8: val_mean_io_u improved from 0.67037 to 0.74750, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 170ms/step - loss: 0.9458 - mean_io_u: 0.7323 - dice_coeficient: 0.7648 - val_loss: 0.9440 - val_mean_io_u: 0.7475 - val_dice_coeficient: 0.8012
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9436 - mean_io_u: 0.7685 - dice_coeficient: 0.8054
# Epoch 9: val_mean_io_u improved from 0.74750 to 0.76427, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 172ms/step - loss: 0.9436 - mean_io_u: 0.7685 - dice_coeficient: 0.8054 - val_loss: 0.9433 - val_mean_io_u: 0.7643 - val_dice_coeficient: 0.8121
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9431 - mean_io_u: 0.7757 - dice_coeficient: 0.8115
# Epoch 10: val_mean_io_u did not improve from 0.76427
# 51/51 [==============================] - 9s 172ms/step - loss: 0.9431 - mean_io_u: 0.7757 - dice_coeficient: 0.8115 - val_loss: 0.9429 - val_mean_io_u: 0.7605 - val_dice_coeficient: 0.8131
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9418 - mean_io_u: 0.7538 - dice_coeficient: 0.8022
# Epoch 11: val_mean_io_u did not improve from 0.76427
# 51/51 [==============================] - 9s 173ms/step - loss: 0.9418 - mean_io_u: 0.7538 - dice_coeficient: 0.8022 - val_loss: 0.9403 - val_mean_io_u: 0.7411 - val_dice_coeficient: 0.7969
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9401 - mean_io_u: 0.7727 - dice_coeficient: 0.8052
# Epoch 12: val_mean_io_u did not improve from 0.76427
# 51/51 [==============================] - 9s 175ms/step - loss: 0.9401 - mean_io_u: 0.7727 - dice_coeficient: 0.8052 - val_loss: 0.9399 - val_mean_io_u: 0.7603 - val_dice_coeficient: 0.7996
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9395 - mean_io_u: 0.7873 - dice_coeficient: 0.8111
# Epoch 13: val_mean_io_u improved from 0.76427 to 0.77464, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 176ms/step - loss: 0.9395 - mean_io_u: 0.7873 - dice_coeficient: 0.8111 - val_loss: 0.9394 - val_mean_io_u: 0.7746 - val_dice_coeficient: 0.8061
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9392 - mean_io_u: 0.7954 - dice_coeficient: 0.8151
# Epoch 14: val_mean_io_u improved from 0.77464 to 0.77703, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 176ms/step - loss: 0.9392 - mean_io_u: 0.7954 - dice_coeficient: 0.8151 - val_loss: 0.9391 - val_mean_io_u: 0.7770 - val_dice_coeficient: 0.8090
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9389 - mean_io_u: 0.7994 - dice_coeficient: 0.8180
# Epoch 15: val_mean_io_u improved from 0.77703 to 0.78451, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 176ms/step - loss: 0.9389 - mean_io_u: 0.7994 - dice_coeficient: 0.8180 - val_loss: 0.9388 - val_mean_io_u: 0.7845 - val_dice_coeficient: 0.8143
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9387 - mean_io_u: 0.8023 - dice_coeficient: 0.8204
# Epoch 16: val_mean_io_u improved from 0.78451 to 0.79421, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9387 - mean_io_u: 0.8023 - dice_coeficient: 0.8204 - val_loss: 0.9384 - val_mean_io_u: 0.7942 - val_dice_coeficient: 0.8217
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9385 - mean_io_u: 0.8056 - dice_coeficient: 0.8227
# Epoch 17: val_mean_io_u did not improve from 0.79421
# 51/51 [==============================] - 9s 177ms/step - loss: 0.9385 - mean_io_u: 0.8056 - dice_coeficient: 0.8227 - val_loss: 0.9384 - val_mean_io_u: 0.7938 - val_dice_coeficient: 0.8196
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9383 - mean_io_u: 0.8083 - dice_coeficient: 0.8243
# Epoch 18: val_mean_io_u improved from 0.79421 to 0.79500, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 177ms/step - loss: 0.9383 - mean_io_u: 0.8083 - dice_coeficient: 0.8243 - val_loss: 0.9382 - val_mean_io_u: 0.7950 - val_dice_coeficient: 0.8216
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9382 - mean_io_u: 0.8105 - dice_coeficient: 0.8260
# Epoch 19: val_mean_io_u improved from 0.79500 to 0.79841, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 176ms/step - loss: 0.9382 - mean_io_u: 0.8105 - dice_coeficient: 0.8260 - val_loss: 0.9380 - val_mean_io_u: 0.7984 - val_dice_coeficient: 0.8234
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9381 - mean_io_u: 0.8127 - dice_coeficient: 0.8274
# Epoch 20: val_mean_io_u improved from 0.79841 to 0.80082, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9381 - mean_io_u: 0.8127 - dice_coeficient: 0.8274 - val_loss: 0.9379 - val_mean_io_u: 0.8008 - val_dice_coeficient: 0.8258
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9380 - mean_io_u: 0.8138 - dice_coeficient: 0.8286
# Epoch 21: val_mean_io_u improved from 0.80082 to 0.80558, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9380 - mean_io_u: 0.8138 - dice_coeficient: 0.8286 - val_loss: 0.9379 - val_mean_io_u: 0.8056 - val_dice_coeficient: 0.8273
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9379 - mean_io_u: 0.8156 - dice_coeficient: 0.8298
# Epoch 22: val_mean_io_u improved from 0.80558 to 0.81128, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9379 - mean_io_u: 0.8156 - dice_coeficient: 0.8298 - val_loss: 0.9377 - val_mean_io_u: 0.8113 - val_dice_coeficient: 0.8302
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9378 - mean_io_u: 0.8174 - dice_coeficient: 0.8307
# Epoch 23: val_mean_io_u did not improve from 0.81128
# 51/51 [==============================] - 9s 176ms/step - loss: 0.9378 - mean_io_u: 0.8174 - dice_coeficient: 0.8307 - val_loss: 0.9377 - val_mean_io_u: 0.8077 - val_dice_coeficient: 0.8292
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9377 - mean_io_u: 0.8179 - dice_coeficient: 0.8317
# Epoch 24: val_mean_io_u improved from 0.81128 to 0.81165, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 179ms/step - loss: 0.9377 - mean_io_u: 0.8179 - dice_coeficient: 0.8317 - val_loss: 0.9375 - val_mean_io_u: 0.8117 - val_dice_coeficient: 0.8326
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9376 - mean_io_u: 0.8194 - dice_coeficient: 0.8326
# Epoch 25: val_mean_io_u improved from 0.81165 to 0.81240, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9376 - mean_io_u: 0.8194 - dice_coeficient: 0.8326 - val_loss: 0.9375 - val_mean_io_u: 0.8124 - val_dice_coeficient: 0.8330
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9376 - mean_io_u: 0.8203 - dice_coeficient: 0.8335
# Epoch 26: val_mean_io_u improved from 0.81240 to 0.81318, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9376 - mean_io_u: 0.8203 - dice_coeficient: 0.8335 - val_loss: 0.9375 - val_mean_io_u: 0.8132 - val_dice_coeficient: 0.8329
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9375 - mean_io_u: 0.8216 - dice_coeficient: 0.8344
# Epoch 27: val_mean_io_u improved from 0.81318 to 0.81326, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 180ms/step - loss: 0.9375 - mean_io_u: 0.8216 - dice_coeficient: 0.8344 - val_loss: 0.9374 - val_mean_io_u: 0.8133 - val_dice_coeficient: 0.8339
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9375 - mean_io_u: 0.8219 - dice_coeficient: 0.8350
# Epoch 28: val_mean_io_u improved from 0.81326 to 0.81671, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 180ms/step - loss: 0.9375 - mean_io_u: 0.8219 - dice_coeficient: 0.8350 - val_loss: 0.9372 - val_mean_io_u: 0.8167 - val_dice_coeficient: 0.8364
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9374 - mean_io_u: 0.8226 - dice_coeficient: 0.8356
# Epoch 29: val_mean_io_u did not improve from 0.81671
# 51/51 [==============================] - 9s 178ms/step - loss: 0.9374 - mean_io_u: 0.8226 - dice_coeficient: 0.8356 - val_loss: 0.9373 - val_mean_io_u: 0.8159 - val_dice_coeficient: 0.8351
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9374 - mean_io_u: 0.8232 - dice_coeficient: 0.8359
# Epoch 30: val_mean_io_u improved from 0.81671 to 0.81749, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 180ms/step - loss: 0.9374 - mean_io_u: 0.8232 - dice_coeficient: 0.8359 - val_loss: 0.9372 - val_mean_io_u: 0.8175 - val_dice_coeficient: 0.8359
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9373 - mean_io_u: 0.8235 - dice_coeficient: 0.8367
# Epoch 31: val_mean_io_u did not improve from 0.81749
# 51/51 [==============================] - 9s 180ms/step - loss: 0.9373 - mean_io_u: 0.8235 - dice_coeficient: 0.8367 - val_loss: 0.9371 - val_mean_io_u: 0.8163 - val_dice_coeficient: 0.8368
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9373 - mean_io_u: 0.8241 - dice_coeficient: 0.8369
# Epoch 32: val_mean_io_u improved from 0.81749 to 0.82027, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 179ms/step - loss: 0.9373 - mean_io_u: 0.8241 - dice_coeficient: 0.8369 - val_loss: 0.9371 - val_mean_io_u: 0.8203 - val_dice_coeficient: 0.8384
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9372 - mean_io_u: 0.8241 - dice_coeficient: 0.8379
# Epoch 33: val_mean_io_u did not improve from 0.82027
# 51/51 [==============================] - 9s 179ms/step - loss: 0.9372 - mean_io_u: 0.8241 - dice_coeficient: 0.8379 - val_loss: 0.9371 - val_mean_io_u: 0.8180 - val_dice_coeficient: 0.8384
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9372 - mean_io_u: 0.8242 - dice_coeficient: 0.8379
# Epoch 34: val_mean_io_u improved from 0.82027 to 0.82122, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 180ms/step - loss: 0.9372 - mean_io_u: 0.8242 - dice_coeficient: 0.8379 - val_loss: 0.9370 - val_mean_io_u: 0.8212 - val_dice_coeficient: 0.8397
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9372 - mean_io_u: 0.8247 - dice_coeficient: 0.8383
# Epoch 35: val_mean_io_u did not improve from 0.82122
# 51/51 [==============================] - 9s 181ms/step - loss: 0.9372 - mean_io_u: 0.8247 - dice_coeficient: 0.8383 - val_loss: 0.9370 - val_mean_io_u: 0.8203 - val_dice_coeficient: 0.8391
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9372 - mean_io_u: 0.8249 - dice_coeficient: 0.8387
# Epoch 36: val_mean_io_u did not improve from 0.82122
# 51/51 [==============================] - 9s 179ms/step - loss: 0.9372 - mean_io_u: 0.8249 - dice_coeficient: 0.8387 - val_loss: 0.9370 - val_mean_io_u: 0.8173 - val_dice_coeficient: 0.8383
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9371 - mean_io_u: 0.8250 - dice_coeficient: 0.8390
# Epoch 37: val_mean_io_u did not improve from 0.82122
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9371 - mean_io_u: 0.8250 - dice_coeficient: 0.8390 - val_loss: 0.9369 - val_mean_io_u: 0.8204 - val_dice_coeficient: 0.8400
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9371 - mean_io_u: 0.8253 - dice_coeficient: 0.8395
# Epoch 38: val_mean_io_u improved from 0.82122 to 0.82244, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 187ms/step - loss: 0.9371 - mean_io_u: 0.8253 - dice_coeficient: 0.8395 - val_loss: 0.9369 - val_mean_io_u: 0.8224 - val_dice_coeficient: 0.8411
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9371 - mean_io_u: 0.8252 - dice_coeficient: 0.8399
# Epoch 39: val_mean_io_u did not improve from 0.82244
# 51/51 [==============================] - 9s 184ms/step - loss: 0.9371 - mean_io_u: 0.8252 - dice_coeficient: 0.8399 - val_loss: 0.9369 - val_mean_io_u: 0.8222 - val_dice_coeficient: 0.8411
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9370 - mean_io_u: 0.8254 - dice_coeficient: 0.8401
# Epoch 40: val_mean_io_u did not improve from 0.82244
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9370 - mean_io_u: 0.8254 - dice_coeficient: 0.8401 - val_loss: 0.9369 - val_mean_io_u: 0.8190 - val_dice_coeficient: 0.8399
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9370 - mean_io_u: 0.8255 - dice_coeficient: 0.8403
# Epoch 41: val_mean_io_u did not improve from 0.82244
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9370 - mean_io_u: 0.8255 - dice_coeficient: 0.8403 - val_loss: 0.9368 - val_mean_io_u: 0.8201 - val_dice_coeficient: 0.8413
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9370 - mean_io_u: 0.8259 - dice_coeficient: 0.8407
# Epoch 42: val_mean_io_u improved from 0.82244 to 0.82411, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9370 - mean_io_u: 0.8259 - dice_coeficient: 0.8407 - val_loss: 0.9368 - val_mean_io_u: 0.8241 - val_dice_coeficient: 0.8419
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9370 - mean_io_u: 0.8267 - dice_coeficient: 0.8411
# Epoch 43: val_mean_io_u did not improve from 0.82411
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9370 - mean_io_u: 0.8267 - dice_coeficient: 0.8411 - val_loss: 0.9368 - val_mean_io_u: 0.8217 - val_dice_coeficient: 0.8415
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9369 - mean_io_u: 0.8263 - dice_coeficient: 0.8412
# Epoch 44: val_mean_io_u improved from 0.82411 to 0.82424, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9369 - mean_io_u: 0.8263 - dice_coeficient: 0.8412 - val_loss: 0.9367 - val_mean_io_u: 0.8242 - val_dice_coeficient: 0.8428
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9369 - mean_io_u: 0.8270 - dice_coeficient: 0.8414
# Epoch 45: val_mean_io_u did not improve from 0.82424
# 51/51 [==============================] - 9s 184ms/step - loss: 0.9369 - mean_io_u: 0.8270 - dice_coeficient: 0.8414 - val_loss: 0.9367 - val_mean_io_u: 0.8234 - val_dice_coeficient: 0.8430
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9369 - mean_io_u: 0.8271 - dice_coeficient: 0.8416
# Epoch 46: val_mean_io_u did not improve from 0.82424
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9369 - mean_io_u: 0.8271 - dice_coeficient: 0.8416 - val_loss: 0.9368 - val_mean_io_u: 0.8232 - val_dice_coeficient: 0.8427
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9369 - mean_io_u: 0.8275 - dice_coeficient: 0.8418
# Epoch 47: val_mean_io_u did not improve from 0.82424
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9369 - mean_io_u: 0.8275 - dice_coeficient: 0.8418 - val_loss: 0.9367 - val_mean_io_u: 0.8227 - val_dice_coeficient: 0.8425
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8281 - dice_coeficient: 0.8421
# Epoch 48: val_mean_io_u improved from 0.82424 to 0.82529, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9368 - mean_io_u: 0.8281 - dice_coeficient: 0.8421 - val_loss: 0.9367 - val_mean_io_u: 0.8253 - val_dice_coeficient: 0.8433
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8287 - dice_coeficient: 0.8423
# Epoch 49: val_mean_io_u improved from 0.82529 to 0.82549, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9368 - mean_io_u: 0.8287 - dice_coeficient: 0.8423 - val_loss: 0.9367 - val_mean_io_u: 0.8255 - val_dice_coeficient: 0.8438
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8288 - dice_coeficient: 0.8426
# Epoch 50: val_mean_io_u did not improve from 0.82549
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9368 - mean_io_u: 0.8288 - dice_coeficient: 0.8426 - val_loss: 0.9367 - val_mean_io_u: 0.8230 - val_dice_coeficient: 0.8426
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8293 - dice_coeficient: 0.8429
# Epoch 51: val_mean_io_u improved from 0.82549 to 0.82895, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9368 - mean_io_u: 0.8293 - dice_coeficient: 0.8429 - val_loss: 0.9366 - val_mean_io_u: 0.8289 - val_dice_coeficient: 0.8443
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8299 - dice_coeficient: 0.8429
# Epoch 52: val_mean_io_u did not improve from 0.82895
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9368 - mean_io_u: 0.8299 - dice_coeficient: 0.8429 - val_loss: 0.9366 - val_mean_io_u: 0.8272 - val_dice_coeficient: 0.8439
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9368 - mean_io_u: 0.8303 - dice_coeficient: 0.8432
# Epoch 53: val_mean_io_u did not improve from 0.82895
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9368 - mean_io_u: 0.8303 - dice_coeficient: 0.8432 - val_loss: 0.9367 - val_mean_io_u: 0.8245 - val_dice_coeficient: 0.8422
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8304 - dice_coeficient: 0.8434
# Epoch 54: val_mean_io_u did not improve from 0.82895
# 51/51 [==============================] - 9s 184ms/step - loss: 0.9367 - mean_io_u: 0.8304 - dice_coeficient: 0.8434 - val_loss: 0.9366 - val_mean_io_u: 0.8283 - val_dice_coeficient: 0.8441
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8313 - dice_coeficient: 0.8434
# Epoch 55: val_mean_io_u did not improve from 0.82895
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9367 - mean_io_u: 0.8313 - dice_coeficient: 0.8434 - val_loss: 0.9366 - val_mean_io_u: 0.8283 - val_dice_coeficient: 0.8446
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8318 - dice_coeficient: 0.8438
# Epoch 56: val_mean_io_u did not improve from 0.82895
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9367 - mean_io_u: 0.8318 - dice_coeficient: 0.8438 - val_loss: 0.9366 - val_mean_io_u: 0.8276 - val_dice_coeficient: 0.8441
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8321 - dice_coeficient: 0.8439
# Epoch 57: val_mean_io_u did not improve from 0.82895
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9367 - mean_io_u: 0.8321 - dice_coeficient: 0.8439 - val_loss: 0.9366 - val_mean_io_u: 0.8289 - val_dice_coeficient: 0.8444
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8322 - dice_coeficient: 0.8441
# Epoch 58: val_mean_io_u did not improve from 0.82895
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9367 - mean_io_u: 0.8322 - dice_coeficient: 0.8441 - val_loss: 0.9365 - val_mean_io_u: 0.8274 - val_dice_coeficient: 0.8438
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9367 - mean_io_u: 0.8324 - dice_coeficient: 0.8442
# Epoch 59: val_mean_io_u improved from 0.82895 to 0.83017, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9367 - mean_io_u: 0.8324 - dice_coeficient: 0.8442 - val_loss: 0.9366 - val_mean_io_u: 0.8302 - val_dice_coeficient: 0.8448
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8329 - dice_coeficient: 0.8445
# Epoch 60: val_mean_io_u did not improve from 0.83017
# 51/51 [==============================] - 9s 185ms/step - loss: 0.9366 - mean_io_u: 0.8329 - dice_coeficient: 0.8445 - val_loss: 0.9366 - val_mean_io_u: 0.8299 - val_dice_coeficient: 0.8443
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8334 - dice_coeficient: 0.8441
# Epoch 61: val_mean_io_u improved from 0.83017 to 0.83059, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9366 - mean_io_u: 0.8334 - dice_coeficient: 0.8441 - val_loss: 0.9365 - val_mean_io_u: 0.8306 - val_dice_coeficient: 0.8449
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8336 - dice_coeficient: 0.8446
# Epoch 62: val_mean_io_u did not improve from 0.83059
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9366 - mean_io_u: 0.8336 - dice_coeficient: 0.8446 - val_loss: 0.9365 - val_mean_io_u: 0.8303 - val_dice_coeficient: 0.8448
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8338 - dice_coeficient: 0.8445
# Epoch 63: val_mean_io_u improved from 0.83059 to 0.83155, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9366 - mean_io_u: 0.8338 - dice_coeficient: 0.8445 - val_loss: 0.9365 - val_mean_io_u: 0.8316 - val_dice_coeficient: 0.8453
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8341 - dice_coeficient: 0.8448
# Epoch 64: val_mean_io_u improved from 0.83155 to 0.83270, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9366 - mean_io_u: 0.8341 - dice_coeficient: 0.8448 - val_loss: 0.9365 - val_mean_io_u: 0.8327 - val_dice_coeficient: 0.8456
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8346 - dice_coeficient: 0.8449
# Epoch 65: val_mean_io_u did not improve from 0.83270
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9366 - mean_io_u: 0.8346 - dice_coeficient: 0.8449 - val_loss: 0.9365 - val_mean_io_u: 0.8309 - val_dice_coeficient: 0.8444
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8349 - dice_coeficient: 0.8452
# Epoch 66: val_mean_io_u improved from 0.83270 to 0.83306, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 190ms/step - loss: 0.9366 - mean_io_u: 0.8349 - dice_coeficient: 0.8452 - val_loss: 0.9364 - val_mean_io_u: 0.8331 - val_dice_coeficient: 0.8456
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9366 - mean_io_u: 0.8356 - dice_coeficient: 0.8452
# Epoch 67: val_mean_io_u did not improve from 0.83306
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9366 - mean_io_u: 0.8356 - dice_coeficient: 0.8452 - val_loss: 0.9365 - val_mean_io_u: 0.8316 - val_dice_coeficient: 0.8449
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9365 - mean_io_u: 0.8357 - dice_coeficient: 0.8454
# Epoch 68: val_mean_io_u did not improve from 0.83306
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9365 - mean_io_u: 0.8357 - dice_coeficient: 0.8454 - val_loss: 0.9364 - val_mean_io_u: 0.8315 - val_dice_coeficient: 0.8448
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9365 - mean_io_u: 0.8358 - dice_coeficient: 0.8452
# Epoch 69: val_mean_io_u improved from 0.83306 to 0.83405, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9365 - mean_io_u: 0.8358 - dice_coeficient: 0.8452 - val_loss: 0.9364 - val_mean_io_u: 0.8341 - val_dice_coeficient: 0.8460
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9365 - mean_io_u: 0.8365 - dice_coeficient: 0.8454
# Epoch 70: val_mean_io_u improved from 0.83405 to 0.83527, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9365 - mean_io_u: 0.8365 - dice_coeficient: 0.8454 - val_loss: 0.9364 - val_mean_io_u: 0.8353 - val_dice_coeficient: 0.8463
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9365 - mean_io_u: 0.8368 - dice_coeficient: 0.8455
# Epoch 71: val_mean_io_u did not improve from 0.83527
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9365 - mean_io_u: 0.8368 - dice_coeficient: 0.8455 - val_loss: 0.9364 - val_mean_io_u: 0.8343 - val_dice_coeficient: 0.8457
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9365 - mean_io_u: 0.8371 - dice_coeficient: 0.8453
# Epoch 72: val_mean_io_u did not improve from 0.83527
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9365 - mean_io_u: 0.8371 - dice_coeficient: 0.8453 - val_loss: 0.9364 - val_mean_io_u: 0.8347 - val_dice_coeficient: 0.8458
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9365 - mean_io_u: 0.8374 - dice_coeficient: 0.8456
# Epoch 73: val_mean_io_u did not improve from 0.83527
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9365 - mean_io_u: 0.8374 - dice_coeficient: 0.8456 - val_loss: 0.9364 - val_mean_io_u: 0.8349 - val_dice_coeficient: 0.8457
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9365 - mean_io_u: 0.8375 - dice_coeficient: 0.8456
# Epoch 74: val_mean_io_u improved from 0.83527 to 0.83668, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9365 - mean_io_u: 0.8375 - dice_coeficient: 0.8456 - val_loss: 0.9364 - val_mean_io_u: 0.8367 - val_dice_coeficient: 0.8460
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9365 - mean_io_u: 0.8381 - dice_coeficient: 0.8459
# Epoch 75: val_mean_io_u did not improve from 0.83668
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9365 - mean_io_u: 0.8381 - dice_coeficient: 0.8459 - val_loss: 0.9364 - val_mean_io_u: 0.8361 - val_dice_coeficient: 0.8460
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9365 - mean_io_u: 0.8383 - dice_coeficient: 0.8459
# Epoch 76: val_mean_io_u did not improve from 0.83668
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9365 - mean_io_u: 0.8383 - dice_coeficient: 0.8459 - val_loss: 0.9364 - val_mean_io_u: 0.8337 - val_dice_coeficient: 0.8453
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8385 - dice_coeficient: 0.8460
# Epoch 77: val_mean_io_u did not improve from 0.83668
# 51/51 [==============================] - 9s 186ms/step - loss: 0.9364 - mean_io_u: 0.8385 - dice_coeficient: 0.8460 - val_loss: 0.9364 - val_mean_io_u: 0.8350 - val_dice_coeficient: 0.8456
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8392 - dice_coeficient: 0.8462
# Epoch 78: val_mean_io_u improved from 0.83668 to 0.83798, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 190ms/step - loss: 0.9364 - mean_io_u: 0.8392 - dice_coeficient: 0.8462 - val_loss: 0.9363 - val_mean_io_u: 0.8380 - val_dice_coeficient: 0.8468
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8391 - dice_coeficient: 0.8460
# Epoch 79: val_mean_io_u did not improve from 0.83798
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9364 - mean_io_u: 0.8391 - dice_coeficient: 0.8460 - val_loss: 0.9363 - val_mean_io_u: 0.8361 - val_dice_coeficient: 0.8461
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8395 - dice_coeficient: 0.8463
# Epoch 80: val_mean_io_u did not improve from 0.83798
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9364 - mean_io_u: 0.8395 - dice_coeficient: 0.8463 - val_loss: 0.9363 - val_mean_io_u: 0.8347 - val_dice_coeficient: 0.8452
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8393 - dice_coeficient: 0.8461
# Epoch 81: val_mean_io_u improved from 0.83798 to 0.83840, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 192ms/step - loss: 0.9364 - mean_io_u: 0.8393 - dice_coeficient: 0.8461 - val_loss: 0.9363 - val_mean_io_u: 0.8384 - val_dice_coeficient: 0.8470
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8397 - dice_coeficient: 0.8465
# Epoch 82: val_mean_io_u did not improve from 0.83840
# 51/51 [==============================] - 10s 187ms/step - loss: 0.9364 - mean_io_u: 0.8397 - dice_coeficient: 0.8465 - val_loss: 0.9363 - val_mean_io_u: 0.8369 - val_dice_coeficient: 0.8464
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8398 - dice_coeficient: 0.8465
# Epoch 83: val_mean_io_u did not improve from 0.83840
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9364 - mean_io_u: 0.8398 - dice_coeficient: 0.8465 - val_loss: 0.9363 - val_mean_io_u: 0.8375 - val_dice_coeficient: 0.8464
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8401 - dice_coeficient: 0.8467
# Epoch 84: val_mean_io_u did not improve from 0.83840
# 51/51 [==============================] - 10s 190ms/step - loss: 0.9364 - mean_io_u: 0.8401 - dice_coeficient: 0.8467 - val_loss: 0.9363 - val_mean_io_u: 0.8378 - val_dice_coeficient: 0.8465
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8399 - dice_coeficient: 0.8466
# Epoch 85: val_mean_io_u improved from 0.83840 to 0.83940, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9364 - mean_io_u: 0.8399 - dice_coeficient: 0.8466 - val_loss: 0.9363 - val_mean_io_u: 0.8394 - val_dice_coeficient: 0.8473
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8400 - dice_coeficient: 0.8468
# Epoch 86: val_mean_io_u did not improve from 0.83940
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9364 - mean_io_u: 0.8400 - dice_coeficient: 0.8468 - val_loss: 0.9363 - val_mean_io_u: 0.8389 - val_dice_coeficient: 0.8473
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9364 - mean_io_u: 0.8392 - dice_coeficient: 0.8470
# Epoch 87: val_mean_io_u did not improve from 0.83940
# 51/51 [==============================] - 10s 192ms/step - loss: 0.9364 - mean_io_u: 0.8392 - dice_coeficient: 0.8470 - val_loss: 0.9363 - val_mean_io_u: 0.8364 - val_dice_coeficient: 0.8467
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9363 - mean_io_u: 0.8382 - dice_coeficient: 0.8468
# Epoch 88: val_mean_io_u did not improve from 0.83940
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9363 - mean_io_u: 0.8382 - dice_coeficient: 0.8468 - val_loss: 0.9361 - val_mean_io_u: 0.8383 - val_dice_coeficient: 0.8481
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9356 - mean_io_u: 0.8478 - dice_coeficient: 0.8547
# Epoch 89: val_mean_io_u improved from 0.83940 to 0.85453, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 190ms/step - loss: 0.9356 - mean_io_u: 0.8478 - dice_coeficient: 0.8547 - val_loss: 0.9349 - val_mean_io_u: 0.8545 - val_dice_coeficient: 0.8631
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9349 - mean_io_u: 0.8543 - dice_coeficient: 0.8635
# Epoch 90: val_mean_io_u did not improve from 0.85453
# 51/51 [==============================] - 10s 188ms/step - loss: 0.9349 - mean_io_u: 0.8543 - dice_coeficient: 0.8635 - val_loss: 0.9347 - val_mean_io_u: 0.8536 - val_dice_coeficient: 0.8646
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9348 - mean_io_u: 0.8545 - dice_coeficient: 0.8650
# Epoch 91: val_mean_io_u did not improve from 0.85453
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9348 - mean_io_u: 0.8545 - dice_coeficient: 0.8650 - val_loss: 0.9346 - val_mean_io_u: 0.8536 - val_dice_coeficient: 0.8653
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9347 - mean_io_u: 0.8546 - dice_coeficient: 0.8659
# Epoch 92: val_mean_io_u did not improve from 0.85453
# 51/51 [==============================] - 10s 190ms/step - loss: 0.9347 - mean_io_u: 0.8546 - dice_coeficient: 0.8659 - val_loss: 0.9346 - val_mean_io_u: 0.8540 - val_dice_coeficient: 0.8655
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9347 - mean_io_u: 0.8549 - dice_coeficient: 0.8662
# Epoch 93: val_mean_io_u did not improve from 0.85453
# 51/51 [==============================] - 10s 190ms/step - loss: 0.9347 - mean_io_u: 0.8549 - dice_coeficient: 0.8662 - val_loss: 0.9345 - val_mean_io_u: 0.8532 - val_dice_coeficient: 0.8661
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8552 - dice_coeficient: 0.8665
# Epoch 94: val_mean_io_u improved from 0.85453 to 0.85461, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9346 - mean_io_u: 0.8552 - dice_coeficient: 0.8665 - val_loss: 0.9345 - val_mean_io_u: 0.8546 - val_dice_coeficient: 0.8665
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8552 - dice_coeficient: 0.8667
# Epoch 95: val_mean_io_u did not improve from 0.85461
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9346 - mean_io_u: 0.8552 - dice_coeficient: 0.8667 - val_loss: 0.9345 - val_mean_io_u: 0.8540 - val_dice_coeficient: 0.8664
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8555 - dice_coeficient: 0.8670
# Epoch 96: val_mean_io_u improved from 0.85461 to 0.85506, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 191ms/step - loss: 0.9346 - mean_io_u: 0.8555 - dice_coeficient: 0.8670 - val_loss: 0.9345 - val_mean_io_u: 0.8551 - val_dice_coeficient: 0.8666
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8559 - dice_coeficient: 0.8674
# Epoch 97: val_mean_io_u did not improve from 0.85506
# 51/51 [==============================] - 10s 191ms/step - loss: 0.9346 - mean_io_u: 0.8559 - dice_coeficient: 0.8674 - val_loss: 0.9345 - val_mean_io_u: 0.8545 - val_dice_coeficient: 0.8668
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9346 - mean_io_u: 0.8563 - dice_coeficient: 0.8671
# Epoch 98: val_mean_io_u improved from 0.85506 to 0.85575, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9346 - mean_io_u: 0.8563 - dice_coeficient: 0.8671 - val_loss: 0.9345 - val_mean_io_u: 0.8557 - val_dice_coeficient: 0.8675
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8564 - dice_coeficient: 0.8675
# Epoch 99: val_mean_io_u did not improve from 0.85575
# 51/51 [==============================] - 10s 192ms/step - loss: 0.9345 - mean_io_u: 0.8564 - dice_coeficient: 0.8675 - val_loss: 0.9345 - val_mean_io_u: 0.8531 - val_dice_coeficient: 0.8665
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9345 - mean_io_u: 0.8565 - dice_coeficient: 0.8678
# Epoch 100: val_mean_io_u improved from 0.85575 to 0.85606, saving model to ../models\u-net_diceLoss.hdf5
# 51/51 [==============================] - 10s 189ms/step - loss: 0.9345 - mean_io_u: 0.8565 - dice_coeficient: 0.8678 - val_loss: 0.9344 - val_mean_io_u: 0.8561 - val_dice_coeficient: 0.8673

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='lower right')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/u-net_100epochs.hdf5')

# %%
pred = unet_model.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 2s 25ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1), cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx], cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
