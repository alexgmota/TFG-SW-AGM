# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)

# %%
# https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape, 
                    padding_color = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size, interpolation=cv2.INTER_NEAREST)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 120:-120,:]
    img = resize_with_pad(img, (HEIGHT, WIDTH))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 120:-120,:]
    mask = resize_with_pad(mask, (HEIGHT, WIDTH), (50, 50, 50))
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx], cmap='magma')
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1), cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8154

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4, clipvalue=0.5, decay=1e-6), 
    loss=tversky_loss,
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_tversky.hdf5',
    verbose=1,
    monitor='val_mean_io_u',
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)

print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4512 - mean_io_u: 0.6533 - dice_coeficient: 0.5501
# Epoch 1: val_mean_io_u improved from -inf to 0.74451, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 37s 393ms/step - loss: 0.4512 - mean_io_u: 0.6533 - dice_coeficient: 0.5501 - val_loss: 0.3070 - val_mean_io_u: 0.7445 - val_dice_coeficient: 0.6941
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2612 - mean_io_u: 0.7779 - dice_coeficient: 0.7391
# Epoch 2: val_mean_io_u improved from 0.74451 to 0.79743, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 15s 292ms/step - loss: 0.2612 - mean_io_u: 0.7779 - dice_coeficient: 0.7391 - val_loss: 0.2367 - val_mean_io_u: 0.7974 - val_dice_coeficient: 0.7640
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1978 - mean_io_u: 0.8243 - dice_coeficient: 0.8024
# Epoch 3: val_mean_io_u improved from 0.79743 to 0.84347, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 15s 295ms/step - loss: 0.1978 - mean_io_u: 0.8243 - dice_coeficient: 0.8024 - val_loss: 0.1731 - val_mean_io_u: 0.8435 - val_dice_coeficient: 0.8274
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1491 - mean_io_u: 0.8594 - dice_coeficient: 0.8509
# Epoch 4: val_mean_io_u improved from 0.84347 to 0.86829, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 15s 301ms/step - loss: 0.1491 - mean_io_u: 0.8594 - dice_coeficient: 0.8509 - val_loss: 0.1376 - val_mean_io_u: 0.8683 - val_dice_coeficient: 0.8628
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1262 - mean_io_u: 0.8756 - dice_coeficient: 0.8737
# Epoch 5: val_mean_io_u improved from 0.86829 to 0.87764, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 15s 303ms/step - loss: 0.1262 - mean_io_u: 0.8756 - dice_coeficient: 0.8737 - val_loss: 0.1242 - val_mean_io_u: 0.8776 - val_dice_coeficient: 0.8761
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1176 - mean_io_u: 0.8820 - dice_coeficient: 0.8825
# Epoch 6: val_mean_io_u improved from 0.87764 to 0.88189, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 16s 307ms/step - loss: 0.1176 - mean_io_u: 0.8820 - dice_coeficient: 0.8825 - val_loss: 0.1164 - val_mean_io_u: 0.8819 - val_dice_coeficient: 0.8840
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1048 - mean_io_u: 0.8898 - dice_coeficient: 0.8953
# Epoch 7: val_mean_io_u improved from 0.88189 to 0.89393, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 16s 315ms/step - loss: 0.1048 - mean_io_u: 0.8898 - dice_coeficient: 0.8953 - val_loss: 0.0999 - val_mean_io_u: 0.8939 - val_dice_coeficient: 0.9004
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0961 - mean_io_u: 0.8966 - dice_coeficient: 0.9040
# Epoch 8: val_mean_io_u improved from 0.89393 to 0.89684, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 16s 315ms/step - loss: 0.0961 - mean_io_u: 0.8966 - dice_coeficient: 0.9040 - val_loss: 0.0966 - val_mean_io_u: 0.8968 - val_dice_coeficient: 0.9037
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0929 - mean_io_u: 0.8993 - dice_coeficient: 0.9070
# Epoch 9: val_mean_io_u improved from 0.89684 to 0.89829, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 16s 317ms/step - loss: 0.0929 - mean_io_u: 0.8993 - dice_coeficient: 0.9070 - val_loss: 0.0932 - val_mean_io_u: 0.8983 - val_dice_coeficient: 0.9071
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0889 - mean_io_u: 0.9020 - dice_coeficient: 0.9112
# Epoch 10: val_mean_io_u improved from 0.89829 to 0.89956, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 16s 319ms/step - loss: 0.0889 - mean_io_u: 0.9020 - dice_coeficient: 0.9112 - val_loss: 0.0893 - val_mean_io_u: 0.8996 - val_dice_coeficient: 0.9110
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0837 - mean_io_u: 0.9023 - dice_coeficient: 0.9163
# Epoch 11: val_mean_io_u improved from 0.89956 to 0.90431, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 16s 321ms/step - loss: 0.0837 - mean_io_u: 0.9023 - dice_coeficient: 0.9163 - val_loss: 0.0744 - val_mean_io_u: 0.9043 - val_dice_coeficient: 0.9258
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0651 - mean_io_u: 0.9150 - dice_coeficient: 0.9349
# Epoch 12: val_mean_io_u improved from 0.90431 to 0.91785, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 16s 322ms/step - loss: 0.0651 - mean_io_u: 0.9150 - dice_coeficient: 0.9349 - val_loss: 0.0618 - val_mean_io_u: 0.9179 - val_dice_coeficient: 0.9384
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0568 - mean_io_u: 0.9217 - dice_coeficient: 0.9431
# Epoch 13: val_mean_io_u improved from 0.91785 to 0.92484, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 16s 324ms/step - loss: 0.0568 - mean_io_u: 0.9217 - dice_coeficient: 0.9431 - val_loss: 0.0549 - val_mean_io_u: 0.9248 - val_dice_coeficient: 0.9452
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0526 - mean_io_u: 0.9269 - dice_coeficient: 0.9474
# Epoch 14: val_mean_io_u improved from 0.92484 to 0.92754, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 16s 324ms/step - loss: 0.0526 - mean_io_u: 0.9269 - dice_coeficient: 0.9474 - val_loss: 0.0527 - val_mean_io_u: 0.9275 - val_dice_coeficient: 0.9474
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0507 - mean_io_u: 0.9295 - dice_coeficient: 0.9493
# Epoch 15: val_mean_io_u improved from 0.92754 to 0.92857, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 326ms/step - loss: 0.0507 - mean_io_u: 0.9295 - dice_coeficient: 0.9493 - val_loss: 0.0522 - val_mean_io_u: 0.9286 - val_dice_coeficient: 0.9479
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0493 - mean_io_u: 0.9314 - dice_coeficient: 0.9507
# Epoch 16: val_mean_io_u improved from 0.92857 to 0.93130, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 326ms/step - loss: 0.0493 - mean_io_u: 0.9314 - dice_coeficient: 0.9507 - val_loss: 0.0501 - val_mean_io_u: 0.9313 - val_dice_coeficient: 0.9500
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0475 - mean_io_u: 0.9334 - dice_coeficient: 0.9526
# Epoch 17: val_mean_io_u improved from 0.93130 to 0.93279, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 327ms/step - loss: 0.0475 - mean_io_u: 0.9334 - dice_coeficient: 0.9526 - val_loss: 0.0481 - val_mean_io_u: 0.9328 - val_dice_coeficient: 0.9521
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0441 - mean_io_u: 0.9356 - dice_coeficient: 0.9559
# Epoch 18: val_mean_io_u improved from 0.93279 to 0.93607, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 326ms/step - loss: 0.0441 - mean_io_u: 0.9356 - dice_coeficient: 0.9559 - val_loss: 0.0433 - val_mean_io_u: 0.9361 - val_dice_coeficient: 0.9569
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0386 - mean_io_u: 0.9404 - dice_coeficient: 0.9614
# Epoch 19: val_mean_io_u improved from 0.93607 to 0.94070, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 329ms/step - loss: 0.0386 - mean_io_u: 0.9404 - dice_coeficient: 0.9614 - val_loss: 0.0386 - val_mean_io_u: 0.9407 - val_dice_coeficient: 0.9616
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0353 - mean_io_u: 0.9445 - dice_coeficient: 0.9647
# Epoch 20: val_mean_io_u improved from 0.94070 to 0.94349, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0353 - mean_io_u: 0.9445 - dice_coeficient: 0.9647 - val_loss: 0.0371 - val_mean_io_u: 0.9435 - val_dice_coeficient: 0.9630
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0337 - mean_io_u: 0.9469 - dice_coeficient: 0.9663
# Epoch 21: val_mean_io_u improved from 0.94349 to 0.94486, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.0337 - mean_io_u: 0.9469 - dice_coeficient: 0.9663 - val_loss: 0.0358 - val_mean_io_u: 0.9449 - val_dice_coeficient: 0.9643
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0323 - mean_io_u: 0.9489 - dice_coeficient: 0.9676
# Epoch 22: val_mean_io_u improved from 0.94486 to 0.94730, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.0323 - mean_io_u: 0.9489 - dice_coeficient: 0.9676 - val_loss: 0.0347 - val_mean_io_u: 0.9473 - val_dice_coeficient: 0.9654
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0313 - mean_io_u: 0.9505 - dice_coeficient: 0.9687
# Epoch 23: val_mean_io_u improved from 0.94730 to 0.94884, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0313 - mean_io_u: 0.9505 - dice_coeficient: 0.9687 - val_loss: 0.0336 - val_mean_io_u: 0.9488 - val_dice_coeficient: 0.9665
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0302 - mean_io_u: 0.9522 - dice_coeficient: 0.9698
# Epoch 24: val_mean_io_u improved from 0.94884 to 0.95044, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.0302 - mean_io_u: 0.9522 - dice_coeficient: 0.9698 - val_loss: 0.0329 - val_mean_io_u: 0.9504 - val_dice_coeficient: 0.9672
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0291 - mean_io_u: 0.9539 - dice_coeficient: 0.9708
# Epoch 25: val_mean_io_u improved from 0.95044 to 0.95149, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.0291 - mean_io_u: 0.9539 - dice_coeficient: 0.9708 - val_loss: 0.0317 - val_mean_io_u: 0.9515 - val_dice_coeficient: 0.9684
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0280 - mean_io_u: 0.9554 - dice_coeficient: 0.9721
# Epoch 26: val_mean_io_u improved from 0.95149 to 0.95236, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 331ms/step - loss: 0.0280 - mean_io_u: 0.9554 - dice_coeficient: 0.9721 - val_loss: 0.0307 - val_mean_io_u: 0.9524 - val_dice_coeficient: 0.9694
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0267 - mean_io_u: 0.9571 - dice_coeficient: 0.9733
# Epoch 27: val_mean_io_u improved from 0.95236 to 0.95466, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.0267 - mean_io_u: 0.9571 - dice_coeficient: 0.9733 - val_loss: 0.0300 - val_mean_io_u: 0.9547 - val_dice_coeficient: 0.9701
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0257 - mean_io_u: 0.9586 - dice_coeficient: 0.9743
# Epoch 28: val_mean_io_u improved from 0.95466 to 0.95684, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.0257 - mean_io_u: 0.9586 - dice_coeficient: 0.9743 - val_loss: 0.0285 - val_mean_io_u: 0.9568 - val_dice_coeficient: 0.9716
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0250 - mean_io_u: 0.9597 - dice_coeficient: 0.9750
# Epoch 29: val_mean_io_u improved from 0.95684 to 0.95706, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.0250 - mean_io_u: 0.9597 - dice_coeficient: 0.9750 - val_loss: 0.0283 - val_mean_io_u: 0.9571 - val_dice_coeficient: 0.9718
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0244 - mean_io_u: 0.9609 - dice_coeficient: 0.9756
# Epoch 30: val_mean_io_u improved from 0.95706 to 0.95821, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.0244 - mean_io_u: 0.9609 - dice_coeficient: 0.9756 - val_loss: 0.0277 - val_mean_io_u: 0.9582 - val_dice_coeficient: 0.9724
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0237 - mean_io_u: 0.9619 - dice_coeficient: 0.9763
# Epoch 31: val_mean_io_u improved from 0.95821 to 0.95865, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 331ms/step - loss: 0.0237 - mean_io_u: 0.9619 - dice_coeficient: 0.9763 - val_loss: 0.0271 - val_mean_io_u: 0.9586 - val_dice_coeficient: 0.9730
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0231 - mean_io_u: 0.9630 - dice_coeficient: 0.9769
# Epoch 32: val_mean_io_u improved from 0.95865 to 0.96038, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 331ms/step - loss: 0.0231 - mean_io_u: 0.9630 - dice_coeficient: 0.9769 - val_loss: 0.0266 - val_mean_io_u: 0.9604 - val_dice_coeficient: 0.9735
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0225 - mean_io_u: 0.9640 - dice_coeficient: 0.9775
# Epoch 33: val_mean_io_u improved from 0.96038 to 0.96140, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 331ms/step - loss: 0.0225 - mean_io_u: 0.9640 - dice_coeficient: 0.9775 - val_loss: 0.0260 - val_mean_io_u: 0.9614 - val_dice_coeficient: 0.9741
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0221 - mean_io_u: 0.9649 - dice_coeficient: 0.9779
# Epoch 34: val_mean_io_u improved from 0.96140 to 0.96160, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.0221 - mean_io_u: 0.9649 - dice_coeficient: 0.9779 - val_loss: 0.0261 - val_mean_io_u: 0.9616 - val_dice_coeficient: 0.9740
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0218 - mean_io_u: 0.9657 - dice_coeficient: 0.9782
# Epoch 35: val_mean_io_u improved from 0.96160 to 0.96269, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.0218 - mean_io_u: 0.9657 - dice_coeficient: 0.9782 - val_loss: 0.0256 - val_mean_io_u: 0.9627 - val_dice_coeficient: 0.9745
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0213 - mean_io_u: 0.9665 - dice_coeficient: 0.9787
# Epoch 36: val_mean_io_u improved from 0.96269 to 0.96289, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.0213 - mean_io_u: 0.9665 - dice_coeficient: 0.9787 - val_loss: 0.0253 - val_mean_io_u: 0.9629 - val_dice_coeficient: 0.9748
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0211 - mean_io_u: 0.9671 - dice_coeficient: 0.9789
# Epoch 37: val_mean_io_u improved from 0.96289 to 0.96403, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.0211 - mean_io_u: 0.9671 - dice_coeficient: 0.9789 - val_loss: 0.0250 - val_mean_io_u: 0.9640 - val_dice_coeficient: 0.9751
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0207 - mean_io_u: 0.9680 - dice_coeficient: 0.9794
# Epoch 38: val_mean_io_u improved from 0.96403 to 0.96431, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.0207 - mean_io_u: 0.9680 - dice_coeficient: 0.9794 - val_loss: 0.0250 - val_mean_io_u: 0.9643 - val_dice_coeficient: 0.9751
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0205 - mean_io_u: 0.9686 - dice_coeficient: 0.9795
# Epoch 39: val_mean_io_u improved from 0.96431 to 0.96488, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.0205 - mean_io_u: 0.9686 - dice_coeficient: 0.9795 - val_loss: 0.0248 - val_mean_io_u: 0.9649 - val_dice_coeficient: 0.9753
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0202 - mean_io_u: 0.9691 - dice_coeficient: 0.9798
# Epoch 40: val_mean_io_u improved from 0.96488 to 0.96550, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0202 - mean_io_u: 0.9691 - dice_coeficient: 0.9798 - val_loss: 0.0244 - val_mean_io_u: 0.9655 - val_dice_coeficient: 0.9757
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0200 - mean_io_u: 0.9697 - dice_coeficient: 0.9800
# Epoch 41: val_mean_io_u improved from 0.96550 to 0.96624, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.0200 - mean_io_u: 0.9697 - dice_coeficient: 0.9800 - val_loss: 0.0242 - val_mean_io_u: 0.9662 - val_dice_coeficient: 0.9759
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0197 - mean_io_u: 0.9703 - dice_coeficient: 0.9803
# Epoch 42: val_mean_io_u improved from 0.96624 to 0.96633, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0197 - mean_io_u: 0.9703 - dice_coeficient: 0.9803 - val_loss: 0.0243 - val_mean_io_u: 0.9663 - val_dice_coeficient: 0.9758
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0195 - mean_io_u: 0.9709 - dice_coeficient: 0.9805
# Epoch 43: val_mean_io_u improved from 0.96633 to 0.96700, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.0195 - mean_io_u: 0.9709 - dice_coeficient: 0.9805 - val_loss: 0.0239 - val_mean_io_u: 0.9670 - val_dice_coeficient: 0.9762
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0193 - mean_io_u: 0.9715 - dice_coeficient: 0.9807
# Epoch 44: val_mean_io_u improved from 0.96700 to 0.96766, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0193 - mean_io_u: 0.9715 - dice_coeficient: 0.9807 - val_loss: 0.0237 - val_mean_io_u: 0.9677 - val_dice_coeficient: 0.9764
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0191 - mean_io_u: 0.9718 - dice_coeficient: 0.9809
# Epoch 45: val_mean_io_u did not improve from 0.96766
# 51/51 [==============================] - 17s 330ms/step - loss: 0.0191 - mean_io_u: 0.9718 - dice_coeficient: 0.9809 - val_loss: 0.0238 - val_mean_io_u: 0.9677 - val_dice_coeficient: 0.9763
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0189 - mean_io_u: 0.9723 - dice_coeficient: 0.9811
# Epoch 46: val_mean_io_u improved from 0.96766 to 0.96791, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.0189 - mean_io_u: 0.9723 - dice_coeficient: 0.9811 - val_loss: 0.0235 - val_mean_io_u: 0.9679 - val_dice_coeficient: 0.9765
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0185 - mean_io_u: 0.9730 - dice_coeficient: 0.9815
# Epoch 47: val_mean_io_u improved from 0.96791 to 0.96880, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.0185 - mean_io_u: 0.9730 - dice_coeficient: 0.9815 - val_loss: 0.0233 - val_mean_io_u: 0.9688 - val_dice_coeficient: 0.9768
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0184 - mean_io_u: 0.9735 - dice_coeficient: 0.9816
# Epoch 48: val_mean_io_u improved from 0.96880 to 0.96944, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0184 - mean_io_u: 0.9735 - dice_coeficient: 0.9816 - val_loss: 0.0230 - val_mean_io_u: 0.9694 - val_dice_coeficient: 0.9770
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0181 - mean_io_u: 0.9740 - dice_coeficient: 0.9818
# Epoch 49: val_mean_io_u improved from 0.96944 to 0.96982, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0181 - mean_io_u: 0.9740 - dice_coeficient: 0.9818 - val_loss: 0.0229 - val_mean_io_u: 0.9698 - val_dice_coeficient: 0.9772
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0179 - mean_io_u: 0.9744 - dice_coeficient: 0.9821
# Epoch 50: val_mean_io_u improved from 0.96982 to 0.96997, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0179 - mean_io_u: 0.9744 - dice_coeficient: 0.9821 - val_loss: 0.0228 - val_mean_io_u: 0.9700 - val_dice_coeficient: 0.9773
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0179 - mean_io_u: 0.9746 - dice_coeficient: 0.9821
# Epoch 51: val_mean_io_u improved from 0.96997 to 0.97056, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0179 - mean_io_u: 0.9746 - dice_coeficient: 0.9821 - val_loss: 0.0225 - val_mean_io_u: 0.9706 - val_dice_coeficient: 0.9776
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0178 - mean_io_u: 0.9750 - dice_coeficient: 0.9822
# Epoch 52: val_mean_io_u improved from 0.97056 to 0.97075, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.0178 - mean_io_u: 0.9750 - dice_coeficient: 0.9822 - val_loss: 0.0225 - val_mean_io_u: 0.9708 - val_dice_coeficient: 0.9776
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0176 - mean_io_u: 0.9754 - dice_coeficient: 0.9824
# Epoch 53: val_mean_io_u improved from 0.97075 to 0.97079, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.0176 - mean_io_u: 0.9754 - dice_coeficient: 0.9824 - val_loss: 0.0225 - val_mean_io_u: 0.9708 - val_dice_coeficient: 0.9776
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0176 - mean_io_u: 0.9756 - dice_coeficient: 0.9824
# Epoch 54: val_mean_io_u improved from 0.97079 to 0.97095, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0176 - mean_io_u: 0.9756 - dice_coeficient: 0.9824 - val_loss: 0.0225 - val_mean_io_u: 0.9710 - val_dice_coeficient: 0.9776
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0175 - mean_io_u: 0.9759 - dice_coeficient: 0.9825
# Epoch 55: val_mean_io_u improved from 0.97095 to 0.97156, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 337ms/step - loss: 0.0175 - mean_io_u: 0.9759 - dice_coeficient: 0.9825 - val_loss: 0.0223 - val_mean_io_u: 0.9716 - val_dice_coeficient: 0.9778
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0173 - mean_io_u: 0.9762 - dice_coeficient: 0.9827
# Epoch 56: val_mean_io_u did not improve from 0.97156
# 51/51 [==============================] - 17s 332ms/step - loss: 0.0173 - mean_io_u: 0.9762 - dice_coeficient: 0.9827 - val_loss: 0.0224 - val_mean_io_u: 0.9716 - val_dice_coeficient: 0.9776
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0173 - mean_io_u: 0.9765 - dice_coeficient: 0.9827
# Epoch 57: val_mean_io_u did not improve from 0.97156
# 51/51 [==============================] - 17s 332ms/step - loss: 0.0173 - mean_io_u: 0.9765 - dice_coeficient: 0.9827 - val_loss: 0.0225 - val_mean_io_u: 0.9715 - val_dice_coeficient: 0.9776
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0173 - mean_io_u: 0.9766 - dice_coeficient: 0.9827
# Epoch 58: val_mean_io_u improved from 0.97156 to 0.97195, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 338ms/step - loss: 0.0173 - mean_io_u: 0.9766 - dice_coeficient: 0.9827 - val_loss: 0.0223 - val_mean_io_u: 0.9719 - val_dice_coeficient: 0.9778
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0171 - mean_io_u: 0.9770 - dice_coeficient: 0.9829
# Epoch 59: val_mean_io_u improved from 0.97195 to 0.97212, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 337ms/step - loss: 0.0171 - mean_io_u: 0.9770 - dice_coeficient: 0.9829 - val_loss: 0.0224 - val_mean_io_u: 0.9721 - val_dice_coeficient: 0.9777
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0171 - mean_io_u: 0.9772 - dice_coeficient: 0.9829
# Epoch 60: val_mean_io_u did not improve from 0.97212
# 51/51 [==============================] - 17s 332ms/step - loss: 0.0171 - mean_io_u: 0.9772 - dice_coeficient: 0.9829 - val_loss: 0.0225 - val_mean_io_u: 0.9721 - val_dice_coeficient: 0.9776
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0171 - mean_io_u: 0.9775 - dice_coeficient: 0.9829
# Epoch 61: val_mean_io_u improved from 0.97212 to 0.97263, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 338ms/step - loss: 0.0171 - mean_io_u: 0.9775 - dice_coeficient: 0.9829 - val_loss: 0.0222 - val_mean_io_u: 0.9726 - val_dice_coeficient: 0.9779
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0169 - mean_io_u: 0.9778 - dice_coeficient: 0.9831
# Epoch 62: val_mean_io_u did not improve from 0.97263
# 51/51 [==============================] - 17s 331ms/step - loss: 0.0169 - mean_io_u: 0.9778 - dice_coeficient: 0.9831 - val_loss: 0.0223 - val_mean_io_u: 0.9726 - val_dice_coeficient: 0.9778
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0170 - mean_io_u: 0.9777 - dice_coeficient: 0.9829
# Epoch 63: val_mean_io_u improved from 0.97263 to 0.97276, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 338ms/step - loss: 0.0170 - mean_io_u: 0.9777 - dice_coeficient: 0.9829 - val_loss: 0.0223 - val_mean_io_u: 0.9728 - val_dice_coeficient: 0.9778
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0170 - mean_io_u: 0.9780 - dice_coeficient: 0.9830
# Epoch 64: val_mean_io_u did not improve from 0.97276
# 51/51 [==============================] - 17s 333ms/step - loss: 0.0170 - mean_io_u: 0.9780 - dice_coeficient: 0.9830 - val_loss: 0.0224 - val_mean_io_u: 0.9728 - val_dice_coeficient: 0.9777
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0169 - mean_io_u: 0.9781 - dice_coeficient: 0.9831
# Epoch 65: val_mean_io_u improved from 0.97276 to 0.97316, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 338ms/step - loss: 0.0169 - mean_io_u: 0.9781 - dice_coeficient: 0.9831 - val_loss: 0.0222 - val_mean_io_u: 0.9732 - val_dice_coeficient: 0.9779
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0170 - mean_io_u: 0.9783 - dice_coeficient: 0.9830
# Epoch 66: val_mean_io_u did not improve from 0.97316
# 51/51 [==============================] - 17s 333ms/step - loss: 0.0170 - mean_io_u: 0.9783 - dice_coeficient: 0.9830 - val_loss: 0.0227 - val_mean_io_u: 0.9728 - val_dice_coeficient: 0.9774
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0170 - mean_io_u: 0.9784 - dice_coeficient: 0.9830
# Epoch 67: val_mean_io_u improved from 0.97316 to 0.97334, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 339ms/step - loss: 0.0170 - mean_io_u: 0.9784 - dice_coeficient: 0.9830 - val_loss: 0.0222 - val_mean_io_u: 0.9733 - val_dice_coeficient: 0.9779
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9787 - dice_coeficient: 0.9833
# Epoch 68: val_mean_io_u improved from 0.97334 to 0.97365, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.0168 - mean_io_u: 0.9787 - dice_coeficient: 0.9833 - val_loss: 0.0221 - val_mean_io_u: 0.9736 - val_dice_coeficient: 0.9780
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9789 - dice_coeficient: 0.9833
# Epoch 69: val_mean_io_u improved from 0.97365 to 0.97372, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0167 - mean_io_u: 0.9789 - dice_coeficient: 0.9833 - val_loss: 0.0221 - val_mean_io_u: 0.9737 - val_dice_coeficient: 0.9780
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9790 - dice_coeficient: 0.9832
# Epoch 70: val_mean_io_u improved from 0.97372 to 0.97379, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 337ms/step - loss: 0.0168 - mean_io_u: 0.9790 - dice_coeficient: 0.9832 - val_loss: 0.0221 - val_mean_io_u: 0.9738 - val_dice_coeficient: 0.9780
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9792 - dice_coeficient: 0.9833
# Epoch 71: val_mean_io_u improved from 0.97379 to 0.97384, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 337ms/step - loss: 0.0167 - mean_io_u: 0.9792 - dice_coeficient: 0.9833 - val_loss: 0.0220 - val_mean_io_u: 0.9738 - val_dice_coeficient: 0.9780
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9793 - dice_coeficient: 0.9833
# Epoch 72: val_mean_io_u did not improve from 0.97384
# 51/51 [==============================] - 17s 332ms/step - loss: 0.0166 - mean_io_u: 0.9793 - dice_coeficient: 0.9833 - val_loss: 0.0222 - val_mean_io_u: 0.9738 - val_dice_coeficient: 0.9779
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9794 - dice_coeficient: 0.9833
# Epoch 73: val_mean_io_u improved from 0.97384 to 0.97407, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.0167 - mean_io_u: 0.9794 - dice_coeficient: 0.9833 - val_loss: 0.0221 - val_mean_io_u: 0.9741 - val_dice_coeficient: 0.9779
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9795 - dice_coeficient: 0.9833
# Epoch 74: val_mean_io_u did not improve from 0.97407
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0166 - mean_io_u: 0.9795 - dice_coeficient: 0.9833 - val_loss: 0.0225 - val_mean_io_u: 0.9737 - val_dice_coeficient: 0.9776
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9794 - dice_coeficient: 0.9832
# Epoch 75: val_mean_io_u did not improve from 0.97407
# 51/51 [==============================] - 17s 333ms/step - loss: 0.0168 - mean_io_u: 0.9794 - dice_coeficient: 0.9832 - val_loss: 0.0222 - val_mean_io_u: 0.9740 - val_dice_coeficient: 0.9779
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9797 - dice_coeficient: 0.9833
# Epoch 76: val_mean_io_u improved from 0.97407 to 0.97448, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 339ms/step - loss: 0.0167 - mean_io_u: 0.9797 - dice_coeficient: 0.9833 - val_loss: 0.0219 - val_mean_io_u: 0.9745 - val_dice_coeficient: 0.9782
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.9799 - dice_coeficient: 0.9834
# Epoch 77: val_mean_io_u did not improve from 0.97448
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0166 - mean_io_u: 0.9799 - dice_coeficient: 0.9834 - val_loss: 0.0220 - val_mean_io_u: 0.9745 - val_dice_coeficient: 0.9780
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0165 - mean_io_u: 0.9800 - dice_coeficient: 0.9835
# Epoch 78: val_mean_io_u improved from 0.97448 to 0.97471, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 337ms/step - loss: 0.0165 - mean_io_u: 0.9800 - dice_coeficient: 0.9835 - val_loss: 0.0220 - val_mean_io_u: 0.9747 - val_dice_coeficient: 0.9781
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0165 - mean_io_u: 0.9801 - dice_coeficient: 0.9835
# Epoch 79: val_mean_io_u did not improve from 0.97471
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0165 - mean_io_u: 0.9801 - dice_coeficient: 0.9835 - val_loss: 0.0221 - val_mean_io_u: 0.9747 - val_dice_coeficient: 0.9780
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0165 - mean_io_u: 0.9801 - dice_coeficient: 0.9835
# Epoch 80: val_mean_io_u did not improve from 0.97471
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0165 - mean_io_u: 0.9801 - dice_coeficient: 0.9835 - val_loss: 0.0221 - val_mean_io_u: 0.9746 - val_dice_coeficient: 0.9779
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9800 - dice_coeficient: 0.9833
# Epoch 81: val_mean_io_u did not improve from 0.97471
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0167 - mean_io_u: 0.9800 - dice_coeficient: 0.9833 - val_loss: 0.0222 - val_mean_io_u: 0.9746 - val_dice_coeficient: 0.9778
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9800 - dice_coeficient: 0.9832
# Epoch 82: val_mean_io_u improved from 0.97471 to 0.97479, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 339ms/step - loss: 0.0168 - mean_io_u: 0.9800 - dice_coeficient: 0.9832 - val_loss: 0.0222 - val_mean_io_u: 0.9748 - val_dice_coeficient: 0.9779
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9801 - dice_coeficient: 0.9832
# Epoch 83: val_mean_io_u did not improve from 0.97479
# 51/51 [==============================] - 17s 336ms/step - loss: 0.0168 - mean_io_u: 0.9801 - dice_coeficient: 0.9832 - val_loss: 0.0221 - val_mean_io_u: 0.9747 - val_dice_coeficient: 0.9779
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9803 - dice_coeficient: 0.9833
# Epoch 84: val_mean_io_u improved from 0.97479 to 0.97481, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 340ms/step - loss: 0.0167 - mean_io_u: 0.9803 - dice_coeficient: 0.9833 - val_loss: 0.0222 - val_mean_io_u: 0.9748 - val_dice_coeficient: 0.9778
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9804 - dice_coeficient: 0.9833
# Epoch 85: val_mean_io_u improved from 0.97481 to 0.97484, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 340ms/step - loss: 0.0167 - mean_io_u: 0.9804 - dice_coeficient: 0.9833 - val_loss: 0.0223 - val_mean_io_u: 0.9748 - val_dice_coeficient: 0.9778
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9805 - dice_coeficient: 0.9833
# Epoch 86: val_mean_io_u improved from 0.97484 to 0.97515, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 339ms/step - loss: 0.0167 - mean_io_u: 0.9805 - dice_coeficient: 0.9833 - val_loss: 0.0220 - val_mean_io_u: 0.9751 - val_dice_coeficient: 0.9781
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9805 - dice_coeficient: 0.9833
# Epoch 87: val_mean_io_u did not improve from 0.97515
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0167 - mean_io_u: 0.9805 - dice_coeficient: 0.9833 - val_loss: 0.0225 - val_mean_io_u: 0.9746 - val_dice_coeficient: 0.9776
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9804 - dice_coeficient: 0.9832
# Epoch 88: val_mean_io_u did not improve from 0.97515
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0168 - mean_io_u: 0.9804 - dice_coeficient: 0.9832 - val_loss: 0.0225 - val_mean_io_u: 0.9748 - val_dice_coeficient: 0.9776
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9806 - dice_coeficient: 0.9833
# Epoch 89: val_mean_io_u did not improve from 0.97515
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0167 - mean_io_u: 0.9806 - dice_coeficient: 0.9833 - val_loss: 0.0222 - val_mean_io_u: 0.9751 - val_dice_coeficient: 0.9779
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9807 - dice_coeficient: 0.9833
# Epoch 90: val_mean_io_u improved from 0.97515 to 0.97517, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 340ms/step - loss: 0.0167 - mean_io_u: 0.9807 - dice_coeficient: 0.9833 - val_loss: 0.0222 - val_mean_io_u: 0.9752 - val_dice_coeficient: 0.9779
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0165 - mean_io_u: 0.9809 - dice_coeficient: 0.9835
# Epoch 91: val_mean_io_u improved from 0.97517 to 0.97528, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 339ms/step - loss: 0.0165 - mean_io_u: 0.9809 - dice_coeficient: 0.9835 - val_loss: 0.0221 - val_mean_io_u: 0.9753 - val_dice_coeficient: 0.9780
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9808 - dice_coeficient: 0.9833
# Epoch 92: val_mean_io_u did not improve from 0.97528
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0167 - mean_io_u: 0.9808 - dice_coeficient: 0.9833 - val_loss: 0.0223 - val_mean_io_u: 0.9751 - val_dice_coeficient: 0.9778
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0170 - mean_io_u: 0.9805 - dice_coeficient: 0.9830
# Epoch 93: val_mean_io_u did not improve from 0.97528
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0170 - mean_io_u: 0.9805 - dice_coeficient: 0.9830 - val_loss: 0.0227 - val_mean_io_u: 0.9748 - val_dice_coeficient: 0.9774
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0169 - mean_io_u: 0.9806 - dice_coeficient: 0.9831
# Epoch 94: val_mean_io_u did not improve from 0.97528
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0169 - mean_io_u: 0.9806 - dice_coeficient: 0.9831 - val_loss: 0.0224 - val_mean_io_u: 0.9751 - val_dice_coeficient: 0.9777
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0169 - mean_io_u: 0.9807 - dice_coeficient: 0.9831
# Epoch 95: val_mean_io_u did not improve from 0.97528
# 51/51 [==============================] - 17s 335ms/step - loss: 0.0169 - mean_io_u: 0.9807 - dice_coeficient: 0.9831 - val_loss: 0.0224 - val_mean_io_u: 0.9750 - val_dice_coeficient: 0.9776
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9808 - dice_coeficient: 0.9832
# Epoch 96: val_mean_io_u did not improve from 0.97528
# 51/51 [==============================] - 17s 336ms/step - loss: 0.0168 - mean_io_u: 0.9808 - dice_coeficient: 0.9832 - val_loss: 0.0225 - val_mean_io_u: 0.9751 - val_dice_coeficient: 0.9776
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9809 - dice_coeficient: 0.9832
# Epoch 97: val_mean_io_u did not improve from 0.97528
# 51/51 [==============================] - 17s 336ms/step - loss: 0.0168 - mean_io_u: 0.9809 - dice_coeficient: 0.9832 - val_loss: 0.0224 - val_mean_io_u: 0.9752 - val_dice_coeficient: 0.9777
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9809 - dice_coeficient: 0.9832
# Epoch 98: val_mean_io_u improved from 0.97528 to 0.97537, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 340ms/step - loss: 0.0168 - mean_io_u: 0.9809 - dice_coeficient: 0.9832 - val_loss: 0.0223 - val_mean_io_u: 0.9754 - val_dice_coeficient: 0.9778
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0168 - mean_io_u: 0.9810 - dice_coeficient: 0.9832
# Epoch 99: val_mean_io_u improved from 0.97537 to 0.97552, saving model to swin-unet_tversky.hdf5
# 51/51 [==============================] - 17s 339ms/step - loss: 0.0168 - mean_io_u: 0.9810 - dice_coeficient: 0.9832 - val_loss: 0.0222 - val_mean_io_u: 0.9755 - val_dice_coeficient: 0.9779
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.9811 - dice_coeficient: 0.9833
# Epoch 100: val_mean_io_u did not improve from 0.97552
# 51/51 [==============================] - 17s 334ms/step - loss: 0.0167 - mean_io_u: 0.9811 - dice_coeficient: 0.9833 - val_loss: 0.0226 - val_mean_io_u: 0.9751 - val_dice_coeficient: 0.9775

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='lower right')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 5s 46ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1), cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx], cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
