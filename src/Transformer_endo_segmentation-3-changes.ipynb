# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8154

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

# def dice_loss(y_true, y_pred):
#     return 1 - dice_coeficient(y_true, y_pred)

# def tversky(y_true, y_pred, smooth=1, alpha=0.8):
#     T = tf.keras.backend.flatten(y_true)
#     P = tf.keras.backend.flatten(y_pred)
#     TP = tf.keras.backend.sum(T * P)
#     FN = tf.keras.backend.sum(T * (1 - P))
#     FP = tf.keras.backend.sum((1 - T) * P)
#     return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


# def tversky_loss(y_true, y_pred):
#     return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, clipvalue=0.5, decay=1e-6), 
    loss=sm.losses.DiceLoss(),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_train_Weights.hdf5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto'
)

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.7862 - mean_io_u: 0.4631 - dice_coeficient: 0.4397
# Epoch 1: val_loss improved from inf to 0.63085, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 40s 382ms/step - loss: 0.7862 - mean_io_u: 0.4631 - dice_coeficient: 0.4397 - val_loss: 0.6308 - val_mean_io_u: 0.4721 - val_dice_coeficient: 0.6558
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5339 - mean_io_u: 0.5066 - dice_coeficient: 0.7223
# Epoch 2: val_loss improved from 0.63085 to 0.45510, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 310ms/step - loss: 0.5339 - mean_io_u: 0.5066 - dice_coeficient: 0.7223 - val_loss: 0.4551 - val_mean_io_u: 0.5475 - val_dice_coeficient: 0.7668
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4134 - mean_io_u: 0.5832 - dice_coeficient: 0.7928
# Epoch 3: val_loss improved from 0.45510 to 0.37599, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 318ms/step - loss: 0.4134 - mean_io_u: 0.5832 - dice_coeficient: 0.7928 - val_loss: 0.3760 - val_mean_io_u: 0.6140 - val_dice_coeficient: 0.8163
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3632 - mean_io_u: 0.6326 - dice_coeficient: 0.8232
# Epoch 4: val_loss improved from 0.37599 to 0.34222, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 329ms/step - loss: 0.3632 - mean_io_u: 0.6326 - dice_coeficient: 0.8232 - val_loss: 0.3422 - val_mean_io_u: 0.6471 - val_dice_coeficient: 0.8313
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3256 - mean_io_u: 0.6604 - dice_coeficient: 0.8413
# Epoch 5: val_loss improved from 0.34222 to 0.31330, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.3256 - mean_io_u: 0.6604 - dice_coeficient: 0.8413 - val_loss: 0.3133 - val_mean_io_u: 0.6785 - val_dice_coeficient: 0.8526
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3021 - mean_io_u: 0.6892 - dice_coeficient: 0.8563
# Epoch 6: val_loss improved from 0.31330 to 0.29965, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 340ms/step - loss: 0.3021 - mean_io_u: 0.6892 - dice_coeficient: 0.8563 - val_loss: 0.2996 - val_mean_io_u: 0.6996 - val_dice_coeficient: 0.8586
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2926 - mean_io_u: 0.7072 - dice_coeficient: 0.8635
# Epoch 7: val_loss improved from 0.29965 to 0.28905, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 344ms/step - loss: 0.2926 - mean_io_u: 0.7072 - dice_coeficient: 0.8635 - val_loss: 0.2890 - val_mean_io_u: 0.7090 - val_dice_coeficient: 0.8651
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2810 - mean_io_u: 0.7200 - dice_coeficient: 0.8687
# Epoch 8: val_loss improved from 0.28905 to 0.28004, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 346ms/step - loss: 0.2810 - mean_io_u: 0.7200 - dice_coeficient: 0.8687 - val_loss: 0.2800 - val_mean_io_u: 0.7240 - val_dice_coeficient: 0.8704
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2737 - mean_io_u: 0.7317 - dice_coeficient: 0.8736
# Epoch 9: val_loss improved from 0.28004 to 0.27444, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 349ms/step - loss: 0.2737 - mean_io_u: 0.7317 - dice_coeficient: 0.8736 - val_loss: 0.2744 - val_mean_io_u: 0.7387 - val_dice_coeficient: 0.8736
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2687 - mean_io_u: 0.7431 - dice_coeficient: 0.8758
# Epoch 10: val_loss improved from 0.27444 to 0.27055, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 353ms/step - loss: 0.2687 - mean_io_u: 0.7431 - dice_coeficient: 0.8758 - val_loss: 0.2706 - val_mean_io_u: 0.7467 - val_dice_coeficient: 0.8764
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2618 - mean_io_u: 0.7550 - dice_coeficient: 0.8799
# Epoch 11: val_loss improved from 0.27055 to 0.26387, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 354ms/step - loss: 0.2618 - mean_io_u: 0.7550 - dice_coeficient: 0.8799 - val_loss: 0.2639 - val_mean_io_u: 0.7583 - val_dice_coeficient: 0.8814
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2627 - mean_io_u: 0.7611 - dice_coeficient: 0.8827
# Epoch 12: val_loss improved from 0.26387 to 0.25698, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 356ms/step - loss: 0.2627 - mean_io_u: 0.7611 - dice_coeficient: 0.8827 - val_loss: 0.2570 - val_mean_io_u: 0.7613 - val_dice_coeficient: 0.8830
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2485 - mean_io_u: 0.7660 - dice_coeficient: 0.8851
# Epoch 13: val_loss improved from 0.25698 to 0.24778, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 362ms/step - loss: 0.2485 - mean_io_u: 0.7660 - dice_coeficient: 0.8851 - val_loss: 0.2478 - val_mean_io_u: 0.7677 - val_dice_coeficient: 0.8857
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2450 - mean_io_u: 0.7728 - dice_coeficient: 0.8880
# Epoch 14: val_loss improved from 0.24778 to 0.24367, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 361ms/step - loss: 0.2450 - mean_io_u: 0.7728 - dice_coeficient: 0.8880 - val_loss: 0.2437 - val_mean_io_u: 0.7748 - val_dice_coeficient: 0.8884
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2363 - mean_io_u: 0.7760 - dice_coeficient: 0.8905
# Epoch 15: val_loss improved from 0.24367 to 0.23644, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 360ms/step - loss: 0.2363 - mean_io_u: 0.7760 - dice_coeficient: 0.8905 - val_loss: 0.2364 - val_mean_io_u: 0.7780 - val_dice_coeficient: 0.8901
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2311 - mean_io_u: 0.7825 - dice_coeficient: 0.8930
# Epoch 16: val_loss improved from 0.23644 to 0.22790, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 363ms/step - loss: 0.2311 - mean_io_u: 0.7825 - dice_coeficient: 0.8930 - val_loss: 0.2279 - val_mean_io_u: 0.7847 - val_dice_coeficient: 0.8930
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2230 - mean_io_u: 0.7887 - dice_coeficient: 0.8958
# Epoch 17: val_loss improved from 0.22790 to 0.22526, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 357ms/step - loss: 0.2230 - mean_io_u: 0.7887 - dice_coeficient: 0.8958 - val_loss: 0.2253 - val_mean_io_u: 0.7902 - val_dice_coeficient: 0.8950
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2255 - mean_io_u: 0.7931 - dice_coeficient: 0.8961
# Epoch 18: val_loss did not improve from 0.22526
# 51/51 [==============================] - 18s 353ms/step - loss: 0.2255 - mean_io_u: 0.7931 - dice_coeficient: 0.8961 - val_loss: 0.2272 - val_mean_io_u: 0.7944 - val_dice_coeficient: 0.8944
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2170 - mean_io_u: 0.7990 - dice_coeficient: 0.8982
# Epoch 19: val_loss improved from 0.22526 to 0.21885, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.2170 - mean_io_u: 0.7990 - dice_coeficient: 0.8982 - val_loss: 0.2188 - val_mean_io_u: 0.8014 - val_dice_coeficient: 0.8989
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2115 - mean_io_u: 0.8048 - dice_coeficient: 0.9013
# Epoch 20: val_loss improved from 0.21885 to 0.21617, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 363ms/step - loss: 0.2115 - mean_io_u: 0.8048 - dice_coeficient: 0.9013 - val_loss: 0.2162 - val_mean_io_u: 0.8024 - val_dice_coeficient: 0.9004
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2115 - mean_io_u: 0.8081 - dice_coeficient: 0.9027
# Epoch 21: val_loss improved from 0.21617 to 0.21450, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 353ms/step - loss: 0.2115 - mean_io_u: 0.8081 - dice_coeficient: 0.9027 - val_loss: 0.2145 - val_mean_io_u: 0.8078 - val_dice_coeficient: 0.9014
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2075 - mean_io_u: 0.8121 - dice_coeficient: 0.9047
# Epoch 22: val_loss improved from 0.21450 to 0.20769, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 368ms/step - loss: 0.2075 - mean_io_u: 0.8121 - dice_coeficient: 0.9047 - val_loss: 0.2077 - val_mean_io_u: 0.8179 - val_dice_coeficient: 0.9090
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1994 - mean_io_u: 0.8226 - dice_coeficient: 0.9153
# Epoch 23: val_loss improved from 0.20769 to 0.20476, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 365ms/step - loss: 0.1994 - mean_io_u: 0.8226 - dice_coeficient: 0.9153 - val_loss: 0.2048 - val_mean_io_u: 0.8235 - val_dice_coeficient: 0.9153
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2047 - mean_io_u: 0.8235 - dice_coeficient: 0.9146
# Epoch 24: val_loss did not improve from 0.20476
# 51/51 [==============================] - 18s 358ms/step - loss: 0.2047 - mean_io_u: 0.8235 - dice_coeficient: 0.9146 - val_loss: 0.2054 - val_mean_io_u: 0.8246 - val_dice_coeficient: 0.9140
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1979 - mean_io_u: 0.8288 - dice_coeficient: 0.9178
# Epoch 25: val_loss improved from 0.20476 to 0.20052, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1979 - mean_io_u: 0.8288 - dice_coeficient: 0.9178 - val_loss: 0.2005 - val_mean_io_u: 0.8298 - val_dice_coeficient: 0.9162
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1942 - mean_io_u: 0.8328 - dice_coeficient: 0.9197
# Epoch 26: val_loss improved from 0.20052 to 0.20029, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1942 - mean_io_u: 0.8328 - dice_coeficient: 0.9197 - val_loss: 0.2003 - val_mean_io_u: 0.8314 - val_dice_coeficient: 0.9174
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1929 - mean_io_u: 0.8357 - dice_coeficient: 0.9206
# Epoch 27: val_loss improved from 0.20029 to 0.19535, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 368ms/step - loss: 0.1929 - mean_io_u: 0.8357 - dice_coeficient: 0.9206 - val_loss: 0.1954 - val_mean_io_u: 0.8368 - val_dice_coeficient: 0.9198
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1877 - mean_io_u: 0.8391 - dice_coeficient: 0.9224
# Epoch 28: val_loss did not improve from 0.19535
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1877 - mean_io_u: 0.8391 - dice_coeficient: 0.9224 - val_loss: 0.1967 - val_mean_io_u: 0.8394 - val_dice_coeficient: 0.9207
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1923 - mean_io_u: 0.8418 - dice_coeficient: 0.9236
# Epoch 29: val_loss improved from 0.19535 to 0.19369, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.1923 - mean_io_u: 0.8418 - dice_coeficient: 0.9236 - val_loss: 0.1937 - val_mean_io_u: 0.8411 - val_dice_coeficient: 0.9219
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1903 - mean_io_u: 0.8429 - dice_coeficient: 0.9224
# Epoch 30: val_loss improved from 0.19369 to 0.19146, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.1903 - mean_io_u: 0.8429 - dice_coeficient: 0.9224 - val_loss: 0.1915 - val_mean_io_u: 0.8444 - val_dice_coeficient: 0.9216
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1820 - mean_io_u: 0.8467 - dice_coeficient: 0.9249
# Epoch 31: val_loss improved from 0.19146 to 0.18937, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1820 - mean_io_u: 0.8467 - dice_coeficient: 0.9249 - val_loss: 0.1894 - val_mean_io_u: 0.8419 - val_dice_coeficient: 0.9216
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1822 - mean_io_u: 0.8483 - dice_coeficient: 0.9261
# Epoch 32: val_loss improved from 0.18937 to 0.18293, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1822 - mean_io_u: 0.8483 - dice_coeficient: 0.9261 - val_loss: 0.1829 - val_mean_io_u: 0.8506 - val_dice_coeficient: 0.9257
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1756 - mean_io_u: 0.8523 - dice_coeficient: 0.9287
# Epoch 33: val_loss improved from 0.18293 to 0.18108, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1756 - mean_io_u: 0.8523 - dice_coeficient: 0.9287 - val_loss: 0.1811 - val_mean_io_u: 0.8524 - val_dice_coeficient: 0.9271
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1737 - mean_io_u: 0.8539 - dice_coeficient: 0.9298
# Epoch 34: val_loss improved from 0.18108 to 0.18042, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1737 - mean_io_u: 0.8539 - dice_coeficient: 0.9298 - val_loss: 0.1804 - val_mean_io_u: 0.8528 - val_dice_coeficient: 0.9275
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1742 - mean_io_u: 0.8561 - dice_coeficient: 0.9305
# Epoch 35: val_loss improved from 0.18042 to 0.17964, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1742 - mean_io_u: 0.8561 - dice_coeficient: 0.9305 - val_loss: 0.1796 - val_mean_io_u: 0.8562 - val_dice_coeficient: 0.9279
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1710 - mean_io_u: 0.8573 - dice_coeficient: 0.9307
# Epoch 36: val_loss improved from 0.17964 to 0.17929, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1710 - mean_io_u: 0.8573 - dice_coeficient: 0.9307 - val_loss: 0.1793 - val_mean_io_u: 0.8548 - val_dice_coeficient: 0.9269
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1712 - mean_io_u: 0.8599 - dice_coeficient: 0.9324
# Epoch 37: val_loss improved from 0.17929 to 0.17357, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.1712 - mean_io_u: 0.8599 - dice_coeficient: 0.9324 - val_loss: 0.1736 - val_mean_io_u: 0.8596 - val_dice_coeficient: 0.9305
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1633 - mean_io_u: 0.8623 - dice_coeficient: 0.9340
# Epoch 38: val_loss did not improve from 0.17357
# 51/51 [==============================] - 18s 361ms/step - loss: 0.1633 - mean_io_u: 0.8623 - dice_coeficient: 0.9340 - val_loss: 0.1789 - val_mean_io_u: 0.8562 - val_dice_coeficient: 0.9271
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1667 - mean_io_u: 0.8629 - dice_coeficient: 0.9329
# Epoch 39: val_loss improved from 0.17357 to 0.17106, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1667 - mean_io_u: 0.8629 - dice_coeficient: 0.9329 - val_loss: 0.1711 - val_mean_io_u: 0.8642 - val_dice_coeficient: 0.9313
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1636 - mean_io_u: 0.8662 - dice_coeficient: 0.9349
# Epoch 40: val_loss improved from 0.17106 to 0.17076, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1636 - mean_io_u: 0.8662 - dice_coeficient: 0.9349 - val_loss: 0.1708 - val_mean_io_u: 0.8652 - val_dice_coeficient: 0.9320
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1630 - mean_io_u: 0.8674 - dice_coeficient: 0.9358
# Epoch 41: val_loss improved from 0.17076 to 0.16975, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1630 - mean_io_u: 0.8674 - dice_coeficient: 0.9358 - val_loss: 0.1697 - val_mean_io_u: 0.8664 - val_dice_coeficient: 0.9331
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1614 - mean_io_u: 0.8677 - dice_coeficient: 0.9358
# Epoch 42: val_loss did not improve from 0.16975
# 51/51 [==============================] - 19s 364ms/step - loss: 0.1614 - mean_io_u: 0.8677 - dice_coeficient: 0.9358 - val_loss: 0.1720 - val_mean_io_u: 0.8679 - val_dice_coeficient: 0.9327
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1626 - mean_io_u: 0.8702 - dice_coeficient: 0.9380
# Epoch 43: val_loss improved from 0.16975 to 0.16587, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.1626 - mean_io_u: 0.8702 - dice_coeficient: 0.9380 - val_loss: 0.1659 - val_mean_io_u: 0.8709 - val_dice_coeficient: 0.9364
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1576 - mean_io_u: 0.8735 - dice_coeficient: 0.9400
# Epoch 44: val_loss did not improve from 0.16587
# 51/51 [==============================] - 19s 368ms/step - loss: 0.1576 - mean_io_u: 0.8735 - dice_coeficient: 0.9400 - val_loss: 0.1663 - val_mean_io_u: 0.8728 - val_dice_coeficient: 0.9370
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1606 - mean_io_u: 0.8749 - dice_coeficient: 0.9408
# Epoch 45: val_loss improved from 0.16587 to 0.16453, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.1606 - mean_io_u: 0.8749 - dice_coeficient: 0.9408 - val_loss: 0.1645 - val_mean_io_u: 0.8748 - val_dice_coeficient: 0.9382
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1544 - mean_io_u: 0.8772 - dice_coeficient: 0.9424
# Epoch 46: val_loss improved from 0.16453 to 0.16199, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1544 - mean_io_u: 0.8772 - dice_coeficient: 0.9424 - val_loss: 0.1620 - val_mean_io_u: 0.8758 - val_dice_coeficient: 0.9394
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1550 - mean_io_u: 0.8785 - dice_coeficient: 0.9434
# Epoch 47: val_loss improved from 0.16199 to 0.16038, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.1550 - mean_io_u: 0.8785 - dice_coeficient: 0.9434 - val_loss: 0.1604 - val_mean_io_u: 0.8771 - val_dice_coeficient: 0.9402
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1497 - mean_io_u: 0.8815 - dice_coeficient: 0.9454
# Epoch 48: val_loss improved from 0.16038 to 0.15864, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.1497 - mean_io_u: 0.8815 - dice_coeficient: 0.9454 - val_loss: 0.1586 - val_mean_io_u: 0.8831 - val_dice_coeficient: 0.9464
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1520 - mean_io_u: 0.8900 - dice_coeficient: 0.9552
# Epoch 49: val_loss improved from 0.15864 to 0.15470, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.1520 - mean_io_u: 0.8900 - dice_coeficient: 0.9552 - val_loss: 0.1547 - val_mean_io_u: 0.8900 - val_dice_coeficient: 0.9532
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1457 - mean_io_u: 0.8922 - dice_coeficient: 0.9574
# Epoch 50: val_loss improved from 0.15470 to 0.15442, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1457 - mean_io_u: 0.8922 - dice_coeficient: 0.9574 - val_loss: 0.1544 - val_mean_io_u: 0.8910 - val_dice_coeficient: 0.9538
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1437 - mean_io_u: 0.8932 - dice_coeficient: 0.9582
# Epoch 51: val_loss improved from 0.15442 to 0.15332, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 375ms/step - loss: 0.1437 - mean_io_u: 0.8932 - dice_coeficient: 0.9582 - val_loss: 0.1533 - val_mean_io_u: 0.8911 - val_dice_coeficient: 0.9545
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1443 - mean_io_u: 0.8944 - dice_coeficient: 0.9589
# Epoch 52: val_loss improved from 0.15332 to 0.15279, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.1443 - mean_io_u: 0.8944 - dice_coeficient: 0.9589 - val_loss: 0.1528 - val_mean_io_u: 0.8927 - val_dice_coeficient: 0.9551
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1399 - mean_io_u: 0.8954 - dice_coeficient: 0.9593
# Epoch 53: val_loss did not improve from 0.15279
# 51/51 [==============================] - 19s 367ms/step - loss: 0.1399 - mean_io_u: 0.8954 - dice_coeficient: 0.9593 - val_loss: 0.1537 - val_mean_io_u: 0.8933 - val_dice_coeficient: 0.9549
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1468 - mean_io_u: 0.8964 - dice_coeficient: 0.9595
# Epoch 54: val_loss improved from 0.15279 to 0.15223, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.1468 - mean_io_u: 0.8964 - dice_coeficient: 0.9595 - val_loss: 0.1522 - val_mean_io_u: 0.8945 - val_dice_coeficient: 0.9550
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1396 - mean_io_u: 0.8968 - dice_coeficient: 0.9595
# Epoch 55: val_loss improved from 0.15223 to 0.15097, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1396 - mean_io_u: 0.8968 - dice_coeficient: 0.9595 - val_loss: 0.1510 - val_mean_io_u: 0.8959 - val_dice_coeficient: 0.9555
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1423 - mean_io_u: 0.8982 - dice_coeficient: 0.9598
# Epoch 56: val_loss improved from 0.15097 to 0.15054, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 375ms/step - loss: 0.1423 - mean_io_u: 0.8982 - dice_coeficient: 0.9598 - val_loss: 0.1505 - val_mean_io_u: 0.8963 - val_dice_coeficient: 0.9556
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1372 - mean_io_u: 0.8993 - dice_coeficient: 0.9604
# Epoch 57: val_loss improved from 0.15054 to 0.14969, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.1372 - mean_io_u: 0.8993 - dice_coeficient: 0.9604 - val_loss: 0.1497 - val_mean_io_u: 0.8982 - val_dice_coeficient: 0.9562
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1385 - mean_io_u: 0.9004 - dice_coeficient: 0.9609
# Epoch 58: val_loss improved from 0.14969 to 0.14810, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.1385 - mean_io_u: 0.9004 - dice_coeficient: 0.9609 - val_loss: 0.1481 - val_mean_io_u: 0.8990 - val_dice_coeficient: 0.9565
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1388 - mean_io_u: 0.9010 - dice_coeficient: 0.9610
# Epoch 59: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 368ms/step - loss: 0.1388 - mean_io_u: 0.9010 - dice_coeficient: 0.9610 - val_loss: 0.1499 - val_mean_io_u: 0.8989 - val_dice_coeficient: 0.9564
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1381 - mean_io_u: 0.9017 - dice_coeficient: 0.9609
# Epoch 60: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 365ms/step - loss: 0.1381 - mean_io_u: 0.9017 - dice_coeficient: 0.9609 - val_loss: 0.1507 - val_mean_io_u: 0.8996 - val_dice_coeficient: 0.9562
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1403 - mean_io_u: 0.9026 - dice_coeficient: 0.9612
# Epoch 61: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1403 - mean_io_u: 0.9026 - dice_coeficient: 0.9612 - val_loss: 0.1520 - val_mean_io_u: 0.8984 - val_dice_coeficient: 0.9553
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1487 - mean_io_u: 0.9001 - dice_coeficient: 0.9569
# Epoch 62: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 368ms/step - loss: 0.1487 - mean_io_u: 0.9001 - dice_coeficient: 0.9569 - val_loss: 0.1513 - val_mean_io_u: 0.9005 - val_dice_coeficient: 0.9550
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1407 - mean_io_u: 0.9041 - dice_coeficient: 0.9603
# Epoch 63: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1407 - mean_io_u: 0.9041 - dice_coeficient: 0.9603 - val_loss: 0.1509 - val_mean_io_u: 0.9024 - val_dice_coeficient: 0.9560
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1418 - mean_io_u: 0.9043 - dice_coeficient: 0.9596
# Epoch 64: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1418 - mean_io_u: 0.9043 - dice_coeficient: 0.9596 - val_loss: 0.1513 - val_mean_io_u: 0.9039 - val_dice_coeficient: 0.9563
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1427 - mean_io_u: 0.9065 - dice_coeficient: 0.9613
# Epoch 65: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 367ms/step - loss: 0.1427 - mean_io_u: 0.9065 - dice_coeficient: 0.9613 - val_loss: 0.1502 - val_mean_io_u: 0.9048 - val_dice_coeficient: 0.9569
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1409 - mean_io_u: 0.9059 - dice_coeficient: 0.9605
# Epoch 66: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 368ms/step - loss: 0.1409 - mean_io_u: 0.9059 - dice_coeficient: 0.9605 - val_loss: 0.1536 - val_mean_io_u: 0.9031 - val_dice_coeficient: 0.9544
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1454 - mean_io_u: 0.9051 - dice_coeficient: 0.9587
# Epoch 67: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 372ms/step - loss: 0.1454 - mean_io_u: 0.9051 - dice_coeficient: 0.9587 - val_loss: 0.1532 - val_mean_io_u: 0.9036 - val_dice_coeficient: 0.9543
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1424 - mean_io_u: 0.9072 - dice_coeficient: 0.9600
# Epoch 68: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 368ms/step - loss: 0.1424 - mean_io_u: 0.9072 - dice_coeficient: 0.9600 - val_loss: 0.1591 - val_mean_io_u: 0.8974 - val_dice_coeficient: 0.9466
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1476 - mean_io_u: 0.9007 - dice_coeficient: 0.9517
# Epoch 69: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1476 - mean_io_u: 0.9007 - dice_coeficient: 0.9517 - val_loss: 0.1548 - val_mean_io_u: 0.9056 - val_dice_coeficient: 0.9539
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1515 - mean_io_u: 0.9010 - dice_coeficient: 0.9515
# Epoch 70: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1515 - mean_io_u: 0.9010 - dice_coeficient: 0.9515 - val_loss: 0.1556 - val_mean_io_u: 0.9056 - val_dice_coeficient: 0.9526
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1465 - mean_io_u: 0.9091 - dice_coeficient: 0.9575
# Epoch 71: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1465 - mean_io_u: 0.9091 - dice_coeficient: 0.9575 - val_loss: 0.1510 - val_mean_io_u: 0.9075 - val_dice_coeficient: 0.9541
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1381 - mean_io_u: 0.9116 - dice_coeficient: 0.9598
# Epoch 72: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1381 - mean_io_u: 0.9116 - dice_coeficient: 0.9598 - val_loss: 0.1488 - val_mean_io_u: 0.9105 - val_dice_coeficient: 0.9562
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1339 - mean_io_u: 0.9137 - dice_coeficient: 0.9616
# Epoch 73: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 368ms/step - loss: 0.1339 - mean_io_u: 0.9137 - dice_coeficient: 0.9616 - val_loss: 0.1482 - val_mean_io_u: 0.9108 - val_dice_coeficient: 0.9567
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1431 - mean_io_u: 0.9131 - dice_coeficient: 0.9609
# Epoch 74: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 367ms/step - loss: 0.1431 - mean_io_u: 0.9131 - dice_coeficient: 0.9609 - val_loss: 0.1629 - val_mean_io_u: 0.9008 - val_dice_coeficient: 0.9458
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1597 - mean_io_u: 0.8975 - dice_coeficient: 0.9439
# Epoch 75: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1597 - mean_io_u: 0.8975 - dice_coeficient: 0.9439 - val_loss: 0.1543 - val_mean_io_u: 0.9075 - val_dice_coeficient: 0.9513
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1451 - mean_io_u: 0.9117 - dice_coeficient: 0.9562
# Epoch 76: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1451 - mean_io_u: 0.9117 - dice_coeficient: 0.9562 - val_loss: 0.1514 - val_mean_io_u: 0.9107 - val_dice_coeficient: 0.9537
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1440 - mean_io_u: 0.9109 - dice_coeficient: 0.9555
# Epoch 77: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1440 - mean_io_u: 0.9109 - dice_coeficient: 0.9555 - val_loss: 0.1524 - val_mean_io_u: 0.9103 - val_dice_coeficient: 0.9522
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1523 - mean_io_u: 0.9012 - dice_coeficient: 0.9462
# Epoch 78: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 372ms/step - loss: 0.1523 - mean_io_u: 0.9012 - dice_coeficient: 0.9462 - val_loss: 0.1837 - val_mean_io_u: 0.8838 - val_dice_coeficient: 0.9268
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1696 - mean_io_u: 0.8976 - dice_coeficient: 0.9370
# Epoch 79: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 372ms/step - loss: 0.1696 - mean_io_u: 0.8976 - dice_coeficient: 0.9370 - val_loss: 0.1609 - val_mean_io_u: 0.9088 - val_dice_coeficient: 0.9466
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1491 - mean_io_u: 0.9094 - dice_coeficient: 0.9494
# Epoch 80: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1491 - mean_io_u: 0.9094 - dice_coeficient: 0.9494 - val_loss: 0.1641 - val_mean_io_u: 0.9026 - val_dice_coeficient: 0.9423
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1482 - mean_io_u: 0.9126 - dice_coeficient: 0.9520
# Epoch 81: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1482 - mean_io_u: 0.9126 - dice_coeficient: 0.9520 - val_loss: 0.1531 - val_mean_io_u: 0.9132 - val_dice_coeficient: 0.9513
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1591 - mean_io_u: 0.9062 - dice_coeficient: 0.9433
# Epoch 82: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1591 - mean_io_u: 0.9062 - dice_coeficient: 0.9433 - val_loss: 0.1570 - val_mean_io_u: 0.9117 - val_dice_coeficient: 0.9477
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1460 - mean_io_u: 0.9168 - dice_coeficient: 0.9542
# Epoch 83: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1460 - mean_io_u: 0.9168 - dice_coeficient: 0.9542 - val_loss: 0.1516 - val_mean_io_u: 0.9160 - val_dice_coeficient: 0.9526
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1394 - mean_io_u: 0.9192 - dice_coeficient: 0.9572
# Epoch 84: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1394 - mean_io_u: 0.9192 - dice_coeficient: 0.9572 - val_loss: 0.1520 - val_mean_io_u: 0.9159 - val_dice_coeficient: 0.9528
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1348 - mean_io_u: 0.9201 - dice_coeficient: 0.9584
# Epoch 85: val_loss did not improve from 0.14810
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1348 - mean_io_u: 0.9201 - dice_coeficient: 0.9584 - val_loss: 0.1491 - val_mean_io_u: 0.9183 - val_dice_coeficient: 0.9551
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1359 - mean_io_u: 0.9214 - dice_coeficient: 0.9600
# Epoch 86: val_loss improved from 0.14810 to 0.14780, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.1359 - mean_io_u: 0.9214 - dice_coeficient: 0.9600 - val_loss: 0.1478 - val_mean_io_u: 0.9192 - val_dice_coeficient: 0.9559
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1343 - mean_io_u: 0.9217 - dice_coeficient: 0.9606
# Epoch 87: val_loss did not improve from 0.14780
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1343 - mean_io_u: 0.9217 - dice_coeficient: 0.9606 - val_loss: 0.1541 - val_mean_io_u: 0.9134 - val_dice_coeficient: 0.9496
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1455 - mean_io_u: 0.9135 - dice_coeficient: 0.9508
# Epoch 88: val_loss did not improve from 0.14780
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1455 - mean_io_u: 0.9135 - dice_coeficient: 0.9508 - val_loss: 0.1499 - val_mean_io_u: 0.9176 - val_dice_coeficient: 0.9532
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1353 - mean_io_u: 0.9214 - dice_coeficient: 0.9590
# Epoch 89: val_loss improved from 0.14780 to 0.14701, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.1353 - mean_io_u: 0.9214 - dice_coeficient: 0.9590 - val_loss: 0.1470 - val_mean_io_u: 0.9195 - val_dice_coeficient: 0.9552
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1366 - mean_io_u: 0.9215 - dice_coeficient: 0.9591
# Epoch 90: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1366 - mean_io_u: 0.9215 - dice_coeficient: 0.9591 - val_loss: 0.1481 - val_mean_io_u: 0.9193 - val_dice_coeficient: 0.9550
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1495 - mean_io_u: 0.9112 - dice_coeficient: 0.9485
# Epoch 91: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1495 - mean_io_u: 0.9112 - dice_coeficient: 0.9485 - val_loss: 0.1877 - val_mean_io_u: 0.8852 - val_dice_coeficient: 0.9189
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1603 - mean_io_u: 0.9040 - dice_coeficient: 0.9380
# Epoch 92: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1603 - mean_io_u: 0.9040 - dice_coeficient: 0.9380 - val_loss: 0.1824 - val_mean_io_u: 0.8860 - val_dice_coeficient: 0.9199
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1552 - mean_io_u: 0.9101 - dice_coeficient: 0.9422
# Epoch 93: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 372ms/step - loss: 0.1552 - mean_io_u: 0.9101 - dice_coeficient: 0.9422 - val_loss: 0.1547 - val_mean_io_u: 0.9147 - val_dice_coeficient: 0.9470
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1643 - mean_io_u: 0.9063 - dice_coeficient: 0.9389
# Epoch 94: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1643 - mean_io_u: 0.9063 - dice_coeficient: 0.9389 - val_loss: 0.1747 - val_mean_io_u: 0.9066 - val_dice_coeficient: 0.9346
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1572 - mean_io_u: 0.9153 - dice_coeficient: 0.9451
# Epoch 95: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1572 - mean_io_u: 0.9153 - dice_coeficient: 0.9451 - val_loss: 0.1598 - val_mean_io_u: 0.9161 - val_dice_coeficient: 0.9457
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1981 - mean_io_u: 0.8865 - dice_coeficient: 0.9153
# Epoch 96: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1981 - mean_io_u: 0.8865 - dice_coeficient: 0.9153 - val_loss: 0.2063 - val_mean_io_u: 0.8834 - val_dice_coeficient: 0.9098
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1807 - mean_io_u: 0.9016 - dice_coeficient: 0.9278
# Epoch 97: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1807 - mean_io_u: 0.9016 - dice_coeficient: 0.9278 - val_loss: 0.2048 - val_mean_io_u: 0.8861 - val_dice_coeficient: 0.9119
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1982 - mean_io_u: 0.8927 - dice_coeficient: 0.9174
# Epoch 98: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 374ms/step - loss: 0.1982 - mean_io_u: 0.8927 - dice_coeficient: 0.9174 - val_loss: 0.2580 - val_mean_io_u: 0.8386 - val_dice_coeficient: 0.8607
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1914 - mean_io_u: 0.8925 - dice_coeficient: 0.9164
# Epoch 99: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 371ms/step - loss: 0.1914 - mean_io_u: 0.8925 - dice_coeficient: 0.9164 - val_loss: 0.1756 - val_mean_io_u: 0.9079 - val_dice_coeficient: 0.9325
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1759 - mean_io_u: 0.9103 - dice_coeficient: 0.9357
# Epoch 100: val_loss did not improve from 0.14701
# 51/51 [==============================] - 19s 370ms/step - loss: 0.1759 - mean_io_u: 0.9103 - dice_coeficient: 0.9357 - val_loss: 0.1749 - val_mean_io_u: 0.9114 - val_dice_coeficient: 0.9355

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 6s 56ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx])
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
