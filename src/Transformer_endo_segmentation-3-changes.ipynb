# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8152

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4, clipvalue=0.5, decay=1e-6), 
    loss=tversky_loss,
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

# checkpoint = tf.keras.callbacks.ModelCheckpoint(
#     '../models/swin-unet_train_Weights.hdf5',
#     verbose=1,
#     save_best_only=True,
#     save_weights_only=True,
#     mode='auto'
# )

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    # callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - 35s 362ms/step - loss: 0.4418 - mean_io_u: 0.6157 - dice_coeficient: 0.5599 - val_loss: 0.2628 - val_mean_io_u: 0.7534 - val_dice_coeficient: 0.7379
# Epoch 2/100
# 51/51 [==============================] - 16s 307ms/step - loss: 0.2205 - mean_io_u: 0.7737 - dice_coeficient: 0.7799 - val_loss: 0.1836 - val_mean_io_u: 0.7804 - val_dice_coeficient: 0.8169
# Epoch 3/100
# 51/51 [==============================] - 16s 320ms/step - loss: 0.1567 - mean_io_u: 0.8080 - dice_coeficient: 0.8434 - val_loss: 0.1477 - val_mean_io_u: 0.8156 - val_dice_coeficient: 0.8528
# Epoch 4/100
# 51/51 [==============================] - 17s 328ms/step - loss: 0.1376 - mean_io_u: 0.8211 - dice_coeficient: 0.8623 - val_loss: 0.1323 - val_mean_io_u: 0.8234 - val_dice_coeficient: 0.8681
# Epoch 5/100
# 51/51 [==============================] - 17s 336ms/step - loss: 0.1253 - mean_io_u: 0.8271 - dice_coeficient: 0.8747 - val_loss: 0.1229 - val_mean_io_u: 0.8255 - val_dice_coeficient: 0.8776
# Epoch 6/100
# 51/51 [==============================] - 18s 346ms/step - loss: 0.1159 - mean_io_u: 0.8333 - dice_coeficient: 0.8842 - val_loss: 0.1136 - val_mean_io_u: 0.8370 - val_dice_coeficient: 0.8868
# Epoch 7/100
# 51/51 [==============================] - 18s 350ms/step - loss: 0.1087 - mean_io_u: 0.8423 - dice_coeficient: 0.8913 - val_loss: 0.1076 - val_mean_io_u: 0.8441 - val_dice_coeficient: 0.8929
# Epoch 8/100
# 51/51 [==============================] - 18s 357ms/step - loss: 0.1019 - mean_io_u: 0.8480 - dice_coeficient: 0.8982 - val_loss: 0.0995 - val_mean_io_u: 0.8506 - val_dice_coeficient: 0.9008
# Epoch 9/100
# 51/51 [==============================] - 18s 357ms/step - loss: 0.0912 - mean_io_u: 0.8547 - dice_coeficient: 0.9088 - val_loss: 0.0867 - val_mean_io_u: 0.8597 - val_dice_coeficient: 0.9136
# Epoch 10/100
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0826 - mean_io_u: 0.8659 - dice_coeficient: 0.9175 - val_loss: 0.0811 - val_mean_io_u: 0.8679 - val_dice_coeficient: 0.9192
# Epoch 11/100
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0787 - mean_io_u: 0.8726 - dice_coeficient: 0.9213 - val_loss: 0.0772 - val_mean_io_u: 0.8751 - val_dice_coeficient: 0.9231
# Epoch 12/100
# 51/51 [==============================] - 19s 367ms/step - loss: 0.0750 - mean_io_u: 0.8779 - dice_coeficient: 0.9250 - val_loss: 0.0738 - val_mean_io_u: 0.8806 - val_dice_coeficient: 0.9265
# Epoch 13/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0725 - mean_io_u: 0.8827 - dice_coeficient: 0.9274 - val_loss: 0.0725 - val_mean_io_u: 0.8832 - val_dice_coeficient: 0.9277
# Epoch 14/100
# 51/51 [==============================] - 18s 361ms/step - loss: 0.0709 - mean_io_u: 0.8859 - dice_coeficient: 0.9292 - val_loss: 0.0707 - val_mean_io_u: 0.8871 - val_dice_coeficient: 0.9295
# Epoch 15/100
# 51/51 [==============================] - 19s 370ms/step - loss: 0.0680 - mean_io_u: 0.8892 - dice_coeficient: 0.9320 - val_loss: 0.0669 - val_mean_io_u: 0.8906 - val_dice_coeficient: 0.9334
# Epoch 16/100
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0634 - mean_io_u: 0.8929 - dice_coeficient: 0.9367 - val_loss: 0.0627 - val_mean_io_u: 0.8947 - val_dice_coeficient: 0.9376
# Epoch 17/100
# 51/51 [==============================] - 19s 369ms/step - loss: 0.0587 - mean_io_u: 0.8979 - dice_coeficient: 0.9415 - val_loss: 0.0572 - val_mean_io_u: 0.9000 - val_dice_coeficient: 0.9430
# Epoch 18/100
# 51/51 [==============================] - 19s 367ms/step - loss: 0.0534 - mean_io_u: 0.9035 - dice_coeficient: 0.9466 - val_loss: 0.0547 - val_mean_io_u: 0.9033 - val_dice_coeficient: 0.9455
# Epoch 19/100
# 51/51 [==============================] - 19s 369ms/step - loss: 0.0492 - mean_io_u: 0.9075 - dice_coeficient: 0.9508 - val_loss: 0.0492 - val_mean_io_u: 0.9081 - val_dice_coeficient: 0.9510
# Epoch 20/100
# 51/51 [==============================] - 19s 370ms/step - loss: 0.0451 - mean_io_u: 0.9130 - dice_coeficient: 0.9549 - val_loss: 0.0473 - val_mean_io_u: 0.9126 - val_dice_coeficient: 0.9529
# Epoch 21/100
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0431 - mean_io_u: 0.9164 - dice_coeficient: 0.9569 - val_loss: 0.0453 - val_mean_io_u: 0.9162 - val_dice_coeficient: 0.9549
# Epoch 22/100
# 51/51 [==============================] - 19s 369ms/step - loss: 0.0417 - mean_io_u: 0.9195 - dice_coeficient: 0.9583 - val_loss: 0.0443 - val_mean_io_u: 0.9185 - val_dice_coeficient: 0.9558
# Epoch 23/100
# 51/51 [==============================] - 19s 369ms/step - loss: 0.0402 - mean_io_u: 0.9224 - dice_coeficient: 0.9598 - val_loss: 0.0434 - val_mean_io_u: 0.9208 - val_dice_coeficient: 0.9567
# Epoch 24/100
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0394 - mean_io_u: 0.9249 - dice_coeficient: 0.9605 - val_loss: 0.0432 - val_mean_io_u: 0.9236 - val_dice_coeficient: 0.9570
# Epoch 25/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0387 - mean_io_u: 0.9270 - dice_coeficient: 0.9613 - val_loss: 0.0422 - val_mean_io_u: 0.9259 - val_dice_coeficient: 0.9580
# Epoch 26/100
# 51/51 [==============================] - 19s 369ms/step - loss: 0.0380 - mean_io_u: 0.9290 - dice_coeficient: 0.9620 - val_loss: 0.0419 - val_mean_io_u: 0.9267 - val_dice_coeficient: 0.9582
# Epoch 27/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0374 - mean_io_u: 0.9307 - dice_coeficient: 0.9626 - val_loss: 0.0415 - val_mean_io_u: 0.9286 - val_dice_coeficient: 0.9587
# Epoch 28/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0367 - mean_io_u: 0.9324 - dice_coeficient: 0.9633 - val_loss: 0.0408 - val_mean_io_u: 0.9304 - val_dice_coeficient: 0.9594
# Epoch 29/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0363 - mean_io_u: 0.9337 - dice_coeficient: 0.9637 - val_loss: 0.0402 - val_mean_io_u: 0.9312 - val_dice_coeficient: 0.9600
# Epoch 30/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0354 - mean_io_u: 0.9354 - dice_coeficient: 0.9646 - val_loss: 0.0394 - val_mean_io_u: 0.9334 - val_dice_coeficient: 0.9607
# Epoch 31/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0347 - mean_io_u: 0.9371 - dice_coeficient: 0.9654 - val_loss: 0.0389 - val_mean_io_u: 0.9346 - val_dice_coeficient: 0.9613
# Epoch 32/100
# 51/51 [==============================] - 19s 369ms/step - loss: 0.0340 - mean_io_u: 0.9385 - dice_coeficient: 0.9660 - val_loss: 0.0384 - val_mean_io_u: 0.9365 - val_dice_coeficient: 0.9618
# Epoch 33/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0333 - mean_io_u: 0.9400 - dice_coeficient: 0.9667 - val_loss: 0.0381 - val_mean_io_u: 0.9371 - val_dice_coeficient: 0.9621
# Epoch 34/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0328 - mean_io_u: 0.9412 - dice_coeficient: 0.9672 - val_loss: 0.0372 - val_mean_io_u: 0.9385 - val_dice_coeficient: 0.9629
# Epoch 35/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0323 - mean_io_u: 0.9425 - dice_coeficient: 0.9678 - val_loss: 0.0371 - val_mean_io_u: 0.9394 - val_dice_coeficient: 0.9631
# Epoch 36/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0321 - mean_io_u: 0.9436 - dice_coeficient: 0.9679 - val_loss: 0.0369 - val_mean_io_u: 0.9410 - val_dice_coeficient: 0.9632
# Epoch 37/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0314 - mean_io_u: 0.9449 - dice_coeficient: 0.9685 - val_loss: 0.0363 - val_mean_io_u: 0.9413 - val_dice_coeficient: 0.9638
# Epoch 38/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0308 - mean_io_u: 0.9460 - dice_coeficient: 0.9692 - val_loss: 0.0360 - val_mean_io_u: 0.9430 - val_dice_coeficient: 0.9642
# Epoch 39/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0303 - mean_io_u: 0.9471 - dice_coeficient: 0.9696 - val_loss: 0.0357 - val_mean_io_u: 0.9430 - val_dice_coeficient: 0.9645
# Epoch 40/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0301 - mean_io_u: 0.9479 - dice_coeficient: 0.9699 - val_loss: 0.0351 - val_mean_io_u: 0.9445 - val_dice_coeficient: 0.9650
# Epoch 41/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0291 - mean_io_u: 0.9492 - dice_coeficient: 0.9709 - val_loss: 0.0339 - val_mean_io_u: 0.9460 - val_dice_coeficient: 0.9662
# Epoch 42/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0282 - mean_io_u: 0.9506 - dice_coeficient: 0.9718 - val_loss: 0.0330 - val_mean_io_u: 0.9471 - val_dice_coeficient: 0.9672
# Epoch 43/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0277 - mean_io_u: 0.9518 - dice_coeficient: 0.9723 - val_loss: 0.0328 - val_mean_io_u: 0.9481 - val_dice_coeficient: 0.9674
# Epoch 44/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0270 - mean_io_u: 0.9527 - dice_coeficient: 0.9730 - val_loss: 0.0324 - val_mean_io_u: 0.9488 - val_dice_coeficient: 0.9678
# Epoch 45/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0267 - mean_io_u: 0.9536 - dice_coeficient: 0.9733 - val_loss: 0.0324 - val_mean_io_u: 0.9493 - val_dice_coeficient: 0.9678
# Epoch 46/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0265 - mean_io_u: 0.9545 - dice_coeficient: 0.9735 - val_loss: 0.0321 - val_mean_io_u: 0.9500 - val_dice_coeficient: 0.9680
# Epoch 47/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0262 - mean_io_u: 0.9552 - dice_coeficient: 0.9738 - val_loss: 0.0316 - val_mean_io_u: 0.9514 - val_dice_coeficient: 0.9686
# Epoch 48/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0257 - mean_io_u: 0.9562 - dice_coeficient: 0.9743 - val_loss: 0.0312 - val_mean_io_u: 0.9521 - val_dice_coeficient: 0.9689
# Epoch 49/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0255 - mean_io_u: 0.9568 - dice_coeficient: 0.9745 - val_loss: 0.0310 - val_mean_io_u: 0.9529 - val_dice_coeficient: 0.9691
# Epoch 50/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0249 - mean_io_u: 0.9577 - dice_coeficient: 0.9751 - val_loss: 0.0310 - val_mean_io_u: 0.9531 - val_dice_coeficient: 0.9691
# Epoch 51/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0247 - mean_io_u: 0.9583 - dice_coeficient: 0.9754 - val_loss: 0.0301 - val_mean_io_u: 0.9542 - val_dice_coeficient: 0.9701
# Epoch 52/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0241 - mean_io_u: 0.9594 - dice_coeficient: 0.9759 - val_loss: 0.0299 - val_mean_io_u: 0.9547 - val_dice_coeficient: 0.9703
# Epoch 53/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0239 - mean_io_u: 0.9599 - dice_coeficient: 0.9762 - val_loss: 0.0298 - val_mean_io_u: 0.9556 - val_dice_coeficient: 0.9704
# Epoch 54/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0235 - mean_io_u: 0.9607 - dice_coeficient: 0.9765 - val_loss: 0.0293 - val_mean_io_u: 0.9564 - val_dice_coeficient: 0.9708
# Epoch 55/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0231 - mean_io_u: 0.9615 - dice_coeficient: 0.9769 - val_loss: 0.0291 - val_mean_io_u: 0.9570 - val_dice_coeficient: 0.9711
# Epoch 56/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0229 - mean_io_u: 0.9621 - dice_coeficient: 0.9771 - val_loss: 0.0289 - val_mean_io_u: 0.9573 - val_dice_coeficient: 0.9713
# Epoch 57/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0227 - mean_io_u: 0.9626 - dice_coeficient: 0.9773 - val_loss: 0.0290 - val_mean_io_u: 0.9578 - val_dice_coeficient: 0.9712
# Epoch 58/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0224 - mean_io_u: 0.9632 - dice_coeficient: 0.9775 - val_loss: 0.0283 - val_mean_io_u: 0.9586 - val_dice_coeficient: 0.9719
# Epoch 59/100
# 51/51 [==============================] - 19s 380ms/step - loss: 0.0221 - mean_io_u: 0.9639 - dice_coeficient: 0.9779 - val_loss: 0.0284 - val_mean_io_u: 0.9588 - val_dice_coeficient: 0.9717
# Epoch 60/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0218 - mean_io_u: 0.9644 - dice_coeficient: 0.9782 - val_loss: 0.0281 - val_mean_io_u: 0.9595 - val_dice_coeficient: 0.9720
# Epoch 61/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0213 - mean_io_u: 0.9652 - dice_coeficient: 0.9787 - val_loss: 0.0277 - val_mean_io_u: 0.9603 - val_dice_coeficient: 0.9724
# Epoch 62/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0209 - mean_io_u: 0.9658 - dice_coeficient: 0.9790 - val_loss: 0.0273 - val_mean_io_u: 0.9606 - val_dice_coeficient: 0.9728
# Epoch 63/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0205 - mean_io_u: 0.9666 - dice_coeficient: 0.9794 - val_loss: 0.0270 - val_mean_io_u: 0.9610 - val_dice_coeficient: 0.9731
# Epoch 64/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0203 - mean_io_u: 0.9670 - dice_coeficient: 0.9797 - val_loss: 0.0269 - val_mean_io_u: 0.9616 - val_dice_coeficient: 0.9732
# Epoch 65/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0200 - mean_io_u: 0.9675 - dice_coeficient: 0.9800 - val_loss: 0.0268 - val_mean_io_u: 0.9620 - val_dice_coeficient: 0.9733
# Epoch 66/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0198 - mean_io_u: 0.9680 - dice_coeficient: 0.9802 - val_loss: 0.0265 - val_mean_io_u: 0.9625 - val_dice_coeficient: 0.9736
# Epoch 67/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0195 - mean_io_u: 0.9685 - dice_coeficient: 0.9805 - val_loss: 0.0262 - val_mean_io_u: 0.9630 - val_dice_coeficient: 0.9739
# Epoch 68/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0195 - mean_io_u: 0.9688 - dice_coeficient: 0.9806 - val_loss: 0.0264 - val_mean_io_u: 0.9632 - val_dice_coeficient: 0.9737
# Epoch 69/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0193 - mean_io_u: 0.9692 - dice_coeficient: 0.9807 - val_loss: 0.0265 - val_mean_io_u: 0.9633 - val_dice_coeficient: 0.9736
# Epoch 70/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0192 - mean_io_u: 0.9696 - dice_coeficient: 0.9808 - val_loss: 0.0261 - val_mean_io_u: 0.9638 - val_dice_coeficient: 0.9740
# Epoch 71/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0189 - mean_io_u: 0.9701 - dice_coeficient: 0.9811 - val_loss: 0.0259 - val_mean_io_u: 0.9641 - val_dice_coeficient: 0.9742
# Epoch 72/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0188 - mean_io_u: 0.9704 - dice_coeficient: 0.9812 - val_loss: 0.0259 - val_mean_io_u: 0.9647 - val_dice_coeficient: 0.9742
# Epoch 73/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0187 - mean_io_u: 0.9708 - dice_coeficient: 0.9813 - val_loss: 0.0259 - val_mean_io_u: 0.9647 - val_dice_coeficient: 0.9742
# Epoch 74/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0187 - mean_io_u: 0.9710 - dice_coeficient: 0.9813 - val_loss: 0.0258 - val_mean_io_u: 0.9649 - val_dice_coeficient: 0.9743
# Epoch 75/100
# 51/51 [==============================] - 19s 379ms/step - loss: 0.0184 - mean_io_u: 0.9715 - dice_coeficient: 0.9816 - val_loss: 0.0256 - val_mean_io_u: 0.9653 - val_dice_coeficient: 0.9746
# Epoch 76/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0182 - mean_io_u: 0.9718 - dice_coeficient: 0.9818 - val_loss: 0.0257 - val_mean_io_u: 0.9653 - val_dice_coeficient: 0.9744
# Epoch 77/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0181 - mean_io_u: 0.9721 - dice_coeficient: 0.9819 - val_loss: 0.0256 - val_mean_io_u: 0.9659 - val_dice_coeficient: 0.9746
# Epoch 78/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0181 - mean_io_u: 0.9723 - dice_coeficient: 0.9819 - val_loss: 0.0254 - val_mean_io_u: 0.9660 - val_dice_coeficient: 0.9747
# Epoch 79/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0179 - mean_io_u: 0.9728 - dice_coeficient: 0.9821 - val_loss: 0.0256 - val_mean_io_u: 0.9661 - val_dice_coeficient: 0.9745
# Epoch 80/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0178 - mean_io_u: 0.9730 - dice_coeficient: 0.9822 - val_loss: 0.0252 - val_mean_io_u: 0.9666 - val_dice_coeficient: 0.9749
# Epoch 81/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0177 - mean_io_u: 0.9733 - dice_coeficient: 0.9823 - val_loss: 0.0254 - val_mean_io_u: 0.9665 - val_dice_coeficient: 0.9748
# Epoch 82/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0176 - mean_io_u: 0.9736 - dice_coeficient: 0.9824 - val_loss: 0.0252 - val_mean_io_u: 0.9668 - val_dice_coeficient: 0.9749
# Epoch 83/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0175 - mean_io_u: 0.9739 - dice_coeficient: 0.9825 - val_loss: 0.0250 - val_mean_io_u: 0.9673 - val_dice_coeficient: 0.9751
# Epoch 84/100
# 51/51 [==============================] - 19s 379ms/step - loss: 0.0174 - mean_io_u: 0.9741 - dice_coeficient: 0.9826 - val_loss: 0.0253 - val_mean_io_u: 0.9670 - val_dice_coeficient: 0.9748
# Epoch 85/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0174 - mean_io_u: 0.9743 - dice_coeficient: 0.9826 - val_loss: 0.0250 - val_mean_io_u: 0.9676 - val_dice_coeficient: 0.9751
# Epoch 86/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0172 - mean_io_u: 0.9746 - dice_coeficient: 0.9828 - val_loss: 0.0251 - val_mean_io_u: 0.9676 - val_dice_coeficient: 0.9750
# Epoch 87/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0171 - mean_io_u: 0.9749 - dice_coeficient: 0.9829 - val_loss: 0.0250 - val_mean_io_u: 0.9677 - val_dice_coeficient: 0.9751
# Epoch 88/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0171 - mean_io_u: 0.9749 - dice_coeficient: 0.9829 - val_loss: 0.0249 - val_mean_io_u: 0.9680 - val_dice_coeficient: 0.9752
# Epoch 89/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0170 - mean_io_u: 0.9752 - dice_coeficient: 0.9830 - val_loss: 0.0251 - val_mean_io_u: 0.9680 - val_dice_coeficient: 0.9750
# Epoch 90/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0169 - mean_io_u: 0.9755 - dice_coeficient: 0.9831 - val_loss: 0.0250 - val_mean_io_u: 0.9682 - val_dice_coeficient: 0.9751
# Epoch 91/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0168 - mean_io_u: 0.9757 - dice_coeficient: 0.9832 - val_loss: 0.0251 - val_mean_io_u: 0.9681 - val_dice_coeficient: 0.9750
# Epoch 92/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0169 - mean_io_u: 0.9758 - dice_coeficient: 0.9832 - val_loss: 0.0249 - val_mean_io_u: 0.9685 - val_dice_coeficient: 0.9752
# Epoch 93/100
# 51/51 [==============================] - 19s 380ms/step - loss: 0.0167 - mean_io_u: 0.9762 - dice_coeficient: 0.9833 - val_loss: 0.0249 - val_mean_io_u: 0.9685 - val_dice_coeficient: 0.9752
# Epoch 94/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0166 - mean_io_u: 0.9763 - dice_coeficient: 0.9833 - val_loss: 0.0248 - val_mean_io_u: 0.9687 - val_dice_coeficient: 0.9753
# Epoch 95/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0166 - mean_io_u: 0.9765 - dice_coeficient: 0.9834 - val_loss: 0.0248 - val_mean_io_u: 0.9691 - val_dice_coeficient: 0.9754
# Epoch 96/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0166 - mean_io_u: 0.9766 - dice_coeficient: 0.9834 - val_loss: 0.0250 - val_mean_io_u: 0.9691 - val_dice_coeficient: 0.9752
# Epoch 97/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0165 - mean_io_u: 0.9767 - dice_coeficient: 0.9835 - val_loss: 0.0249 - val_mean_io_u: 0.9690 - val_dice_coeficient: 0.9752
# Epoch 98/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0164 - mean_io_u: 0.9770 - dice_coeficient: 0.9836 - val_loss: 0.0246 - val_mean_io_u: 0.9694 - val_dice_coeficient: 0.9755
# Epoch 99/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0164 - mean_io_u: 0.9772 - dice_coeficient: 0.9836 - val_loss: 0.0246 - val_mean_io_u: 0.9696 - val_dice_coeficient: 0.9755
# Epoch 100/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0163 - mean_io_u: 0.9773 - dice_coeficient: 0.9837 - val_loss: 0.0247 - val_mean_io_u: 0.9696 - val_dice_coeficient: 0.9754

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 5s 48ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx])
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
