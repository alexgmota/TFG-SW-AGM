# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8154

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, clipvalue=0.5, decay=1e-6), 
    loss=tversky_loss,
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

# checkpoint = tf.keras.callbacks.ModelCheckpoint(
#     '../models/swin-unet_train_Weights.hdf5',
#     verbose=1,
#     save_best_only=True,
#     save_weights_only=True,
#     mode='auto'
# )

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    # callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - 35s 367ms/step - loss: 0.5843 - mean_io_u: 0.4699 - dice_coeficient: 0.4175 - val_loss: 0.3952 - val_mean_io_u: 0.4993 - val_dice_coeficient: 0.6054
# Epoch 2/100
# 51/51 [==============================] - 15s 299ms/step - loss: 0.3178 - mean_io_u: 0.5416 - dice_coeficient: 0.6828 - val_loss: 0.2588 - val_mean_io_u: 0.5822 - val_dice_coeficient: 0.7419
# Epoch 3/100
# 51/51 [==============================] - 16s 305ms/step - loss: 0.2454 - mean_io_u: 0.6098 - dice_coeficient: 0.7546 - val_loss: 0.2390 - val_mean_io_u: 0.6294 - val_dice_coeficient: 0.7618
# Epoch 4/100
# 51/51 [==============================] - 16s 315ms/step - loss: 0.2213 - mean_io_u: 0.6333 - dice_coeficient: 0.7788 - val_loss: 0.2029 - val_mean_io_u: 0.6510 - val_dice_coeficient: 0.7977
# Epoch 5/100
# 51/51 [==============================] - 16s 322ms/step - loss: 0.1865 - mean_io_u: 0.6631 - dice_coeficient: 0.8135 - val_loss: 0.1707 - val_mean_io_u: 0.6845 - val_dice_coeficient: 0.8298
# Epoch 6/100
# 51/51 [==============================] - 17s 327ms/step - loss: 0.1502 - mean_io_u: 0.6873 - dice_coeficient: 0.8499 - val_loss: 0.1362 - val_mean_io_u: 0.7009 - val_dice_coeficient: 0.8641
# Epoch 7/100
# 51/51 [==============================] - 17s 330ms/step - loss: 0.1202 - mean_io_u: 0.7198 - dice_coeficient: 0.8799 - val_loss: 0.1098 - val_mean_io_u: 0.7396 - val_dice_coeficient: 0.8905
# Epoch 8/100
# 51/51 [==============================] - 17s 334ms/step - loss: 0.1061 - mean_io_u: 0.7525 - dice_coeficient: 0.8940 - val_loss: 0.1031 - val_mean_io_u: 0.7618 - val_dice_coeficient: 0.8972
# Epoch 9/100
# 51/51 [==============================] - 17s 337ms/step - loss: 0.1008 - mean_io_u: 0.7693 - dice_coeficient: 0.8992 - val_loss: 0.0992 - val_mean_io_u: 0.7750 - val_dice_coeficient: 0.9011
# Epoch 10/100
# 51/51 [==============================] - 17s 340ms/step - loss: 0.0975 - mean_io_u: 0.7817 - dice_coeficient: 0.9026 - val_loss: 0.0964 - val_mean_io_u: 0.7873 - val_dice_coeficient: 0.9039
# Epoch 11/100
# 51/51 [==============================] - 17s 342ms/step - loss: 0.0922 - mean_io_u: 0.7924 - dice_coeficient: 0.9079 - val_loss: 0.0829 - val_mean_io_u: 0.8003 - val_dice_coeficient: 0.9173
# Epoch 12/100
# 51/51 [==============================] - 18s 347ms/step - loss: 0.0808 - mean_io_u: 0.8074 - dice_coeficient: 0.9192 - val_loss: 0.0801 - val_mean_io_u: 0.8122 - val_dice_coeficient: 0.9202
# Epoch 13/100
# 51/51 [==============================] - 18s 347ms/step - loss: 0.0786 - mean_io_u: 0.8163 - dice_coeficient: 0.9213 - val_loss: 0.0781 - val_mean_io_u: 0.8187 - val_dice_coeficient: 0.9221
# Epoch 14/100
# 51/51 [==============================] - 18s 346ms/step - loss: 0.0743 - mean_io_u: 0.8242 - dice_coeficient: 0.9258 - val_loss: 0.0739 - val_mean_io_u: 0.8254 - val_dice_coeficient: 0.9263
# Epoch 15/100
# 51/51 [==============================] - 18s 348ms/step - loss: 0.0724 - mean_io_u: 0.8310 - dice_coeficient: 0.9276 - val_loss: 0.0726 - val_mean_io_u: 0.8331 - val_dice_coeficient: 0.9276
# Epoch 16/100
# 51/51 [==============================] - 18s 350ms/step - loss: 0.0712 - mean_io_u: 0.8374 - dice_coeficient: 0.9289 - val_loss: 0.0715 - val_mean_io_u: 0.8378 - val_dice_coeficient: 0.9287
# Epoch 17/100
# 51/51 [==============================] - 18s 352ms/step - loss: 0.0702 - mean_io_u: 0.8426 - dice_coeficient: 0.9300 - val_loss: 0.0710 - val_mean_io_u: 0.8428 - val_dice_coeficient: 0.9293
# Epoch 18/100
# 51/51 [==============================] - 18s 352ms/step - loss: 0.0691 - mean_io_u: 0.8469 - dice_coeficient: 0.9309 - val_loss: 0.0693 - val_mean_io_u: 0.8468 - val_dice_coeficient: 0.9309
# Epoch 19/100
# 51/51 [==============================] - 18s 353ms/step - loss: 0.0679 - mean_io_u: 0.8515 - dice_coeficient: 0.9320 - val_loss: 0.0686 - val_mean_io_u: 0.8530 - val_dice_coeficient: 0.9316
# Epoch 20/100
# 51/51 [==============================] - 18s 353ms/step - loss: 0.0671 - mean_io_u: 0.8554 - dice_coeficient: 0.9329 - val_loss: 0.0678 - val_mean_io_u: 0.8559 - val_dice_coeficient: 0.9325
# Epoch 21/100
# 51/51 [==============================] - 18s 353ms/step - loss: 0.0664 - mean_io_u: 0.8594 - dice_coeficient: 0.9337 - val_loss: 0.0673 - val_mean_io_u: 0.8598 - val_dice_coeficient: 0.9329
# Epoch 22/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0659 - mean_io_u: 0.8624 - dice_coeficient: 0.9341 - val_loss: 0.0666 - val_mean_io_u: 0.8628 - val_dice_coeficient: 0.9336
# Epoch 23/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0652 - mean_io_u: 0.8656 - dice_coeficient: 0.9347 - val_loss: 0.0663 - val_mean_io_u: 0.8654 - val_dice_coeficient: 0.9340
# Epoch 24/100
# 51/51 [==============================] - 18s 353ms/step - loss: 0.0649 - mean_io_u: 0.8682 - dice_coeficient: 0.9350 - val_loss: 0.0661 - val_mean_io_u: 0.8679 - val_dice_coeficient: 0.9341
# Epoch 25/100
# 51/51 [==============================] - 18s 355ms/step - loss: 0.0643 - mean_io_u: 0.8710 - dice_coeficient: 0.9357 - val_loss: 0.0654 - val_mean_io_u: 0.8703 - val_dice_coeficient: 0.9348
# Epoch 26/100
# 51/51 [==============================] - 18s 356ms/step - loss: 0.0637 - mean_io_u: 0.8734 - dice_coeficient: 0.9364 - val_loss: 0.0648 - val_mean_io_u: 0.8737 - val_dice_coeficient: 0.9354
# Epoch 27/100
# 51/51 [==============================] - 18s 357ms/step - loss: 0.0633 - mean_io_u: 0.8756 - dice_coeficient: 0.9367 - val_loss: 0.0645 - val_mean_io_u: 0.8757 - val_dice_coeficient: 0.9357
# Epoch 28/100
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0627 - mean_io_u: 0.8779 - dice_coeficient: 0.9374 - val_loss: 0.0640 - val_mean_io_u: 0.8772 - val_dice_coeficient: 0.9362
# Epoch 29/100
# 51/51 [==============================] - 18s 362ms/step - loss: 0.0622 - mean_io_u: 0.8799 - dice_coeficient: 0.9379 - val_loss: 0.0635 - val_mean_io_u: 0.8797 - val_dice_coeficient: 0.9367
# Epoch 30/100
# 51/51 [==============================] - 18s 360ms/step - loss: 0.0618 - mean_io_u: 0.8817 - dice_coeficient: 0.9382 - val_loss: 0.0631 - val_mean_io_u: 0.8823 - val_dice_coeficient: 0.9371
# Epoch 31/100
# 51/51 [==============================] - 18s 361ms/step - loss: 0.0611 - mean_io_u: 0.8838 - dice_coeficient: 0.9389 - val_loss: 0.0629 - val_mean_io_u: 0.8827 - val_dice_coeficient: 0.9373
# Epoch 32/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0606 - mean_io_u: 0.8852 - dice_coeficient: 0.9394 - val_loss: 0.0621 - val_mean_io_u: 0.8852 - val_dice_coeficient: 0.9381
# Epoch 33/100
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0598 - mean_io_u: 0.8871 - dice_coeficient: 0.9402 - val_loss: 0.0616 - val_mean_io_u: 0.8858 - val_dice_coeficient: 0.9386
# Epoch 34/100
# 51/51 [==============================] - 18s 363ms/step - loss: 0.0594 - mean_io_u: 0.8887 - dice_coeficient: 0.9406 - val_loss: 0.0610 - val_mean_io_u: 0.8888 - val_dice_coeficient: 0.9391
# Epoch 35/100
# 51/51 [==============================] - 18s 362ms/step - loss: 0.0586 - mean_io_u: 0.8903 - dice_coeficient: 0.9414 - val_loss: 0.0602 - val_mean_io_u: 0.8897 - val_dice_coeficient: 0.9399
# Epoch 36/100
# 51/51 [==============================] - 18s 363ms/step - loss: 0.0574 - mean_io_u: 0.8914 - dice_coeficient: 0.9426 - val_loss: 0.0586 - val_mean_io_u: 0.8906 - val_dice_coeficient: 0.9416
# Epoch 37/100
# 51/51 [==============================] - 18s 362ms/step - loss: 0.0551 - mean_io_u: 0.8928 - dice_coeficient: 0.9448 - val_loss: 0.0567 - val_mean_io_u: 0.8927 - val_dice_coeficient: 0.9435
# Epoch 38/100
# 51/51 [==============================] - 18s 361ms/step - loss: 0.0536 - mean_io_u: 0.8951 - dice_coeficient: 0.9465 - val_loss: 0.0557 - val_mean_io_u: 0.8940 - val_dice_coeficient: 0.9444
# Epoch 39/100
# 51/51 [==============================] - 19s 364ms/step - loss: 0.0523 - mean_io_u: 0.8972 - dice_coeficient: 0.9476 - val_loss: 0.0548 - val_mean_io_u: 0.8969 - val_dice_coeficient: 0.9453
# Epoch 40/100
# 51/51 [==============================] - 19s 367ms/step - loss: 0.0515 - mean_io_u: 0.8991 - dice_coeficient: 0.9485 - val_loss: 0.0543 - val_mean_io_u: 0.8982 - val_dice_coeficient: 0.9459
# Epoch 41/100
# 51/51 [==============================] - 18s 363ms/step - loss: 0.0508 - mean_io_u: 0.9006 - dice_coeficient: 0.9492 - val_loss: 0.0535 - val_mean_io_u: 0.8992 - val_dice_coeficient: 0.9466
# Epoch 42/100
# 51/51 [==============================] - 19s 363ms/step - loss: 0.0498 - mean_io_u: 0.9021 - dice_coeficient: 0.9502 - val_loss: 0.0529 - val_mean_io_u: 0.9010 - val_dice_coeficient: 0.9473
# Epoch 43/100
# 51/51 [==============================] - 19s 366ms/step - loss: 0.0493 - mean_io_u: 0.9035 - dice_coeficient: 0.9508 - val_loss: 0.0528 - val_mean_io_u: 0.9024 - val_dice_coeficient: 0.9474
# Epoch 44/100
# 51/51 [==============================] - 19s 366ms/step - loss: 0.0489 - mean_io_u: 0.9049 - dice_coeficient: 0.9511 - val_loss: 0.0523 - val_mean_io_u: 0.9044 - val_dice_coeficient: 0.9478
# Epoch 45/100
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0483 - mean_io_u: 0.9064 - dice_coeficient: 0.9516 - val_loss: 0.0519 - val_mean_io_u: 0.9048 - val_dice_coeficient: 0.9483
# Epoch 46/100
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0479 - mean_io_u: 0.9076 - dice_coeficient: 0.9521 - val_loss: 0.0512 - val_mean_io_u: 0.9066 - val_dice_coeficient: 0.9489
# Epoch 47/100
# 51/51 [==============================] - 19s 369ms/step - loss: 0.0475 - mean_io_u: 0.9088 - dice_coeficient: 0.9525 - val_loss: 0.0510 - val_mean_io_u: 0.9076 - val_dice_coeficient: 0.9492
# Epoch 48/100
# 51/51 [==============================] - 19s 365ms/step - loss: 0.0468 - mean_io_u: 0.9100 - dice_coeficient: 0.9532 - val_loss: 0.0503 - val_mean_io_u: 0.9087 - val_dice_coeficient: 0.9499
# Epoch 49/100
# 51/51 [==============================] - 19s 366ms/step - loss: 0.0459 - mean_io_u: 0.9108 - dice_coeficient: 0.9540 - val_loss: 0.0495 - val_mean_io_u: 0.9090 - val_dice_coeficient: 0.9507
# Epoch 50/100
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0444 - mean_io_u: 0.9118 - dice_coeficient: 0.9557 - val_loss: 0.0474 - val_mean_io_u: 0.9104 - val_dice_coeficient: 0.9528
# Epoch 51/100
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0413 - mean_io_u: 0.9131 - dice_coeficient: 0.9587 - val_loss: 0.0440 - val_mean_io_u: 0.9119 - val_dice_coeficient: 0.9561
# Epoch 52/100
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0380 - mean_io_u: 0.9155 - dice_coeficient: 0.9620 - val_loss: 0.0411 - val_mean_io_u: 0.9145 - val_dice_coeficient: 0.9591
# Epoch 53/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0360 - mean_io_u: 0.9180 - dice_coeficient: 0.9641 - val_loss: 0.0400 - val_mean_io_u: 0.9161 - val_dice_coeficient: 0.9601
# Epoch 54/100
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0349 - mean_io_u: 0.9199 - dice_coeficient: 0.9651 - val_loss: 0.0395 - val_mean_io_u: 0.9178 - val_dice_coeficient: 0.9607
# Epoch 55/100
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0343 - mean_io_u: 0.9212 - dice_coeficient: 0.9657 - val_loss: 0.0391 - val_mean_io_u: 0.9188 - val_dice_coeficient: 0.9611
# Epoch 56/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0337 - mean_io_u: 0.9226 - dice_coeficient: 0.9663 - val_loss: 0.0383 - val_mean_io_u: 0.9210 - val_dice_coeficient: 0.9619
# Epoch 57/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0329 - mean_io_u: 0.9239 - dice_coeficient: 0.9671 - val_loss: 0.0377 - val_mean_io_u: 0.9219 - val_dice_coeficient: 0.9624
# Epoch 58/100
# 51/51 [==============================] - 19s 369ms/step - loss: 0.0321 - mean_io_u: 0.9253 - dice_coeficient: 0.9678 - val_loss: 0.0371 - val_mean_io_u: 0.9229 - val_dice_coeficient: 0.9630
# Epoch 59/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0316 - mean_io_u: 0.9263 - dice_coeficient: 0.9684 - val_loss: 0.0368 - val_mean_io_u: 0.9237 - val_dice_coeficient: 0.9633
# Epoch 60/100
# 51/51 [==============================] - 19s 370ms/step - loss: 0.0311 - mean_io_u: 0.9275 - dice_coeficient: 0.9689 - val_loss: 0.0365 - val_mean_io_u: 0.9257 - val_dice_coeficient: 0.9637
# Epoch 61/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0307 - mean_io_u: 0.9287 - dice_coeficient: 0.9692 - val_loss: 0.0361 - val_mean_io_u: 0.9264 - val_dice_coeficient: 0.9640
# Epoch 62/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0303 - mean_io_u: 0.9296 - dice_coeficient: 0.9697 - val_loss: 0.0359 - val_mean_io_u: 0.9271 - val_dice_coeficient: 0.9643
# Epoch 63/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0299 - mean_io_u: 0.9306 - dice_coeficient: 0.9701 - val_loss: 0.0353 - val_mean_io_u: 0.9288 - val_dice_coeficient: 0.9649
# Epoch 64/100
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0295 - mean_io_u: 0.9316 - dice_coeficient: 0.9705 - val_loss: 0.0351 - val_mean_io_u: 0.9297 - val_dice_coeficient: 0.9650
# Epoch 65/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0291 - mean_io_u: 0.9326 - dice_coeficient: 0.9709 - val_loss: 0.0349 - val_mean_io_u: 0.9293 - val_dice_coeficient: 0.9652
# Epoch 66/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0289 - mean_io_u: 0.9334 - dice_coeficient: 0.9712 - val_loss: 0.0347 - val_mean_io_u: 0.9309 - val_dice_coeficient: 0.9655
# Epoch 67/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0285 - mean_io_u: 0.9342 - dice_coeficient: 0.9715 - val_loss: 0.0343 - val_mean_io_u: 0.9314 - val_dice_coeficient: 0.9658
# Epoch 68/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0281 - mean_io_u: 0.9353 - dice_coeficient: 0.9720 - val_loss: 0.0340 - val_mean_io_u: 0.9325 - val_dice_coeficient: 0.9661
# Epoch 69/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0278 - mean_io_u: 0.9359 - dice_coeficient: 0.9721 - val_loss: 0.0338 - val_mean_io_u: 0.9332 - val_dice_coeficient: 0.9663
# Epoch 70/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0275 - mean_io_u: 0.9367 - dice_coeficient: 0.9725 - val_loss: 0.0337 - val_mean_io_u: 0.9333 - val_dice_coeficient: 0.9664
# Epoch 71/100
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0272 - mean_io_u: 0.9374 - dice_coeficient: 0.9728 - val_loss: 0.0333 - val_mean_io_u: 0.9345 - val_dice_coeficient: 0.9668
# Epoch 72/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0269 - mean_io_u: 0.9383 - dice_coeficient: 0.9731 - val_loss: 0.0331 - val_mean_io_u: 0.9353 - val_dice_coeficient: 0.9671
# Epoch 73/100
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0267 - mean_io_u: 0.9389 - dice_coeficient: 0.9733 - val_loss: 0.0328 - val_mean_io_u: 0.9362 - val_dice_coeficient: 0.9673
# Epoch 74/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0263 - mean_io_u: 0.9396 - dice_coeficient: 0.9737 - val_loss: 0.0327 - val_mean_io_u: 0.9365 - val_dice_coeficient: 0.9674
# Epoch 75/100
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0257 - mean_io_u: 0.9404 - dice_coeficient: 0.9743 - val_loss: 0.0318 - val_mean_io_u: 0.9374 - val_dice_coeficient: 0.9684
# Epoch 76/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0249 - mean_io_u: 0.9414 - dice_coeficient: 0.9751 - val_loss: 0.0315 - val_mean_io_u: 0.9380 - val_dice_coeficient: 0.9686
# Epoch 77/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0246 - mean_io_u: 0.9422 - dice_coeficient: 0.9754 - val_loss: 0.0313 - val_mean_io_u: 0.9390 - val_dice_coeficient: 0.9688
# Epoch 78/100
# 51/51 [==============================] - 19s 381ms/step - loss: 0.0244 - mean_io_u: 0.9427 - dice_coeficient: 0.9755 - val_loss: 0.0312 - val_mean_io_u: 0.9397 - val_dice_coeficient: 0.9689
# Epoch 79/100
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0243 - mean_io_u: 0.9433 - dice_coeficient: 0.9757 - val_loss: 0.0308 - val_mean_io_u: 0.9401 - val_dice_coeficient: 0.9693
# Epoch 80/100
# 51/51 [==============================] - 19s 382ms/step - loss: 0.0239 - mean_io_u: 0.9441 - dice_coeficient: 0.9761 - val_loss: 0.0308 - val_mean_io_u: 0.9406 - val_dice_coeficient: 0.9694
# Epoch 81/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0236 - mean_io_u: 0.9447 - dice_coeficient: 0.9764 - val_loss: 0.0306 - val_mean_io_u: 0.9412 - val_dice_coeficient: 0.9696
# Epoch 82/100
# 51/51 [==============================] - 19s 381ms/step - loss: 0.0234 - mean_io_u: 0.9453 - dice_coeficient: 0.9765 - val_loss: 0.0305 - val_mean_io_u: 0.9414 - val_dice_coeficient: 0.9697
# Epoch 83/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0232 - mean_io_u: 0.9457 - dice_coeficient: 0.9768 - val_loss: 0.0302 - val_mean_io_u: 0.9424 - val_dice_coeficient: 0.9700
# Epoch 84/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0229 - mean_io_u: 0.9464 - dice_coeficient: 0.9771 - val_loss: 0.0300 - val_mean_io_u: 0.9429 - val_dice_coeficient: 0.9702
# Epoch 85/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0227 - mean_io_u: 0.9469 - dice_coeficient: 0.9773 - val_loss: 0.0299 - val_mean_io_u: 0.9433 - val_dice_coeficient: 0.9702
# Epoch 86/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0225 - mean_io_u: 0.9475 - dice_coeficient: 0.9775 - val_loss: 0.0299 - val_mean_io_u: 0.9435 - val_dice_coeficient: 0.9703
# Epoch 87/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0223 - mean_io_u: 0.9480 - dice_coeficient: 0.9777 - val_loss: 0.0296 - val_mean_io_u: 0.9442 - val_dice_coeficient: 0.9705
# Epoch 88/100
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0221 - mean_io_u: 0.9485 - dice_coeficient: 0.9779 - val_loss: 0.0297 - val_mean_io_u: 0.9445 - val_dice_coeficient: 0.9704
# Epoch 89/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0219 - mean_io_u: 0.9490 - dice_coeficient: 0.9781 - val_loss: 0.0296 - val_mean_io_u: 0.9449 - val_dice_coeficient: 0.9705
# Epoch 90/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0217 - mean_io_u: 0.9494 - dice_coeficient: 0.9782 - val_loss: 0.0294 - val_mean_io_u: 0.9457 - val_dice_coeficient: 0.9708
# Epoch 91/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0216 - mean_io_u: 0.9499 - dice_coeficient: 0.9784 - val_loss: 0.0293 - val_mean_io_u: 0.9460 - val_dice_coeficient: 0.9708
# Epoch 92/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0215 - mean_io_u: 0.9504 - dice_coeficient: 0.9785 - val_loss: 0.0293 - val_mean_io_u: 0.9460 - val_dice_coeficient: 0.9708
# Epoch 93/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0214 - mean_io_u: 0.9507 - dice_coeficient: 0.9786 - val_loss: 0.0291 - val_mean_io_u: 0.9468 - val_dice_coeficient: 0.9710
# Epoch 94/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0212 - mean_io_u: 0.9512 - dice_coeficient: 0.9788 - val_loss: 0.0291 - val_mean_io_u: 0.9472 - val_dice_coeficient: 0.9711
# Epoch 95/100
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0210 - mean_io_u: 0.9517 - dice_coeficient: 0.9790 - val_loss: 0.0289 - val_mean_io_u: 0.9475 - val_dice_coeficient: 0.9712
# Epoch 96/100
# 51/51 [==============================] - 19s 382ms/step - loss: 0.0208 - mean_io_u: 0.9521 - dice_coeficient: 0.9793 - val_loss: 0.0288 - val_mean_io_u: 0.9478 - val_dice_coeficient: 0.9713
# Epoch 97/100
# 51/51 [==============================] - 19s 378ms/step - loss: 0.0206 - mean_io_u: 0.9525 - dice_coeficient: 0.9794 - val_loss: 0.0288 - val_mean_io_u: 0.9483 - val_dice_coeficient: 0.9714
# Epoch 98/100
# 51/51 [==============================] - 19s 381ms/step - loss: 0.0204 - mean_io_u: 0.9529 - dice_coeficient: 0.9796 - val_loss: 0.0285 - val_mean_io_u: 0.9488 - val_dice_coeficient: 0.9716
# Epoch 99/100
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0203 - mean_io_u: 0.9533 - dice_coeficient: 0.9797 - val_loss: 0.0286 - val_mean_io_u: 0.9489 - val_dice_coeficient: 0.9716
# Epoch 100/100
# 51/51 [==============================] - 19s 379ms/step - loss: 0.0202 - mean_io_u: 0.9536 - dice_coeficient: 0.9798 - val_loss: 0.0284 - val_mean_io_u: 0.9492 - val_dice_coeficient: 0.9717

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 6s 53ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx])
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
