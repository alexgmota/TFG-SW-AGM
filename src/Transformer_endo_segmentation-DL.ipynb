# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
CLASS_WEIGHTS = [2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
 1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
 3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
 4.36967906e-03]

# %%
# https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape, 
                    padding_color = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size, interpolation=cv2.INTER_NEAREST)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 120:-120,:]
    img = resize_with_pad(img, (HEIGHT, WIDTH))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 120:-120,:]
    mask = resize_with_pad(mask, (HEIGHT, WIDTH), (50, 50, 50))
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx], cmap='magma')
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(6,6))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1), cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8157

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

def dice_loss(y_true, y_pred):
    return 1 - dice_coeficient(y_true, y_pred)

def tversky(y_true, y_pred, smooth=1e-6, alpha=0.75):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)
    TP = tf.keras.backend.sum(T * P)
    FN = tf.keras.backend.sum(T * (1 - P))
    FP = tf.keras.backend.sum((1 - T) * P)
    return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


def tversky_loss(y_true, y_pred):
    return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-4, clipvalue=0.5, decay=1e-6), 
    loss=sm.losses.DiceLoss(class_weights=CLASS_WEIGHTS),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_diceLoss.hdf5',
    verbose=1,
    monitor='val_mean_io_u',
    save_best_only=True,
    save_weights_only=True,
    mode='max'
)

print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9575 - mean_io_u: 0.6506 - dice_coeficient: 0.5724
# Epoch 1: val_mean_io_u improved from -inf to 0.77034, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 36s 368ms/step - loss: 0.9575 - mean_io_u: 0.6506 - dice_coeficient: 0.5724 - val_loss: 0.9445 - val_mean_io_u: 0.7703 - val_dice_coeficient: 0.7353
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9406 - mean_io_u: 0.8048 - dice_coeficient: 0.7927
# Epoch 2: val_mean_io_u improved from 0.77034 to 0.82203, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 15s 296ms/step - loss: 0.9406 - mean_io_u: 0.8048 - dice_coeficient: 0.7927 - val_loss: 0.9382 - val_mean_io_u: 0.8220 - val_dice_coeficient: 0.8236
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9363 - mean_io_u: 0.8292 - dice_coeficient: 0.8416
# Epoch 3: val_mean_io_u improved from 0.82203 to 0.83132, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 15s 299ms/step - loss: 0.9363 - mean_io_u: 0.8292 - dice_coeficient: 0.8416 - val_loss: 0.9350 - val_mean_io_u: 0.8313 - val_dice_coeficient: 0.8512
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9336 - mean_io_u: 0.8390 - dice_coeficient: 0.8658
# Epoch 4: val_mean_io_u improved from 0.83132 to 0.84473, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 16s 306ms/step - loss: 0.9336 - mean_io_u: 0.8390 - dice_coeficient: 0.8658 - val_loss: 0.9327 - val_mean_io_u: 0.8447 - val_dice_coeficient: 0.8753
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9321 - mean_io_u: 0.8516 - dice_coeficient: 0.8823
# Epoch 5: val_mean_io_u improved from 0.84473 to 0.85284, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 16s 310ms/step - loss: 0.9321 - mean_io_u: 0.8516 - dice_coeficient: 0.8823 - val_loss: 0.9318 - val_mean_io_u: 0.8528 - val_dice_coeficient: 0.8846
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9312 - mean_io_u: 0.8596 - dice_coeficient: 0.8920
# Epoch 6: val_mean_io_u improved from 0.85284 to 0.85868, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 16s 311ms/step - loss: 0.9312 - mean_io_u: 0.8596 - dice_coeficient: 0.8920 - val_loss: 0.9308 - val_mean_io_u: 0.8587 - val_dice_coeficient: 0.8952
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9303 - mean_io_u: 0.8655 - dice_coeficient: 0.9002
# Epoch 7: val_mean_io_u improved from 0.85868 to 0.86782, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 16s 314ms/step - loss: 0.9303 - mean_io_u: 0.8655 - dice_coeficient: 0.9002 - val_loss: 0.9302 - val_mean_io_u: 0.8678 - val_dice_coeficient: 0.9009
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9298 - mean_io_u: 0.8708 - dice_coeficient: 0.9052
# Epoch 8: val_mean_io_u improved from 0.86782 to 0.87196, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 16s 318ms/step - loss: 0.9298 - mean_io_u: 0.8708 - dice_coeficient: 0.9052 - val_loss: 0.9298 - val_mean_io_u: 0.8720 - val_dice_coeficient: 0.9054
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9294 - mean_io_u: 0.8752 - dice_coeficient: 0.9086
# Epoch 9: val_mean_io_u improved from 0.87196 to 0.87472, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 16s 321ms/step - loss: 0.9294 - mean_io_u: 0.8752 - dice_coeficient: 0.9086 - val_loss: 0.9295 - val_mean_io_u: 0.8747 - val_dice_coeficient: 0.9083
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9292 - mean_io_u: 0.8786 - dice_coeficient: 0.9111
# Epoch 10: val_mean_io_u improved from 0.87472 to 0.87845, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 16s 322ms/step - loss: 0.9292 - mean_io_u: 0.8786 - dice_coeficient: 0.9111 - val_loss: 0.9291 - val_mean_io_u: 0.8784 - val_dice_coeficient: 0.9112
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9289 - mean_io_u: 0.8834 - dice_coeficient: 0.9143
# Epoch 11: val_mean_io_u improved from 0.87845 to 0.88382, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 327ms/step - loss: 0.9289 - mean_io_u: 0.8834 - dice_coeficient: 0.9143 - val_loss: 0.9289 - val_mean_io_u: 0.8838 - val_dice_coeficient: 0.9145
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9286 - mean_io_u: 0.8872 - dice_coeficient: 0.9176
# Epoch 12: val_mean_io_u improved from 0.88382 to 0.88785, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.9286 - mean_io_u: 0.8872 - dice_coeficient: 0.9176 - val_loss: 0.9287 - val_mean_io_u: 0.8878 - val_dice_coeficient: 0.9167
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9284 - mean_io_u: 0.8912 - dice_coeficient: 0.9204
# Epoch 13: val_mean_io_u improved from 0.88785 to 0.89165, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 331ms/step - loss: 0.9284 - mean_io_u: 0.8912 - dice_coeficient: 0.9204 - val_loss: 0.9284 - val_mean_io_u: 0.8917 - val_dice_coeficient: 0.9195
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9282 - mean_io_u: 0.8952 - dice_coeficient: 0.9228
# Epoch 14: val_mean_io_u improved from 0.89165 to 0.89494, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.9282 - mean_io_u: 0.8952 - dice_coeficient: 0.9228 - val_loss: 0.9283 - val_mean_io_u: 0.8949 - val_dice_coeficient: 0.9214
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9280 - mean_io_u: 0.8993 - dice_coeficient: 0.9259
# Epoch 15: val_mean_io_u improved from 0.89494 to 0.89912, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 329ms/step - loss: 0.9280 - mean_io_u: 0.8993 - dice_coeficient: 0.9259 - val_loss: 0.9281 - val_mean_io_u: 0.8991 - val_dice_coeficient: 0.9245
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9278 - mean_io_u: 0.9026 - dice_coeficient: 0.9278
# Epoch 16: val_mean_io_u improved from 0.89912 to 0.90140, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 328ms/step - loss: 0.9278 - mean_io_u: 0.9026 - dice_coeficient: 0.9278 - val_loss: 0.9280 - val_mean_io_u: 0.9014 - val_dice_coeficient: 0.9254
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9277 - mean_io_u: 0.9062 - dice_coeficient: 0.9309
# Epoch 17: val_mean_io_u improved from 0.90140 to 0.91046, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.9277 - mean_io_u: 0.9062 - dice_coeficient: 0.9309 - val_loss: 0.9276 - val_mean_io_u: 0.9105 - val_dice_coeficient: 0.9343
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9273 - mean_io_u: 0.9145 - dice_coeficient: 0.9380
# Epoch 18: val_mean_io_u improved from 0.91046 to 0.91378, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.9273 - mean_io_u: 0.9145 - dice_coeficient: 0.9380 - val_loss: 0.9274 - val_mean_io_u: 0.9138 - val_dice_coeficient: 0.9357
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9272 - mean_io_u: 0.9166 - dice_coeficient: 0.9392
# Epoch 19: val_mean_io_u improved from 0.91378 to 0.91524, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.9272 - mean_io_u: 0.9166 - dice_coeficient: 0.9392 - val_loss: 0.9273 - val_mean_io_u: 0.9152 - val_dice_coeficient: 0.9369
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9271 - mean_io_u: 0.9186 - dice_coeficient: 0.9404
# Epoch 20: val_mean_io_u improved from 0.91524 to 0.91585, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.9271 - mean_io_u: 0.9186 - dice_coeficient: 0.9404 - val_loss: 0.9274 - val_mean_io_u: 0.9158 - val_dice_coeficient: 0.9363
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9270 - mean_io_u: 0.9206 - dice_coeficient: 0.9416
# Epoch 21: val_mean_io_u improved from 0.91585 to 0.91836, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 331ms/step - loss: 0.9270 - mean_io_u: 0.9206 - dice_coeficient: 0.9416 - val_loss: 0.9272 - val_mean_io_u: 0.9184 - val_dice_coeficient: 0.9386
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9268 - mean_io_u: 0.9224 - dice_coeficient: 0.9426
# Epoch 22: val_mean_io_u improved from 0.91836 to 0.92026, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 335ms/step - loss: 0.9268 - mean_io_u: 0.9224 - dice_coeficient: 0.9426 - val_loss: 0.9271 - val_mean_io_u: 0.9203 - val_dice_coeficient: 0.9390
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9268 - mean_io_u: 0.9241 - dice_coeficient: 0.9438
# Epoch 23: val_mean_io_u improved from 0.92026 to 0.92299, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.9268 - mean_io_u: 0.9241 - dice_coeficient: 0.9438 - val_loss: 0.9270 - val_mean_io_u: 0.9230 - val_dice_coeficient: 0.9417
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9267 - mean_io_u: 0.9263 - dice_coeficient: 0.9455
# Epoch 24: val_mean_io_u improved from 0.92299 to 0.92447, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.9267 - mean_io_u: 0.9263 - dice_coeficient: 0.9455 - val_loss: 0.9269 - val_mean_io_u: 0.9245 - val_dice_coeficient: 0.9420
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9266 - mean_io_u: 0.9278 - dice_coeficient: 0.9460
# Epoch 25: val_mean_io_u improved from 0.92447 to 0.92510, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.9266 - mean_io_u: 0.9278 - dice_coeficient: 0.9460 - val_loss: 0.9269 - val_mean_io_u: 0.9251 - val_dice_coeficient: 0.9425
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9266 - mean_io_u: 0.9288 - dice_coeficient: 0.9465
# Epoch 26: val_mean_io_u improved from 0.92510 to 0.92655, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.9266 - mean_io_u: 0.9288 - dice_coeficient: 0.9465 - val_loss: 0.9269 - val_mean_io_u: 0.9265 - val_dice_coeficient: 0.9428
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9261 - mean_io_u: 0.9371 - dice_coeficient: 0.9545
# Epoch 27: val_mean_io_u improved from 0.92655 to 0.93874, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.9261 - mean_io_u: 0.9371 - dice_coeficient: 0.9545 - val_loss: 0.9262 - val_mean_io_u: 0.9387 - val_dice_coeficient: 0.9544
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9258 - mean_io_u: 0.9435 - dice_coeficient: 0.9600
# Epoch 28: val_mean_io_u improved from 0.93874 to 0.94086, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.9258 - mean_io_u: 0.9435 - dice_coeficient: 0.9600 - val_loss: 0.9261 - val_mean_io_u: 0.9409 - val_dice_coeficient: 0.9563
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9257 - mean_io_u: 0.9446 - dice_coeficient: 0.9608
# Epoch 29: val_mean_io_u improved from 0.94086 to 0.94173, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 343ms/step - loss: 0.9257 - mean_io_u: 0.9446 - dice_coeficient: 0.9608 - val_loss: 0.9261 - val_mean_io_u: 0.9417 - val_dice_coeficient: 0.9565
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9257 - mean_io_u: 0.9456 - dice_coeficient: 0.9612
# Epoch 30: val_mean_io_u improved from 0.94173 to 0.94271, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.9257 - mean_io_u: 0.9456 - dice_coeficient: 0.9612 - val_loss: 0.9260 - val_mean_io_u: 0.9427 - val_dice_coeficient: 0.9570
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9256 - mean_io_u: 0.9465 - dice_coeficient: 0.9617
# Epoch 31: val_mean_io_u improved from 0.94271 to 0.94308, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 341ms/step - loss: 0.9256 - mean_io_u: 0.9465 - dice_coeficient: 0.9617 - val_loss: 0.9260 - val_mean_io_u: 0.9431 - val_dice_coeficient: 0.9573
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9256 - mean_io_u: 0.9471 - dice_coeficient: 0.9619
# Epoch 32: val_mean_io_u improved from 0.94308 to 0.94388, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 338ms/step - loss: 0.9256 - mean_io_u: 0.9471 - dice_coeficient: 0.9619 - val_loss: 0.9260 - val_mean_io_u: 0.9439 - val_dice_coeficient: 0.9573
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9256 - mean_io_u: 0.9477 - dice_coeficient: 0.9621
# Epoch 33: val_mean_io_u improved from 0.94388 to 0.94439, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 343ms/step - loss: 0.9256 - mean_io_u: 0.9477 - dice_coeficient: 0.9621 - val_loss: 0.9260 - val_mean_io_u: 0.9444 - val_dice_coeficient: 0.9575
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9256 - mean_io_u: 0.9483 - dice_coeficient: 0.9622
# Epoch 34: val_mean_io_u improved from 0.94439 to 0.94462, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 335ms/step - loss: 0.9256 - mean_io_u: 0.9483 - dice_coeficient: 0.9622 - val_loss: 0.9260 - val_mean_io_u: 0.9446 - val_dice_coeficient: 0.9576
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9256 - mean_io_u: 0.9491 - dice_coeficient: 0.9625
# Epoch 35: val_mean_io_u improved from 0.94462 to 0.94573, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9256 - mean_io_u: 0.9491 - dice_coeficient: 0.9625 - val_loss: 0.9259 - val_mean_io_u: 0.9457 - val_dice_coeficient: 0.9581
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9255 - mean_io_u: 0.9498 - dice_coeficient: 0.9630
# Epoch 36: val_mean_io_u improved from 0.94573 to 0.94638, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.9255 - mean_io_u: 0.9498 - dice_coeficient: 0.9630 - val_loss: 0.9259 - val_mean_io_u: 0.9464 - val_dice_coeficient: 0.9582
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9255 - mean_io_u: 0.9503 - dice_coeficient: 0.9629
# Epoch 37: val_mean_io_u improved from 0.94638 to 0.94687, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.9255 - mean_io_u: 0.9503 - dice_coeficient: 0.9629 - val_loss: 0.9259 - val_mean_io_u: 0.9469 - val_dice_coeficient: 0.9583
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9255 - mean_io_u: 0.9513 - dice_coeficient: 0.9635
# Epoch 38: val_mean_io_u improved from 0.94687 to 0.94752, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 340ms/step - loss: 0.9255 - mean_io_u: 0.9513 - dice_coeficient: 0.9635 - val_loss: 0.9259 - val_mean_io_u: 0.9475 - val_dice_coeficient: 0.9590
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9522 - dice_coeficient: 0.9641
# Epoch 39: val_mean_io_u improved from 0.94752 to 0.94818, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 346ms/step - loss: 0.9254 - mean_io_u: 0.9522 - dice_coeficient: 0.9641 - val_loss: 0.9258 - val_mean_io_u: 0.9482 - val_dice_coeficient: 0.9591
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9526 - dice_coeficient: 0.9643
# Epoch 40: val_mean_io_u did not improve from 0.94818
# 51/51 [==============================] - 17s 340ms/step - loss: 0.9254 - mean_io_u: 0.9526 - dice_coeficient: 0.9643 - val_loss: 0.9259 - val_mean_io_u: 0.9481 - val_dice_coeficient: 0.9589
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9530 - dice_coeficient: 0.9642
# Epoch 41: val_mean_io_u improved from 0.94818 to 0.94952, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 341ms/step - loss: 0.9254 - mean_io_u: 0.9530 - dice_coeficient: 0.9642 - val_loss: 0.9258 - val_mean_io_u: 0.9495 - val_dice_coeficient: 0.9596
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9536 - dice_coeficient: 0.9646
# Epoch 42: val_mean_io_u did not improve from 0.94952
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9254 - mean_io_u: 0.9536 - dice_coeficient: 0.9646 - val_loss: 0.9258 - val_mean_io_u: 0.9494 - val_dice_coeficient: 0.9595
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9541 - dice_coeficient: 0.9647
# Epoch 43: val_mean_io_u improved from 0.94952 to 0.94961, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 345ms/step - loss: 0.9254 - mean_io_u: 0.9541 - dice_coeficient: 0.9647 - val_loss: 0.9258 - val_mean_io_u: 0.9496 - val_dice_coeficient: 0.9594
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9545 - dice_coeficient: 0.9649
# Epoch 44: val_mean_io_u improved from 0.94961 to 0.95000, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 339ms/step - loss: 0.9254 - mean_io_u: 0.9545 - dice_coeficient: 0.9649 - val_loss: 0.9258 - val_mean_io_u: 0.9500 - val_dice_coeficient: 0.9595
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9548 - dice_coeficient: 0.9650
# Epoch 45: val_mean_io_u improved from 0.95000 to 0.95052, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9254 - mean_io_u: 0.9548 - dice_coeficient: 0.9650 - val_loss: 0.9258 - val_mean_io_u: 0.9505 - val_dice_coeficient: 0.9597
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9552 - dice_coeficient: 0.9651
# Epoch 46: val_mean_io_u did not improve from 0.95052
# 51/51 [==============================] - 17s 328ms/step - loss: 0.9254 - mean_io_u: 0.9552 - dice_coeficient: 0.9651 - val_loss: 0.9258 - val_mean_io_u: 0.9504 - val_dice_coeficient: 0.9594
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9254 - mean_io_u: 0.9556 - dice_coeficient: 0.9651
# Epoch 47: val_mean_io_u improved from 0.95052 to 0.95105, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 334ms/step - loss: 0.9254 - mean_io_u: 0.9556 - dice_coeficient: 0.9651 - val_loss: 0.9258 - val_mean_io_u: 0.9511 - val_dice_coeficient: 0.9598
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9560 - dice_coeficient: 0.9652
# Epoch 48: val_mean_io_u improved from 0.95105 to 0.95144, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 344ms/step - loss: 0.9253 - mean_io_u: 0.9560 - dice_coeficient: 0.9652 - val_loss: 0.9258 - val_mean_io_u: 0.9514 - val_dice_coeficient: 0.9600
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9566 - dice_coeficient: 0.9655
# Epoch 49: val_mean_io_u improved from 0.95144 to 0.95195, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 341ms/step - loss: 0.9253 - mean_io_u: 0.9566 - dice_coeficient: 0.9655 - val_loss: 0.9258 - val_mean_io_u: 0.9519 - val_dice_coeficient: 0.9602
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9570 - dice_coeficient: 0.9658
# Epoch 50: val_mean_io_u improved from 0.95195 to 0.95198, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9253 - mean_io_u: 0.9570 - dice_coeficient: 0.9658 - val_loss: 0.9258 - val_mean_io_u: 0.9520 - val_dice_coeficient: 0.9602
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9572 - dice_coeficient: 0.9659
# Epoch 51: val_mean_io_u improved from 0.95198 to 0.95219, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9253 - mean_io_u: 0.9572 - dice_coeficient: 0.9659 - val_loss: 0.9257 - val_mean_io_u: 0.9522 - val_dice_coeficient: 0.9602
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9576 - dice_coeficient: 0.9659
# Epoch 52: val_mean_io_u improved from 0.95219 to 0.95242, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9253 - mean_io_u: 0.9576 - dice_coeficient: 0.9659 - val_loss: 0.9258 - val_mean_io_u: 0.9524 - val_dice_coeficient: 0.9601
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9578 - dice_coeficient: 0.9660
# Epoch 53: val_mean_io_u improved from 0.95242 to 0.95275, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 341ms/step - loss: 0.9253 - mean_io_u: 0.9578 - dice_coeficient: 0.9660 - val_loss: 0.9258 - val_mean_io_u: 0.9527 - val_dice_coeficient: 0.9602
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9581 - dice_coeficient: 0.9661
# Epoch 54: val_mean_io_u improved from 0.95275 to 0.95304, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 340ms/step - loss: 0.9253 - mean_io_u: 0.9581 - dice_coeficient: 0.9661 - val_loss: 0.9258 - val_mean_io_u: 0.9530 - val_dice_coeficient: 0.9601
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9583 - dice_coeficient: 0.9660
# Epoch 55: val_mean_io_u improved from 0.95304 to 0.95314, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 341ms/step - loss: 0.9253 - mean_io_u: 0.9583 - dice_coeficient: 0.9660 - val_loss: 0.9258 - val_mean_io_u: 0.9531 - val_dice_coeficient: 0.9602
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9586 - dice_coeficient: 0.9662
# Epoch 56: val_mean_io_u improved from 0.95314 to 0.95338, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9253 - mean_io_u: 0.9586 - dice_coeficient: 0.9662 - val_loss: 0.9257 - val_mean_io_u: 0.9534 - val_dice_coeficient: 0.9603
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9589 - dice_coeficient: 0.9663
# Epoch 57: val_mean_io_u improved from 0.95338 to 0.95377, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 341ms/step - loss: 0.9253 - mean_io_u: 0.9589 - dice_coeficient: 0.9663 - val_loss: 0.9257 - val_mean_io_u: 0.9538 - val_dice_coeficient: 0.9604
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9591 - dice_coeficient: 0.9663
# Epoch 58: val_mean_io_u improved from 0.95377 to 0.95391, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 349ms/step - loss: 0.9253 - mean_io_u: 0.9591 - dice_coeficient: 0.9663 - val_loss: 0.9257 - val_mean_io_u: 0.9539 - val_dice_coeficient: 0.9605
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9253 - mean_io_u: 0.9595 - dice_coeficient: 0.9664
# Epoch 59: val_mean_io_u improved from 0.95391 to 0.95417, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 343ms/step - loss: 0.9253 - mean_io_u: 0.9595 - dice_coeficient: 0.9664 - val_loss: 0.9257 - val_mean_io_u: 0.9542 - val_dice_coeficient: 0.9605
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9597 - dice_coeficient: 0.9666
# Epoch 60: val_mean_io_u did not improve from 0.95417
# 51/51 [==============================] - 17s 337ms/step - loss: 0.9252 - mean_io_u: 0.9597 - dice_coeficient: 0.9666 - val_loss: 0.9258 - val_mean_io_u: 0.9539 - val_dice_coeficient: 0.9602
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9597 - dice_coeficient: 0.9664
# Epoch 61: val_mean_io_u improved from 0.95417 to 0.95428, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9252 - mean_io_u: 0.9597 - dice_coeficient: 0.9664 - val_loss: 0.9257 - val_mean_io_u: 0.9543 - val_dice_coeficient: 0.9603
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9600 - dice_coeficient: 0.9665
# Epoch 62: val_mean_io_u did not improve from 0.95428
# 51/51 [==============================] - 17s 339ms/step - loss: 0.9252 - mean_io_u: 0.9600 - dice_coeficient: 0.9665 - val_loss: 0.9258 - val_mean_io_u: 0.9542 - val_dice_coeficient: 0.9602
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9602 - dice_coeficient: 0.9665
# Epoch 63: val_mean_io_u improved from 0.95428 to 0.95478, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9252 - mean_io_u: 0.9602 - dice_coeficient: 0.9665 - val_loss: 0.9257 - val_mean_io_u: 0.9548 - val_dice_coeficient: 0.9606
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9604 - dice_coeficient: 0.9666
# Epoch 64: val_mean_io_u improved from 0.95478 to 0.95491, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9252 - mean_io_u: 0.9604 - dice_coeficient: 0.9666 - val_loss: 0.9257 - val_mean_io_u: 0.9549 - val_dice_coeficient: 0.9606
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9607 - dice_coeficient: 0.9667
# Epoch 65: val_mean_io_u did not improve from 0.95491
# 51/51 [==============================] - 17s 339ms/step - loss: 0.9252 - mean_io_u: 0.9607 - dice_coeficient: 0.9667 - val_loss: 0.9257 - val_mean_io_u: 0.9549 - val_dice_coeficient: 0.9605
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9608 - dice_coeficient: 0.9668
# Epoch 66: val_mean_io_u improved from 0.95491 to 0.95492, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 344ms/step - loss: 0.9252 - mean_io_u: 0.9608 - dice_coeficient: 0.9668 - val_loss: 0.9257 - val_mean_io_u: 0.9549 - val_dice_coeficient: 0.9605
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9610 - dice_coeficient: 0.9669
# Epoch 67: val_mean_io_u improved from 0.95492 to 0.95535, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 344ms/step - loss: 0.9252 - mean_io_u: 0.9610 - dice_coeficient: 0.9669 - val_loss: 0.9257 - val_mean_io_u: 0.9554 - val_dice_coeficient: 0.9606
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9612 - dice_coeficient: 0.9669
# Epoch 68: val_mean_io_u did not improve from 0.95535
# 51/51 [==============================] - 17s 340ms/step - loss: 0.9252 - mean_io_u: 0.9612 - dice_coeficient: 0.9669 - val_loss: 0.9257 - val_mean_io_u: 0.9549 - val_dice_coeficient: 0.9602
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9615 - dice_coeficient: 0.9670
# Epoch 69: val_mean_io_u improved from 0.95535 to 0.95589, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 345ms/step - loss: 0.9252 - mean_io_u: 0.9615 - dice_coeficient: 0.9670 - val_loss: 0.9257 - val_mean_io_u: 0.9559 - val_dice_coeficient: 0.9609
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9618 - dice_coeficient: 0.9672
# Epoch 70: val_mean_io_u did not improve from 0.95589
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9252 - mean_io_u: 0.9618 - dice_coeficient: 0.9672 - val_loss: 0.9257 - val_mean_io_u: 0.9558 - val_dice_coeficient: 0.9608
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9619 - dice_coeficient: 0.9673
# Epoch 71: val_mean_io_u improved from 0.95589 to 0.95607, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 346ms/step - loss: 0.9252 - mean_io_u: 0.9619 - dice_coeficient: 0.9673 - val_loss: 0.9257 - val_mean_io_u: 0.9561 - val_dice_coeficient: 0.9610
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9622 - dice_coeficient: 0.9673
# Epoch 72: val_mean_io_u did not improve from 0.95607
# 51/51 [==============================] - 17s 343ms/step - loss: 0.9252 - mean_io_u: 0.9622 - dice_coeficient: 0.9673 - val_loss: 0.9257 - val_mean_io_u: 0.9561 - val_dice_coeficient: 0.9610
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9623 - dice_coeficient: 0.9674
# Epoch 73: val_mean_io_u improved from 0.95607 to 0.95626, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 349ms/step - loss: 0.9252 - mean_io_u: 0.9623 - dice_coeficient: 0.9674 - val_loss: 0.9257 - val_mean_io_u: 0.9563 - val_dice_coeficient: 0.9611
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9624 - dice_coeficient: 0.9674
# Epoch 74: val_mean_io_u did not improve from 0.95626
# 51/51 [==============================] - 17s 341ms/step - loss: 0.9252 - mean_io_u: 0.9624 - dice_coeficient: 0.9674 - val_loss: 0.9257 - val_mean_io_u: 0.9562 - val_dice_coeficient: 0.9610
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9625 - dice_coeficient: 0.9674
# Epoch 75: val_mean_io_u improved from 0.95626 to 0.95646, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 347ms/step - loss: 0.9252 - mean_io_u: 0.9625 - dice_coeficient: 0.9674 - val_loss: 0.9257 - val_mean_io_u: 0.9565 - val_dice_coeficient: 0.9610
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9627 - dice_coeficient: 0.9674
# Epoch 76: val_mean_io_u did not improve from 0.95646
# 51/51 [==============================] - 17s 340ms/step - loss: 0.9252 - mean_io_u: 0.9627 - dice_coeficient: 0.9674 - val_loss: 0.9257 - val_mean_io_u: 0.9564 - val_dice_coeficient: 0.9610
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9628 - dice_coeficient: 0.9675
# Epoch 77: val_mean_io_u did not improve from 0.95646
# 51/51 [==============================] - 17s 340ms/step - loss: 0.9252 - mean_io_u: 0.9628 - dice_coeficient: 0.9675 - val_loss: 0.9257 - val_mean_io_u: 0.9562 - val_dice_coeficient: 0.9607
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9628 - dice_coeficient: 0.9674
# Epoch 78: val_mean_io_u improved from 0.95646 to 0.95684, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 347ms/step - loss: 0.9252 - mean_io_u: 0.9628 - dice_coeficient: 0.9674 - val_loss: 0.9257 - val_mean_io_u: 0.9568 - val_dice_coeficient: 0.9611
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9630 - dice_coeficient: 0.9675
# Epoch 79: val_mean_io_u did not improve from 0.95684
# 51/51 [==============================] - 18s 349ms/step - loss: 0.9252 - mean_io_u: 0.9630 - dice_coeficient: 0.9675 - val_loss: 0.9257 - val_mean_io_u: 0.9568 - val_dice_coeficient: 0.9610
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9632 - dice_coeficient: 0.9676
# Epoch 80: val_mean_io_u improved from 0.95684 to 0.95688, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 345ms/step - loss: 0.9251 - mean_io_u: 0.9632 - dice_coeficient: 0.9676 - val_loss: 0.9257 - val_mean_io_u: 0.9569 - val_dice_coeficient: 0.9611
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9632 - dice_coeficient: 0.9675
# Epoch 81: val_mean_io_u did not improve from 0.95688
# 51/51 [==============================] - 17s 340ms/step - loss: 0.9252 - mean_io_u: 0.9632 - dice_coeficient: 0.9675 - val_loss: 0.9257 - val_mean_io_u: 0.9569 - val_dice_coeficient: 0.9610
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9633 - dice_coeficient: 0.9676
# Epoch 82: val_mean_io_u improved from 0.95688 to 0.95707, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9252 - mean_io_u: 0.9633 - dice_coeficient: 0.9676 - val_loss: 0.9257 - val_mean_io_u: 0.9571 - val_dice_coeficient: 0.9611
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9634 - dice_coeficient: 0.9676
# Epoch 83: val_mean_io_u did not improve from 0.95707
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9252 - mean_io_u: 0.9634 - dice_coeficient: 0.9676 - val_loss: 0.9257 - val_mean_io_u: 0.9569 - val_dice_coeficient: 0.9609
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9635 - dice_coeficient: 0.9676
# Epoch 84: val_mean_io_u did not improve from 0.95707
# 51/51 [==============================] - 17s 341ms/step - loss: 0.9251 - mean_io_u: 0.9635 - dice_coeficient: 0.9676 - val_loss: 0.9257 - val_mean_io_u: 0.9568 - val_dice_coeficient: 0.9608
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9636 - dice_coeficient: 0.9676
# Epoch 85: val_mean_io_u improved from 0.95707 to 0.95709, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 347ms/step - loss: 0.9251 - mean_io_u: 0.9636 - dice_coeficient: 0.9676 - val_loss: 0.9257 - val_mean_io_u: 0.9571 - val_dice_coeficient: 0.9609
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9638 - dice_coeficient: 0.9677
# Epoch 86: val_mean_io_u improved from 0.95709 to 0.95727, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 346ms/step - loss: 0.9251 - mean_io_u: 0.9638 - dice_coeficient: 0.9677 - val_loss: 0.9257 - val_mean_io_u: 0.9573 - val_dice_coeficient: 0.9610
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9637 - dice_coeficient: 0.9676
# Epoch 87: val_mean_io_u did not improve from 0.95727
# 51/51 [==============================] - 17s 342ms/step - loss: 0.9252 - mean_io_u: 0.9637 - dice_coeficient: 0.9676 - val_loss: 0.9257 - val_mean_io_u: 0.9572 - val_dice_coeficient: 0.9609
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9638 - dice_coeficient: 0.9676
# Epoch 88: val_mean_io_u improved from 0.95727 to 0.95731, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 17s 341ms/step - loss: 0.9252 - mean_io_u: 0.9638 - dice_coeficient: 0.9676 - val_loss: 0.9257 - val_mean_io_u: 0.9573 - val_dice_coeficient: 0.9610
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9638 - dice_coeficient: 0.9677
# Epoch 89: val_mean_io_u did not improve from 0.95731
# 51/51 [==============================] - 17s 340ms/step - loss: 0.9251 - mean_io_u: 0.9638 - dice_coeficient: 0.9677 - val_loss: 0.9257 - val_mean_io_u: 0.9573 - val_dice_coeficient: 0.9609
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9639 - dice_coeficient: 0.9676
# Epoch 90: val_mean_io_u improved from 0.95731 to 0.95746, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 345ms/step - loss: 0.9252 - mean_io_u: 0.9639 - dice_coeficient: 0.9676 - val_loss: 0.9257 - val_mean_io_u: 0.9575 - val_dice_coeficient: 0.9610
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9640 - dice_coeficient: 0.9676
# Epoch 91: val_mean_io_u did not improve from 0.95746
# 51/51 [==============================] - 17s 340ms/step - loss: 0.9251 - mean_io_u: 0.9640 - dice_coeficient: 0.9676 - val_loss: 0.9257 - val_mean_io_u: 0.9573 - val_dice_coeficient: 0.9608
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9252 - mean_io_u: 0.9640 - dice_coeficient: 0.9677
# Epoch 92: val_mean_io_u improved from 0.95746 to 0.95755, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 344ms/step - loss: 0.9252 - mean_io_u: 0.9640 - dice_coeficient: 0.9677 - val_loss: 0.9257 - val_mean_io_u: 0.9575 - val_dice_coeficient: 0.9610
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9642 - dice_coeficient: 0.9678
# Epoch 93: val_mean_io_u did not improve from 0.95755
# 51/51 [==============================] - 17s 341ms/step - loss: 0.9251 - mean_io_u: 0.9642 - dice_coeficient: 0.9678 - val_loss: 0.9257 - val_mean_io_u: 0.9574 - val_dice_coeficient: 0.9609
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9644 - dice_coeficient: 0.9678
# Epoch 94: val_mean_io_u improved from 0.95755 to 0.95756, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 346ms/step - loss: 0.9251 - mean_io_u: 0.9644 - dice_coeficient: 0.9678 - val_loss: 0.9257 - val_mean_io_u: 0.9576 - val_dice_coeficient: 0.9609
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9644 - dice_coeficient: 0.9678
# Epoch 95: val_mean_io_u improved from 0.95756 to 0.95765, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 350ms/step - loss: 0.9251 - mean_io_u: 0.9644 - dice_coeficient: 0.9678 - val_loss: 0.9257 - val_mean_io_u: 0.9577 - val_dice_coeficient: 0.9610
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9644 - dice_coeficient: 0.9679
# Epoch 96: val_mean_io_u did not improve from 0.95765
# 51/51 [==============================] - 18s 346ms/step - loss: 0.9251 - mean_io_u: 0.9644 - dice_coeficient: 0.9679 - val_loss: 0.9257 - val_mean_io_u: 0.9576 - val_dice_coeficient: 0.9610
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9646 - dice_coeficient: 0.9679
# Epoch 97: val_mean_io_u improved from 0.95765 to 0.95770, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 349ms/step - loss: 0.9251 - mean_io_u: 0.9646 - dice_coeficient: 0.9679 - val_loss: 0.9257 - val_mean_io_u: 0.9577 - val_dice_coeficient: 0.9610
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9644 - dice_coeficient: 0.9677
# Epoch 98: val_mean_io_u improved from 0.95770 to 0.95776, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 359ms/step - loss: 0.9251 - mean_io_u: 0.9644 - dice_coeficient: 0.9677 - val_loss: 0.9257 - val_mean_io_u: 0.9578 - val_dice_coeficient: 0.9609
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9646 - dice_coeficient: 0.9678
# Epoch 99: val_mean_io_u improved from 0.95776 to 0.95802, saving model to ../models\swin-unet_diceLoss.hdf5
# 51/51 [==============================] - 18s 349ms/step - loss: 0.9251 - mean_io_u: 0.9646 - dice_coeficient: 0.9678 - val_loss: 0.9257 - val_mean_io_u: 0.9580 - val_dice_coeficient: 0.9611
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9251 - mean_io_u: 0.9646 - dice_coeficient: 0.9678
# Epoch 100: val_mean_io_u did not improve from 0.95802
# 51/51 [==============================] - 18s 348ms/step - loss: 0.9251 - mean_io_u: 0.9646 - dice_coeficient: 0.9678 - val_loss: 0.9257 - val_mean_io_u: 0.9579 - val_dice_coeficient: 0.9610

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper right')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model metrics')
plt.ylabel('score')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='lower right')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 5s 54ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1), cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx], cmap='magma', norm=plt.Normalize(vmin=0, vmax=12))
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
