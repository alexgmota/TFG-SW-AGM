# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8154

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

# def dice_loss(y_true, y_pred):
#     return 1 - dice_coeficient(y_true, y_pred)

# def tversky(y_true, y_pred, smooth=1, alpha=0.8):
#     T = tf.keras.backend.flatten(y_true)
#     P = tf.keras.backend.flatten(y_pred)
#     TP = tf.keras.backend.sum(T * P)
#     FN = tf.keras.backend.sum(T * (1 - P))
#     FP = tf.keras.backend.sum((1 - T) * P)
#     return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


# def tversky_loss(y_true, y_pred):
#     return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])

# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, clipvalue=0.5), 
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_train_Weights.hdf5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto'
)

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=200,
    batch_size=64,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/200
# 101/101 [==============================] - ETA: 0s - loss: 1.2028 - mean_io_u: 0.4615 - dice_coeficient: 0.5332
# Epoch 1: val_loss improved from inf to 0.58217, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 31s 187ms/step - loss: 1.2028 - mean_io_u: 0.4615 - dice_coeficient: 0.5332 - val_loss: 0.5822 - val_mean_io_u: 0.4615 - val_dice_coeficient: 0.7340
# Epoch 2/200
# 101/101 [==============================] - ETA: 0s - loss: 0.4126 - mean_io_u: 0.4615 - dice_coeficient: 0.8010
# Epoch 2: val_loss improved from 0.58217 to 0.30113, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 16s 160ms/step - loss: 0.4126 - mean_io_u: 0.4615 - dice_coeficient: 0.8010 - val_loss: 0.3011 - val_mean_io_u: 0.4615 - val_dice_coeficient: 0.8467
# Epoch 3/200
# 101/101 [==============================] - ETA: 0s - loss: 0.2475 - mean_io_u: 0.4615 - dice_coeficient: 0.8714
# Epoch 3: val_loss improved from 0.30113 to 0.21701, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 16s 163ms/step - loss: 0.2475 - mean_io_u: 0.4615 - dice_coeficient: 0.8714 - val_loss: 0.2170 - val_mean_io_u: 0.4615 - val_dice_coeficient: 0.8875
# Epoch 4/200
# 101/101 [==============================] - ETA: 0s - loss: 0.1916 - mean_io_u: 0.4615 - dice_coeficient: 0.8982
# Epoch 4: val_loss improved from 0.21701 to 0.18384, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 17s 168ms/step - loss: 0.1916 - mean_io_u: 0.4615 - dice_coeficient: 0.8982 - val_loss: 0.1838 - val_mean_io_u: 0.4615 - val_dice_coeficient: 0.9048
# Epoch 5/200
# 101/101 [==============================] - ETA: 0s - loss: 0.1607 - mean_io_u: 0.4615 - dice_coeficient: 0.9132
# Epoch 5: val_loss improved from 0.18384 to 0.15676, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 17s 172ms/step - loss: 0.1607 - mean_io_u: 0.4615 - dice_coeficient: 0.9132 - val_loss: 0.1568 - val_mean_io_u: 0.4616 - val_dice_coeficient: 0.9180
# Epoch 6/200
# 101/101 [==============================] - ETA: 0s - loss: 0.1406 - mean_io_u: 0.4616 - dice_coeficient: 0.9233
# Epoch 6: val_loss improved from 0.15676 to 0.14364, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 18s 174ms/step - loss: 0.1406 - mean_io_u: 0.4616 - dice_coeficient: 0.9233 - val_loss: 0.1436 - val_mean_io_u: 0.4616 - val_dice_coeficient: 0.9251
# Epoch 7/200
# 101/101 [==============================] - ETA: 0s - loss: 0.1281 - mean_io_u: 0.4616 - dice_coeficient: 0.9298
# Epoch 7: val_loss improved from 0.14364 to 0.13326, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 18s 175ms/step - loss: 0.1281 - mean_io_u: 0.4616 - dice_coeficient: 0.9298 - val_loss: 0.1333 - val_mean_io_u: 0.4616 - val_dice_coeficient: 0.9314
# Epoch 8/200
# 101/101 [==============================] - ETA: 0s - loss: 0.1182 - mean_io_u: 0.4617 - dice_coeficient: 0.9352
# Epoch 8: val_loss improved from 0.13326 to 0.12231, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 19s 186ms/step - loss: 0.1182 - mean_io_u: 0.4617 - dice_coeficient: 0.9352 - val_loss: 0.1223 - val_mean_io_u: 0.4617 - val_dice_coeficient: 0.9362
# Epoch 9/200
# 101/101 [==============================] - ETA: 0s - loss: 0.1099 - mean_io_u: 0.4618 - dice_coeficient: 0.9395
# Epoch 9: val_loss improved from 0.12231 to 0.11762, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 19s 184ms/step - loss: 0.1099 - mean_io_u: 0.4618 - dice_coeficient: 0.9395 - val_loss: 0.1176 - val_mean_io_u: 0.4618 - val_dice_coeficient: 0.9393
# Epoch 10/200
# 101/101 [==============================] - ETA: 0s - loss: 0.1022 - mean_io_u: 0.4620 - dice_coeficient: 0.9434
# Epoch 10: val_loss improved from 0.11762 to 0.11364, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 18s 183ms/step - loss: 0.1022 - mean_io_u: 0.4620 - dice_coeficient: 0.9434 - val_loss: 0.1136 - val_mean_io_u: 0.4624 - val_dice_coeficient: 0.9431
# Epoch 11/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0978 - mean_io_u: 0.4623 - dice_coeficient: 0.9461
# Epoch 11: val_loss improved from 0.11364 to 0.11146, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0978 - mean_io_u: 0.4623 - dice_coeficient: 0.9461 - val_loss: 0.1115 - val_mean_io_u: 0.4626 - val_dice_coeficient: 0.9444
# Epoch 12/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0926 - mean_io_u: 0.4627 - dice_coeficient: 0.9487
# Epoch 12: val_loss improved from 0.11146 to 0.10709, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0926 - mean_io_u: 0.4627 - dice_coeficient: 0.9487 - val_loss: 0.1071 - val_mean_io_u: 0.4625 - val_dice_coeficient: 0.9460
# Epoch 13/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0887 - mean_io_u: 0.4630 - dice_coeficient: 0.9508
# Epoch 13: val_loss improved from 0.10709 to 0.10248, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 19s 185ms/step - loss: 0.0887 - mean_io_u: 0.4630 - dice_coeficient: 0.9508 - val_loss: 0.1025 - val_mean_io_u: 0.4630 - val_dice_coeficient: 0.9487
# Epoch 14/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0862 - mean_io_u: 0.4638 - dice_coeficient: 0.9525
# Epoch 14: val_loss did not improve from 0.10248
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0862 - mean_io_u: 0.4638 - dice_coeficient: 0.9525 - val_loss: 0.1062 - val_mean_io_u: 0.4631 - val_dice_coeficient: 0.9484
# Epoch 15/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0821 - mean_io_u: 0.4640 - dice_coeficient: 0.9542
# Epoch 15: val_loss improved from 0.10248 to 0.09952, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 19s 186ms/step - loss: 0.0821 - mean_io_u: 0.4640 - dice_coeficient: 0.9542 - val_loss: 0.0995 - val_mean_io_u: 0.4643 - val_dice_coeficient: 0.9516
# Epoch 16/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0793 - mean_io_u: 0.4647 - dice_coeficient: 0.9558
# Epoch 16: val_loss improved from 0.09952 to 0.09843, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 19s 188ms/step - loss: 0.0793 - mean_io_u: 0.4647 - dice_coeficient: 0.9558 - val_loss: 0.0984 - val_mean_io_u: 0.4654 - val_dice_coeficient: 0.9527
# Epoch 17/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0766 - mean_io_u: 0.4657 - dice_coeficient: 0.9573
# Epoch 17: val_loss improved from 0.09843 to 0.09570, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 19s 187ms/step - loss: 0.0766 - mean_io_u: 0.4657 - dice_coeficient: 0.9573 - val_loss: 0.0957 - val_mean_io_u: 0.4662 - val_dice_coeficient: 0.9541
# Epoch 18/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0741 - mean_io_u: 0.4666 - dice_coeficient: 0.9587
# Epoch 18: val_loss did not improve from 0.09570
# 101/101 [==============================] - 19s 189ms/step - loss: 0.0741 - mean_io_u: 0.4666 - dice_coeficient: 0.9587 - val_loss: 0.0965 - val_mean_io_u: 0.4664 - val_dice_coeficient: 0.9548
# Epoch 19/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0725 - mean_io_u: 0.4673 - dice_coeficient: 0.9596
# Epoch 19: val_loss did not improve from 0.09570
# 101/101 [==============================] - 19s 187ms/step - loss: 0.0725 - mean_io_u: 0.4673 - dice_coeficient: 0.9596 - val_loss: 0.0964 - val_mean_io_u: 0.4673 - val_dice_coeficient: 0.9544
# Epoch 20/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0695 - mean_io_u: 0.4683 - dice_coeficient: 0.9610
# Epoch 20: val_loss improved from 0.09570 to 0.09395, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 19s 188ms/step - loss: 0.0695 - mean_io_u: 0.4683 - dice_coeficient: 0.9610 - val_loss: 0.0940 - val_mean_io_u: 0.4691 - val_dice_coeficient: 0.9572
# Epoch 21/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0686 - mean_io_u: 0.4700 - dice_coeficient: 0.9618
# Epoch 21: val_loss did not improve from 0.09395
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0686 - mean_io_u: 0.4700 - dice_coeficient: 0.9618 - val_loss: 0.0947 - val_mean_io_u: 0.4702 - val_dice_coeficient: 0.9568
# Epoch 22/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0668 - mean_io_u: 0.4703 - dice_coeficient: 0.9628
# Epoch 22: val_loss did not improve from 0.09395
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0668 - mean_io_u: 0.4703 - dice_coeficient: 0.9628 - val_loss: 0.0955 - val_mean_io_u: 0.4703 - val_dice_coeficient: 0.9563
# Epoch 23/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0649 - mean_io_u: 0.4723 - dice_coeficient: 0.9637
# Epoch 23: val_loss improved from 0.09395 to 0.09076, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 21s 205ms/step - loss: 0.0649 - mean_io_u: 0.4723 - dice_coeficient: 0.9637 - val_loss: 0.0908 - val_mean_io_u: 0.4715 - val_dice_coeficient: 0.9578
# Epoch 24/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0628 - mean_io_u: 0.4731 - dice_coeficient: 0.9645
# Epoch 24: val_loss improved from 0.09076 to 0.08839, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0628 - mean_io_u: 0.4731 - dice_coeficient: 0.9645 - val_loss: 0.0884 - val_mean_io_u: 0.4741 - val_dice_coeficient: 0.9602
# Epoch 25/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0631 - mean_io_u: 0.4748 - dice_coeficient: 0.9650
# Epoch 25: val_loss did not improve from 0.08839
# 101/101 [==============================] - 19s 193ms/step - loss: 0.0631 - mean_io_u: 0.4748 - dice_coeficient: 0.9650 - val_loss: 0.0909 - val_mean_io_u: 0.4711 - val_dice_coeficient: 0.9595
# Epoch 26/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0604 - mean_io_u: 0.4747 - dice_coeficient: 0.9658
# Epoch 26: val_loss did not improve from 0.08839
# 101/101 [==============================] - 19s 193ms/step - loss: 0.0604 - mean_io_u: 0.4747 - dice_coeficient: 0.9658 - val_loss: 0.0898 - val_mean_io_u: 0.4793 - val_dice_coeficient: 0.9619
# Epoch 27/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0592 - mean_io_u: 0.4787 - dice_coeficient: 0.9668
# Epoch 27: val_loss did not improve from 0.08839
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0592 - mean_io_u: 0.4787 - dice_coeficient: 0.9668 - val_loss: 0.0894 - val_mean_io_u: 0.4770 - val_dice_coeficient: 0.9609
# Epoch 28/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0580 - mean_io_u: 0.4790 - dice_coeficient: 0.9674
# Epoch 28: val_loss did not improve from 0.08839
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0580 - mean_io_u: 0.4790 - dice_coeficient: 0.9674 - val_loss: 0.0914 - val_mean_io_u: 0.4775 - val_dice_coeficient: 0.9603
# Epoch 29/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0575 - mean_io_u: 0.4795 - dice_coeficient: 0.9677
# Epoch 29: val_loss did not improve from 0.08839
# 101/101 [==============================] - 19s 193ms/step - loss: 0.0575 - mean_io_u: 0.4795 - dice_coeficient: 0.9677 - val_loss: 0.0928 - val_mean_io_u: 0.4793 - val_dice_coeficient: 0.9614
# Epoch 30/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0580 - mean_io_u: 0.4774 - dice_coeficient: 0.9676
# Epoch 30: val_loss improved from 0.08839 to 0.08828, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 20s 201ms/step - loss: 0.0580 - mean_io_u: 0.4774 - dice_coeficient: 0.9676 - val_loss: 0.0883 - val_mean_io_u: 0.4792 - val_dice_coeficient: 0.9630
# Epoch 31/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0551 - mean_io_u: 0.4796 - dice_coeficient: 0.9689
# Epoch 31: val_loss improved from 0.08828 to 0.08733, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 24s 240ms/step - loss: 0.0551 - mean_io_u: 0.4796 - dice_coeficient: 0.9689 - val_loss: 0.0873 - val_mean_io_u: 0.4810 - val_dice_coeficient: 0.9639
# Epoch 32/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0539 - mean_io_u: 0.4837 - dice_coeficient: 0.9695
# Epoch 32: val_loss did not improve from 0.08733
# 101/101 [==============================] - 19s 189ms/step - loss: 0.0539 - mean_io_u: 0.4837 - dice_coeficient: 0.9695 - val_loss: 0.0916 - val_mean_io_u: 0.4805 - val_dice_coeficient: 0.9614
# Epoch 33/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0541 - mean_io_u: 0.4832 - dice_coeficient: 0.9698
# Epoch 33: val_loss did not improve from 0.08733
# 101/101 [==============================] - 19s 193ms/step - loss: 0.0541 - mean_io_u: 0.4832 - dice_coeficient: 0.9698 - val_loss: 0.0937 - val_mean_io_u: 0.4783 - val_dice_coeficient: 0.9607
# Epoch 34/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0542 - mean_io_u: 0.4800 - dice_coeficient: 0.9697
# Epoch 34: val_loss did not improve from 0.08733
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0542 - mean_io_u: 0.4800 - dice_coeficient: 0.9697 - val_loss: 0.0892 - val_mean_io_u: 0.4794 - val_dice_coeficient: 0.9639
# Epoch 35/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0517 - mean_io_u: 0.4814 - dice_coeficient: 0.9708
# Epoch 35: val_loss did not improve from 0.08733
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0517 - mean_io_u: 0.4814 - dice_coeficient: 0.9708 - val_loss: 0.0875 - val_mean_io_u: 0.4863 - val_dice_coeficient: 0.9649
# Epoch 36/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0498 - mean_io_u: 0.4871 - dice_coeficient: 0.9717
# Epoch 36: val_loss improved from 0.08733 to 0.08705, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 21s 213ms/step - loss: 0.0498 - mean_io_u: 0.4871 - dice_coeficient: 0.9717 - val_loss: 0.0870 - val_mean_io_u: 0.4864 - val_dice_coeficient: 0.9651
# Epoch 37/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0506 - mean_io_u: 0.4884 - dice_coeficient: 0.9716
# Epoch 37: val_loss did not improve from 0.08705
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0506 - mean_io_u: 0.4884 - dice_coeficient: 0.9716 - val_loss: 0.0950 - val_mean_io_u: 0.4865 - val_dice_coeficient: 0.9639
# Epoch 38/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0505 - mean_io_u: 0.4852 - dice_coeficient: 0.9719
# Epoch 38: val_loss improved from 0.08705 to 0.08683, saving model to ../models\swin-unet_train_Weights.hdf5
# 101/101 [==============================] - 20s 200ms/step - loss: 0.0505 - mean_io_u: 0.4852 - dice_coeficient: 0.9719 - val_loss: 0.0868 - val_mean_io_u: 0.4854 - val_dice_coeficient: 0.9651
# Epoch 39/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0470 - mean_io_u: 0.4903 - dice_coeficient: 0.9731
# Epoch 39: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0470 - mean_io_u: 0.4903 - dice_coeficient: 0.9731 - val_loss: 0.0910 - val_mean_io_u: 0.4944 - val_dice_coeficient: 0.9659
# Epoch 40/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0471 - mean_io_u: 0.4920 - dice_coeficient: 0.9733
# Epoch 40: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0471 - mean_io_u: 0.4920 - dice_coeficient: 0.9733 - val_loss: 0.0879 - val_mean_io_u: 0.4910 - val_dice_coeficient: 0.9654
# Epoch 41/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0470 - mean_io_u: 0.4937 - dice_coeficient: 0.9734
# Epoch 41: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0470 - mean_io_u: 0.4937 - dice_coeficient: 0.9734 - val_loss: 0.0906 - val_mean_io_u: 0.4925 - val_dice_coeficient: 0.9651
# Epoch 42/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0465 - mean_io_u: 0.4936 - dice_coeficient: 0.9740
# Epoch 42: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0465 - mean_io_u: 0.4936 - dice_coeficient: 0.9740 - val_loss: 0.0883 - val_mean_io_u: 0.4915 - val_dice_coeficient: 0.9668
# Epoch 43/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0447 - mean_io_u: 0.4941 - dice_coeficient: 0.9745
# Epoch 43: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 197ms/step - loss: 0.0447 - mean_io_u: 0.4941 - dice_coeficient: 0.9745 - val_loss: 0.0877 - val_mean_io_u: 0.4969 - val_dice_coeficient: 0.9663
# Epoch 44/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0428 - mean_io_u: 0.5043 - dice_coeficient: 0.9754
# Epoch 44: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0428 - mean_io_u: 0.5043 - dice_coeficient: 0.9754 - val_loss: 0.0898 - val_mean_io_u: 0.5009 - val_dice_coeficient: 0.9669
# Epoch 45/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0446 - mean_io_u: 0.5036 - dice_coeficient: 0.9751
# Epoch 45: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0446 - mean_io_u: 0.5036 - dice_coeficient: 0.9751 - val_loss: 0.0919 - val_mean_io_u: 0.4955 - val_dice_coeficient: 0.9655
# Epoch 46/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0441 - mean_io_u: 0.4980 - dice_coeficient: 0.9750
# Epoch 46: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 193ms/step - loss: 0.0441 - mean_io_u: 0.4980 - dice_coeficient: 0.9750 - val_loss: 0.0880 - val_mean_io_u: 0.5027 - val_dice_coeficient: 0.9678
# Epoch 47/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0448 - mean_io_u: 0.5008 - dice_coeficient: 0.9751
# Epoch 47: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 197ms/step - loss: 0.0448 - mean_io_u: 0.5008 - dice_coeficient: 0.9751 - val_loss: 0.0893 - val_mean_io_u: 0.4995 - val_dice_coeficient: 0.9676
# Epoch 48/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0408 - mean_io_u: 0.5059 - dice_coeficient: 0.9764
# Epoch 48: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0408 - mean_io_u: 0.5059 - dice_coeficient: 0.9764 - val_loss: 0.0904 - val_mean_io_u: 0.5090 - val_dice_coeficient: 0.9678
# Epoch 49/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0449 - mean_io_u: 0.4991 - dice_coeficient: 0.9754
# Epoch 49: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0449 - mean_io_u: 0.4991 - dice_coeficient: 0.9754 - val_loss: 0.0888 - val_mean_io_u: 0.5014 - val_dice_coeficient: 0.9680
# Epoch 50/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0388 - mean_io_u: 0.5070 - dice_coeficient: 0.9773
# Epoch 50: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0388 - mean_io_u: 0.5070 - dice_coeficient: 0.9773 - val_loss: 0.0894 - val_mean_io_u: 0.5134 - val_dice_coeficient: 0.9688
# Epoch 51/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0406 - mean_io_u: 0.5127 - dice_coeficient: 0.9771
# Epoch 51: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0406 - mean_io_u: 0.5127 - dice_coeficient: 0.9771 - val_loss: 0.0942 - val_mean_io_u: 0.5065 - val_dice_coeficient: 0.9670
# Epoch 52/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0395 - mean_io_u: 0.5108 - dice_coeficient: 0.9774
# Epoch 52: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0395 - mean_io_u: 0.5108 - dice_coeficient: 0.9774 - val_loss: 0.0900 - val_mean_io_u: 0.5179 - val_dice_coeficient: 0.9687
# Epoch 53/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0361 - mean_io_u: 0.5235 - dice_coeficient: 0.9790
# Epoch 53: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0361 - mean_io_u: 0.5235 - dice_coeficient: 0.9790 - val_loss: 0.0916 - val_mean_io_u: 0.5257 - val_dice_coeficient: 0.9691
# Epoch 54/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0349 - mean_io_u: 0.5356 - dice_coeficient: 0.9796
# Epoch 54: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0349 - mean_io_u: 0.5356 - dice_coeficient: 0.9796 - val_loss: 0.0932 - val_mean_io_u: 0.5358 - val_dice_coeficient: 0.9693
# Epoch 55/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0371 - mean_io_u: 0.5283 - dice_coeficient: 0.9790
# Epoch 55: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0371 - mean_io_u: 0.5283 - dice_coeficient: 0.9790 - val_loss: 0.0912 - val_mean_io_u: 0.5356 - val_dice_coeficient: 0.9698
# Epoch 56/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0344 - mean_io_u: 0.5439 - dice_coeficient: 0.9800
# Epoch 56: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0344 - mean_io_u: 0.5439 - dice_coeficient: 0.9800 - val_loss: 0.0927 - val_mean_io_u: 0.5480 - val_dice_coeficient: 0.9703
# Epoch 57/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0358 - mean_io_u: 0.5382 - dice_coeficient: 0.9797
# Epoch 57: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0358 - mean_io_u: 0.5382 - dice_coeficient: 0.9797 - val_loss: 0.0917 - val_mean_io_u: 0.5357 - val_dice_coeficient: 0.9697
# Epoch 58/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0352 - mean_io_u: 0.5404 - dice_coeficient: 0.9798
# Epoch 58: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0352 - mean_io_u: 0.5404 - dice_coeficient: 0.9798 - val_loss: 0.0954 - val_mean_io_u: 0.5389 - val_dice_coeficient: 0.9698
# Epoch 59/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0338 - mean_io_u: 0.5447 - dice_coeficient: 0.9805
# Epoch 59: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0338 - mean_io_u: 0.5447 - dice_coeficient: 0.9805 - val_loss: 0.0966 - val_mean_io_u: 0.5437 - val_dice_coeficient: 0.9689
# Epoch 60/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0334 - mean_io_u: 0.5521 - dice_coeficient: 0.9807
# Epoch 60: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0334 - mean_io_u: 0.5521 - dice_coeficient: 0.9807 - val_loss: 0.1018 - val_mean_io_u: 0.5464 - val_dice_coeficient: 0.9680
# Epoch 61/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0344 - mean_io_u: 0.5504 - dice_coeficient: 0.9806
# Epoch 61: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0344 - mean_io_u: 0.5504 - dice_coeficient: 0.9806 - val_loss: 0.0941 - val_mean_io_u: 0.5447 - val_dice_coeficient: 0.9704
# Epoch 62/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0346 - mean_io_u: 0.5539 - dice_coeficient: 0.9806
# Epoch 62: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0346 - mean_io_u: 0.5539 - dice_coeficient: 0.9806 - val_loss: 0.0995 - val_mean_io_u: 0.5322 - val_dice_coeficient: 0.9679
# Epoch 63/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0384 - mean_io_u: 0.5326 - dice_coeficient: 0.9790
# Epoch 63: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0384 - mean_io_u: 0.5326 - dice_coeficient: 0.9790 - val_loss: 0.0930 - val_mean_io_u: 0.5389 - val_dice_coeficient: 0.9706
# Epoch 64/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0345 - mean_io_u: 0.5370 - dice_coeficient: 0.9804
# Epoch 64: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0345 - mean_io_u: 0.5370 - dice_coeficient: 0.9804 - val_loss: 0.0961 - val_mean_io_u: 0.5246 - val_dice_coeficient: 0.9685
# Epoch 65/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0332 - mean_io_u: 0.5410 - dice_coeficient: 0.9809
# Epoch 65: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0332 - mean_io_u: 0.5410 - dice_coeficient: 0.9809 - val_loss: 0.0928 - val_mean_io_u: 0.5472 - val_dice_coeficient: 0.9710
# Epoch 66/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0319 - mean_io_u: 0.5499 - dice_coeficient: 0.9816
# Epoch 66: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 198ms/step - loss: 0.0319 - mean_io_u: 0.5499 - dice_coeficient: 0.9816 - val_loss: 0.0956 - val_mean_io_u: 0.5465 - val_dice_coeficient: 0.9705
# Epoch 67/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0325 - mean_io_u: 0.5479 - dice_coeficient: 0.9814
# Epoch 67: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0325 - mean_io_u: 0.5479 - dice_coeficient: 0.9814 - val_loss: 0.0951 - val_mean_io_u: 0.5503 - val_dice_coeficient: 0.9709
# Epoch 68/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0299 - mean_io_u: 0.5556 - dice_coeficient: 0.9826
# Epoch 68: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0299 - mean_io_u: 0.5556 - dice_coeficient: 0.9826 - val_loss: 0.0957 - val_mean_io_u: 0.5556 - val_dice_coeficient: 0.9713
# Epoch 69/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0283 - mean_io_u: 0.5716 - dice_coeficient: 0.9833
# Epoch 69: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 197ms/step - loss: 0.0283 - mean_io_u: 0.5716 - dice_coeficient: 0.9833 - val_loss: 0.0969 - val_mean_io_u: 0.5718 - val_dice_coeficient: 0.9715
# Epoch 70/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0273 - mean_io_u: 0.5835 - dice_coeficient: 0.9838
# Epoch 70: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0273 - mean_io_u: 0.5835 - dice_coeficient: 0.9838 - val_loss: 0.0985 - val_mean_io_u: 0.5836 - val_dice_coeficient: 0.9717
# Epoch 71/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0274 - mean_io_u: 0.5970 - dice_coeficient: 0.9840
# Epoch 71: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 197ms/step - loss: 0.0274 - mean_io_u: 0.5970 - dice_coeficient: 0.9840 - val_loss: 0.0991 - val_mean_io_u: 0.6008 - val_dice_coeficient: 0.9720
# Epoch 72/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0273 - mean_io_u: 0.6011 - dice_coeficient: 0.9841
# Epoch 72: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0273 - mean_io_u: 0.6011 - dice_coeficient: 0.9841 - val_loss: 0.0995 - val_mean_io_u: 0.6004 - val_dice_coeficient: 0.9719
# Epoch 73/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0276 - mean_io_u: 0.5985 - dice_coeficient: 0.9841
# Epoch 73: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0276 - mean_io_u: 0.5985 - dice_coeficient: 0.9841 - val_loss: 0.1000 - val_mean_io_u: 0.6008 - val_dice_coeficient: 0.9721
# Epoch 74/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0259 - mean_io_u: 0.6118 - dice_coeficient: 0.9848
# Epoch 74: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0259 - mean_io_u: 0.6118 - dice_coeficient: 0.9848 - val_loss: 0.1022 - val_mean_io_u: 0.6113 - val_dice_coeficient: 0.9719
# Epoch 75/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0274 - mean_io_u: 0.6082 - dice_coeficient: 0.9844
# Epoch 75: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0274 - mean_io_u: 0.6082 - dice_coeficient: 0.9844 - val_loss: 0.1006 - val_mean_io_u: 0.6082 - val_dice_coeficient: 0.9722
# Epoch 76/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0251 - mean_io_u: 0.6208 - dice_coeficient: 0.9852
# Epoch 76: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0251 - mean_io_u: 0.6208 - dice_coeficient: 0.9852 - val_loss: 0.1018 - val_mean_io_u: 0.6304 - val_dice_coeficient: 0.9726
# Epoch 77/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0256 - mean_io_u: 0.6277 - dice_coeficient: 0.9852
# Epoch 77: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 197ms/step - loss: 0.0256 - mean_io_u: 0.6277 - dice_coeficient: 0.9852 - val_loss: 0.1031 - val_mean_io_u: 0.6076 - val_dice_coeficient: 0.9720
# Epoch 78/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0257 - mean_io_u: 0.6152 - dice_coeficient: 0.9852
# Epoch 78: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0257 - mean_io_u: 0.6152 - dice_coeficient: 0.9852 - val_loss: 0.1022 - val_mean_io_u: 0.6219 - val_dice_coeficient: 0.9727
# Epoch 79/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0240 - mean_io_u: 0.6326 - dice_coeficient: 0.9859
# Epoch 79: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 199ms/step - loss: 0.0240 - mean_io_u: 0.6326 - dice_coeficient: 0.9859 - val_loss: 0.1047 - val_mean_io_u: 0.6369 - val_dice_coeficient: 0.9725
# Epoch 80/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0236 - mean_io_u: 0.6447 - dice_coeficient: 0.9862
# Epoch 80: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0236 - mean_io_u: 0.6447 - dice_coeficient: 0.9862 - val_loss: 0.1051 - val_mean_io_u: 0.6472 - val_dice_coeficient: 0.9729
# Epoch 81/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0233 - mean_io_u: 0.6496 - dice_coeficient: 0.9863
# Epoch 81: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0233 - mean_io_u: 0.6496 - dice_coeficient: 0.9863 - val_loss: 0.1063 - val_mean_io_u: 0.6596 - val_dice_coeficient: 0.9730
# Epoch 82/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0226 - mean_io_u: 0.6622 - dice_coeficient: 0.9867
# Epoch 82: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0226 - mean_io_u: 0.6622 - dice_coeficient: 0.9867 - val_loss: 0.1075 - val_mean_io_u: 0.6604 - val_dice_coeficient: 0.9729
# Epoch 83/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0228 - mean_io_u: 0.6642 - dice_coeficient: 0.9867
# Epoch 83: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 197ms/step - loss: 0.0228 - mean_io_u: 0.6642 - dice_coeficient: 0.9867 - val_loss: 0.1098 - val_mean_io_u: 0.6664 - val_dice_coeficient: 0.9729
# Epoch 84/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0228 - mean_io_u: 0.6683 - dice_coeficient: 0.9868
# Epoch 84: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0228 - mean_io_u: 0.6683 - dice_coeficient: 0.9868 - val_loss: 0.1096 - val_mean_io_u: 0.6656 - val_dice_coeficient: 0.9728
# Epoch 85/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0225 - mean_io_u: 0.6717 - dice_coeficient: 0.9870
# Epoch 85: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0225 - mean_io_u: 0.6717 - dice_coeficient: 0.9870 - val_loss: 0.1096 - val_mean_io_u: 0.6698 - val_dice_coeficient: 0.9731
# Epoch 86/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0220 - mean_io_u: 0.6750 - dice_coeficient: 0.9872
# Epoch 86: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0220 - mean_io_u: 0.6750 - dice_coeficient: 0.9872 - val_loss: 0.1124 - val_mean_io_u: 0.6730 - val_dice_coeficient: 0.9727
# Epoch 87/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0218 - mean_io_u: 0.6789 - dice_coeficient: 0.9873
# Epoch 87: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0218 - mean_io_u: 0.6789 - dice_coeficient: 0.9873 - val_loss: 0.1115 - val_mean_io_u: 0.6864 - val_dice_coeficient: 0.9730
# Epoch 88/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0214 - mean_io_u: 0.6850 - dice_coeficient: 0.9875
# Epoch 88: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0214 - mean_io_u: 0.6850 - dice_coeficient: 0.9875 - val_loss: 0.1128 - val_mean_io_u: 0.6802 - val_dice_coeficient: 0.9732
# Epoch 89/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0209 - mean_io_u: 0.6892 - dice_coeficient: 0.9878
# Epoch 89: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0209 - mean_io_u: 0.6892 - dice_coeficient: 0.9878 - val_loss: 0.1136 - val_mean_io_u: 0.6864 - val_dice_coeficient: 0.9730
# Epoch 90/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0214 - mean_io_u: 0.6901 - dice_coeficient: 0.9877
# Epoch 90: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0214 - mean_io_u: 0.6901 - dice_coeficient: 0.9877 - val_loss: 0.1142 - val_mean_io_u: 0.6915 - val_dice_coeficient: 0.9731
# Epoch 91/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0203 - mean_io_u: 0.6948 - dice_coeficient: 0.9881
# Epoch 91: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 197ms/step - loss: 0.0203 - mean_io_u: 0.6948 - dice_coeficient: 0.9881 - val_loss: 0.1149 - val_mean_io_u: 0.6953 - val_dice_coeficient: 0.9732
# Epoch 92/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0195 - mean_io_u: 0.7014 - dice_coeficient: 0.9885
# Epoch 92: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0195 - mean_io_u: 0.7014 - dice_coeficient: 0.9885 - val_loss: 0.1158 - val_mean_io_u: 0.7026 - val_dice_coeficient: 0.9734
# Epoch 93/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0193 - mean_io_u: 0.7087 - dice_coeficient: 0.9887
# Epoch 93: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 197ms/step - loss: 0.0193 - mean_io_u: 0.7087 - dice_coeficient: 0.9887 - val_loss: 0.1173 - val_mean_io_u: 0.7070 - val_dice_coeficient: 0.9734
# Epoch 94/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0192 - mean_io_u: 0.7118 - dice_coeficient: 0.9888
# Epoch 94: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0192 - mean_io_u: 0.7118 - dice_coeficient: 0.9888 - val_loss: 0.1186 - val_mean_io_u: 0.7127 - val_dice_coeficient: 0.9733
# Epoch 95/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0194 - mean_io_u: 0.7149 - dice_coeficient: 0.9888
# Epoch 95: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0194 - mean_io_u: 0.7149 - dice_coeficient: 0.9888 - val_loss: 0.1194 - val_mean_io_u: 0.7127 - val_dice_coeficient: 0.9734
# Epoch 96/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0190 - mean_io_u: 0.7187 - dice_coeficient: 0.9890
# Epoch 96: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0190 - mean_io_u: 0.7187 - dice_coeficient: 0.9890 - val_loss: 0.1209 - val_mean_io_u: 0.7146 - val_dice_coeficient: 0.9734
# Epoch 97/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0186 - mean_io_u: 0.7207 - dice_coeficient: 0.9892
# Epoch 97: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 198ms/step - loss: 0.0186 - mean_io_u: 0.7207 - dice_coeficient: 0.9892 - val_loss: 0.1198 - val_mean_io_u: 0.7197 - val_dice_coeficient: 0.9737
# Epoch 98/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0181 - mean_io_u: 0.7253 - dice_coeficient: 0.9895
# Epoch 98: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 198ms/step - loss: 0.0181 - mean_io_u: 0.7253 - dice_coeficient: 0.9895 - val_loss: 0.1219 - val_mean_io_u: 0.7243 - val_dice_coeficient: 0.9737
# Epoch 99/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0177 - mean_io_u: 0.7291 - dice_coeficient: 0.9897
# Epoch 99: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0177 - mean_io_u: 0.7291 - dice_coeficient: 0.9897 - val_loss: 0.1234 - val_mean_io_u: 0.7279 - val_dice_coeficient: 0.9737
# Epoch 100/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0175 - mean_io_u: 0.7333 - dice_coeficient: 0.9898
# Epoch 100: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0175 - mean_io_u: 0.7333 - dice_coeficient: 0.9898 - val_loss: 0.1239 - val_mean_io_u: 0.7338 - val_dice_coeficient: 0.9739
# Epoch 101/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0169 - mean_io_u: 0.7391 - dice_coeficient: 0.9901
# Epoch 101: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0169 - mean_io_u: 0.7391 - dice_coeficient: 0.9901 - val_loss: 0.1266 - val_mean_io_u: 0.7381 - val_dice_coeficient: 0.9736
# Epoch 102/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0169 - mean_io_u: 0.7414 - dice_coeficient: 0.9902
# Epoch 102: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0169 - mean_io_u: 0.7414 - dice_coeficient: 0.9902 - val_loss: 0.1255 - val_mean_io_u: 0.7402 - val_dice_coeficient: 0.9739
# Epoch 103/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.7454 - dice_coeficient: 0.9903
# Epoch 103: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0166 - mean_io_u: 0.7454 - dice_coeficient: 0.9903 - val_loss: 0.1269 - val_mean_io_u: 0.7443 - val_dice_coeficient: 0.9740
# Epoch 104/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0163 - mean_io_u: 0.7502 - dice_coeficient: 0.9905
# Epoch 104: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0163 - mean_io_u: 0.7502 - dice_coeficient: 0.9905 - val_loss: 0.1284 - val_mean_io_u: 0.7470 - val_dice_coeficient: 0.9737
# Epoch 105/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0162 - mean_io_u: 0.7528 - dice_coeficient: 0.9906
# Epoch 105: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0162 - mean_io_u: 0.7528 - dice_coeficient: 0.9906 - val_loss: 0.1296 - val_mean_io_u: 0.7522 - val_dice_coeficient: 0.9739
# Epoch 106/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.7549 - dice_coeficient: 0.9905
# Epoch 106: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0166 - mean_io_u: 0.7549 - dice_coeficient: 0.9905 - val_loss: 0.1306 - val_mean_io_u: 0.7491 - val_dice_coeficient: 0.9737
# Epoch 107/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0166 - mean_io_u: 0.7532 - dice_coeficient: 0.9905
# Epoch 107: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0166 - mean_io_u: 0.7532 - dice_coeficient: 0.9905 - val_loss: 0.1300 - val_mean_io_u: 0.7481 - val_dice_coeficient: 0.9738
# Epoch 108/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0158 - mean_io_u: 0.7560 - dice_coeficient: 0.9908
# Epoch 108: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0158 - mean_io_u: 0.7560 - dice_coeficient: 0.9908 - val_loss: 0.1302 - val_mean_io_u: 0.7520 - val_dice_coeficient: 0.9740
# Epoch 109/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0151 - mean_io_u: 0.7611 - dice_coeficient: 0.9912
# Epoch 109: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0151 - mean_io_u: 0.7611 - dice_coeficient: 0.9912 - val_loss: 0.1311 - val_mean_io_u: 0.7599 - val_dice_coeficient: 0.9742
# Epoch 110/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0147 - mean_io_u: 0.7648 - dice_coeficient: 0.9914
# Epoch 110: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 195ms/step - loss: 0.0147 - mean_io_u: 0.7648 - dice_coeficient: 0.9914 - val_loss: 0.1334 - val_mean_io_u: 0.7640 - val_dice_coeficient: 0.9742
# Epoch 111/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0142 - mean_io_u: 0.7699 - dice_coeficient: 0.9917
# Epoch 111: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0142 - mean_io_u: 0.7699 - dice_coeficient: 0.9917 - val_loss: 0.1344 - val_mean_io_u: 0.7675 - val_dice_coeficient: 0.9742
# Epoch 112/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0141 - mean_io_u: 0.7734 - dice_coeficient: 0.9918
# Epoch 112: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0141 - mean_io_u: 0.7734 - dice_coeficient: 0.9918 - val_loss: 0.1361 - val_mean_io_u: 0.7693 - val_dice_coeficient: 0.9742
# Epoch 113/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0143 - mean_io_u: 0.7756 - dice_coeficient: 0.9918
# Epoch 113: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 185ms/step - loss: 0.0143 - mean_io_u: 0.7756 - dice_coeficient: 0.9918 - val_loss: 0.1367 - val_mean_io_u: 0.7727 - val_dice_coeficient: 0.9742
# Epoch 114/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0138 - mean_io_u: 0.7791 - dice_coeficient: 0.9920
# Epoch 114: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0138 - mean_io_u: 0.7791 - dice_coeficient: 0.9920 - val_loss: 0.1384 - val_mean_io_u: 0.7756 - val_dice_coeficient: 0.9741
# Epoch 115/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0139 - mean_io_u: 0.7807 - dice_coeficient: 0.9920
# Epoch 115: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0139 - mean_io_u: 0.7807 - dice_coeficient: 0.9920 - val_loss: 0.1384 - val_mean_io_u: 0.7776 - val_dice_coeficient: 0.9742
# Epoch 116/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0135 - mean_io_u: 0.7837 - dice_coeficient: 0.9922
# Epoch 116: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0135 - mean_io_u: 0.7837 - dice_coeficient: 0.9922 - val_loss: 0.1405 - val_mean_io_u: 0.7788 - val_dice_coeficient: 0.9742
# Epoch 117/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0135 - mean_io_u: 0.7863 - dice_coeficient: 0.9922
# Epoch 117: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0135 - mean_io_u: 0.7863 - dice_coeficient: 0.9922 - val_loss: 0.1412 - val_mean_io_u: 0.7842 - val_dice_coeficient: 0.9743
# Epoch 118/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0133 - mean_io_u: 0.7890 - dice_coeficient: 0.9924
# Epoch 118: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0133 - mean_io_u: 0.7890 - dice_coeficient: 0.9924 - val_loss: 0.1415 - val_mean_io_u: 0.7845 - val_dice_coeficient: 0.9744
# Epoch 119/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0134 - mean_io_u: 0.7898 - dice_coeficient: 0.9924
# Epoch 119: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0134 - mean_io_u: 0.7898 - dice_coeficient: 0.9924 - val_loss: 0.1432 - val_mean_io_u: 0.7871 - val_dice_coeficient: 0.9742
# Epoch 120/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0129 - mean_io_u: 0.7923 - dice_coeficient: 0.9926
# Epoch 120: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0129 - mean_io_u: 0.7923 - dice_coeficient: 0.9926 - val_loss: 0.1433 - val_mean_io_u: 0.7898 - val_dice_coeficient: 0.9743
# Epoch 121/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0127 - mean_io_u: 0.7943 - dice_coeficient: 0.9927
# Epoch 121: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0127 - mean_io_u: 0.7943 - dice_coeficient: 0.9927 - val_loss: 0.1441 - val_mean_io_u: 0.7935 - val_dice_coeficient: 0.9744
# Epoch 122/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0122 - mean_io_u: 0.7973 - dice_coeficient: 0.9930
# Epoch 122: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0122 - mean_io_u: 0.7973 - dice_coeficient: 0.9930 - val_loss: 0.1462 - val_mean_io_u: 0.7913 - val_dice_coeficient: 0.9743
# Epoch 123/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0120 - mean_io_u: 0.7999 - dice_coeficient: 0.9931
# Epoch 123: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0120 - mean_io_u: 0.7999 - dice_coeficient: 0.9931 - val_loss: 0.1474 - val_mean_io_u: 0.7975 - val_dice_coeficient: 0.9745
# Epoch 124/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0121 - mean_io_u: 0.8023 - dice_coeficient: 0.9931
# Epoch 124: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 185ms/step - loss: 0.0121 - mean_io_u: 0.8023 - dice_coeficient: 0.9931 - val_loss: 0.1470 - val_mean_io_u: 0.8008 - val_dice_coeficient: 0.9746
# Epoch 125/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0117 - mean_io_u: 0.8049 - dice_coeficient: 0.9933
# Epoch 125: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0117 - mean_io_u: 0.8049 - dice_coeficient: 0.9933 - val_loss: 0.1479 - val_mean_io_u: 0.8011 - val_dice_coeficient: 0.9746
# Epoch 126/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0115 - mean_io_u: 0.8064 - dice_coeficient: 0.9934
# Epoch 126: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0115 - mean_io_u: 0.8064 - dice_coeficient: 0.9934 - val_loss: 0.1497 - val_mean_io_u: 0.8022 - val_dice_coeficient: 0.9744
# Epoch 127/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0119 - mean_io_u: 0.8075 - dice_coeficient: 0.9933
# Epoch 127: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0119 - mean_io_u: 0.8075 - dice_coeficient: 0.9933 - val_loss: 0.1498 - val_mean_io_u: 0.8058 - val_dice_coeficient: 0.9746
# Epoch 128/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0115 - mean_io_u: 0.8094 - dice_coeficient: 0.9935
# Epoch 128: val_loss did not improve from 0.08683
# ...
# 101/101 [==============================] - 18s 182ms/step - loss: 0.0068 - mean_io_u: 0.7849 - dice_coeficient: 0.9957 - val_loss: 0.1514 - val_mean_io_u: 0.7821 - val_dice_coeficient: 0.9750
# Epoch 158/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0068 - mean_io_u: 0.7977 - dice_coeficient: 0.9959
# Epoch 158: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 182ms/step - loss: 0.0068 - mean_io_u: 0.7977 - dice_coeficient: 0.9959 - val_loss: 0.1551 - val_mean_io_u: 0.7875 - val_dice_coeficient: 0.9748
# Epoch 159/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0075 - mean_io_u: 0.7992 - dice_coeficient: 0.9956
# Epoch 159: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 182ms/step - loss: 0.0075 - mean_io_u: 0.7992 - dice_coeficient: 0.9956 - val_loss: 0.1542 - val_mean_io_u: 0.8017 - val_dice_coeficient: 0.9753
# Epoch 160/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0075 - mean_io_u: 0.8013 - dice_coeficient: 0.9958
# Epoch 160: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0075 - mean_io_u: 0.8013 - dice_coeficient: 0.9958 - val_loss: 0.1562 - val_mean_io_u: 0.8071 - val_dice_coeficient: 0.9753
# Epoch 161/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0062 - mean_io_u: 0.8147 - dice_coeficient: 0.9963
# Epoch 161: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 180ms/step - loss: 0.0062 - mean_io_u: 0.8147 - dice_coeficient: 0.9963 - val_loss: 0.1590 - val_mean_io_u: 0.8098 - val_dice_coeficient: 0.9752
# Epoch 162/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0061 - mean_io_u: 0.8196 - dice_coeficient: 0.9964
# Epoch 162: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0061 - mean_io_u: 0.8196 - dice_coeficient: 0.9964 - val_loss: 0.1614 - val_mean_io_u: 0.8162 - val_dice_coeficient: 0.9752
# Epoch 163/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0063 - mean_io_u: 0.8233 - dice_coeficient: 0.9964
# Epoch 163: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0063 - mean_io_u: 0.8233 - dice_coeficient: 0.9964 - val_loss: 0.1630 - val_mean_io_u: 0.8194 - val_dice_coeficient: 0.9751
# Epoch 164/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0064 - mean_io_u: 0.8263 - dice_coeficient: 0.9964
# Epoch 164: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0064 - mean_io_u: 0.8263 - dice_coeficient: 0.9964 - val_loss: 0.1639 - val_mean_io_u: 0.8224 - val_dice_coeficient: 0.9752
# Epoch 165/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0064 - mean_io_u: 0.8298 - dice_coeficient: 0.9964
# Epoch 165: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 182ms/step - loss: 0.0064 - mean_io_u: 0.8298 - dice_coeficient: 0.9964 - val_loss: 0.1658 - val_mean_io_u: 0.8260 - val_dice_coeficient: 0.9752
# Epoch 166/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0065 - mean_io_u: 0.8324 - dice_coeficient: 0.9964
# Epoch 166: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0065 - mean_io_u: 0.8324 - dice_coeficient: 0.9964 - val_loss: 0.1664 - val_mean_io_u: 0.8260 - val_dice_coeficient: 0.9752
# Epoch 167/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0068 - mean_io_u: 0.8341 - dice_coeficient: 0.9963
# Epoch 167: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 183ms/step - loss: 0.0068 - mean_io_u: 0.8341 - dice_coeficient: 0.9963 - val_loss: 0.1674 - val_mean_io_u: 0.8282 - val_dice_coeficient: 0.9751
# Epoch 168/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0067 - mean_io_u: 0.8357 - dice_coeficient: 0.9963
# Epoch 168: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0067 - mean_io_u: 0.8357 - dice_coeficient: 0.9963 - val_loss: 0.1701 - val_mean_io_u: 0.8317 - val_dice_coeficient: 0.9750
# Epoch 169/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0071 - mean_io_u: 0.8368 - dice_coeficient: 0.9961
# Epoch 169: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0071 - mean_io_u: 0.8368 - dice_coeficient: 0.9961 - val_loss: 0.1704 - val_mean_io_u: 0.8292 - val_dice_coeficient: 0.9748
# Epoch 170/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0074 - mean_io_u: 0.8376 - dice_coeficient: 0.9960
# Epoch 170: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 184ms/step - loss: 0.0074 - mean_io_u: 0.8376 - dice_coeficient: 0.9960 - val_loss: 0.1716 - val_mean_io_u: 0.8301 - val_dice_coeficient: 0.9748
# Epoch 171/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0075 - mean_io_u: 0.8383 - dice_coeficient: 0.9960
# Epoch 171: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 185ms/step - loss: 0.0075 - mean_io_u: 0.8383 - dice_coeficient: 0.9960 - val_loss: 0.1717 - val_mean_io_u: 0.8323 - val_dice_coeficient: 0.9749
# Epoch 172/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0078 - mean_io_u: 0.8394 - dice_coeficient: 0.9958
# Epoch 172: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 182ms/step - loss: 0.0078 - mean_io_u: 0.8394 - dice_coeficient: 0.9958 - val_loss: 0.1721 - val_mean_io_u: 0.8328 - val_dice_coeficient: 0.9748
# Epoch 173/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0085 - mean_io_u: 0.8390 - dice_coeficient: 0.9956
# Epoch 173: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0085 - mean_io_u: 0.8390 - dice_coeficient: 0.9956 - val_loss: 0.1729 - val_mean_io_u: 0.8322 - val_dice_coeficient: 0.9745
# Epoch 174/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0083 - mean_io_u: 0.8380 - dice_coeficient: 0.9956
# Epoch 174: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 182ms/step - loss: 0.0083 - mean_io_u: 0.8380 - dice_coeficient: 0.9956 - val_loss: 0.1718 - val_mean_io_u: 0.8332 - val_dice_coeficient: 0.9748
# Epoch 175/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0082 - mean_io_u: 0.8373 - dice_coeficient: 0.9956
# Epoch 175: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 182ms/step - loss: 0.0082 - mean_io_u: 0.8373 - dice_coeficient: 0.9956 - val_loss: 0.1717 - val_mean_io_u: 0.8331 - val_dice_coeficient: 0.9748
# Epoch 176/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0074 - mean_io_u: 0.8396 - dice_coeficient: 0.9960
# Epoch 176: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0074 - mean_io_u: 0.8396 - dice_coeficient: 0.9960 - val_loss: 0.1717 - val_mean_io_u: 0.8366 - val_dice_coeficient: 0.9749
# Epoch 177/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0074 - mean_io_u: 0.8397 - dice_coeficient: 0.9961
# Epoch 177: val_loss did not improve from 0.08683
# 101/101 [==============================] - 18s 183ms/step - loss: 0.0074 - mean_io_u: 0.8397 - dice_coeficient: 0.9961 - val_loss: 0.1714 - val_mean_io_u: 0.8360 - val_dice_coeficient: 0.9751
# Epoch 178/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0070 - mean_io_u: 0.8418 - dice_coeficient: 0.9963
# Epoch 178: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 196ms/step - loss: 0.0070 - mean_io_u: 0.8418 - dice_coeficient: 0.9963 - val_loss: 0.1714 - val_mean_io_u: 0.8348 - val_dice_coeficient: 0.9751
# Epoch 179/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0069 - mean_io_u: 0.8419 - dice_coeficient: 0.9963
# Epoch 179: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 198ms/step - loss: 0.0069 - mean_io_u: 0.8419 - dice_coeficient: 0.9963 - val_loss: 0.1738 - val_mean_io_u: 0.8345 - val_dice_coeficient: 0.9749
# Epoch 180/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0066 - mean_io_u: 0.8448 - dice_coeficient: 0.9965
# Epoch 180: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 193ms/step - loss: 0.0066 - mean_io_u: 0.8448 - dice_coeficient: 0.9965 - val_loss: 0.1734 - val_mean_io_u: 0.8378 - val_dice_coeficient: 0.9750
# Epoch 181/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0065 - mean_io_u: 0.8452 - dice_coeficient: 0.9966
# Epoch 181: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 192ms/step - loss: 0.0065 - mean_io_u: 0.8452 - dice_coeficient: 0.9966 - val_loss: 0.1748 - val_mean_io_u: 0.8400 - val_dice_coeficient: 0.9750
# Epoch 182/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0065 - mean_io_u: 0.8464 - dice_coeficient: 0.9966
# Epoch 182: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 194ms/step - loss: 0.0065 - mean_io_u: 0.8464 - dice_coeficient: 0.9966 - val_loss: 0.1748 - val_mean_io_u: 0.8409 - val_dice_coeficient: 0.9752
# Epoch 183/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0064 - mean_io_u: 0.8480 - dice_coeficient: 0.9967
# Epoch 183: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 192ms/step - loss: 0.0064 - mean_io_u: 0.8480 - dice_coeficient: 0.9967 - val_loss: 0.1773 - val_mean_io_u: 0.8428 - val_dice_coeficient: 0.9749
# Epoch 184/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0068 - mean_io_u: 0.8477 - dice_coeficient: 0.9965
# Epoch 184: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0068 - mean_io_u: 0.8477 - dice_coeficient: 0.9965 - val_loss: 0.1769 - val_mean_io_u: 0.8419 - val_dice_coeficient: 0.9750
# Epoch 185/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0068 - mean_io_u: 0.8473 - dice_coeficient: 0.9965
# Epoch 185: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 193ms/step - loss: 0.0068 - mean_io_u: 0.8473 - dice_coeficient: 0.9965 - val_loss: 0.1768 - val_mean_io_u: 0.8412 - val_dice_coeficient: 0.9749
# Epoch 186/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0067 - mean_io_u: 0.8485 - dice_coeficient: 0.9965
# Epoch 186: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0067 - mean_io_u: 0.8485 - dice_coeficient: 0.9965 - val_loss: 0.1779 - val_mean_io_u: 0.8448 - val_dice_coeficient: 0.9750
# Epoch 187/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0067 - mean_io_u: 0.8497 - dice_coeficient: 0.9965
# Epoch 187: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0067 - mean_io_u: 0.8497 - dice_coeficient: 0.9965 - val_loss: 0.1790 - val_mean_io_u: 0.8442 - val_dice_coeficient: 0.9747
# Epoch 188/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0074 - mean_io_u: 0.8494 - dice_coeficient: 0.9962
# Epoch 188: val_loss did not improve from 0.08683
# 101/101 [==============================] - 20s 193ms/step - loss: 0.0074 - mean_io_u: 0.8494 - dice_coeficient: 0.9962 - val_loss: 0.1790 - val_mean_io_u: 0.8425 - val_dice_coeficient: 0.9748
# Epoch 189/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0076 - mean_io_u: 0.8482 - dice_coeficient: 0.9961
# Epoch 189: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0076 - mean_io_u: 0.8482 - dice_coeficient: 0.9961 - val_loss: 0.1787 - val_mean_io_u: 0.8421 - val_dice_coeficient: 0.9747
# Epoch 190/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0072 - mean_io_u: 0.8486 - dice_coeficient: 0.9962
# Epoch 190: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0072 - mean_io_u: 0.8486 - dice_coeficient: 0.9962 - val_loss: 0.1785 - val_mean_io_u: 0.8447 - val_dice_coeficient: 0.9748
# Epoch 191/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0072 - mean_io_u: 0.8497 - dice_coeficient: 0.9963
# Epoch 191: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0072 - mean_io_u: 0.8497 - dice_coeficient: 0.9963 - val_loss: 0.1790 - val_mean_io_u: 0.8437 - val_dice_coeficient: 0.9749
# Epoch 192/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0070 - mean_io_u: 0.8495 - dice_coeficient: 0.9964
# Epoch 192: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 190ms/step - loss: 0.0070 - mean_io_u: 0.8495 - dice_coeficient: 0.9964 - val_loss: 0.1791 - val_mean_io_u: 0.8439 - val_dice_coeficient: 0.9749
# Epoch 193/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0069 - mean_io_u: 0.8500 - dice_coeficient: 0.9964
# Epoch 193: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 192ms/step - loss: 0.0069 - mean_io_u: 0.8500 - dice_coeficient: 0.9964 - val_loss: 0.1790 - val_mean_io_u: 0.8460 - val_dice_coeficient: 0.9750
# Epoch 194/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0069 - mean_io_u: 0.8506 - dice_coeficient: 0.9964
# Epoch 194: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0069 - mean_io_u: 0.8506 - dice_coeficient: 0.9964 - val_loss: 0.1806 - val_mean_io_u: 0.8442 - val_dice_coeficient: 0.9748
# Epoch 195/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0067 - mean_io_u: 0.8507 - dice_coeficient: 0.9966
# Epoch 195: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 192ms/step - loss: 0.0067 - mean_io_u: 0.8507 - dice_coeficient: 0.9966 - val_loss: 0.1804 - val_mean_io_u: 0.8438 - val_dice_coeficient: 0.9749
# Epoch 196/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0068 - mean_io_u: 0.8507 - dice_coeficient: 0.9965
# Epoch 196: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 192ms/step - loss: 0.0068 - mean_io_u: 0.8507 - dice_coeficient: 0.9965 - val_loss: 0.1802 - val_mean_io_u: 0.8442 - val_dice_coeficient: 0.9749
# Epoch 197/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0067 - mean_io_u: 0.8512 - dice_coeficient: 0.9966
# Epoch 197: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0067 - mean_io_u: 0.8512 - dice_coeficient: 0.9966 - val_loss: 0.1785 - val_mean_io_u: 0.8421 - val_dice_coeficient: 0.9750
# Epoch 198/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0064 - mean_io_u: 0.8515 - dice_coeficient: 0.9967
# Epoch 198: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 192ms/step - loss: 0.0064 - mean_io_u: 0.8515 - dice_coeficient: 0.9967 - val_loss: 0.1819 - val_mean_io_u: 0.8454 - val_dice_coeficient: 0.9747
# Epoch 199/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0063 - mean_io_u: 0.8523 - dice_coeficient: 0.9968
# Epoch 199: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0063 - mean_io_u: 0.8523 - dice_coeficient: 0.9968 - val_loss: 0.1801 - val_mean_io_u: 0.8471 - val_dice_coeficient: 0.9751
# Epoch 200/200
# 101/101 [==============================] - ETA: 0s - loss: 0.0076 - mean_io_u: 0.8497 - dice_coeficient: 0.9963
# Epoch 200: val_loss did not improve from 0.08683
# 101/101 [==============================] - 19s 191ms/step - loss: 0.0076 - mean_io_u: 0.8497 - dice_coeficient: 0.9963 - val_loss: 0.1837 - val_mean_io_u: 0.8397 - val_dice_coeficient: 0.9739

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 5s 47ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx])
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
