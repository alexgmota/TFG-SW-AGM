# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 4427

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

# def dice_loss(y_true, y_pred):
#     return 1 - dice_coeficient(y_true, y_pred)

# def tversky(y_true, y_pred, smooth=1, alpha=0.8):
#     T = tf.keras.backend.flatten(y_true)
#     P = tf.keras.backend.flatten(y_pred)
#     TP = tf.keras.backend.sum(T * P)
#     FN = tf.keras.backend.sum(T * (1 - P))
#     FP = tf.keras.backend.sum((1 - T) * P)
#     return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


# def tversky_loss(y_true, y_pred):
#     return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])

# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, clipvalue=0.5), 
    loss=tf.keras.losses.categorical_crossentropy,
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_train_Weights.hdf5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto'
)

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=4,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.3664 - mean_io_u: 0.4616 - dice_coeficient: 0.8360
# Epoch 1: val_loss improved from inf to 0.18300, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 156s 87ms/step - loss: 0.3664 - mean_io_u: 0.4616 - dice_coeficient: 0.8360 - val_loss: 0.1830 - val_mean_io_u: 0.4616 - val_dice_coeficient: 0.9097
# Epoch 2/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.1446 - mean_io_u: 0.4617 - dice_coeficient: 0.9272
# Epoch 2: val_loss improved from 0.18300 to 0.13456, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 146s 90ms/step - loss: 0.1446 - mean_io_u: 0.4617 - dice_coeficient: 0.9272 - val_loss: 0.1346 - val_mean_io_u: 0.4617 - val_dice_coeficient: 0.9348
# Epoch 3/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.1173 - mean_io_u: 0.4617 - dice_coeficient: 0.9409
# Epoch 3: val_loss improved from 0.13456 to 0.11549, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 138s 85ms/step - loss: 0.1173 - mean_io_u: 0.4617 - dice_coeficient: 0.9409 - val_loss: 0.1155 - val_mean_io_u: 0.4617 - val_dice_coeficient: 0.9438
# Epoch 4/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.1051 - mean_io_u: 0.4618 - dice_coeficient: 0.9471
# Epoch 4: val_loss improved from 0.11549 to 0.10026, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 130s 80ms/step - loss: 0.1051 - mean_io_u: 0.4618 - dice_coeficient: 0.9471 - val_loss: 0.1003 - val_mean_io_u: 0.4617 - val_dice_coeficient: 0.9508
# Epoch 5/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0937 - mean_io_u: 0.4618 - dice_coeficient: 0.9524
# Epoch 5: val_loss did not improve from 0.10026
# 1616/1616 [==============================] - 129s 80ms/step - loss: 0.0937 - mean_io_u: 0.4618 - dice_coeficient: 0.9524 - val_loss: 0.1046 - val_mean_io_u: 0.4618 - val_dice_coeficient: 0.9499
# Epoch 6/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0867 - mean_io_u: 0.4618 - dice_coeficient: 0.9557
# Epoch 6: val_loss did not improve from 0.10026
# 1616/1616 [==============================] - 131s 81ms/step - loss: 0.0867 - mean_io_u: 0.4618 - dice_coeficient: 0.9557 - val_loss: 0.1004 - val_mean_io_u: 0.4619 - val_dice_coeficient: 0.9544
# Epoch 7/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0812 - mean_io_u: 0.4618 - dice_coeficient: 0.9586
# Epoch 7: val_loss improved from 0.10026 to 0.09368, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 130s 81ms/step - loss: 0.0812 - mean_io_u: 0.4618 - dice_coeficient: 0.9586 - val_loss: 0.0937 - val_mean_io_u: 0.4621 - val_dice_coeficient: 0.9575
# Epoch 8/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0770 - mean_io_u: 0.4619 - dice_coeficient: 0.9604
# Epoch 8: val_loss improved from 0.09368 to 0.08620, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 135s 84ms/step - loss: 0.0770 - mean_io_u: 0.4619 - dice_coeficient: 0.9604 - val_loss: 0.0862 - val_mean_io_u: 0.4620 - val_dice_coeficient: 0.9597
# Epoch 9/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0738 - mean_io_u: 0.4620 - dice_coeficient: 0.9620
# Epoch 9: val_loss improved from 0.08620 to 0.08375, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 131s 81ms/step - loss: 0.0738 - mean_io_u: 0.4620 - dice_coeficient: 0.9620 - val_loss: 0.0838 - val_mean_io_u: 0.4616 - val_dice_coeficient: 0.9600
# Epoch 10/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0699 - mean_io_u: 0.4619 - dice_coeficient: 0.9639
# Epoch 10: val_loss improved from 0.08375 to 0.08301, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 132s 82ms/step - loss: 0.0699 - mean_io_u: 0.4619 - dice_coeficient: 0.9639 - val_loss: 0.0830 - val_mean_io_u: 0.4624 - val_dice_coeficient: 0.9628
# Epoch 11/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0673 - mean_io_u: 0.4620 - dice_coeficient: 0.9651
# Epoch 11: val_loss improved from 0.08301 to 0.08035, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 130s 81ms/step - loss: 0.0673 - mean_io_u: 0.4620 - dice_coeficient: 0.9651 - val_loss: 0.0803 - val_mean_io_u: 0.4620 - val_dice_coeficient: 0.9634
# Epoch 12/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0654 - mean_io_u: 0.4620 - dice_coeficient: 0.9662
# Epoch 12: val_loss did not improve from 0.08035
# 1616/1616 [==============================] - 135s 84ms/step - loss: 0.0654 - mean_io_u: 0.4620 - dice_coeficient: 0.9662 - val_loss: 0.0804 - val_mean_io_u: 0.4620 - val_dice_coeficient: 0.9640
# Epoch 13/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0617 - mean_io_u: 0.4623 - dice_coeficient: 0.9677
# Epoch 13: val_loss improved from 0.08035 to 0.07870, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 135s 84ms/step - loss: 0.0617 - mean_io_u: 0.4623 - dice_coeficient: 0.9677 - val_loss: 0.0787 - val_mean_io_u: 0.4617 - val_dice_coeficient: 0.9630
# Epoch 14/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0608 - mean_io_u: 0.4624 - dice_coeficient: 0.9683
# Epoch 14: val_loss improved from 0.07870 to 0.07863, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 130s 80ms/step - loss: 0.0608 - mean_io_u: 0.4624 - dice_coeficient: 0.9683 - val_loss: 0.0786 - val_mean_io_u: 0.4621 - val_dice_coeficient: 0.9640
# Epoch 15/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0584 - mean_io_u: 0.4622 - dice_coeficient: 0.9694
# Epoch 15: val_loss improved from 0.07863 to 0.07685, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 139s 86ms/step - loss: 0.0584 - mean_io_u: 0.4622 - dice_coeficient: 0.9694 - val_loss: 0.0769 - val_mean_io_u: 0.4620 - val_dice_coeficient: 0.9660
# Epoch 16/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0556 - mean_io_u: 0.4627 - dice_coeficient: 0.9706
# Epoch 16: val_loss did not improve from 0.07685
# 1616/1616 [==============================] - 136s 84ms/step - loss: 0.0556 - mean_io_u: 0.4627 - dice_coeficient: 0.9706 - val_loss: 0.0795 - val_mean_io_u: 0.4628 - val_dice_coeficient: 0.9666
# Epoch 17/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0541 - mean_io_u: 0.4627 - dice_coeficient: 0.9714
# Epoch 17: val_loss did not improve from 0.07685
# 1616/1616 [==============================] - 127s 79ms/step - loss: 0.0541 - mean_io_u: 0.4627 - dice_coeficient: 0.9714 - val_loss: 0.0775 - val_mean_io_u: 0.4627 - val_dice_coeficient: 0.9665
# Epoch 18/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0530 - mean_io_u: 0.4632 - dice_coeficient: 0.9720
# Epoch 18: val_loss improved from 0.07685 to 0.07670, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 124s 76ms/step - loss: 0.0530 - mean_io_u: 0.4632 - dice_coeficient: 0.9720 - val_loss: 0.0767 - val_mean_io_u: 0.4627 - val_dice_coeficient: 0.9677
# Epoch 19/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0509 - mean_io_u: 0.4636 - dice_coeficient: 0.9730
# Epoch 19: val_loss did not improve from 0.07670
# 1616/1616 [==============================] - 130s 80ms/step - loss: 0.0509 - mean_io_u: 0.4636 - dice_coeficient: 0.9730 - val_loss: 0.0844 - val_mean_io_u: 0.4638 - val_dice_coeficient: 0.9657
# Epoch 20/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0504 - mean_io_u: 0.4638 - dice_coeficient: 0.9733
# Epoch 20: val_loss improved from 0.07670 to 0.07602, saving model to ../models\swin-unet_train_Weights.hdf5
# 1616/1616 [==============================] - 134s 83ms/step - loss: 0.0504 - mean_io_u: 0.4638 - dice_coeficient: 0.9733 - val_loss: 0.0760 - val_mean_io_u: 0.4628 - val_dice_coeficient: 0.9685
# Epoch 21/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0492 - mean_io_u: 0.4656 - dice_coeficient: 0.9739
# Epoch 21: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 142s 88ms/step - loss: 0.0492 - mean_io_u: 0.4656 - dice_coeficient: 0.9739 - val_loss: 0.0785 - val_mean_io_u: 0.4643 - val_dice_coeficient: 0.9682
# Epoch 22/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0473 - mean_io_u: 0.4657 - dice_coeficient: 0.9747
# Epoch 22: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 134s 83ms/step - loss: 0.0473 - mean_io_u: 0.4657 - dice_coeficient: 0.9747 - val_loss: 0.0832 - val_mean_io_u: 0.4637 - val_dice_coeficient: 0.9674
# Epoch 23/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0462 - mean_io_u: 0.4667 - dice_coeficient: 0.9753
# Epoch 23: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 140s 86ms/step - loss: 0.0462 - mean_io_u: 0.4667 - dice_coeficient: 0.9753 - val_loss: 0.0834 - val_mean_io_u: 0.4663 - val_dice_coeficient: 0.9664
# Epoch 24/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0458 - mean_io_u: 0.4662 - dice_coeficient: 0.9756
# Epoch 24: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 138s 85ms/step - loss: 0.0458 - mean_io_u: 0.4662 - dice_coeficient: 0.9756 - val_loss: 0.0807 - val_mean_io_u: 0.4721 - val_dice_coeficient: 0.9701
# Epoch 25/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0448 - mean_io_u: 0.4673 - dice_coeficient: 0.9763
# Epoch 25: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 133s 82ms/step - loss: 0.0448 - mean_io_u: 0.4673 - dice_coeficient: 0.9763 - val_loss: 0.0810 - val_mean_io_u: 0.4682 - val_dice_coeficient: 0.9699
# Epoch 26/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0422 - mean_io_u: 0.4684 - dice_coeficient: 0.9773
# Epoch 26: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 131s 81ms/step - loss: 0.0422 - mean_io_u: 0.4684 - dice_coeficient: 0.9773 - val_loss: 0.0804 - val_mean_io_u: 0.4694 - val_dice_coeficient: 0.9707
# Epoch 27/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0416 - mean_io_u: 0.4707 - dice_coeficient: 0.9776
# Epoch 27: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 138s 86ms/step - loss: 0.0416 - mean_io_u: 0.4707 - dice_coeficient: 0.9776 - val_loss: 0.0807 - val_mean_io_u: 0.4725 - val_dice_coeficient: 0.9699
# Epoch 28/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0421 - mean_io_u: 0.4713 - dice_coeficient: 0.9775
# Epoch 28: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 132s 82ms/step - loss: 0.0421 - mean_io_u: 0.4713 - dice_coeficient: 0.9775 - val_loss: 0.0813 - val_mean_io_u: 0.4701 - val_dice_coeficient: 0.9697
# Epoch 29/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0405 - mean_io_u: 0.4752 - dice_coeficient: 0.9783
# Epoch 29: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 132s 81ms/step - loss: 0.0405 - mean_io_u: 0.4752 - dice_coeficient: 0.9783 - val_loss: 0.0804 - val_mean_io_u: 0.4664 - val_dice_coeficient: 0.9701
# Epoch 30/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0397 - mean_io_u: 0.4722 - dice_coeficient: 0.9786
# Epoch 30: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 134s 83ms/step - loss: 0.0397 - mean_io_u: 0.4722 - dice_coeficient: 0.9786 - val_loss: 0.0797 - val_mean_io_u: 0.4773 - val_dice_coeficient: 0.9707
# Epoch 31/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0386 - mean_io_u: 0.4763 - dice_coeficient: 0.9793
# Epoch 31: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 134s 83ms/step - loss: 0.0386 - mean_io_u: 0.4763 - dice_coeficient: 0.9793 - val_loss: 0.0792 - val_mean_io_u: 0.4760 - val_dice_coeficient: 0.9717
# Epoch 32/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0370 - mean_io_u: 0.4803 - dice_coeficient: 0.9800
# Epoch 32: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 128s 79ms/step - loss: 0.0370 - mean_io_u: 0.4803 - dice_coeficient: 0.9800 - val_loss: 0.0901 - val_mean_io_u: 0.4695 - val_dice_coeficient: 0.9678
# Epoch 33/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0367 - mean_io_u: 0.4828 - dice_coeficient: 0.9801
# Epoch 33: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 131s 81ms/step - loss: 0.0367 - mean_io_u: 0.4828 - dice_coeficient: 0.9801 - val_loss: 0.0846 - val_mean_io_u: 0.4664 - val_dice_coeficient: 0.9692
# Epoch 34/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0360 - mean_io_u: 0.4786 - dice_coeficient: 0.9806
# Epoch 34: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 133s 82ms/step - loss: 0.0360 - mean_io_u: 0.4786 - dice_coeficient: 0.9806 - val_loss: 0.0840 - val_mean_io_u: 0.4805 - val_dice_coeficient: 0.9716
# Epoch 35/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0346 - mean_io_u: 0.4879 - dice_coeficient: 0.9811
# Epoch 35: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 126s 78ms/step - loss: 0.0346 - mean_io_u: 0.4879 - dice_coeficient: 0.9811 - val_loss: 0.0854 - val_mean_io_u: 0.4887 - val_dice_coeficient: 0.9718
# Epoch 36/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0338 - mean_io_u: 0.4924 - dice_coeficient: 0.9816
# Epoch 36: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 132s 82ms/step - loss: 0.0338 - mean_io_u: 0.4924 - dice_coeficient: 0.9816 - val_loss: 0.0841 - val_mean_io_u: 0.4878 - val_dice_coeficient: 0.9721
# Epoch 37/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0329 - mean_io_u: 0.4940 - dice_coeficient: 0.9821
# Epoch 37: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 141s 87ms/step - loss: 0.0329 - mean_io_u: 0.4940 - dice_coeficient: 0.9821 - val_loss: 0.0876 - val_mean_io_u: 0.4940 - val_dice_coeficient: 0.9722
# Epoch 38/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0341 - mean_io_u: 0.4915 - dice_coeficient: 0.9816
# Epoch 38: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 133s 82ms/step - loss: 0.0341 - mean_io_u: 0.4915 - dice_coeficient: 0.9816 - val_loss: 0.0841 - val_mean_io_u: 0.4847 - val_dice_coeficient: 0.9718
# Epoch 39/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0314 - mean_io_u: 0.4992 - dice_coeficient: 0.9829
# Epoch 39: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 135s 84ms/step - loss: 0.0314 - mean_io_u: 0.4992 - dice_coeficient: 0.9829 - val_loss: 0.0838 - val_mean_io_u: 0.4843 - val_dice_coeficient: 0.9716
# Epoch 40/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0317 - mean_io_u: 0.5031 - dice_coeficient: 0.9829
# Epoch 40: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 130s 80ms/step - loss: 0.0317 - mean_io_u: 0.5031 - dice_coeficient: 0.9829 - val_loss: 0.0852 - val_mean_io_u: 0.4787 - val_dice_coeficient: 0.9720
# Epoch 41/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0307 - mean_io_u: 0.5049 - dice_coeficient: 0.9832
# Epoch 41: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 130s 80ms/step - loss: 0.0307 - mean_io_u: 0.5049 - dice_coeficient: 0.9832 - val_loss: 0.0880 - val_mean_io_u: 0.5050 - val_dice_coeficient: 0.9715
# Epoch 42/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0299 - mean_io_u: 0.5050 - dice_coeficient: 0.9840
# Epoch 42: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 133s 82ms/step - loss: 0.0299 - mean_io_u: 0.5050 - dice_coeficient: 0.9840 - val_loss: 0.0883 - val_mean_io_u: 0.4935 - val_dice_coeficient: 0.9730
# Epoch 43/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0286 - mean_io_u: 0.5087 - dice_coeficient: 0.9844
# Epoch 43: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 129s 80ms/step - loss: 0.0286 - mean_io_u: 0.5087 - dice_coeficient: 0.9844 - val_loss: 0.0930 - val_mean_io_u: 0.5109 - val_dice_coeficient: 0.9712
# Epoch 44/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0283 - mean_io_u: 0.5099 - dice_coeficient: 0.9846
# Epoch 44: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 141s 87ms/step - loss: 0.0283 - mean_io_u: 0.5099 - dice_coeficient: 0.9846 - val_loss: 0.0920 - val_mean_io_u: 0.5106 - val_dice_coeficient: 0.9727
# Epoch 45/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0267 - mean_io_u: 0.5246 - dice_coeficient: 0.9854
# Epoch 45: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 132s 82ms/step - loss: 0.0267 - mean_io_u: 0.5246 - dice_coeficient: 0.9854 - val_loss: 0.0937 - val_mean_io_u: 0.5157 - val_dice_coeficient: 0.9722
# Epoch 46/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0266 - mean_io_u: 0.5257 - dice_coeficient: 0.9855
# Epoch 46: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 134s 83ms/step - loss: 0.0266 - mean_io_u: 0.5257 - dice_coeficient: 0.9855 - val_loss: 0.0942 - val_mean_io_u: 0.5222 - val_dice_coeficient: 0.9726
# Epoch 47/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0259 - mean_io_u: 0.5293 - dice_coeficient: 0.9859
# Epoch 47: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 128s 79ms/step - loss: 0.0259 - mean_io_u: 0.5293 - dice_coeficient: 0.9859 - val_loss: 0.0940 - val_mean_io_u: 0.5293 - val_dice_coeficient: 0.9734
# Epoch 48/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0250 - mean_io_u: 0.5406 - dice_coeficient: 0.9863
# Epoch 48: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 134s 83ms/step - loss: 0.0250 - mean_io_u: 0.5406 - dice_coeficient: 0.9863 - val_loss: 0.0954 - val_mean_io_u: 0.5307 - val_dice_coeficient: 0.9731
# Epoch 49/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0266 - mean_io_u: 0.5334 - dice_coeficient: 0.9856
# Epoch 49: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 131s 81ms/step - loss: 0.0266 - mean_io_u: 0.5334 - dice_coeficient: 0.9856 - val_loss: 0.0949 - val_mean_io_u: 0.5446 - val_dice_coeficient: 0.9737
# Epoch 50/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0225 - mean_io_u: 0.5689 - dice_coeficient: 0.9875
# Epoch 50: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 141s 87ms/step - loss: 0.0225 - mean_io_u: 0.5689 - dice_coeficient: 0.9875 - val_loss: 0.1003 - val_mean_io_u: 0.5511 - val_dice_coeficient: 0.9728
# Epoch 51/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0239 - mean_io_u: 0.5592 - dice_coeficient: 0.9872
# Epoch 51: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 129s 80ms/step - loss: 0.0239 - mean_io_u: 0.5592 - dice_coeficient: 0.9872 - val_loss: 0.0969 - val_mean_io_u: 0.5350 - val_dice_coeficient: 0.9731
# Epoch 52/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0225 - mean_io_u: 0.5662 - dice_coeficient: 0.9876
# Epoch 52: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 131s 81ms/step - loss: 0.0225 - mean_io_u: 0.5662 - dice_coeficient: 0.9876 - val_loss: 0.1030 - val_mean_io_u: 0.5845 - val_dice_coeficient: 0.9730
# Epoch 53/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0227 - mean_io_u: 0.5739 - dice_coeficient: 0.9877
# Epoch 53: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 136s 84ms/step - loss: 0.0227 - mean_io_u: 0.5739 - dice_coeficient: 0.9877 - val_loss: 0.1004 - val_mean_io_u: 0.5690 - val_dice_coeficient: 0.9739
# Epoch 54/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0219 - mean_io_u: 0.5831 - dice_coeficient: 0.9882
# Epoch 54: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 127s 79ms/step - loss: 0.0219 - mean_io_u: 0.5831 - dice_coeficient: 0.9882 - val_loss: 0.0989 - val_mean_io_u: 0.5193 - val_dice_coeficient: 0.9733
# Epoch 55/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0217 - mean_io_u: 0.5526 - dice_coeficient: 0.9882
# Epoch 55: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 134s 83ms/step - loss: 0.0217 - mean_io_u: 0.5526 - dice_coeficient: 0.9882 - val_loss: 0.1013 - val_mean_io_u: 0.5811 - val_dice_coeficient: 0.9746
# Epoch 56/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0209 - mean_io_u: 0.5867 - dice_coeficient: 0.9886
# Epoch 56: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 142s 88ms/step - loss: 0.0209 - mean_io_u: 0.5867 - dice_coeficient: 0.9886 - val_loss: 0.1029 - val_mean_io_u: 0.5854 - val_dice_coeficient: 0.9743
# Epoch 57/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0209 - mean_io_u: 0.5843 - dice_coeficient: 0.9886
# Epoch 57: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 126s 78ms/step - loss: 0.0209 - mean_io_u: 0.5843 - dice_coeficient: 0.9886 - val_loss: 0.1056 - val_mean_io_u: 0.5997 - val_dice_coeficient: 0.9740
# Epoch 58/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0216 - mean_io_u: 0.5731 - dice_coeficient: 0.9886
# Epoch 58: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 135s 83ms/step - loss: 0.0216 - mean_io_u: 0.5731 - dice_coeficient: 0.9886 - val_loss: 0.1024 - val_mean_io_u: 0.5451 - val_dice_coeficient: 0.9737
# Epoch 59/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0191 - mean_io_u: 0.5938 - dice_coeficient: 0.9896
# Epoch 59: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 135s 84ms/step - loss: 0.0191 - mean_io_u: 0.5938 - dice_coeficient: 0.9896 - val_loss: 0.1074 - val_mean_io_u: 0.5880 - val_dice_coeficient: 0.9738
# Epoch 60/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0187 - mean_io_u: 0.6143 - dice_coeficient: 0.9898
# Epoch 60: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 133s 82ms/step - loss: 0.0187 - mean_io_u: 0.6143 - dice_coeficient: 0.9898 - val_loss: 0.1122 - val_mean_io_u: 0.6279 - val_dice_coeficient: 0.9736
# Epoch 61/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0200 - mean_io_u: 0.6183 - dice_coeficient: 0.9894
# Epoch 61: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 135s 83ms/step - loss: 0.0200 - mean_io_u: 0.6183 - dice_coeficient: 0.9894 - val_loss: 0.1056 - val_mean_io_u: 0.5959 - val_dice_coeficient: 0.9746
# Epoch 62/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0234 - mean_io_u: 0.5892 - dice_coeficient: 0.9881
# Epoch 62: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 140s 86ms/step - loss: 0.0234 - mean_io_u: 0.5892 - dice_coeficient: 0.9881 - val_loss: 0.1067 - val_mean_io_u: 0.5375 - val_dice_coeficient: 0.9703
# Epoch 63/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0195 - mean_io_u: 0.5846 - dice_coeficient: 0.9894
# Epoch 63: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 133s 82ms/step - loss: 0.0195 - mean_io_u: 0.5846 - dice_coeficient: 0.9894 - val_loss: 0.1052 - val_mean_io_u: 0.6147 - val_dice_coeficient: 0.9752
# Epoch 64/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0197 - mean_io_u: 0.6037 - dice_coeficient: 0.9896
# Epoch 64: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 126s 78ms/step - loss: 0.0197 - mean_io_u: 0.6037 - dice_coeficient: 0.9896 - val_loss: 0.1058 - val_mean_io_u: 0.6214 - val_dice_coeficient: 0.9753
# Epoch 65/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0193 - mean_io_u: 0.6089 - dice_coeficient: 0.9899
# Epoch 65: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 139s 86ms/step - loss: 0.0193 - mean_io_u: 0.6089 - dice_coeficient: 0.9899 - val_loss: 0.1050 - val_mean_io_u: 0.6023 - val_dice_coeficient: 0.9749
# Epoch 66/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0164 - mean_io_u: 0.6349 - dice_coeficient: 0.9910
# Epoch 66: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 133s 82ms/step - loss: 0.0164 - mean_io_u: 0.6349 - dice_coeficient: 0.9910 - val_loss: 0.1133 - val_mean_io_u: 0.6298 - val_dice_coeficient: 0.9744
# Epoch 67/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0165 - mean_io_u: 0.6482 - dice_coeficient: 0.9911
# Epoch 67: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 148s 91ms/step - loss: 0.0165 - mean_io_u: 0.6482 - dice_coeficient: 0.9911 - val_loss: 0.1133 - val_mean_io_u: 0.6326 - val_dice_coeficient: 0.9746
# Epoch 68/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0185 - mean_io_u: 0.6284 - dice_coeficient: 0.9902
# Epoch 68: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 134s 83ms/step - loss: 0.0185 - mean_io_u: 0.6284 - dice_coeficient: 0.9902 - val_loss: 0.1130 - val_mean_io_u: 0.6078 - val_dice_coeficient: 0.9742
# Epoch 69/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0167 - mean_io_u: 0.6391 - dice_coeficient: 0.9909
# Epoch 69: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 134s 83ms/step - loss: 0.0167 - mean_io_u: 0.6391 - dice_coeficient: 0.9909 - val_loss: 0.1127 - val_mean_io_u: 0.6538 - val_dice_coeficient: 0.9751
# Epoch 70/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0163 - mean_io_u: 0.6619 - dice_coeficient: 0.9913
# Epoch 70: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 131s 81ms/step - loss: 0.0163 - mean_io_u: 0.6619 - dice_coeficient: 0.9913 - val_loss: 0.1166 - val_mean_io_u: 0.6518 - val_dice_coeficient: 0.9744
# Epoch 71/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0155 - mean_io_u: 0.6645 - dice_coeficient: 0.9916
# Epoch 71: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 131s 81ms/step - loss: 0.0155 - mean_io_u: 0.6645 - dice_coeficient: 0.9916 - val_loss: 0.1166 - val_mean_io_u: 0.6578 - val_dice_coeficient: 0.9749
# Epoch 72/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0152 - mean_io_u: 0.6761 - dice_coeficient: 0.9919
# Epoch 72: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 128s 79ms/step - loss: 0.0152 - mean_io_u: 0.6761 - dice_coeficient: 0.9919 - val_loss: 0.1179 - val_mean_io_u: 0.6610 - val_dice_coeficient: 0.9749
# Epoch 73/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0151 - mean_io_u: 0.6832 - dice_coeficient: 0.9919
# Epoch 73: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 137s 85ms/step - loss: 0.0151 - mean_io_u: 0.6832 - dice_coeficient: 0.9919 - val_loss: 0.1176 - val_mean_io_u: 0.6751 - val_dice_coeficient: 0.9749
# Epoch 74/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0151 - mean_io_u: 0.6866 - dice_coeficient: 0.9920
# Epoch 74: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 137s 85ms/step - loss: 0.0151 - mean_io_u: 0.6866 - dice_coeficient: 0.9920 - val_loss: 0.1197 - val_mean_io_u: 0.6759 - val_dice_coeficient: 0.9744
# Epoch 75/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0147 - mean_io_u: 0.6879 - dice_coeficient: 0.9922
# Epoch 75: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 137s 85ms/step - loss: 0.0147 - mean_io_u: 0.6879 - dice_coeficient: 0.9922 - val_loss: 0.1194 - val_mean_io_u: 0.6893 - val_dice_coeficient: 0.9751
# Epoch 76/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0143 - mean_io_u: 0.6963 - dice_coeficient: 0.9924
# Epoch 76: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 133s 82ms/step - loss: 0.0143 - mean_io_u: 0.6963 - dice_coeficient: 0.9924 - val_loss: 0.1201 - val_mean_io_u: 0.6882 - val_dice_coeficient: 0.9749
# Epoch 77/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0139 - mean_io_u: 0.7038 - dice_coeficient: 0.9926
# Epoch 77: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 135s 83ms/step - loss: 0.0139 - mean_io_u: 0.7038 - dice_coeficient: 0.9926 - val_loss: 0.1211 - val_mean_io_u: 0.6960 - val_dice_coeficient: 0.9750
# Epoch 78/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0140 - mean_io_u: 0.7028 - dice_coeficient: 0.9926
# Epoch 78: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 137s 85ms/step - loss: 0.0140 - mean_io_u: 0.7028 - dice_coeficient: 0.9926 - val_loss: 0.1214 - val_mean_io_u: 0.6945 - val_dice_coeficient: 0.9752
# Epoch 79/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0130 - mean_io_u: 0.7135 - dice_coeficient: 0.9931
# Epoch 79: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 132s 82ms/step - loss: 0.0130 - mean_io_u: 0.7135 - dice_coeficient: 0.9931 - val_loss: 0.1228 - val_mean_io_u: 0.7021 - val_dice_coeficient: 0.9751
# Epoch 80/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0134 - mean_io_u: 0.7160 - dice_coeficient: 0.9930
# Epoch 80: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 137s 85ms/step - loss: 0.0134 - mean_io_u: 0.7160 - dice_coeficient: 0.9930 - val_loss: 0.1227 - val_mean_io_u: 0.6984 - val_dice_coeficient: 0.9752
# Epoch 81/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0128 - mean_io_u: 0.7205 - dice_coeficient: 0.9933
# Epoch 81: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 132s 82ms/step - loss: 0.0128 - mean_io_u: 0.7205 - dice_coeficient: 0.9933 - val_loss: 0.1245 - val_mean_io_u: 0.7024 - val_dice_coeficient: 0.9750
# Epoch 82/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0125 - mean_io_u: 0.7242 - dice_coeficient: 0.9934
# Epoch 82: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 132s 82ms/step - loss: 0.0125 - mean_io_u: 0.7242 - dice_coeficient: 0.9934 - val_loss: 0.1265 - val_mean_io_u: 0.7123 - val_dice_coeficient: 0.9750
# Epoch 83/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0125 - mean_io_u: 0.7267 - dice_coeficient: 0.9935
# Epoch 83: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 139s 86ms/step - loss: 0.0125 - mean_io_u: 0.7267 - dice_coeficient: 0.9935 - val_loss: 0.1260 - val_mean_io_u: 0.7107 - val_dice_coeficient: 0.9751
# Epoch 84/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0123 - mean_io_u: 0.7262 - dice_coeficient: 0.9936
# Epoch 84: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 141s 87ms/step - loss: 0.0123 - mean_io_u: 0.7262 - dice_coeficient: 0.9936 - val_loss: 0.1269 - val_mean_io_u: 0.7178 - val_dice_coeficient: 0.9752
# Epoch 85/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0119 - mean_io_u: 0.7336 - dice_coeficient: 0.9938
# Epoch 85: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 129s 80ms/step - loss: 0.0119 - mean_io_u: 0.7336 - dice_coeficient: 0.9938 - val_loss: 0.1316 - val_mean_io_u: 0.7095 - val_dice_coeficient: 0.9743
# Epoch 86/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0119 - mean_io_u: 0.7352 - dice_coeficient: 0.9938
# Epoch 86: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 132s 82ms/step - loss: 0.0119 - mean_io_u: 0.7352 - dice_coeficient: 0.9938 - val_loss: 0.1293 - val_mean_io_u: 0.7245 - val_dice_coeficient: 0.9751
# Epoch 87/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0116 - mean_io_u: 0.7378 - dice_coeficient: 0.9940
# Epoch 87: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 136s 84ms/step - loss: 0.0116 - mean_io_u: 0.7378 - dice_coeficient: 0.9940 - val_loss: 0.1294 - val_mean_io_u: 0.7304 - val_dice_coeficient: 0.9752
# Epoch 88/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0114 - mean_io_u: 0.7425 - dice_coeficient: 0.9941
# Epoch 88: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 127s 79ms/step - loss: 0.0114 - mean_io_u: 0.7425 - dice_coeficient: 0.9941 - val_loss: 0.1293 - val_mean_io_u: 0.7334 - val_dice_coeficient: 0.9755
# Epoch 89/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0115 - mean_io_u: 0.7438 - dice_coeficient: 0.9941
# Epoch 89: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 137s 85ms/step - loss: 0.0115 - mean_io_u: 0.7438 - dice_coeficient: 0.9941 - val_loss: 0.1304 - val_mean_io_u: 0.7288 - val_dice_coeficient: 0.9751
# Epoch 90/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0117 - mean_io_u: 0.7409 - dice_coeficient: 0.9939
# Epoch 90: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 139s 86ms/step - loss: 0.0117 - mean_io_u: 0.7409 - dice_coeficient: 0.9939 - val_loss: 0.1296 - val_mean_io_u: 0.7360 - val_dice_coeficient: 0.9754
# Epoch 91/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0112 - mean_io_u: 0.7468 - dice_coeficient: 0.9942
# Epoch 91: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 138s 86ms/step - loss: 0.0112 - mean_io_u: 0.7468 - dice_coeficient: 0.9942 - val_loss: 0.1310 - val_mean_io_u: 0.7298 - val_dice_coeficient: 0.9750
# Epoch 92/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0109 - mean_io_u: 0.7497 - dice_coeficient: 0.9943
# Epoch 92: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 138s 85ms/step - loss: 0.0109 - mean_io_u: 0.7497 - dice_coeficient: 0.9943 - val_loss: 0.1324 - val_mean_io_u: 0.7338 - val_dice_coeficient: 0.9750
# Epoch 93/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0115 - mean_io_u: 0.7521 - dice_coeficient: 0.9941
# Epoch 93: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 131s 81ms/step - loss: 0.0115 - mean_io_u: 0.7521 - dice_coeficient: 0.9941 - val_loss: 0.1315 - val_mean_io_u: 0.7508 - val_dice_coeficient: 0.9755
# Epoch 94/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0187 - mean_io_u: 0.7149 - dice_coeficient: 0.9909
# Epoch 94: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 137s 85ms/step - loss: 0.0187 - mean_io_u: 0.7149 - dice_coeficient: 0.9909 - val_loss: 0.1208 - val_mean_io_u: 0.7035 - val_dice_coeficient: 0.9748
# Epoch 95/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0096 - mean_io_u: 0.7479 - dice_coeficient: 0.9944
# Epoch 95: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 135s 84ms/step - loss: 0.0096 - mean_io_u: 0.7479 - dice_coeficient: 0.9944 - val_loss: 0.1338 - val_mean_io_u: 0.7701 - val_dice_coeficient: 0.9759
# Epoch 96/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0085 - mean_io_u: 0.7892 - dice_coeficient: 0.9955
# Epoch 96: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 137s 85ms/step - loss: 0.0085 - mean_io_u: 0.7892 - dice_coeficient: 0.9955 - val_loss: 0.1379 - val_mean_io_u: 0.7640 - val_dice_coeficient: 0.9754
# Epoch 97/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0124 - mean_io_u: 0.7671 - dice_coeficient: 0.9938
# Epoch 97: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 136s 84ms/step - loss: 0.0124 - mean_io_u: 0.7671 - dice_coeficient: 0.9938 - val_loss: 0.1337 - val_mean_io_u: 0.7545 - val_dice_coeficient: 0.9752
# Epoch 98/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0108 - mean_io_u: 0.7742 - dice_coeficient: 0.9943
# Epoch 98: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 136s 84ms/step - loss: 0.0108 - mean_io_u: 0.7742 - dice_coeficient: 0.9943 - val_loss: 0.1348 - val_mean_io_u: 0.7603 - val_dice_coeficient: 0.9754
# Epoch 99/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0120 - mean_io_u: 0.7692 - dice_coeficient: 0.9940
# Epoch 99: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 130s 80ms/step - loss: 0.0120 - mean_io_u: 0.7692 - dice_coeficient: 0.9940 - val_loss: 0.1319 - val_mean_io_u: 0.7476 - val_dice_coeficient: 0.9753
# Epoch 100/100
# 1616/1616 [==============================] - ETA: 0s - loss: 0.0095 - mean_io_u: 0.7771 - dice_coeficient: 0.9949
# Epoch 100: val_loss did not improve from 0.07602
# 1616/1616 [==============================] - 132s 82ms/step - loss: 0.0095 - mean_io_u: 0.7771 - dice_coeficient: 0.9949 - val_loss: 0.1384 - val_mean_io_u: 0.7634 - val_dice_coeficient: 0.9750

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 6s 52ms/step

# %%
idx = random.randint(0, len(pred)-1)

plt.figure(figsize=(15,15))
plt.subplot(131)
plt.imshow(X_test[idx])
plt.title('Image')
plt.axis("off")

plt.subplot(132)
plt.imshow(tf.argmax(y_test[idx], axis=-1))
plt.title('Mask')
plt.axis("off")

plt.subplot(133)
plt.imshow(pred[idx])
plt.title('Prediction')
plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
