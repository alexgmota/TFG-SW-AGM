# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 41419

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

# def dice_loss(y_true, y_pred):
#     return 1 - dice_coeficient(y_true, y_pred)

# def tversky(y_true, y_pred, smooth=1, alpha=0.8):
#     T = tf.keras.backend.flatten(y_true)
#     P = tf.keras.backend.flatten(y_pred)
#     TP = tf.keras.backend.sum(T * P)
#     FN = tf.keras.backend.sum(T * (1 - P))
#     FP = tf.keras.backend.sum((1 - T) * P)
#     return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


# def tversky_loss(y_true, y_pred):
#     return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, decay=1e-4), 
    loss=sm.losses.JaccardLoss(),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract_1 (patch_extract  (None, 256, 48)     0           ['input_2[0][0]']
#  )
#
#  patch_embedding_1 (patch_embed  (None, 256, 128)    39040       ['patch_extract_1[0][0]']
#  ding)
#
#  swin_transformer_block_14 (Swi  (None, 256, 128)    198724      ['patch_embedding_1[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_15 (Swi  (None, 256, 128)    202820      ['swin_transformer_block_14[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_3 (patch_merging  (None, 64, 256)     131072      ['swin_transformer_block_15[0][0]
#  )                                                               ']
#
#  swin_transformer_block_16 (Swi  (None, 64, 256)     527192      ['patch_merging_3[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_17 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_16[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_4 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_17[0][0]
#  )                                                               ']
#
#  swin_transformer_block_18 (Swi  (None, 16, 512)     1578072     ['patch_merging_4[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_19 (Swi  (None, 16, 512)     1578136     ['swin_transformer_block_18[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_merging_5 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_19[0][0]
#  )                                                               ']
#
#  swin_transformer_block_20 (Swi  (None, 4, 1024)     5252696     ['patch_merging_5[0][0]']
#  nTransformerBlock)
#
#  swin_transformer_block_21 (Swi  (None, 4, 1024)     5252712     ['swin_transformer_block_20[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_4 (patch_expan  (None, 16, 512)     2097152     ['swin_transformer_block_21[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding_4[0][0]',
#  e)                                                               'swin_transformer_block_19[0][0]
#                                                                  ']
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_22 (Swi  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_23 (Swi  (None, 16, 512)     1578136     ['swin_transformer_block_22[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_5 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_23[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_5[0][0]',
#  e)                                                               'swin_transformer_block_17[0][0]
#                                                                  ']
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_24 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_25 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_24[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_6 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_25[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_6[0][0]',
#  e)                                                               'swin_transformer_block_15[0][0]
#                                                                  ']
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_26 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_27 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_26[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_7 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_27[0][0]
#  ding)                                                           ']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 13)   416         ['patch_expanding_7[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_train_Weights.hdf5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto'
)

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.8635 - mean_io_u: 0.4697 - dice_coeficient: 0.4444
# Epoch 1: val_loss improved from inf to 0.76402, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 32s 354ms/step - loss: 0.8635 - mean_io_u: 0.4697 - dice_coeficient: 0.4444 - val_loss: 0.7640 - val_mean_io_u: 0.5064 - val_dice_coeficient: 0.6941
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.6887 - mean_io_u: 0.5594 - dice_coeficient: 0.7611
# Epoch 2: val_loss improved from 0.76402 to 0.60814, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 306ms/step - loss: 0.6887 - mean_io_u: 0.5594 - dice_coeficient: 0.7611 - val_loss: 0.6081 - val_mean_io_u: 0.6132 - val_dice_coeficient: 0.7929
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5519 - mean_io_u: 0.6404 - dice_coeficient: 0.8180
# Epoch 3: val_loss improved from 0.60814 to 0.50353, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 327ms/step - loss: 0.5519 - mean_io_u: 0.6404 - dice_coeficient: 0.8180 - val_loss: 0.5035 - val_mean_io_u: 0.6710 - val_dice_coeficient: 0.8328
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4793 - mean_io_u: 0.6919 - dice_coeficient: 0.8434
# Epoch 4: val_loss improved from 0.50353 to 0.45579, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 330ms/step - loss: 0.4793 - mean_io_u: 0.6919 - dice_coeficient: 0.8434 - val_loss: 0.4558 - val_mean_io_u: 0.7116 - val_dice_coeficient: 0.8523
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4420 - mean_io_u: 0.7221 - dice_coeficient: 0.8579
# Epoch 5: val_loss improved from 0.45579 to 0.43413, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 337ms/step - loss: 0.4420 - mean_io_u: 0.7221 - dice_coeficient: 0.8579 - val_loss: 0.4341 - val_mean_io_u: 0.7328 - val_dice_coeficient: 0.8609
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4230 - mean_io_u: 0.7404 - dice_coeficient: 0.8662
# Epoch 6: val_loss improved from 0.43413 to 0.41608, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 346ms/step - loss: 0.4230 - mean_io_u: 0.7404 - dice_coeficient: 0.8662 - val_loss: 0.4161 - val_mean_io_u: 0.7452 - val_dice_coeficient: 0.8687
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4093 - mean_io_u: 0.7538 - dice_coeficient: 0.8725
# Epoch 7: val_loss improved from 0.41608 to 0.40602, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 347ms/step - loss: 0.4093 - mean_io_u: 0.7538 - dice_coeficient: 0.8725 - val_loss: 0.4060 - val_mean_io_u: 0.7565 - val_dice_coeficient: 0.8729
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3967 - mean_io_u: 0.7656 - dice_coeficient: 0.8779
# Epoch 8: val_loss improved from 0.40602 to 0.39654, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 355ms/step - loss: 0.3967 - mean_io_u: 0.7656 - dice_coeficient: 0.8779 - val_loss: 0.3965 - val_mean_io_u: 0.7673 - val_dice_coeficient: 0.8779
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3899 - mean_io_u: 0.7750 - dice_coeficient: 0.8813
# Epoch 9: val_loss improved from 0.39654 to 0.38900, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 359ms/step - loss: 0.3899 - mean_io_u: 0.7750 - dice_coeficient: 0.8813 - val_loss: 0.3890 - val_mean_io_u: 0.7796 - val_dice_coeficient: 0.8821
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3803 - mean_io_u: 0.7807 - dice_coeficient: 0.8858
# Epoch 10: val_loss improved from 0.38900 to 0.37802, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.3803 - mean_io_u: 0.7807 - dice_coeficient: 0.8858 - val_loss: 0.3780 - val_mean_io_u: 0.7837 - val_dice_coeficient: 0.8867
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3686 - mean_io_u: 0.7858 - dice_coeficient: 0.8906
# Epoch 11: val_loss improved from 0.37802 to 0.36815, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 360ms/step - loss: 0.3686 - mean_io_u: 0.7858 - dice_coeficient: 0.8906 - val_loss: 0.3681 - val_mean_io_u: 0.7915 - val_dice_coeficient: 0.8918
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3633 - mean_io_u: 0.8005 - dice_coeficient: 0.9019
# Epoch 12: val_loss improved from 0.36815 to 0.35614, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 365ms/step - loss: 0.3633 - mean_io_u: 0.8005 - dice_coeficient: 0.9019 - val_loss: 0.3561 - val_mean_io_u: 0.8053 - val_dice_coeficient: 0.9061
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3454 - mean_io_u: 0.8098 - dice_coeficient: 0.9094
# Epoch 13: val_loss improved from 0.35614 to 0.34635, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.3454 - mean_io_u: 0.8098 - dice_coeficient: 0.9094 - val_loss: 0.3464 - val_mean_io_u: 0.8117 - val_dice_coeficient: 0.9090
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3432 - mean_io_u: 0.8159 - dice_coeficient: 0.9119
# Epoch 14: val_loss improved from 0.34635 to 0.34144, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 362ms/step - loss: 0.3432 - mean_io_u: 0.8159 - dice_coeficient: 0.9119 - val_loss: 0.3414 - val_mean_io_u: 0.8197 - val_dice_coeficient: 0.9109
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3327 - mean_io_u: 0.8216 - dice_coeficient: 0.9137
# Epoch 15: val_loss improved from 0.34144 to 0.34105, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.3327 - mean_io_u: 0.8216 - dice_coeficient: 0.9137 - val_loss: 0.3411 - val_mean_io_u: 0.8217 - val_dice_coeficient: 0.9114
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3332 - mean_io_u: 0.8256 - dice_coeficient: 0.9149
# Epoch 16: val_loss improved from 0.34105 to 0.33494, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.3332 - mean_io_u: 0.8256 - dice_coeficient: 0.9149 - val_loss: 0.3349 - val_mean_io_u: 0.8262 - val_dice_coeficient: 0.9140
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3251 - mean_io_u: 0.8301 - dice_coeficient: 0.9173
# Epoch 17: val_loss improved from 0.33494 to 0.33206, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 363ms/step - loss: 0.3251 - mean_io_u: 0.8301 - dice_coeficient: 0.9173 - val_loss: 0.3321 - val_mean_io_u: 0.8296 - val_dice_coeficient: 0.9152
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3251 - mean_io_u: 0.8341 - dice_coeficient: 0.9189
# Epoch 18: val_loss improved from 0.33206 to 0.32581, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.3251 - mean_io_u: 0.8341 - dice_coeficient: 0.9189 - val_loss: 0.3258 - val_mean_io_u: 0.8340 - val_dice_coeficient: 0.9174
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3183 - mean_io_u: 0.8380 - dice_coeficient: 0.9206
# Epoch 19: val_loss improved from 0.32581 to 0.32294, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.3183 - mean_io_u: 0.8380 - dice_coeficient: 0.9206 - val_loss: 0.3229 - val_mean_io_u: 0.8397 - val_dice_coeficient: 0.9189
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3123 - mean_io_u: 0.8429 - dice_coeficient: 0.9217
# Epoch 20: val_loss improved from 0.32294 to 0.31865, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.3123 - mean_io_u: 0.8429 - dice_coeficient: 0.9217 - val_loss: 0.3187 - val_mean_io_u: 0.8410 - val_dice_coeficient: 0.9194
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3096 - mean_io_u: 0.8452 - dice_coeficient: 0.9225
# Epoch 21: val_loss improved from 0.31865 to 0.31493, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 367ms/step - loss: 0.3096 - mean_io_u: 0.8452 - dice_coeficient: 0.9225 - val_loss: 0.3149 - val_mean_io_u: 0.8442 - val_dice_coeficient: 0.9203
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3061 - mean_io_u: 0.8474 - dice_coeficient: 0.9233
# Epoch 22: val_loss improved from 0.31493 to 0.31410, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.3061 - mean_io_u: 0.8474 - dice_coeficient: 0.9233 - val_loss: 0.3141 - val_mean_io_u: 0.8470 - val_dice_coeficient: 0.9201
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3080 - mean_io_u: 0.8491 - dice_coeficient: 0.9218
# Epoch 23: val_loss did not improve from 0.31410
# 51/51 [==============================] - 19s 365ms/step - loss: 0.3080 - mean_io_u: 0.8491 - dice_coeficient: 0.9218 - val_loss: 0.3154 - val_mean_io_u: 0.8502 - val_dice_coeficient: 0.9199
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3032 - mean_io_u: 0.8521 - dice_coeficient: 0.9232
# Epoch 24: val_loss did not improve from 0.31410
# 51/51 [==============================] - 19s 366ms/step - loss: 0.3032 - mean_io_u: 0.8521 - dice_coeficient: 0.9232 - val_loss: 0.3164 - val_mean_io_u: 0.8481 - val_dice_coeficient: 0.9187
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3018 - mean_io_u: 0.8550 - dice_coeficient: 0.9244
# Epoch 25: val_loss improved from 0.31410 to 0.30825, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.3018 - mean_io_u: 0.8550 - dice_coeficient: 0.9244 - val_loss: 0.3083 - val_mean_io_u: 0.8552 - val_dice_coeficient: 0.9230
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2972 - mean_io_u: 0.8579 - dice_coeficient: 0.9262
# Epoch 26: val_loss improved from 0.30825 to 0.30621, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2972 - mean_io_u: 0.8579 - dice_coeficient: 0.9262 - val_loss: 0.3062 - val_mean_io_u: 0.8584 - val_dice_coeficient: 0.9240
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2941 - mean_io_u: 0.8601 - dice_coeficient: 0.9270
# Epoch 27: val_loss improved from 0.30621 to 0.30509, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2941 - mean_io_u: 0.8601 - dice_coeficient: 0.9270 - val_loss: 0.3051 - val_mean_io_u: 0.8588 - val_dice_coeficient: 0.9242
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2923 - mean_io_u: 0.8619 - dice_coeficient: 0.9278
# Epoch 28: val_loss improved from 0.30509 to 0.30240, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2923 - mean_io_u: 0.8619 - dice_coeficient: 0.9278 - val_loss: 0.3024 - val_mean_io_u: 0.8609 - val_dice_coeficient: 0.9250
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2940 - mean_io_u: 0.8640 - dice_coeficient: 0.9285
# Epoch 29: val_loss improved from 0.30240 to 0.30146, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2940 - mean_io_u: 0.8640 - dice_coeficient: 0.9285 - val_loss: 0.3015 - val_mean_io_u: 0.8623 - val_dice_coeficient: 0.9257
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2881 - mean_io_u: 0.8657 - dice_coeficient: 0.9291
# Epoch 30: val_loss improved from 0.30146 to 0.30049, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2881 - mean_io_u: 0.8657 - dice_coeficient: 0.9291 - val_loss: 0.3005 - val_mean_io_u: 0.8654 - val_dice_coeficient: 0.9262
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2887 - mean_io_u: 0.8675 - dice_coeficient: 0.9297
# Epoch 31: val_loss improved from 0.30049 to 0.30022, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2887 - mean_io_u: 0.8675 - dice_coeficient: 0.9297 - val_loss: 0.3002 - val_mean_io_u: 0.8659 - val_dice_coeficient: 0.9258
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2881 - mean_io_u: 0.8691 - dice_coeficient: 0.9300
# Epoch 32: val_loss improved from 0.30022 to 0.29864, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2881 - mean_io_u: 0.8691 - dice_coeficient: 0.9300 - val_loss: 0.2986 - val_mean_io_u: 0.8680 - val_dice_coeficient: 0.9271
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2861 - mean_io_u: 0.8707 - dice_coeficient: 0.9306
# Epoch 33: val_loss improved from 0.29864 to 0.29789, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2861 - mean_io_u: 0.8707 - dice_coeficient: 0.9306 - val_loss: 0.2979 - val_mean_io_u: 0.8701 - val_dice_coeficient: 0.9272
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2840 - mean_io_u: 0.8721 - dice_coeficient: 0.9304
# Epoch 34: val_loss did not improve from 0.29789
# 51/51 [==============================] - 19s 367ms/step - loss: 0.2840 - mean_io_u: 0.8721 - dice_coeficient: 0.9304 - val_loss: 0.2986 - val_mean_io_u: 0.8712 - val_dice_coeficient: 0.9272
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2840 - mean_io_u: 0.8735 - dice_coeficient: 0.9312
# Epoch 35: val_loss improved from 0.29789 to 0.29653, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2840 - mean_io_u: 0.8735 - dice_coeficient: 0.9312 - val_loss: 0.2965 - val_mean_io_u: 0.8736 - val_dice_coeficient: 0.9283
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2826 - mean_io_u: 0.8750 - dice_coeficient: 0.9318
# Epoch 36: val_loss improved from 0.29653 to 0.29537, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2826 - mean_io_u: 0.8750 - dice_coeficient: 0.9318 - val_loss: 0.2954 - val_mean_io_u: 0.8746 - val_dice_coeficient: 0.9286
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2833 - mean_io_u: 0.8763 - dice_coeficient: 0.9323
# Epoch 37: val_loss improved from 0.29537 to 0.29506, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2833 - mean_io_u: 0.8763 - dice_coeficient: 0.9323 - val_loss: 0.2951 - val_mean_io_u: 0.8752 - val_dice_coeficient: 0.9285
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2762 - mean_io_u: 0.8780 - dice_coeficient: 0.9334
# Epoch 38: val_loss improved from 0.29506 to 0.29151, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2762 - mean_io_u: 0.8780 - dice_coeficient: 0.9334 - val_loss: 0.2915 - val_mean_io_u: 0.8769 - val_dice_coeficient: 0.9300
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2783 - mean_io_u: 0.8793 - dice_coeficient: 0.9336
# Epoch 39: val_loss improved from 0.29151 to 0.28962, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2783 - mean_io_u: 0.8793 - dice_coeficient: 0.9336 - val_loss: 0.2896 - val_mean_io_u: 0.8782 - val_dice_coeficient: 0.9305
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2751 - mean_io_u: 0.8809 - dice_coeficient: 0.9344
# Epoch 40: val_loss did not improve from 0.28962
# 51/51 [==============================] - 19s 367ms/step - loss: 0.2751 - mean_io_u: 0.8809 - dice_coeficient: 0.9344 - val_loss: 0.2905 - val_mean_io_u: 0.8781 - val_dice_coeficient: 0.9296
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2762 - mean_io_u: 0.8805 - dice_coeficient: 0.9334
# Epoch 41: val_loss improved from 0.28962 to 0.28880, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2762 - mean_io_u: 0.8805 - dice_coeficient: 0.9334 - val_loss: 0.2888 - val_mean_io_u: 0.8798 - val_dice_coeficient: 0.9305
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2735 - mean_io_u: 0.8828 - dice_coeficient: 0.9346
# Epoch 42: val_loss did not improve from 0.28880
# 51/51 [==============================] - 19s 366ms/step - loss: 0.2735 - mean_io_u: 0.8828 - dice_coeficient: 0.9346 - val_loss: 0.2895 - val_mean_io_u: 0.8808 - val_dice_coeficient: 0.9307
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2761 - mean_io_u: 0.8839 - dice_coeficient: 0.9351
# Epoch 43: val_loss improved from 0.28880 to 0.28711, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 375ms/step - loss: 0.2761 - mean_io_u: 0.8839 - dice_coeficient: 0.9351 - val_loss: 0.2871 - val_mean_io_u: 0.8831 - val_dice_coeficient: 0.9315
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2699 - mean_io_u: 0.8851 - dice_coeficient: 0.9358
# Epoch 44: val_loss improved from 0.28711 to 0.28586, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2699 - mean_io_u: 0.8851 - dice_coeficient: 0.9358 - val_loss: 0.2859 - val_mean_io_u: 0.8831 - val_dice_coeficient: 0.9320
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2734 - mean_io_u: 0.8860 - dice_coeficient: 0.9361
# Epoch 45: val_loss improved from 0.28586 to 0.28383, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2734 - mean_io_u: 0.8860 - dice_coeficient: 0.9361 - val_loss: 0.2838 - val_mean_io_u: 0.8846 - val_dice_coeficient: 0.9330
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2733 - mean_io_u: 0.8845 - dice_coeficient: 0.9341
# Epoch 46: val_loss did not improve from 0.28383
# 51/51 [==============================] - 19s 368ms/step - loss: 0.2733 - mean_io_u: 0.8845 - dice_coeficient: 0.9341 - val_loss: 0.2879 - val_mean_io_u: 0.8832 - val_dice_coeficient: 0.9307
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2699 - mean_io_u: 0.8879 - dice_coeficient: 0.9362
# Epoch 47: val_loss improved from 0.28383 to 0.28338, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2699 - mean_io_u: 0.8879 - dice_coeficient: 0.9362 - val_loss: 0.2834 - val_mean_io_u: 0.8872 - val_dice_coeficient: 0.9332
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2652 - mean_io_u: 0.8898 - dice_coeficient: 0.9380
# Epoch 48: val_loss improved from 0.28338 to 0.28215, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2652 - mean_io_u: 0.8898 - dice_coeficient: 0.9380 - val_loss: 0.2822 - val_mean_io_u: 0.8880 - val_dice_coeficient: 0.9339
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2677 - mean_io_u: 0.8907 - dice_coeficient: 0.9385
# Epoch 49: val_loss improved from 0.28215 to 0.28159, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2677 - mean_io_u: 0.8907 - dice_coeficient: 0.9385 - val_loss: 0.2816 - val_mean_io_u: 0.8890 - val_dice_coeficient: 0.9342
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2637 - mean_io_u: 0.8914 - dice_coeficient: 0.9388
# Epoch 50: val_loss did not improve from 0.28159
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2637 - mean_io_u: 0.8914 - dice_coeficient: 0.9388 - val_loss: 0.2950 - val_mean_io_u: 0.8845 - val_dice_coeficient: 0.9277
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2814 - mean_io_u: 0.8852 - dice_coeficient: 0.9308
# Epoch 51: val_loss did not improve from 0.28159
# 51/51 [==============================] - 19s 369ms/step - loss: 0.2814 - mean_io_u: 0.8852 - dice_coeficient: 0.9308 - val_loss: 0.2835 - val_mean_io_u: 0.8894 - val_dice_coeficient: 0.9329
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2926 - mean_io_u: 0.8803 - dice_coeficient: 0.9228
# Epoch 52: val_loss did not improve from 0.28159
# 51/51 [==============================] - 19s 367ms/step - loss: 0.2926 - mean_io_u: 0.8803 - dice_coeficient: 0.9228 - val_loss: 0.2947 - val_mean_io_u: 0.8863 - val_dice_coeficient: 0.9265
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2797 - mean_io_u: 0.8888 - dice_coeficient: 0.9300
# Epoch 53: val_loss did not improve from 0.28159
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2797 - mean_io_u: 0.8888 - dice_coeficient: 0.9300 - val_loss: 0.2874 - val_mean_io_u: 0.8898 - val_dice_coeficient: 0.9304
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2719 - mean_io_u: 0.8935 - dice_coeficient: 0.9359
# Epoch 54: val_loss did not improve from 0.28159
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2719 - mean_io_u: 0.8935 - dice_coeficient: 0.9359 - val_loss: 0.2831 - val_mean_io_u: 0.8919 - val_dice_coeficient: 0.9327
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2644 - mean_io_u: 0.8949 - dice_coeficient: 0.9375
# Epoch 55: val_loss improved from 0.28159 to 0.28131, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2644 - mean_io_u: 0.8949 - dice_coeficient: 0.9375 - val_loss: 0.2813 - val_mean_io_u: 0.8931 - val_dice_coeficient: 0.9337
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2631 - mean_io_u: 0.8964 - dice_coeficient: 0.9392
# Epoch 56: val_loss improved from 0.28131 to 0.27714, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 383ms/step - loss: 0.2631 - mean_io_u: 0.8964 - dice_coeficient: 0.9392 - val_loss: 0.2771 - val_mean_io_u: 0.8970 - val_dice_coeficient: 0.9376
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2706 - mean_io_u: 0.8956 - dice_coeficient: 0.9371
# Epoch 57: val_loss did not improve from 0.27714
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2706 - mean_io_u: 0.8956 - dice_coeficient: 0.9371 - val_loss: 0.2796 - val_mean_io_u: 0.8965 - val_dice_coeficient: 0.9365
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2667 - mean_io_u: 0.8970 - dice_coeficient: 0.9389
# Epoch 58: val_loss did not improve from 0.27714
# 51/51 [==============================] - 19s 368ms/step - loss: 0.2667 - mean_io_u: 0.8970 - dice_coeficient: 0.9389 - val_loss: 0.2827 - val_mean_io_u: 0.8954 - val_dice_coeficient: 0.9344
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2629 - mean_io_u: 0.8997 - dice_coeficient: 0.9410
# Epoch 59: val_loss improved from 0.27714 to 0.27670, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2629 - mean_io_u: 0.8997 - dice_coeficient: 0.9410 - val_loss: 0.2767 - val_mean_io_u: 0.8980 - val_dice_coeficient: 0.9376
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2570 - mean_io_u: 0.9012 - dice_coeficient: 0.9429
# Epoch 60: val_loss improved from 0.27670 to 0.27510, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 375ms/step - loss: 0.2570 - mean_io_u: 0.9012 - dice_coeficient: 0.9429 - val_loss: 0.2751 - val_mean_io_u: 0.8997 - val_dice_coeficient: 0.9385
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2551 - mean_io_u: 0.9022 - dice_coeficient: 0.9435
# Epoch 61: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2551 - mean_io_u: 0.9022 - dice_coeficient: 0.9435 - val_loss: 0.2866 - val_mean_io_u: 0.8960 - val_dice_coeficient: 0.9347
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2811 - mean_io_u: 0.8952 - dice_coeficient: 0.9344
# Epoch 62: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2811 - mean_io_u: 0.8952 - dice_coeficient: 0.9344 - val_loss: 0.2801 - val_mean_io_u: 0.8993 - val_dice_coeficient: 0.9363
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2610 - mean_io_u: 0.9020 - dice_coeficient: 0.9415
# Epoch 63: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2610 - mean_io_u: 0.9020 - dice_coeficient: 0.9415 - val_loss: 0.2947 - val_mean_io_u: 0.8940 - val_dice_coeficient: 0.9303
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2760 - mean_io_u: 0.8981 - dice_coeficient: 0.9344
# Epoch 64: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 370ms/step - loss: 0.2760 - mean_io_u: 0.8981 - dice_coeficient: 0.9344 - val_loss: 0.2797 - val_mean_io_u: 0.9008 - val_dice_coeficient: 0.9363
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2971 - mean_io_u: 0.8916 - dice_coeficient: 0.9276
# Epoch 65: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2971 - mean_io_u: 0.8916 - dice_coeficient: 0.9276 - val_loss: 0.2900 - val_mean_io_u: 0.8968 - val_dice_coeficient: 0.9316
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2743 - mean_io_u: 0.8996 - dice_coeficient: 0.9360
# Epoch 66: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2743 - mean_io_u: 0.8996 - dice_coeficient: 0.9360 - val_loss: 0.2934 - val_mean_io_u: 0.8959 - val_dice_coeficient: 0.9295
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2998 - mean_io_u: 0.8890 - dice_coeficient: 0.9233
# Epoch 67: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2998 - mean_io_u: 0.8890 - dice_coeficient: 0.9233 - val_loss: 0.2906 - val_mean_io_u: 0.8966 - val_dice_coeficient: 0.9302
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2727 - mean_io_u: 0.9013 - dice_coeficient: 0.9371
# Epoch 68: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2727 - mean_io_u: 0.9013 - dice_coeficient: 0.9371 - val_loss: 0.2816 - val_mean_io_u: 0.9000 - val_dice_coeficient: 0.9348
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2631 - mean_io_u: 0.9034 - dice_coeficient: 0.9401
# Epoch 69: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 369ms/step - loss: 0.2631 - mean_io_u: 0.9034 - dice_coeficient: 0.9401 - val_loss: 0.2783 - val_mean_io_u: 0.9016 - val_dice_coeficient: 0.9366
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2686 - mean_io_u: 0.8997 - dice_coeficient: 0.9356
# Epoch 70: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2686 - mean_io_u: 0.8997 - dice_coeficient: 0.9356 - val_loss: 0.2808 - val_mean_io_u: 0.9001 - val_dice_coeficient: 0.9348
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2644 - mean_io_u: 0.9037 - dice_coeficient: 0.9403
# Epoch 71: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2644 - mean_io_u: 0.9037 - dice_coeficient: 0.9403 - val_loss: 0.2774 - val_mean_io_u: 0.9020 - val_dice_coeficient: 0.9369
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2577 - mean_io_u: 0.9049 - dice_coeficient: 0.9418
# Epoch 72: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2577 - mean_io_u: 0.9049 - dice_coeficient: 0.9418 - val_loss: 0.2761 - val_mean_io_u: 0.9028 - val_dice_coeficient: 0.9375
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2568 - mean_io_u: 0.9057 - dice_coeficient: 0.9426
# Epoch 73: val_loss did not improve from 0.27510
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2568 - mean_io_u: 0.9057 - dice_coeficient: 0.9426 - val_loss: 0.2752 - val_mean_io_u: 0.9039 - val_dice_coeficient: 0.9382
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2623 - mean_io_u: 0.9063 - dice_coeficient: 0.9431
# Epoch 74: val_loss improved from 0.27510 to 0.27496, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2623 - mean_io_u: 0.9063 - dice_coeficient: 0.9431 - val_loss: 0.2750 - val_mean_io_u: 0.9043 - val_dice_coeficient: 0.9385
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2554 - mean_io_u: 0.9068 - dice_coeficient: 0.9437
# Epoch 75: val_loss improved from 0.27496 to 0.27409, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2554 - mean_io_u: 0.9068 - dice_coeficient: 0.9437 - val_loss: 0.2741 - val_mean_io_u: 0.9046 - val_dice_coeficient: 0.9389
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2539 - mean_io_u: 0.9073 - dice_coeficient: 0.9441
# Epoch 76: val_loss improved from 0.27409 to 0.27344, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2539 - mean_io_u: 0.9073 - dice_coeficient: 0.9441 - val_loss: 0.2734 - val_mean_io_u: 0.9052 - val_dice_coeficient: 0.9392
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2532 - mean_io_u: 0.9078 - dice_coeficient: 0.9445
# Epoch 77: val_loss improved from 0.27344 to 0.27321, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 390ms/step - loss: 0.2532 - mean_io_u: 0.9078 - dice_coeficient: 0.9445 - val_loss: 0.2732 - val_mean_io_u: 0.9057 - val_dice_coeficient: 0.9395
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2679 - mean_io_u: 0.9018 - dice_coeficient: 0.9373
# Epoch 78: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2679 - mean_io_u: 0.9018 - dice_coeficient: 0.9373 - val_loss: 0.3133 - val_mean_io_u: 0.8922 - val_dice_coeficient: 0.9226
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2887 - mean_io_u: 0.8968 - dice_coeficient: 0.9274
# Epoch 79: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 371ms/step - loss: 0.2887 - mean_io_u: 0.8968 - dice_coeficient: 0.9274 - val_loss: 0.2857 - val_mean_io_u: 0.9020 - val_dice_coeficient: 0.9327
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2963 - mean_io_u: 0.8904 - dice_coeficient: 0.9212
# Epoch 80: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2963 - mean_io_u: 0.8904 - dice_coeficient: 0.9212 - val_loss: 0.3533 - val_mean_io_u: 0.8661 - val_dice_coeficient: 0.8927
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2988 - mean_io_u: 0.8908 - dice_coeficient: 0.9204
# Epoch 81: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2988 - mean_io_u: 0.8908 - dice_coeficient: 0.9204 - val_loss: 0.2917 - val_mean_io_u: 0.8977 - val_dice_coeficient: 0.9289
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3045 - mean_io_u: 0.8879 - dice_coeficient: 0.9184
# Epoch 82: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 372ms/step - loss: 0.3045 - mean_io_u: 0.8879 - dice_coeficient: 0.9184 - val_loss: 0.3423 - val_mean_io_u: 0.8778 - val_dice_coeficient: 0.9042
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3019 - mean_io_u: 0.8937 - dice_coeficient: 0.9245
# Epoch 83: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 370ms/step - loss: 0.3019 - mean_io_u: 0.8937 - dice_coeficient: 0.9245 - val_loss: 0.2963 - val_mean_io_u: 0.8972 - val_dice_coeficient: 0.9287
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2775 - mean_io_u: 0.9016 - dice_coeficient: 0.9347
# Epoch 84: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2775 - mean_io_u: 0.9016 - dice_coeficient: 0.9347 - val_loss: 0.2892 - val_mean_io_u: 0.9006 - val_dice_coeficient: 0.9326
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2688 - mean_io_u: 0.9035 - dice_coeficient: 0.9374
# Epoch 85: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2688 - mean_io_u: 0.9035 - dice_coeficient: 0.9374 - val_loss: 0.2854 - val_mean_io_u: 0.9020 - val_dice_coeficient: 0.9343
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2676 - mean_io_u: 0.9048 - dice_coeficient: 0.9392
# Epoch 86: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2676 - mean_io_u: 0.9048 - dice_coeficient: 0.9392 - val_loss: 0.2832 - val_mean_io_u: 0.9027 - val_dice_coeficient: 0.9355
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2670 - mean_io_u: 0.9052 - dice_coeficient: 0.9398
# Epoch 87: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2670 - mean_io_u: 0.9052 - dice_coeficient: 0.9398 - val_loss: 0.2877 - val_mean_io_u: 0.9011 - val_dice_coeficient: 0.9336
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2707 - mean_io_u: 0.9050 - dice_coeficient: 0.9382
# Epoch 88: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2707 - mean_io_u: 0.9050 - dice_coeficient: 0.9382 - val_loss: 0.2891 - val_mean_io_u: 0.9010 - val_dice_coeficient: 0.9335
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2894 - mean_io_u: 0.8996 - dice_coeficient: 0.9309
# Epoch 89: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 383ms/step - loss: 0.2894 - mean_io_u: 0.8996 - dice_coeficient: 0.9309 - val_loss: 0.3023 - val_mean_io_u: 0.8978 - val_dice_coeficient: 0.9268
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3065 - mean_io_u: 0.8949 - dice_coeficient: 0.9233
# Epoch 90: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 374ms/step - loss: 0.3065 - mean_io_u: 0.8949 - dice_coeficient: 0.9233 - val_loss: 0.2945 - val_mean_io_u: 0.9012 - val_dice_coeficient: 0.9305
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2764 - mean_io_u: 0.9051 - dice_coeficient: 0.9364
# Epoch 91: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2764 - mean_io_u: 0.9051 - dice_coeficient: 0.9364 - val_loss: 0.2879 - val_mean_io_u: 0.9035 - val_dice_coeficient: 0.9337
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3109 - mean_io_u: 0.8904 - dice_coeficient: 0.9179
# Epoch 92: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 372ms/step - loss: 0.3109 - mean_io_u: 0.8904 - dice_coeficient: 0.9179 - val_loss: 0.3711 - val_mean_io_u: 0.8543 - val_dice_coeficient: 0.8799
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3120 - mean_io_u: 0.8901 - dice_coeficient: 0.9150
# Epoch 93: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 377ms/step - loss: 0.3120 - mean_io_u: 0.8901 - dice_coeficient: 0.9150 - val_loss: 0.2998 - val_mean_io_u: 0.9001 - val_dice_coeficient: 0.9258
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2811 - mean_io_u: 0.9025 - dice_coeficient: 0.9304
# Epoch 94: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2811 - mean_io_u: 0.9025 - dice_coeficient: 0.9304 - val_loss: 0.3064 - val_mean_io_u: 0.8945 - val_dice_coeficient: 0.9208
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2811 - mean_io_u: 0.9019 - dice_coeficient: 0.9313
# Epoch 95: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 375ms/step - loss: 0.2811 - mean_io_u: 0.9019 - dice_coeficient: 0.9313 - val_loss: 0.2896 - val_mean_io_u: 0.9023 - val_dice_coeficient: 0.9314
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2694 - mean_io_u: 0.9058 - dice_coeficient: 0.9365
# Epoch 96: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2694 - mean_io_u: 0.9058 - dice_coeficient: 0.9365 - val_loss: 0.2858 - val_mean_io_u: 0.9044 - val_dice_coeficient: 0.9336
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2676 - mean_io_u: 0.9071 - dice_coeficient: 0.9383
# Epoch 97: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2676 - mean_io_u: 0.9071 - dice_coeficient: 0.9383 - val_loss: 0.2846 - val_mean_io_u: 0.9045 - val_dice_coeficient: 0.9342
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2652 - mean_io_u: 0.9077 - dice_coeficient: 0.9391
# Epoch 98: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 376ms/step - loss: 0.2652 - mean_io_u: 0.9077 - dice_coeficient: 0.9391 - val_loss: 0.2826 - val_mean_io_u: 0.9061 - val_dice_coeficient: 0.9354
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2632 - mean_io_u: 0.9086 - dice_coeficient: 0.9402
# Epoch 99: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 378ms/step - loss: 0.2632 - mean_io_u: 0.9086 - dice_coeficient: 0.9402 - val_loss: 0.2817 - val_mean_io_u: 0.9064 - val_dice_coeficient: 0.9361
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2618 - mean_io_u: 0.9091 - dice_coeficient: 0.9409
# Epoch 100: val_loss did not improve from 0.27321
# 51/51 [==============================] - 19s 372ms/step - loss: 0.2618 - mean_io_u: 0.9091 - dice_coeficient: 0.9409 - val_loss: 0.2808 - val_mean_io_u: 0.9068 - val_dice_coeficient: 0.9366

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 5s 52ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx])
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
