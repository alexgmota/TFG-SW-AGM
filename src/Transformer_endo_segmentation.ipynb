# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8154

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

# def dice_loss(y_true, y_pred):
#     return 1 - dice_coeficient(y_true, y_pred)

# def tversky(y_true, y_pred, smooth=1, alpha=0.8):
#     T = tf.keras.backend.flatten(y_true)
#     P = tf.keras.backend.flatten(y_pred)
#     TP = tf.keras.backend.sum(T * P)
#     FN = tf.keras.backend.sum(T * (1 - P))
#     FP = tf.keras.backend.sum((1 - T) * P)
#     return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


# def tversky_loss(y_true, y_pred):
#     return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, decay=1e-4, clipvalue=0.5), 
    loss=sm.losses.JaccardLoss(),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_train_Weights.hdf5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto'
)

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.8740 - mean_io_u: 0.4645 - dice_coeficient: 0.4123
# Epoch 1: val_loss improved from inf to 0.77920, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 37s 379ms/step - loss: 0.8740 - mean_io_u: 0.4645 - dice_coeficient: 0.4123 - val_loss: 0.7792 - val_mean_io_u: 0.4848 - val_dice_coeficient: 0.6484
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.6986 - mean_io_u: 0.5370 - dice_coeficient: 0.7247
# Epoch 2: val_loss improved from 0.77920 to 0.60399, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 312ms/step - loss: 0.6986 - mean_io_u: 0.5370 - dice_coeficient: 0.7247 - val_loss: 0.6040 - val_mean_io_u: 0.5934 - val_dice_coeficient: 0.7816
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5454 - mean_io_u: 0.6270 - dice_coeficient: 0.8001
# Epoch 3: val_loss improved from 0.60399 to 0.49690, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 322ms/step - loss: 0.5454 - mean_io_u: 0.6270 - dice_coeficient: 0.8001 - val_loss: 0.4969 - val_mean_io_u: 0.6538 - val_dice_coeficient: 0.8167
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4717 - mean_io_u: 0.6683 - dice_coeficient: 0.8276
# Epoch 4: val_loss improved from 0.49690 to 0.44496, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 333ms/step - loss: 0.4717 - mean_io_u: 0.6683 - dice_coeficient: 0.8276 - val_loss: 0.4450 - val_mean_io_u: 0.6854 - val_dice_coeficient: 0.8356
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4306 - mean_io_u: 0.6928 - dice_coeficient: 0.8423
# Epoch 5: val_loss improved from 0.44496 to 0.42169, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 339ms/step - loss: 0.4306 - mean_io_u: 0.6928 - dice_coeficient: 0.8423 - val_loss: 0.4217 - val_mean_io_u: 0.7034 - val_dice_coeficient: 0.8471
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4078 - mean_io_u: 0.7099 - dice_coeficient: 0.8509
# Epoch 6: val_loss improved from 0.42169 to 0.39955, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 342ms/step - loss: 0.4078 - mean_io_u: 0.7099 - dice_coeficient: 0.8509 - val_loss: 0.3995 - val_mean_io_u: 0.7169 - val_dice_coeficient: 0.8540
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3900 - mean_io_u: 0.7242 - dice_coeficient: 0.8584
# Epoch 7: val_loss improved from 0.39955 to 0.38512, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 351ms/step - loss: 0.3900 - mean_io_u: 0.7242 - dice_coeficient: 0.8584 - val_loss: 0.3851 - val_mean_io_u: 0.7270 - val_dice_coeficient: 0.8598
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3737 - mean_io_u: 0.7360 - dice_coeficient: 0.8636
# Epoch 8: val_loss improved from 0.38512 to 0.37432, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.3737 - mean_io_u: 0.7360 - dice_coeficient: 0.8636 - val_loss: 0.3743 - val_mean_io_u: 0.7421 - val_dice_coeficient: 0.8642
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3643 - mean_io_u: 0.7462 - dice_coeficient: 0.8678
# Epoch 9: val_loss improved from 0.37432 to 0.36391, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 359ms/step - loss: 0.3643 - mean_io_u: 0.7462 - dice_coeficient: 0.8678 - val_loss: 0.3639 - val_mean_io_u: 0.7488 - val_dice_coeficient: 0.8683
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3580 - mean_io_u: 0.7563 - dice_coeficient: 0.8710
# Epoch 10: val_loss improved from 0.36391 to 0.35992, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.3580 - mean_io_u: 0.7563 - dice_coeficient: 0.8710 - val_loss: 0.3599 - val_mean_io_u: 0.7608 - val_dice_coeficient: 0.8707
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3523 - mean_io_u: 0.7642 - dice_coeficient: 0.8736
# Epoch 11: val_loss improved from 0.35992 to 0.35662, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 368ms/step - loss: 0.3523 - mean_io_u: 0.7642 - dice_coeficient: 0.8736 - val_loss: 0.3566 - val_mean_io_u: 0.7647 - val_dice_coeficient: 0.8726
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3511 - mean_io_u: 0.7707 - dice_coeficient: 0.8755
# Epoch 12: val_loss improved from 0.35662 to 0.34527, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 365ms/step - loss: 0.3511 - mean_io_u: 0.7707 - dice_coeficient: 0.8755 - val_loss: 0.3453 - val_mean_io_u: 0.7732 - val_dice_coeficient: 0.8757
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3320 - mean_io_u: 0.7773 - dice_coeficient: 0.8799
# Epoch 13: val_loss improved from 0.34527 to 0.32776, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.3320 - mean_io_u: 0.7773 - dice_coeficient: 0.8799 - val_loss: 0.3278 - val_mean_io_u: 0.7777 - val_dice_coeficient: 0.8793
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3259 - mean_io_u: 0.7820 - dice_coeficient: 0.8818
# Epoch 14: val_loss improved from 0.32776 to 0.32280, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.3259 - mean_io_u: 0.7820 - dice_coeficient: 0.8818 - val_loss: 0.3228 - val_mean_io_u: 0.7852 - val_dice_coeficient: 0.8811
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3185 - mean_io_u: 0.7884 - dice_coeficient: 0.8840
# Epoch 15: val_loss improved from 0.32280 to 0.31799, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.3185 - mean_io_u: 0.7884 - dice_coeficient: 0.8840 - val_loss: 0.3180 - val_mean_io_u: 0.7902 - val_dice_coeficient: 0.8834
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3152 - mean_io_u: 0.7935 - dice_coeficient: 0.8857
# Epoch 16: val_loss improved from 0.31799 to 0.31649, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.3152 - mean_io_u: 0.7935 - dice_coeficient: 0.8857 - val_loss: 0.3165 - val_mean_io_u: 0.7929 - val_dice_coeficient: 0.8846
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3124 - mean_io_u: 0.7963 - dice_coeficient: 0.8861
# Epoch 17: val_loss improved from 0.31649 to 0.31595, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.3124 - mean_io_u: 0.7963 - dice_coeficient: 0.8861 - val_loss: 0.3160 - val_mean_io_u: 0.7968 - val_dice_coeficient: 0.8847
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3120 - mean_io_u: 0.8012 - dice_coeficient: 0.8879
# Epoch 18: val_loss improved from 0.31595 to 0.31103, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 373ms/step - loss: 0.3120 - mean_io_u: 0.8012 - dice_coeficient: 0.8879 - val_loss: 0.3110 - val_mean_io_u: 0.8015 - val_dice_coeficient: 0.8870
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3047 - mean_io_u: 0.8046 - dice_coeficient: 0.8896
# Epoch 19: val_loss improved from 0.31103 to 0.30816, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 372ms/step - loss: 0.3047 - mean_io_u: 0.8046 - dice_coeficient: 0.8896 - val_loss: 0.3082 - val_mean_io_u: 0.8044 - val_dice_coeficient: 0.8880
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2997 - mean_io_u: 0.8081 - dice_coeficient: 0.8908
# Epoch 20: val_loss improved from 0.30816 to 0.30642, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2997 - mean_io_u: 0.8081 - dice_coeficient: 0.8908 - val_loss: 0.3064 - val_mean_io_u: 0.8088 - val_dice_coeficient: 0.8887
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3005 - mean_io_u: 0.8108 - dice_coeficient: 0.8917
# Epoch 21: val_loss improved from 0.30642 to 0.30419, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 383ms/step - loss: 0.3005 - mean_io_u: 0.8108 - dice_coeficient: 0.8917 - val_loss: 0.3042 - val_mean_io_u: 0.8114 - val_dice_coeficient: 0.8901
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2997 - mean_io_u: 0.8132 - dice_coeficient: 0.8916
# Epoch 22: val_loss improved from 0.30419 to 0.29963, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 375ms/step - loss: 0.2997 - mean_io_u: 0.8132 - dice_coeficient: 0.8916 - val_loss: 0.2996 - val_mean_io_u: 0.8141 - val_dice_coeficient: 0.8904
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2926 - mean_io_u: 0.8161 - dice_coeficient: 0.8928
# Epoch 23: val_loss improved from 0.29963 to 0.29709, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2926 - mean_io_u: 0.8161 - dice_coeficient: 0.8928 - val_loss: 0.2971 - val_mean_io_u: 0.8178 - val_dice_coeficient: 0.8912
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2936 - mean_io_u: 0.8190 - dice_coeficient: 0.8937
# Epoch 24: val_loss improved from 0.29709 to 0.29603, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2936 - mean_io_u: 0.8190 - dice_coeficient: 0.8937 - val_loss: 0.2960 - val_mean_io_u: 0.8177 - val_dice_coeficient: 0.8916
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2916 - mean_io_u: 0.8222 - dice_coeficient: 0.8942
# Epoch 25: val_loss improved from 0.29603 to 0.29479, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 375ms/step - loss: 0.2916 - mean_io_u: 0.8222 - dice_coeficient: 0.8942 - val_loss: 0.2948 - val_mean_io_u: 0.8199 - val_dice_coeficient: 0.8918
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2860 - mean_io_u: 0.8235 - dice_coeficient: 0.8948
# Epoch 26: val_loss improved from 0.29479 to 0.29043, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2860 - mean_io_u: 0.8235 - dice_coeficient: 0.8948 - val_loss: 0.2904 - val_mean_io_u: 0.8225 - val_dice_coeficient: 0.8929
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2831 - mean_io_u: 0.8252 - dice_coeficient: 0.8954
# Epoch 27: val_loss improved from 0.29043 to 0.28835, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 380ms/step - loss: 0.2831 - mean_io_u: 0.8252 - dice_coeficient: 0.8954 - val_loss: 0.2884 - val_mean_io_u: 0.8241 - val_dice_coeficient: 0.8933
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2777 - mean_io_u: 0.8276 - dice_coeficient: 0.8963
# Epoch 28: val_loss improved from 0.28835 to 0.28653, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.2777 - mean_io_u: 0.8276 - dice_coeficient: 0.8963 - val_loss: 0.2865 - val_mean_io_u: 0.8263 - val_dice_coeficient: 0.8940
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2792 - mean_io_u: 0.8295 - dice_coeficient: 0.8968
# Epoch 29: val_loss improved from 0.28653 to 0.28303, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2792 - mean_io_u: 0.8295 - dice_coeficient: 0.8968 - val_loss: 0.2830 - val_mean_io_u: 0.8294 - val_dice_coeficient: 0.8949
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2760 - mean_io_u: 0.8314 - dice_coeficient: 0.8975
# Epoch 30: val_loss improved from 0.28303 to 0.28209, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2760 - mean_io_u: 0.8314 - dice_coeficient: 0.8975 - val_loss: 0.2821 - val_mean_io_u: 0.8304 - val_dice_coeficient: 0.8951
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2723 - mean_io_u: 0.8330 - dice_coeficient: 0.8984
# Epoch 31: val_loss improved from 0.28209 to 0.27777, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2723 - mean_io_u: 0.8330 - dice_coeficient: 0.8984 - val_loss: 0.2778 - val_mean_io_u: 0.8331 - val_dice_coeficient: 0.8965
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2700 - mean_io_u: 0.8353 - dice_coeficient: 0.8994
# Epoch 32: val_loss improved from 0.27777 to 0.27564, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2700 - mean_io_u: 0.8353 - dice_coeficient: 0.8994 - val_loss: 0.2756 - val_mean_io_u: 0.8354 - val_dice_coeficient: 0.8969
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2664 - mean_io_u: 0.8369 - dice_coeficient: 0.8998
# Epoch 33: val_loss improved from 0.27564 to 0.27526, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 378ms/step - loss: 0.2664 - mean_io_u: 0.8369 - dice_coeficient: 0.8998 - val_loss: 0.2753 - val_mean_io_u: 0.8359 - val_dice_coeficient: 0.8971
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2663 - mean_io_u: 0.8381 - dice_coeficient: 0.9000
# Epoch 34: val_loss improved from 0.27526 to 0.27480, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2663 - mean_io_u: 0.8381 - dice_coeficient: 0.9000 - val_loss: 0.2748 - val_mean_io_u: 0.8379 - val_dice_coeficient: 0.8976
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2656 - mean_io_u: 0.8402 - dice_coeficient: 0.9007
# Epoch 35: val_loss improved from 0.27480 to 0.27240, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 380ms/step - loss: 0.2656 - mean_io_u: 0.8402 - dice_coeficient: 0.9007 - val_loss: 0.2724 - val_mean_io_u: 0.8394 - val_dice_coeficient: 0.8980
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2624 - mean_io_u: 0.8413 - dice_coeficient: 0.9008
# Epoch 36: val_loss improved from 0.27240 to 0.27153, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 383ms/step - loss: 0.2624 - mean_io_u: 0.8413 - dice_coeficient: 0.9008 - val_loss: 0.2715 - val_mean_io_u: 0.8411 - val_dice_coeficient: 0.8984
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2642 - mean_io_u: 0.8425 - dice_coeficient: 0.9015
# Epoch 37: val_loss improved from 0.27153 to 0.26886, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2642 - mean_io_u: 0.8425 - dice_coeficient: 0.9015 - val_loss: 0.2689 - val_mean_io_u: 0.8420 - val_dice_coeficient: 0.8992
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2580 - mean_io_u: 0.8436 - dice_coeficient: 0.9022
# Epoch 38: val_loss did not improve from 0.26886
# 51/51 [==============================] - 19s 374ms/step - loss: 0.2580 - mean_io_u: 0.8436 - dice_coeficient: 0.9022 - val_loss: 0.2695 - val_mean_io_u: 0.8420 - val_dice_coeficient: 0.8990
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2592 - mean_io_u: 0.8445 - dice_coeficient: 0.9022
# Epoch 39: val_loss did not improve from 0.26886
# 51/51 [==============================] - 19s 373ms/step - loss: 0.2592 - mean_io_u: 0.8445 - dice_coeficient: 0.9022 - val_loss: 0.2702 - val_mean_io_u: 0.8426 - val_dice_coeficient: 0.8982
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2585 - mean_io_u: 0.8454 - dice_coeficient: 0.9020
# Epoch 40: val_loss did not improve from 0.26886
# 51/51 [==============================] - 19s 376ms/step - loss: 0.2585 - mean_io_u: 0.8454 - dice_coeficient: 0.9020 - val_loss: 0.2691 - val_mean_io_u: 0.8444 - val_dice_coeficient: 0.8990
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2564 - mean_io_u: 0.8467 - dice_coeficient: 0.9028
# Epoch 41: val_loss improved from 0.26886 to 0.26776, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 384ms/step - loss: 0.2564 - mean_io_u: 0.8467 - dice_coeficient: 0.9028 - val_loss: 0.2678 - val_mean_io_u: 0.8457 - val_dice_coeficient: 0.8998
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2558 - mean_io_u: 0.8475 - dice_coeficient: 0.9031
# Epoch 42: val_loss improved from 0.26776 to 0.26721, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2558 - mean_io_u: 0.8475 - dice_coeficient: 0.9031 - val_loss: 0.2672 - val_mean_io_u: 0.8467 - val_dice_coeficient: 0.9000
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2583 - mean_io_u: 0.8485 - dice_coeficient: 0.9034
# Epoch 43: val_loss improved from 0.26721 to 0.26655, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2583 - mean_io_u: 0.8485 - dice_coeficient: 0.9034 - val_loss: 0.2665 - val_mean_io_u: 0.8481 - val_dice_coeficient: 0.9002
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2526 - mean_io_u: 0.8492 - dice_coeficient: 0.9038
# Epoch 44: val_loss improved from 0.26655 to 0.26584, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2526 - mean_io_u: 0.8492 - dice_coeficient: 0.9038 - val_loss: 0.2658 - val_mean_io_u: 0.8486 - val_dice_coeficient: 0.9008
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2591 - mean_io_u: 0.8497 - dice_coeficient: 0.9038
# Epoch 45: val_loss improved from 0.26584 to 0.26581, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 382ms/step - loss: 0.2591 - mean_io_u: 0.8497 - dice_coeficient: 0.9038 - val_loss: 0.2658 - val_mean_io_u: 0.8495 - val_dice_coeficient: 0.9008
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2533 - mean_io_u: 0.8512 - dice_coeficient: 0.9043
# Epoch 46: val_loss improved from 0.26581 to 0.26449, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 382ms/step - loss: 0.2533 - mean_io_u: 0.8512 - dice_coeficient: 0.9043 - val_loss: 0.2645 - val_mean_io_u: 0.8495 - val_dice_coeficient: 0.9010
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2529 - mean_io_u: 0.8516 - dice_coeficient: 0.9047
# Epoch 47: val_loss improved from 0.26449 to 0.26324, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 384ms/step - loss: 0.2529 - mean_io_u: 0.8516 - dice_coeficient: 0.9047 - val_loss: 0.2632 - val_mean_io_u: 0.8509 - val_dice_coeficient: 0.9015
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2491 - mean_io_u: 0.8529 - dice_coeficient: 0.9052
# Epoch 48: val_loss did not improve from 0.26324
# 51/51 [==============================] - 19s 375ms/step - loss: 0.2491 - mean_io_u: 0.8529 - dice_coeficient: 0.9052 - val_loss: 0.2633 - val_mean_io_u: 0.8522 - val_dice_coeficient: 0.9018
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2556 - mean_io_u: 0.8534 - dice_coeficient: 0.9052
# Epoch 49: val_loss improved from 0.26324 to 0.26221, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 387ms/step - loss: 0.2556 - mean_io_u: 0.8534 - dice_coeficient: 0.9052 - val_loss: 0.2622 - val_mean_io_u: 0.8535 - val_dice_coeficient: 0.9020
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2485 - mean_io_u: 0.8542 - dice_coeficient: 0.9057
# Epoch 50: val_loss improved from 0.26221 to 0.26150, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 384ms/step - loss: 0.2485 - mean_io_u: 0.8542 - dice_coeficient: 0.9057 - val_loss: 0.2615 - val_mean_io_u: 0.8532 - val_dice_coeficient: 0.9023
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2455 - mean_io_u: 0.8551 - dice_coeficient: 0.9063
# Epoch 51: val_loss improved from 0.26150 to 0.25919, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 390ms/step - loss: 0.2455 - mean_io_u: 0.8551 - dice_coeficient: 0.9063 - val_loss: 0.2592 - val_mean_io_u: 0.8549 - val_dice_coeficient: 0.9029
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2455 - mean_io_u: 0.8562 - dice_coeficient: 0.9070
# Epoch 52: val_loss improved from 0.25919 to 0.25817, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 390ms/step - loss: 0.2455 - mean_io_u: 0.8562 - dice_coeficient: 0.9070 - val_loss: 0.2582 - val_mean_io_u: 0.8554 - val_dice_coeficient: 0.9034
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2411 - mean_io_u: 0.8572 - dice_coeficient: 0.9072
# Epoch 53: val_loss improved from 0.25817 to 0.25773, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 378ms/step - loss: 0.2411 - mean_io_u: 0.8572 - dice_coeficient: 0.9072 - val_loss: 0.2577 - val_mean_io_u: 0.8570 - val_dice_coeficient: 0.9034
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2462 - mean_io_u: 0.8580 - dice_coeficient: 0.9075
# Epoch 54: val_loss did not improve from 0.25773
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2462 - mean_io_u: 0.8580 - dice_coeficient: 0.9075 - val_loss: 0.2581 - val_mean_io_u: 0.8574 - val_dice_coeficient: 0.9038
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2400 - mean_io_u: 0.8589 - dice_coeficient: 0.9077
# Epoch 55: val_loss improved from 0.25773 to 0.25698, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 384ms/step - loss: 0.2400 - mean_io_u: 0.8589 - dice_coeficient: 0.9077 - val_loss: 0.2570 - val_mean_io_u: 0.8580 - val_dice_coeficient: 0.9040
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2443 - mean_io_u: 0.8593 - dice_coeficient: 0.9078
# Epoch 56: val_loss improved from 0.25698 to 0.25692, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 386ms/step - loss: 0.2443 - mean_io_u: 0.8593 - dice_coeficient: 0.9078 - val_loss: 0.2569 - val_mean_io_u: 0.8577 - val_dice_coeficient: 0.9038
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2396 - mean_io_u: 0.8599 - dice_coeficient: 0.9082
# Epoch 57: val_loss improved from 0.25692 to 0.25657, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 382ms/step - loss: 0.2396 - mean_io_u: 0.8599 - dice_coeficient: 0.9082 - val_loss: 0.2566 - val_mean_io_u: 0.8588 - val_dice_coeficient: 0.9042
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2400 - mean_io_u: 0.8604 - dice_coeficient: 0.9082
# Epoch 58: val_loss improved from 0.25657 to 0.25528, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 383ms/step - loss: 0.2400 - mean_io_u: 0.8604 - dice_coeficient: 0.9082 - val_loss: 0.2553 - val_mean_io_u: 0.8595 - val_dice_coeficient: 0.9045
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2400 - mean_io_u: 0.8612 - dice_coeficient: 0.9087
# Epoch 59: val_loss did not improve from 0.25528
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2400 - mean_io_u: 0.8612 - dice_coeficient: 0.9087 - val_loss: 0.2557 - val_mean_io_u: 0.8595 - val_dice_coeficient: 0.9041
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2401 - mean_io_u: 0.8614 - dice_coeficient: 0.9085
# Epoch 60: val_loss did not improve from 0.25528
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2401 - mean_io_u: 0.8614 - dice_coeficient: 0.9085 - val_loss: 0.2567 - val_mean_io_u: 0.8607 - val_dice_coeficient: 0.9045
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2392 - mean_io_u: 0.8624 - dice_coeficient: 0.9087
# Epoch 61: val_loss improved from 0.25528 to 0.25387, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 383ms/step - loss: 0.2392 - mean_io_u: 0.8624 - dice_coeficient: 0.9087 - val_loss: 0.2539 - val_mean_io_u: 0.8607 - val_dice_coeficient: 0.9045
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2372 - mean_io_u: 0.8625 - dice_coeficient: 0.9083
# Epoch 62: val_loss improved from 0.25387 to 0.25240, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 384ms/step - loss: 0.2372 - mean_io_u: 0.8625 - dice_coeficient: 0.9083 - val_loss: 0.2524 - val_mean_io_u: 0.8606 - val_dice_coeficient: 0.9040
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2313 - mean_io_u: 0.8631 - dice_coeficient: 0.9086
# Epoch 63: val_loss improved from 0.25240 to 0.25228, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 385ms/step - loss: 0.2313 - mean_io_u: 0.8631 - dice_coeficient: 0.9086 - val_loss: 0.2523 - val_mean_io_u: 0.8619 - val_dice_coeficient: 0.9041
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2323 - mean_io_u: 0.8635 - dice_coeficient: 0.9081
# Epoch 64: val_loss improved from 0.25228 to 0.25124, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 383ms/step - loss: 0.2323 - mean_io_u: 0.8635 - dice_coeficient: 0.9081 - val_loss: 0.2512 - val_mean_io_u: 0.8630 - val_dice_coeficient: 0.9047
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2351 - mean_io_u: 0.8646 - dice_coeficient: 0.9090
# Epoch 65: val_loss improved from 0.25124 to 0.24833, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 386ms/step - loss: 0.2351 - mean_io_u: 0.8646 - dice_coeficient: 0.9090 - val_loss: 0.2483 - val_mean_io_u: 0.8633 - val_dice_coeficient: 0.9049
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2286 - mean_io_u: 0.8651 - dice_coeficient: 0.9093
# Epoch 66: val_loss did not improve from 0.24833
# 51/51 [==============================] - 19s 377ms/step - loss: 0.2286 - mean_io_u: 0.8651 - dice_coeficient: 0.9093 - val_loss: 0.2487 - val_mean_io_u: 0.8639 - val_dice_coeficient: 0.9050
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2321 - mean_io_u: 0.8654 - dice_coeficient: 0.9089
# Epoch 67: val_loss improved from 0.24833 to 0.24790, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 383ms/step - loss: 0.2321 - mean_io_u: 0.8654 - dice_coeficient: 0.9089 - val_loss: 0.2479 - val_mean_io_u: 0.8645 - val_dice_coeficient: 0.9050
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2294 - mean_io_u: 0.8662 - dice_coeficient: 0.9092
# Epoch 68: val_loss improved from 0.24790 to 0.24788, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 386ms/step - loss: 0.2294 - mean_io_u: 0.8662 - dice_coeficient: 0.9092 - val_loss: 0.2479 - val_mean_io_u: 0.8654 - val_dice_coeficient: 0.9053
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2243 - mean_io_u: 0.8671 - dice_coeficient: 0.9097
# Epoch 69: val_loss improved from 0.24788 to 0.24778, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 386ms/step - loss: 0.2243 - mean_io_u: 0.8671 - dice_coeficient: 0.9097 - val_loss: 0.2478 - val_mean_io_u: 0.8659 - val_dice_coeficient: 0.9053
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2272 - mean_io_u: 0.8674 - dice_coeficient: 0.9098
# Epoch 70: val_loss did not improve from 0.24778
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2272 - mean_io_u: 0.8674 - dice_coeficient: 0.9098 - val_loss: 0.2485 - val_mean_io_u: 0.8660 - val_dice_coeficient: 0.9050
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2282 - mean_io_u: 0.8681 - dice_coeficient: 0.9102
# Epoch 71: val_loss improved from 0.24778 to 0.24544, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 387ms/step - loss: 0.2282 - mean_io_u: 0.8681 - dice_coeficient: 0.9102 - val_loss: 0.2454 - val_mean_io_u: 0.8670 - val_dice_coeficient: 0.9058
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2228 - mean_io_u: 0.8683 - dice_coeficient: 0.9103
# Epoch 72: val_loss improved from 0.24544 to 0.24535, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 380ms/step - loss: 0.2228 - mean_io_u: 0.8683 - dice_coeficient: 0.9103 - val_loss: 0.2453 - val_mean_io_u: 0.8669 - val_dice_coeficient: 0.9058
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2204 - mean_io_u: 0.8690 - dice_coeficient: 0.9106
# Epoch 73: val_loss did not improve from 0.24535
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2204 - mean_io_u: 0.8690 - dice_coeficient: 0.9106 - val_loss: 0.2459 - val_mean_io_u: 0.8678 - val_dice_coeficient: 0.9058
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2300 - mean_io_u: 0.8691 - dice_coeficient: 0.9104
# Epoch 74: val_loss did not improve from 0.24535
# 51/51 [==============================] - 19s 383ms/step - loss: 0.2300 - mean_io_u: 0.8691 - dice_coeficient: 0.9104 - val_loss: 0.2456 - val_mean_io_u: 0.8677 - val_dice_coeficient: 0.9059
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2217 - mean_io_u: 0.8694 - dice_coeficient: 0.9107
# Epoch 75: val_loss improved from 0.24535 to 0.24387, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 389ms/step - loss: 0.2217 - mean_io_u: 0.8694 - dice_coeficient: 0.9107 - val_loss: 0.2439 - val_mean_io_u: 0.8681 - val_dice_coeficient: 0.9060
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2213 - mean_io_u: 0.8701 - dice_coeficient: 0.9111
# Epoch 76: val_loss improved from 0.24387 to 0.24336, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 385ms/step - loss: 0.2213 - mean_io_u: 0.8701 - dice_coeficient: 0.9111 - val_loss: 0.2434 - val_mean_io_u: 0.8683 - val_dice_coeficient: 0.9064
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2212 - mean_io_u: 0.8702 - dice_coeficient: 0.9107
# Epoch 77: val_loss improved from 0.24336 to 0.24180, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 388ms/step - loss: 0.2212 - mean_io_u: 0.8702 - dice_coeficient: 0.9107 - val_loss: 0.2418 - val_mean_io_u: 0.8687 - val_dice_coeficient: 0.9063
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2166 - mean_io_u: 0.8706 - dice_coeficient: 0.9111
# Epoch 78: val_loss did not improve from 0.24180
# 51/51 [==============================] - 19s 382ms/step - loss: 0.2166 - mean_io_u: 0.8706 - dice_coeficient: 0.9111 - val_loss: 0.2427 - val_mean_io_u: 0.8695 - val_dice_coeficient: 0.9064
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2195 - mean_io_u: 0.8711 - dice_coeficient: 0.9113
# Epoch 79: val_loss improved from 0.24180 to 0.24122, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 385ms/step - loss: 0.2195 - mean_io_u: 0.8711 - dice_coeficient: 0.9113 - val_loss: 0.2412 - val_mean_io_u: 0.8692 - val_dice_coeficient: 0.9066
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2162 - mean_io_u: 0.8714 - dice_coeficient: 0.9116
# Epoch 80: val_loss improved from 0.24122 to 0.24071, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 386ms/step - loss: 0.2162 - mean_io_u: 0.8714 - dice_coeficient: 0.9116 - val_loss: 0.2407 - val_mean_io_u: 0.8703 - val_dice_coeficient: 0.9068
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2182 - mean_io_u: 0.8722 - dice_coeficient: 0.9118
# Epoch 81: val_loss improved from 0.24071 to 0.23966, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 383ms/step - loss: 0.2182 - mean_io_u: 0.8722 - dice_coeficient: 0.9118 - val_loss: 0.2397 - val_mean_io_u: 0.8705 - val_dice_coeficient: 0.9068
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2165 - mean_io_u: 0.8725 - dice_coeficient: 0.9119
# Epoch 82: val_loss did not improve from 0.23966
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2165 - mean_io_u: 0.8725 - dice_coeficient: 0.9119 - val_loss: 0.2409 - val_mean_io_u: 0.8708 - val_dice_coeficient: 0.9066
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2181 - mean_io_u: 0.8726 - dice_coeficient: 0.9118
# Epoch 83: val_loss did not improve from 0.23966
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2181 - mean_io_u: 0.8726 - dice_coeficient: 0.9118 - val_loss: 0.2417 - val_mean_io_u: 0.8711 - val_dice_coeficient: 0.9068
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2150 - mean_io_u: 0.8729 - dice_coeficient: 0.9121
# Epoch 84: val_loss did not improve from 0.23966
# 51/51 [==============================] - 20s 384ms/step - loss: 0.2150 - mean_io_u: 0.8729 - dice_coeficient: 0.9121 - val_loss: 0.2408 - val_mean_io_u: 0.8712 - val_dice_coeficient: 0.9067
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2131 - mean_io_u: 0.8734 - dice_coeficient: 0.9122
# Epoch 85: val_loss improved from 0.23966 to 0.23956, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 384ms/step - loss: 0.2131 - mean_io_u: 0.8734 - dice_coeficient: 0.9122 - val_loss: 0.2396 - val_mean_io_u: 0.8721 - val_dice_coeficient: 0.9070
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2142 - mean_io_u: 0.8738 - dice_coeficient: 0.9124
# Epoch 86: val_loss did not improve from 0.23956
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2142 - mean_io_u: 0.8738 - dice_coeficient: 0.9124 - val_loss: 0.2405 - val_mean_io_u: 0.8726 - val_dice_coeficient: 0.9072
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2165 - mean_io_u: 0.8742 - dice_coeficient: 0.9125
# Epoch 87: val_loss did not improve from 0.23956
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2165 - mean_io_u: 0.8742 - dice_coeficient: 0.9125 - val_loss: 0.2406 - val_mean_io_u: 0.8727 - val_dice_coeficient: 0.9074
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2135 - mean_io_u: 0.8746 - dice_coeficient: 0.9128
# Epoch 88: val_loss did not improve from 0.23956
# 51/51 [==============================] - 19s 382ms/step - loss: 0.2135 - mean_io_u: 0.8746 - dice_coeficient: 0.9128 - val_loss: 0.2402 - val_mean_io_u: 0.8723 - val_dice_coeficient: 0.9073
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2133 - mean_io_u: 0.8747 - dice_coeficient: 0.9130
# Epoch 89: val_loss did not improve from 0.23956
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2133 - mean_io_u: 0.8747 - dice_coeficient: 0.9130 - val_loss: 0.2405 - val_mean_io_u: 0.8732 - val_dice_coeficient: 0.9073
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2136 - mean_io_u: 0.8752 - dice_coeficient: 0.9130
# Epoch 90: val_loss did not improve from 0.23956
# 51/51 [==============================] - 19s 380ms/step - loss: 0.2136 - mean_io_u: 0.8752 - dice_coeficient: 0.9130 - val_loss: 0.2401 - val_mean_io_u: 0.8735 - val_dice_coeficient: 0.9076
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2125 - mean_io_u: 0.8753 - dice_coeficient: 0.9132
# Epoch 91: val_loss did not improve from 0.23956
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2125 - mean_io_u: 0.8753 - dice_coeficient: 0.9132 - val_loss: 0.2403 - val_mean_io_u: 0.8730 - val_dice_coeficient: 0.9072
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2153 - mean_io_u: 0.8755 - dice_coeficient: 0.9129
# Epoch 92: val_loss improved from 0.23956 to 0.23930, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 386ms/step - loss: 0.2153 - mean_io_u: 0.8755 - dice_coeficient: 0.9129 - val_loss: 0.2393 - val_mean_io_u: 0.8742 - val_dice_coeficient: 0.9076
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2113 - mean_io_u: 0.8758 - dice_coeficient: 0.9132
# Epoch 93: val_loss improved from 0.23930 to 0.23870, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 380ms/step - loss: 0.2113 - mean_io_u: 0.8758 - dice_coeficient: 0.9132 - val_loss: 0.2387 - val_mean_io_u: 0.8745 - val_dice_coeficient: 0.9077
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2136 - mean_io_u: 0.8763 - dice_coeficient: 0.9133
# Epoch 94: val_loss improved from 0.23870 to 0.23844, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2136 - mean_io_u: 0.8763 - dice_coeficient: 0.9133 - val_loss: 0.2384 - val_mean_io_u: 0.8744 - val_dice_coeficient: 0.9078
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2115 - mean_io_u: 0.8764 - dice_coeficient: 0.9133
# Epoch 95: val_loss did not improve from 0.23844
# 51/51 [==============================] - 19s 381ms/step - loss: 0.2115 - mean_io_u: 0.8764 - dice_coeficient: 0.9133 - val_loss: 0.2386 - val_mean_io_u: 0.8747 - val_dice_coeficient: 0.9077
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2112 - mean_io_u: 0.8769 - dice_coeficient: 0.9134
# Epoch 96: val_loss did not improve from 0.23844
# 51/51 [==============================] - 19s 379ms/step - loss: 0.2112 - mean_io_u: 0.8769 - dice_coeficient: 0.9134 - val_loss: 0.2403 - val_mean_io_u: 0.8751 - val_dice_coeficient: 0.9075
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2110 - mean_io_u: 0.8772 - dice_coeficient: 0.9136
# Epoch 97: val_loss did not improve from 0.23844
# 51/51 [==============================] - 20s 386ms/step - loss: 0.2110 - mean_io_u: 0.8772 - dice_coeficient: 0.9136 - val_loss: 0.2385 - val_mean_io_u: 0.8753 - val_dice_coeficient: 0.9078
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2146 - mean_io_u: 0.8774 - dice_coeficient: 0.9136
# Epoch 98: val_loss improved from 0.23844 to 0.23818, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 383ms/step - loss: 0.2146 - mean_io_u: 0.8774 - dice_coeficient: 0.9136 - val_loss: 0.2382 - val_mean_io_u: 0.8758 - val_dice_coeficient: 0.9079
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2088 - mean_io_u: 0.8778 - dice_coeficient: 0.9137
# Epoch 99: val_loss did not improve from 0.23818
# 51/51 [==============================] - 19s 382ms/step - loss: 0.2088 - mean_io_u: 0.8778 - dice_coeficient: 0.9137 - val_loss: 0.2387 - val_mean_io_u: 0.8760 - val_dice_coeficient: 0.9079
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2135 - mean_io_u: 0.8779 - dice_coeficient: 0.9138
# Epoch 100: val_loss improved from 0.23818 to 0.23816, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 380ms/step - loss: 0.2135 - mean_io_u: 0.8779 - dice_coeficient: 0.9138 - val_loss: 0.2382 - val_mean_io_u: 0.8760 - val_dice_coeficient: 0.9078

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 5s 54ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx])
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
