# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8154

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

# def dice_loss(y_true, y_pred):
#     return 1 - dice_coeficient(y_true, y_pred)

# def tversky(y_true, y_pred, smooth=1, alpha=0.8):
#     T = tf.keras.backend.flatten(y_true)
#     P = tf.keras.backend.flatten(y_pred)
#     TP = tf.keras.backend.sum(T * P)
#     FN = tf.keras.backend.sum(T * (1 - P))
#     FP = tf.keras.backend.sum((1 - T) * P)
#     return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


# def tversky_loss(y_true, y_pred):
#     return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, decay=1e-4), 
    loss=sm.losses.DiceLoss(),
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_train_Weights.hdf5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto'
)

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.8023 - mean_io_u: 0.4676 - dice_coeficient: 0.4214
# Epoch 1: val_loss improved from inf to 0.68662, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 34s 368ms/step - loss: 0.8023 - mean_io_u: 0.4676 - dice_coeficient: 0.4214 - val_loss: 0.6866 - val_mean_io_u: 0.4880 - val_dice_coeficient: 0.5841
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5862 - mean_io_u: 0.5410 - dice_coeficient: 0.6753
# Epoch 2: val_loss improved from 0.68662 to 0.49553, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 308ms/step - loss: 0.5862 - mean_io_u: 0.5410 - dice_coeficient: 0.6753 - val_loss: 0.4955 - val_mean_io_u: 0.5906 - val_dice_coeficient: 0.7375
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.4532 - mean_io_u: 0.6152 - dice_coeficient: 0.7585
# Epoch 3: val_loss improved from 0.49553 to 0.40598, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 317ms/step - loss: 0.4532 - mean_io_u: 0.6152 - dice_coeficient: 0.7585 - val_loss: 0.4060 - val_mean_io_u: 0.6343 - val_dice_coeficient: 0.7783
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3645 - mean_io_u: 0.6639 - dice_coeficient: 0.8123
# Epoch 4: val_loss improved from 0.40598 to 0.32212, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 327ms/step - loss: 0.3645 - mean_io_u: 0.6639 - dice_coeficient: 0.8123 - val_loss: 0.3221 - val_mean_io_u: 0.6922 - val_dice_coeficient: 0.8394
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2937 - mean_io_u: 0.7027 - dice_coeficient: 0.8540
# Epoch 5: val_loss improved from 0.32212 to 0.27396, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 332ms/step - loss: 0.2937 - mean_io_u: 0.7027 - dice_coeficient: 0.8540 - val_loss: 0.2740 - val_mean_io_u: 0.7091 - val_dice_coeficient: 0.8636
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2560 - mean_io_u: 0.7266 - dice_coeficient: 0.8713
# Epoch 6: val_loss improved from 0.27396 to 0.24274, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 336ms/step - loss: 0.2560 - mean_io_u: 0.7266 - dice_coeficient: 0.8713 - val_loss: 0.2427 - val_mean_io_u: 0.7364 - val_dice_coeficient: 0.8766
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2349 - mean_io_u: 0.7451 - dice_coeficient: 0.8822
# Epoch 7: val_loss improved from 0.24274 to 0.22926, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 343ms/step - loss: 0.2349 - mean_io_u: 0.7451 - dice_coeficient: 0.8822 - val_loss: 0.2293 - val_mean_io_u: 0.7516 - val_dice_coeficient: 0.8843
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2217 - mean_io_u: 0.7600 - dice_coeficient: 0.8890
# Epoch 8: val_loss improved from 0.22926 to 0.22081, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 346ms/step - loss: 0.2217 - mean_io_u: 0.7600 - dice_coeficient: 0.8890 - val_loss: 0.2208 - val_mean_io_u: 0.7630 - val_dice_coeficient: 0.8898
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2163 - mean_io_u: 0.7700 - dice_coeficient: 0.8941
# Epoch 9: val_loss improved from 0.22081 to 0.21337, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 349ms/step - loss: 0.2163 - mean_io_u: 0.7700 - dice_coeficient: 0.8941 - val_loss: 0.2134 - val_mean_io_u: 0.7742 - val_dice_coeficient: 0.8942
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2093 - mean_io_u: 0.7781 - dice_coeficient: 0.8975
# Epoch 10: val_loss improved from 0.21337 to 0.20858, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 350ms/step - loss: 0.2093 - mean_io_u: 0.7781 - dice_coeficient: 0.8975 - val_loss: 0.2086 - val_mean_io_u: 0.7819 - val_dice_coeficient: 0.8976
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2034 - mean_io_u: 0.7872 - dice_coeficient: 0.9009
# Epoch 11: val_loss improved from 0.20858 to 0.20489, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 355ms/step - loss: 0.2034 - mean_io_u: 0.7872 - dice_coeficient: 0.9009 - val_loss: 0.2049 - val_mean_io_u: 0.7906 - val_dice_coeficient: 0.9001
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2048 - mean_io_u: 0.7946 - dice_coeficient: 0.9037
# Epoch 12: val_loss improved from 0.20489 to 0.19896, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 353ms/step - loss: 0.2048 - mean_io_u: 0.7946 - dice_coeficient: 0.9037 - val_loss: 0.1990 - val_mean_io_u: 0.7961 - val_dice_coeficient: 0.9033
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1939 - mean_io_u: 0.8005 - dice_coeficient: 0.9070
# Epoch 13: val_loss improved from 0.19896 to 0.19396, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 357ms/step - loss: 0.1939 - mean_io_u: 0.8005 - dice_coeficient: 0.9070 - val_loss: 0.1940 - val_mean_io_u: 0.8024 - val_dice_coeficient: 0.9061
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1942 - mean_io_u: 0.8049 - dice_coeficient: 0.9089
# Epoch 14: val_loss did not improve from 0.19396
# 51/51 [==============================] - 18s 353ms/step - loss: 0.1942 - mean_io_u: 0.8049 - dice_coeficient: 0.9089 - val_loss: 0.1943 - val_mean_io_u: 0.8054 - val_dice_coeficient: 0.9070
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1902 - mean_io_u: 0.8099 - dice_coeficient: 0.9108
# Epoch 15: val_loss improved from 0.19396 to 0.18980, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 357ms/step - loss: 0.1902 - mean_io_u: 0.8099 - dice_coeficient: 0.9108 - val_loss: 0.1898 - val_mean_io_u: 0.8108 - val_dice_coeficient: 0.9099
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1883 - mean_io_u: 0.8144 - dice_coeficient: 0.9131
# Epoch 16: val_loss improved from 0.18980 to 0.18795, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1883 - mean_io_u: 0.8144 - dice_coeficient: 0.9131 - val_loss: 0.1879 - val_mean_io_u: 0.8148 - val_dice_coeficient: 0.9114
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1836 - mean_io_u: 0.8184 - dice_coeficient: 0.9145
# Epoch 17: val_loss improved from 0.18795 to 0.18685, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 358ms/step - loss: 0.1836 - mean_io_u: 0.8184 - dice_coeficient: 0.9145 - val_loss: 0.1868 - val_mean_io_u: 0.8178 - val_dice_coeficient: 0.9123
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1865 - mean_io_u: 0.8217 - dice_coeficient: 0.9153
# Epoch 18: val_loss improved from 0.18685 to 0.18669, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 360ms/step - loss: 0.1865 - mean_io_u: 0.8217 - dice_coeficient: 0.9153 - val_loss: 0.1867 - val_mean_io_u: 0.8229 - val_dice_coeficient: 0.9127
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1796 - mean_io_u: 0.8247 - dice_coeficient: 0.9163
# Epoch 19: val_loss improved from 0.18669 to 0.18026, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1796 - mean_io_u: 0.8247 - dice_coeficient: 0.9163 - val_loss: 0.1803 - val_mean_io_u: 0.8264 - val_dice_coeficient: 0.9148
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1744 - mean_io_u: 0.8292 - dice_coeficient: 0.9188
# Epoch 20: val_loss improved from 0.18026 to 0.17941, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 360ms/step - loss: 0.1744 - mean_io_u: 0.8292 - dice_coeficient: 0.9188 - val_loss: 0.1794 - val_mean_io_u: 0.8292 - val_dice_coeficient: 0.9163
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1772 - mean_io_u: 0.8318 - dice_coeficient: 0.9198
# Epoch 21: val_loss did not improve from 0.17941
# 51/51 [==============================] - 18s 355ms/step - loss: 0.1772 - mean_io_u: 0.8318 - dice_coeficient: 0.9198 - val_loss: 0.1798 - val_mean_io_u: 0.8314 - val_dice_coeficient: 0.9172
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1731 - mean_io_u: 0.8346 - dice_coeficient: 0.9209
# Epoch 22: val_loss improved from 0.17941 to 0.17555, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1731 - mean_io_u: 0.8346 - dice_coeficient: 0.9209 - val_loss: 0.1755 - val_mean_io_u: 0.8340 - val_dice_coeficient: 0.9184
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1703 - mean_io_u: 0.8370 - dice_coeficient: 0.9216
# Epoch 23: val_loss improved from 0.17555 to 0.17389, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1703 - mean_io_u: 0.8370 - dice_coeficient: 0.9216 - val_loss: 0.1739 - val_mean_io_u: 0.8382 - val_dice_coeficient: 0.9198
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1702 - mean_io_u: 0.8404 - dice_coeficient: 0.9236
# Epoch 24: val_loss improved from 0.17389 to 0.17170, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 361ms/step - loss: 0.1702 - mean_io_u: 0.8404 - dice_coeficient: 0.9236 - val_loss: 0.1717 - val_mean_io_u: 0.8391 - val_dice_coeficient: 0.9211
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1662 - mean_io_u: 0.8427 - dice_coeficient: 0.9250
# Epoch 25: val_loss improved from 0.17170 to 0.16866, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1662 - mean_io_u: 0.8427 - dice_coeficient: 0.9250 - val_loss: 0.1687 - val_mean_io_u: 0.8418 - val_dice_coeficient: 0.9226
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1634 - mean_io_u: 0.8447 - dice_coeficient: 0.9260
# Epoch 26: val_loss did not improve from 0.16866
# 51/51 [==============================] - 18s 357ms/step - loss: 0.1634 - mean_io_u: 0.8447 - dice_coeficient: 0.9260 - val_loss: 0.1693 - val_mean_io_u: 0.8428 - val_dice_coeficient: 0.9221
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1625 - mean_io_u: 0.8470 - dice_coeficient: 0.9265
# Epoch 27: val_loss improved from 0.16866 to 0.16818, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.1625 - mean_io_u: 0.8470 - dice_coeficient: 0.9265 - val_loss: 0.1682 - val_mean_io_u: 0.8464 - val_dice_coeficient: 0.9236
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1586 - mean_io_u: 0.8480 - dice_coeficient: 0.9270
# Epoch 28: val_loss improved from 0.16818 to 0.16804, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 360ms/step - loss: 0.1586 - mean_io_u: 0.8480 - dice_coeficient: 0.9270 - val_loss: 0.1680 - val_mean_io_u: 0.8474 - val_dice_coeficient: 0.9239
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1631 - mean_io_u: 0.8510 - dice_coeficient: 0.9282
# Epoch 29: val_loss improved from 0.16804 to 0.16581, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.1631 - mean_io_u: 0.8510 - dice_coeficient: 0.9282 - val_loss: 0.1658 - val_mean_io_u: 0.8513 - val_dice_coeficient: 0.9252
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1599 - mean_io_u: 0.8534 - dice_coeficient: 0.9291
# Epoch 30: val_loss improved from 0.16581 to 0.16519, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.1599 - mean_io_u: 0.8534 - dice_coeficient: 0.9291 - val_loss: 0.1652 - val_mean_io_u: 0.8521 - val_dice_coeficient: 0.9255
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1567 - mean_io_u: 0.8554 - dice_coeficient: 0.9295
# Epoch 31: val_loss improved from 0.16519 to 0.16279, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 360ms/step - loss: 0.1567 - mean_io_u: 0.8554 - dice_coeficient: 0.9295 - val_loss: 0.1628 - val_mean_io_u: 0.8550 - val_dice_coeficient: 0.9263
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1567 - mean_io_u: 0.8576 - dice_coeficient: 0.9304
# Epoch 32: val_loss improved from 0.16279 to 0.16205, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1567 - mean_io_u: 0.8576 - dice_coeficient: 0.9304 - val_loss: 0.1620 - val_mean_io_u: 0.8563 - val_dice_coeficient: 0.9271
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1521 - mean_io_u: 0.8592 - dice_coeficient: 0.9310
# Epoch 33: val_loss improved from 0.16205 to 0.16134, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1521 - mean_io_u: 0.8592 - dice_coeficient: 0.9310 - val_loss: 0.1613 - val_mean_io_u: 0.8589 - val_dice_coeficient: 0.9272
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1533 - mean_io_u: 0.8612 - dice_coeficient: 0.9312
# Epoch 34: val_loss improved from 0.16134 to 0.16065, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 360ms/step - loss: 0.1533 - mean_io_u: 0.8612 - dice_coeficient: 0.9312 - val_loss: 0.1607 - val_mean_io_u: 0.8602 - val_dice_coeficient: 0.9278
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1538 - mean_io_u: 0.8623 - dice_coeficient: 0.9322
# Epoch 35: val_loss improved from 0.16065 to 0.15908, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1538 - mean_io_u: 0.8623 - dice_coeficient: 0.9322 - val_loss: 0.1591 - val_mean_io_u: 0.8620 - val_dice_coeficient: 0.9284
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1509 - mean_io_u: 0.8633 - dice_coeficient: 0.9323
# Epoch 36: val_loss did not improve from 0.15908
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1509 - mean_io_u: 0.8633 - dice_coeficient: 0.9323 - val_loss: 0.1612 - val_mean_io_u: 0.8621 - val_dice_coeficient: 0.9280
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1557 - mean_io_u: 0.8645 - dice_coeficient: 0.9325
# Epoch 37: val_loss improved from 0.15908 to 0.15837, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.1557 - mean_io_u: 0.8645 - dice_coeficient: 0.9325 - val_loss: 0.1584 - val_mean_io_u: 0.8621 - val_dice_coeficient: 0.9291
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1478 - mean_io_u: 0.8654 - dice_coeficient: 0.9342
# Epoch 38: val_loss improved from 0.15837 to 0.15654, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1478 - mean_io_u: 0.8654 - dice_coeficient: 0.9342 - val_loss: 0.1565 - val_mean_io_u: 0.8646 - val_dice_coeficient: 0.9307
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1487 - mean_io_u: 0.8674 - dice_coeficient: 0.9347
# Epoch 39: val_loss improved from 0.15654 to 0.15614, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1487 - mean_io_u: 0.8674 - dice_coeficient: 0.9347 - val_loss: 0.1561 - val_mean_io_u: 0.8644 - val_dice_coeficient: 0.9307
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1470 - mean_io_u: 0.8687 - dice_coeficient: 0.9354
# Epoch 40: val_loss improved from 0.15614 to 0.15442, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1470 - mean_io_u: 0.8687 - dice_coeficient: 0.9354 - val_loss: 0.1544 - val_mean_io_u: 0.8673 - val_dice_coeficient: 0.9316
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1460 - mean_io_u: 0.8701 - dice_coeficient: 0.9360
# Epoch 41: val_loss did not improve from 0.15442
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1460 - mean_io_u: 0.8701 - dice_coeficient: 0.9360 - val_loss: 0.1548 - val_mean_io_u: 0.8684 - val_dice_coeficient: 0.9318
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1436 - mean_io_u: 0.8713 - dice_coeficient: 0.9364
# Epoch 42: val_loss improved from 0.15442 to 0.15386, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 367ms/step - loss: 0.1436 - mean_io_u: 0.8713 - dice_coeficient: 0.9364 - val_loss: 0.1539 - val_mean_io_u: 0.8690 - val_dice_coeficient: 0.9325
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1457 - mean_io_u: 0.8723 - dice_coeficient: 0.9366
# Epoch 43: val_loss improved from 0.15386 to 0.15271, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 361ms/step - loss: 0.1457 - mean_io_u: 0.8723 - dice_coeficient: 0.9366 - val_loss: 0.1527 - val_mean_io_u: 0.8712 - val_dice_coeficient: 0.9329
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1427 - mean_io_u: 0.8739 - dice_coeficient: 0.9372
# Epoch 44: val_loss improved from 0.15271 to 0.15268, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 367ms/step - loss: 0.1427 - mean_io_u: 0.8739 - dice_coeficient: 0.9372 - val_loss: 0.1527 - val_mean_io_u: 0.8732 - val_dice_coeficient: 0.9330
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1484 - mean_io_u: 0.8747 - dice_coeficient: 0.9374
# Epoch 45: val_loss did not improve from 0.15268
# 51/51 [==============================] - 18s 361ms/step - loss: 0.1484 - mean_io_u: 0.8747 - dice_coeficient: 0.9374 - val_loss: 0.1529 - val_mean_io_u: 0.8730 - val_dice_coeficient: 0.9327
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1450 - mean_io_u: 0.8752 - dice_coeficient: 0.9368
# Epoch 46: val_loss improved from 0.15268 to 0.15266, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1450 - mean_io_u: 0.8752 - dice_coeficient: 0.9368 - val_loss: 0.1527 - val_mean_io_u: 0.8738 - val_dice_coeficient: 0.9330
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1454 - mean_io_u: 0.8766 - dice_coeficient: 0.9379
# Epoch 47: val_loss improved from 0.15266 to 0.15168, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1454 - mean_io_u: 0.8766 - dice_coeficient: 0.9379 - val_loss: 0.1517 - val_mean_io_u: 0.8753 - val_dice_coeficient: 0.9336
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1413 - mean_io_u: 0.8773 - dice_coeficient: 0.9380
# Epoch 48: val_loss did not improve from 0.15168
# 51/51 [==============================] - 18s 356ms/step - loss: 0.1413 - mean_io_u: 0.8773 - dice_coeficient: 0.9380 - val_loss: 0.1543 - val_mean_io_u: 0.8754 - val_dice_coeficient: 0.9327
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1494 - mean_io_u: 0.8778 - dice_coeficient: 0.9375
# Epoch 49: val_loss did not improve from 0.15168
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1494 - mean_io_u: 0.8778 - dice_coeficient: 0.9375 - val_loss: 0.1517 - val_mean_io_u: 0.8769 - val_dice_coeficient: 0.9338
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1420 - mean_io_u: 0.8792 - dice_coeficient: 0.9385
# Epoch 50: val_loss improved from 0.15168 to 0.15079, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1420 - mean_io_u: 0.8792 - dice_coeficient: 0.9385 - val_loss: 0.1508 - val_mean_io_u: 0.8777 - val_dice_coeficient: 0.9343
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1405 - mean_io_u: 0.8800 - dice_coeficient: 0.9390
# Epoch 51: val_loss improved from 0.15079 to 0.15059, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 365ms/step - loss: 0.1405 - mean_io_u: 0.8800 - dice_coeficient: 0.9390 - val_loss: 0.1506 - val_mean_io_u: 0.8780 - val_dice_coeficient: 0.9343
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1421 - mean_io_u: 0.8812 - dice_coeficient: 0.9391
# Epoch 52: val_loss improved from 0.15059 to 0.15040, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1421 - mean_io_u: 0.8812 - dice_coeficient: 0.9391 - val_loss: 0.1504 - val_mean_io_u: 0.8796 - val_dice_coeficient: 0.9349
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1370 - mean_io_u: 0.8822 - dice_coeficient: 0.9400
# Epoch 53: val_loss improved from 0.15040 to 0.15008, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1370 - mean_io_u: 0.8822 - dice_coeficient: 0.9400 - val_loss: 0.1501 - val_mean_io_u: 0.8806 - val_dice_coeficient: 0.9353
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1420 - mean_io_u: 0.8830 - dice_coeficient: 0.9401
# Epoch 54: val_loss improved from 0.15008 to 0.14975, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.1420 - mean_io_u: 0.8830 - dice_coeficient: 0.9401 - val_loss: 0.1498 - val_mean_io_u: 0.8816 - val_dice_coeficient: 0.9355
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1362 - mean_io_u: 0.8837 - dice_coeficient: 0.9402
# Epoch 55: val_loss did not improve from 0.14975
# 51/51 [==============================] - 18s 361ms/step - loss: 0.1362 - mean_io_u: 0.8837 - dice_coeficient: 0.9402 - val_loss: 0.1501 - val_mean_io_u: 0.8818 - val_dice_coeficient: 0.9356
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1408 - mean_io_u: 0.8841 - dice_coeficient: 0.9403
# Epoch 56: val_loss did not improve from 0.14975
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1408 - mean_io_u: 0.8841 - dice_coeficient: 0.9403 - val_loss: 0.1499 - val_mean_io_u: 0.8822 - val_dice_coeficient: 0.9356
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1371 - mean_io_u: 0.8855 - dice_coeficient: 0.9408
# Epoch 57: val_loss improved from 0.14975 to 0.14905, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1371 - mean_io_u: 0.8855 - dice_coeficient: 0.9408 - val_loss: 0.1490 - val_mean_io_u: 0.8836 - val_dice_coeficient: 0.9361
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1367 - mean_io_u: 0.8859 - dice_coeficient: 0.9412
# Epoch 58: val_loss improved from 0.14905 to 0.14835, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1367 - mean_io_u: 0.8859 - dice_coeficient: 0.9412 - val_loss: 0.1483 - val_mean_io_u: 0.8844 - val_dice_coeficient: 0.9365
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1362 - mean_io_u: 0.8867 - dice_coeficient: 0.9417
# Epoch 59: val_loss did not improve from 0.14835
# 51/51 [==============================] - 18s 361ms/step - loss: 0.1362 - mean_io_u: 0.8867 - dice_coeficient: 0.9417 - val_loss: 0.1487 - val_mean_io_u: 0.8844 - val_dice_coeficient: 0.9362
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1362 - mean_io_u: 0.8871 - dice_coeficient: 0.9414
# Epoch 60: val_loss did not improve from 0.14835
# 51/51 [==============================] - 18s 357ms/step - loss: 0.1362 - mean_io_u: 0.8871 - dice_coeficient: 0.9414 - val_loss: 0.1490 - val_mean_io_u: 0.8858 - val_dice_coeficient: 0.9366
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1376 - mean_io_u: 0.8878 - dice_coeficient: 0.9418
# Epoch 61: val_loss did not improve from 0.14835
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1376 - mean_io_u: 0.8878 - dice_coeficient: 0.9418 - val_loss: 0.1484 - val_mean_io_u: 0.8857 - val_dice_coeficient: 0.9368
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1394 - mean_io_u: 0.8885 - dice_coeficient: 0.9420
# Epoch 62: val_loss improved from 0.14835 to 0.14831, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 367ms/step - loss: 0.1394 - mean_io_u: 0.8885 - dice_coeficient: 0.9420 - val_loss: 0.1483 - val_mean_io_u: 0.8862 - val_dice_coeficient: 0.9369
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1355 - mean_io_u: 0.8894 - dice_coeficient: 0.9423
# Epoch 63: val_loss improved from 0.14831 to 0.14814, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1355 - mean_io_u: 0.8894 - dice_coeficient: 0.9423 - val_loss: 0.1481 - val_mean_io_u: 0.8879 - val_dice_coeficient: 0.9371
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1333 - mean_io_u: 0.8897 - dice_coeficient: 0.9425
# Epoch 64: val_loss improved from 0.14814 to 0.14775, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 367ms/step - loss: 0.1333 - mean_io_u: 0.8897 - dice_coeficient: 0.9425 - val_loss: 0.1477 - val_mean_io_u: 0.8881 - val_dice_coeficient: 0.9373
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1389 - mean_io_u: 0.8906 - dice_coeficient: 0.9427
# Epoch 65: val_loss improved from 0.14775 to 0.14735, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 365ms/step - loss: 0.1389 - mean_io_u: 0.8906 - dice_coeficient: 0.9427 - val_loss: 0.1474 - val_mean_io_u: 0.8889 - val_dice_coeficient: 0.9371
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1348 - mean_io_u: 0.8909 - dice_coeficient: 0.9425
# Epoch 66: val_loss did not improve from 0.14735
# 51/51 [==============================] - 18s 361ms/step - loss: 0.1348 - mean_io_u: 0.8909 - dice_coeficient: 0.9425 - val_loss: 0.1478 - val_mean_io_u: 0.8893 - val_dice_coeficient: 0.9374
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1393 - mean_io_u: 0.8911 - dice_coeficient: 0.9420
# Epoch 67: val_loss did not improve from 0.14735
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1393 - mean_io_u: 0.8911 - dice_coeficient: 0.9420 - val_loss: 0.1495 - val_mean_io_u: 0.8882 - val_dice_coeficient: 0.9361
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1371 - mean_io_u: 0.8914 - dice_coeficient: 0.9419
# Epoch 68: val_loss did not improve from 0.14735
# 51/51 [==============================] - 18s 360ms/step - loss: 0.1371 - mean_io_u: 0.8914 - dice_coeficient: 0.9419 - val_loss: 0.1474 - val_mean_io_u: 0.8899 - val_dice_coeficient: 0.9372
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1320 - mean_io_u: 0.8922 - dice_coeficient: 0.9429
# Epoch 69: val_loss did not improve from 0.14735
# 51/51 [==============================] - 19s 365ms/step - loss: 0.1320 - mean_io_u: 0.8922 - dice_coeficient: 0.9429 - val_loss: 0.1479 - val_mean_io_u: 0.8899 - val_dice_coeficient: 0.9370
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1347 - mean_io_u: 0.8930 - dice_coeficient: 0.9430
# Epoch 70: val_loss did not improve from 0.14735
# 51/51 [==============================] - 18s 360ms/step - loss: 0.1347 - mean_io_u: 0.8930 - dice_coeficient: 0.9430 - val_loss: 0.1478 - val_mean_io_u: 0.8914 - val_dice_coeficient: 0.9378
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1356 - mean_io_u: 0.8940 - dice_coeficient: 0.9437
# Epoch 71: val_loss improved from 0.14735 to 0.14671, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 368ms/step - loss: 0.1356 - mean_io_u: 0.8940 - dice_coeficient: 0.9437 - val_loss: 0.1467 - val_mean_io_u: 0.8919 - val_dice_coeficient: 0.9379
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1318 - mean_io_u: 0.8942 - dice_coeficient: 0.9436
# Epoch 72: val_loss improved from 0.14671 to 0.14662, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1318 - mean_io_u: 0.8942 - dice_coeficient: 0.9436 - val_loss: 0.1466 - val_mean_io_u: 0.8924 - val_dice_coeficient: 0.9382
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1293 - mean_io_u: 0.8948 - dice_coeficient: 0.9441
# Epoch 73: val_loss did not improve from 0.14662
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1293 - mean_io_u: 0.8948 - dice_coeficient: 0.9441 - val_loss: 0.1476 - val_mean_io_u: 0.8927 - val_dice_coeficient: 0.9378
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1392 - mean_io_u: 0.8951 - dice_coeficient: 0.9437
# Epoch 74: val_loss did not improve from 0.14662
# 51/51 [==============================] - 18s 361ms/step - loss: 0.1392 - mean_io_u: 0.8951 - dice_coeficient: 0.9437 - val_loss: 0.1473 - val_mean_io_u: 0.8932 - val_dice_coeficient: 0.9380
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1324 - mean_io_u: 0.8955 - dice_coeficient: 0.9440
# Epoch 75: val_loss did not improve from 0.14662
# 51/51 [==============================] - 19s 365ms/step - loss: 0.1324 - mean_io_u: 0.8955 - dice_coeficient: 0.9440 - val_loss: 0.1471 - val_mean_io_u: 0.8934 - val_dice_coeficient: 0.9384
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1330 - mean_io_u: 0.8961 - dice_coeficient: 0.9443
# Epoch 76: val_loss improved from 0.14662 to 0.14627, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1330 - mean_io_u: 0.8961 - dice_coeficient: 0.9443 - val_loss: 0.1463 - val_mean_io_u: 0.8942 - val_dice_coeficient: 0.9386
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1316 - mean_io_u: 0.8968 - dice_coeficient: 0.9447
# Epoch 77: val_loss did not improve from 0.14627
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1316 - mean_io_u: 0.8968 - dice_coeficient: 0.9447 - val_loss: 0.1466 - val_mean_io_u: 0.8948 - val_dice_coeficient: 0.9385
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1282 - mean_io_u: 0.8970 - dice_coeficient: 0.9446
# Epoch 78: val_loss improved from 0.14627 to 0.14588, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 365ms/step - loss: 0.1282 - mean_io_u: 0.8970 - dice_coeficient: 0.9446 - val_loss: 0.1459 - val_mean_io_u: 0.8953 - val_dice_coeficient: 0.9386
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1312 - mean_io_u: 0.8977 - dice_coeficient: 0.9450
# Epoch 79: val_loss improved from 0.14588 to 0.14500, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1312 - mean_io_u: 0.8977 - dice_coeficient: 0.9450 - val_loss: 0.1450 - val_mean_io_u: 0.8955 - val_dice_coeficient: 0.9389
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1288 - mean_io_u: 0.8981 - dice_coeficient: 0.9450
# Epoch 80: val_loss did not improve from 0.14500
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1288 - mean_io_u: 0.8981 - dice_coeficient: 0.9450 - val_loss: 0.1455 - val_mean_io_u: 0.8964 - val_dice_coeficient: 0.9390
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1309 - mean_io_u: 0.8987 - dice_coeficient: 0.9453
# Epoch 81: val_loss did not improve from 0.14500
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1309 - mean_io_u: 0.8987 - dice_coeficient: 0.9453 - val_loss: 0.1450 - val_mean_io_u: 0.8968 - val_dice_coeficient: 0.9393
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1294 - mean_io_u: 0.8990 - dice_coeficient: 0.9455
# Epoch 82: val_loss improved from 0.14500 to 0.14499, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.1294 - mean_io_u: 0.8990 - dice_coeficient: 0.9455 - val_loss: 0.1450 - val_mean_io_u: 0.8965 - val_dice_coeficient: 0.9391
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1314 - mean_io_u: 0.8993 - dice_coeficient: 0.9454
# Epoch 83: val_loss improved from 0.14499 to 0.14497, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 364ms/step - loss: 0.1314 - mean_io_u: 0.8993 - dice_coeficient: 0.9454 - val_loss: 0.1450 - val_mean_io_u: 0.8972 - val_dice_coeficient: 0.9394
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1280 - mean_io_u: 0.8997 - dice_coeficient: 0.9456
# Epoch 84: val_loss did not improve from 0.14497
# 51/51 [==============================] - 18s 360ms/step - loss: 0.1280 - mean_io_u: 0.8997 - dice_coeficient: 0.9456 - val_loss: 0.1457 - val_mean_io_u: 0.8975 - val_dice_coeficient: 0.9390
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1261 - mean_io_u: 0.9000 - dice_coeficient: 0.9457
# Epoch 85: val_loss improved from 0.14497 to 0.14454, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1261 - mean_io_u: 0.9000 - dice_coeficient: 0.9457 - val_loss: 0.1445 - val_mean_io_u: 0.8976 - val_dice_coeficient: 0.9394
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1279 - mean_io_u: 0.9004 - dice_coeficient: 0.9459
# Epoch 86: val_loss did not improve from 0.14454
# 51/51 [==============================] - 18s 360ms/step - loss: 0.1279 - mean_io_u: 0.9004 - dice_coeficient: 0.9459 - val_loss: 0.1448 - val_mean_io_u: 0.8978 - val_dice_coeficient: 0.9392
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1303 - mean_io_u: 0.9006 - dice_coeficient: 0.9458
# Epoch 87: val_loss improved from 0.14454 to 0.14431, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 368ms/step - loss: 0.1303 - mean_io_u: 0.9006 - dice_coeficient: 0.9458 - val_loss: 0.1443 - val_mean_io_u: 0.8988 - val_dice_coeficient: 0.9397
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1275 - mean_io_u: 0.9013 - dice_coeficient: 0.9462
# Epoch 88: val_loss did not improve from 0.14431
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1275 - mean_io_u: 0.9013 - dice_coeficient: 0.9462 - val_loss: 0.1457 - val_mean_io_u: 0.8982 - val_dice_coeficient: 0.9391
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1286 - mean_io_u: 0.9015 - dice_coeficient: 0.9461
# Epoch 89: val_loss did not improve from 0.14431
# 51/51 [==============================] - 18s 361ms/step - loss: 0.1286 - mean_io_u: 0.9015 - dice_coeficient: 0.9461 - val_loss: 0.1461 - val_mean_io_u: 0.8981 - val_dice_coeficient: 0.9390
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1306 - mean_io_u: 0.9014 - dice_coeficient: 0.9457
# Epoch 90: val_loss did not improve from 0.14431
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1306 - mean_io_u: 0.9014 - dice_coeficient: 0.9457 - val_loss: 0.1454 - val_mean_io_u: 0.8993 - val_dice_coeficient: 0.9393
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1294 - mean_io_u: 0.9023 - dice_coeficient: 0.9462
# Epoch 91: val_loss did not improve from 0.14431
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1294 - mean_io_u: 0.9023 - dice_coeficient: 0.9462 - val_loss: 0.1452 - val_mean_io_u: 0.9000 - val_dice_coeficient: 0.9397
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1300 - mean_io_u: 0.9028 - dice_coeficient: 0.9465
# Epoch 92: val_loss did not improve from 0.14431
# 51/51 [==============================] - 19s 364ms/step - loss: 0.1300 - mean_io_u: 0.9028 - dice_coeficient: 0.9465 - val_loss: 0.1450 - val_mean_io_u: 0.9004 - val_dice_coeficient: 0.9396
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1273 - mean_io_u: 0.9031 - dice_coeficient: 0.9465
# Epoch 93: val_loss improved from 0.14431 to 0.14408, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.1273 - mean_io_u: 0.9031 - dice_coeficient: 0.9465 - val_loss: 0.1441 - val_mean_io_u: 0.9008 - val_dice_coeficient: 0.9400
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1296 - mean_io_u: 0.9036 - dice_coeficient: 0.9468
# Epoch 94: val_loss did not improve from 0.14408
# 51/51 [==============================] - 19s 364ms/step - loss: 0.1296 - mean_io_u: 0.9036 - dice_coeficient: 0.9468 - val_loss: 0.1441 - val_mean_io_u: 0.9010 - val_dice_coeficient: 0.9401
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1279 - mean_io_u: 0.9037 - dice_coeficient: 0.9467
# Epoch 95: val_loss improved from 0.14408 to 0.14385, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 362ms/step - loss: 0.1279 - mean_io_u: 0.9037 - dice_coeficient: 0.9467 - val_loss: 0.1438 - val_mean_io_u: 0.9012 - val_dice_coeficient: 0.9402
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1265 - mean_io_u: 0.9042 - dice_coeficient: 0.9472
# Epoch 96: val_loss improved from 0.14385 to 0.14347, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 369ms/step - loss: 0.1265 - mean_io_u: 0.9042 - dice_coeficient: 0.9472 - val_loss: 0.1435 - val_mean_io_u: 0.9018 - val_dice_coeficient: 0.9403
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1264 - mean_io_u: 0.9046 - dice_coeficient: 0.9474
# Epoch 97: val_loss improved from 0.14347 to 0.14335, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.1264 - mean_io_u: 0.9046 - dice_coeficient: 0.9474 - val_loss: 0.1434 - val_mean_io_u: 0.9019 - val_dice_coeficient: 0.9404
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1308 - mean_io_u: 0.9051 - dice_coeficient: 0.9475
# Epoch 98: val_loss improved from 0.14335 to 0.14306, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 363ms/step - loss: 0.1308 - mean_io_u: 0.9051 - dice_coeficient: 0.9475 - val_loss: 0.1431 - val_mean_io_u: 0.9025 - val_dice_coeficient: 0.9404
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1237 - mean_io_u: 0.9052 - dice_coeficient: 0.9478
# Epoch 99: val_loss did not improve from 0.14306
# 51/51 [==============================] - 18s 359ms/step - loss: 0.1237 - mean_io_u: 0.9052 - dice_coeficient: 0.9478 - val_loss: 0.1432 - val_mean_io_u: 0.9029 - val_dice_coeficient: 0.9407
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1292 - mean_io_u: 0.9055 - dice_coeficient: 0.9478
# Epoch 100: val_loss did not improve from 0.14306
# 51/51 [==============================] - 18s 356ms/step - loss: 0.1292 - mean_io_u: 0.9055 - dice_coeficient: 0.9478 - val_loss: 0.1438 - val_mean_io_u: 0.9029 - val_dice_coeficient: 0.9404

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 5s 48ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx])
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
