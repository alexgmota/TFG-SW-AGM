# %% [markdown]
# # Deep Learning: Endoscopy segmentation.
# [Dataset](https://www.kaggle.com/datasets/newslab/cholecseg8k?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import cv2
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
from glob import glob
import segmentation_models as sm
from keras_vision_transformer import swin_layers
from keras_vision_transformer import transformer_layers
from keras_vision_transformer import utils
# Out:
# Segmentation Models: using `keras` framework.

# %%
tf.keras.backend.clear_session()
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
print('GPU avalible: ' + str(len(tf.config.get_visible_devices('GPU')) > 0))
# Out:
# GPU avalible: True

# %%
SEED = 33
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data preparation.

# %%
imgs = glob(f'../*/*/*/frame_*_endo.png')
masks = glob(f'../*/*/*/frame_*_endo_watershed_mask.png')

assert len(imgs) == len(masks)

print(f'Number of samples: {str(len(masks))}')
# Out:
# Number of samples: 8080

# %%
HEIGHT, WIDTH = 64, 64
N = len(masks)
# CLASS_WEIGHTS = np.array([2.45780159e-01, 2.24610010e-01, 2.24005501e-01, 1.87119512e-02,
#  1.46965911e-01, 2.54698498e-02, 2.35562466e-02, 4.28713053e-03,
#  3.93593665e-04, 1.38500705e-02, 6.78984614e-02, 1.01436955e-04,
#  4.36967906e-03])

# %%
X, y = [], []

for img, mask in zip(imgs, masks):
    img = cv2.imread(img)
    img = img[10:-10, 10:-10,:]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (WIDTH, HEIGHT))
    img = img / 255
    X.append(img)

    mask = cv2.imread(mask)
    mask = mask[10:-10, 10:-10,:]
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask = cv2.resize(mask, (WIDTH, HEIGHT), interpolation=cv2.INTER_NEAREST)
    mask = np.expand_dims(mask, axis=-1)

    y.append(mask)

X = np.array(X)
y = np.array(y)

assert X.shape[0:-1] == y.shape[0:-1]

X.shape, y.shape
# Out:
# ((8080, 64, 64, 3), (8080, 64, 64, 1))

# %%
idx = random.randint(0, len(X)-1)

plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(y[idx])
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
labels = [[11],[21],[13],[12],[31],[23],[24],[25],[32],[22],[33],[5]]

y_encoded = np.zeros((N, HEIGHT, WIDTH, 1), dtype=np.uint8)

for i, label in enumerate(labels):
    y_encoded[np.all(label == y, axis=-1)] = i + 1
 
y = tf.keras.utils.to_categorical(y_encoded, num_classes=13)

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(X[idx])
plt.axis("off")
plt.subplot(122)
plt.imshow(tf.argmax(y[idx], axis=-1))
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43) 
import gc
del X
del y
gc.collect()
# Out:
# 8157

# %% [markdown]
# ## Swin-U-Net

# %% [markdown]
# ### Losses

# %%
def dice_coeficient(y_true, y_pred):
    T = tf.keras.backend.flatten(y_true)
    P = tf.keras.backend.flatten(y_pred)

    intersection = tf.keras.backend.sum(T * P)
    dice = (2 * intersection) / (tf.keras.backend.sum(T + P))
    return dice

# def dice_loss(y_true, y_pred):
#     return 1 - dice_coeficient(y_true, y_pred)

# def tversky(y_true, y_pred, smooth=1, alpha=0.8):
#     T = tf.keras.backend.flatten(y_true)
#     P = tf.keras.backend.flatten(y_pred)
#     TP = tf.keras.backend.sum(T * P)
#     FN = tf.keras.backend.sum(T * (1 - P))
#     FP = tf.keras.backend.sum((1 - T) * P)
#     return (TP + smooth) / (TP + alpha * FN + (1 - alpha) * FP + smooth)


# def tversky_loss(y_true, y_pred):
#     return 1 - tversky(y_true, y_pred)


# def focal_tversky_loss(y_true, y_pred, gamma=0.75):
#     tv = tversky(y_true, y_pred)
#     return tf.keras.backend.pow((1 - tv), gamma)

# %% [markdown]
# ### Swin transformer stack

# %%
def swin_transformer_stack(X, stack_num, embed_dim, num_patch, num_heads, window_size, num_mlp, shift_window=True, name=''):
    '''
    Stacked Swin Transformers that share the same token size.
    
    Alternated Window-MSA and Swin-MSA will be configured if `shift_window=True`, Window-MSA only otherwise.
    *Dropout is turned off.
    '''
    # Turn-off dropouts
    mlp_drop_rate = 0 # Droupout after each MLP layer
    attn_drop_rate = 0 # Dropout after Swin-Attention
    proj_drop_rate = 0 # Dropout at the end of each Swin-Attention block, i.e., after linear projections
    drop_path_rate = 0 # Drop-path within skip-connections
    
    qkv_bias = True # Convert embedded patches to query, key, and values with a learnable additive value
    qk_scale = None # None: Re-scale query based on embed dimensions per attention head # Float for user specified scaling factor
    
    if shift_window:
        shift_size = window_size // 2
    else:
        shift_size = 0
    
    for i in range(stack_num):
    
        if i % 2 == 0:
            shift_size_temp = 0
        else:
            shift_size_temp = shift_size

        X = swin_layers.SwinTransformerBlock(dim=embed_dim, 
                                             num_patch=num_patch, 
                                             num_heads=num_heads, 
                                             window_size=window_size, 
                                             shift_size=shift_size_temp, 
                                             num_mlp=num_mlp, 
                                             qkv_bias=qkv_bias, 
                                             qk_scale=qk_scale,
                                             mlp_drop=mlp_drop_rate, 
                                             attn_drop=attn_drop_rate, 
                                             proj_drop=proj_drop_rate, 
                                             drop_path_prob=drop_path_rate, 
                                             name='name{}'.format(i))(X)
    return X


def swin_unet_2d_base(input_tensor, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, shift_window=True, name='swin_unet'):
    '''
    The base of Swin-UNET.
    
    The general structure:
    
    1. Input image --> a sequence of patches --> tokenize these patches
    2. Downsampling: swin-transformer --> patch merging (pooling)
    3. Upsampling: concatenate --> swin-transfprmer --> patch expanding (unpooling)
    4. Model head
    
    '''
    # Compute number be patches to be embeded
    input_size = input_tensor.shape.as_list()[1:]
    num_patch_x = input_size[0]//patch_size[0]
    num_patch_y = input_size[1]//patch_size[1]
    
    # Number of Embedded dimensions
    embed_dim = filter_num_begin
    
    depth_ = depth
    
    X_skip = []

    X = input_tensor
    
    # Patch extraction
    X = transformer_layers.patch_extract(patch_size)(X)

    # Embed patches to tokens
    X = transformer_layers.patch_embedding(num_patch_x*num_patch_y, embed_dim)(X)
    
    # The first Swin Transformer stack
    X = swin_transformer_stack(X, 
                               stack_num=stack_num_down, 
                               embed_dim=embed_dim, 
                               num_patch=(num_patch_x, num_patch_y), 
                               num_heads=num_heads[0], 
                               window_size=window_size[0], 
                               num_mlp=num_mlp, 
                               shift_window=shift_window, 
                               name='{}_swin_down0'.format(name))
    X_skip.append(X)
    
    # Downsampling blocks
    for i in range(depth_-1):
        
        # Patch merging
        X = transformer_layers.patch_merging((num_patch_x, num_patch_y), embed_dim=embed_dim, name='down{}'.format(i))(X)
        
        # update token shape info
        embed_dim = embed_dim*2
        num_patch_x = num_patch_x//2
        num_patch_y = num_patch_y//2
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_down, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i+1], 
                                   window_size=window_size[i+1], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_down{}'.format(name, i+1))
        
        # Store tensors for concat
        X_skip.append(X)
        
    # reverse indexing encoded tensors and hyperparams
    X_skip = X_skip[::-1]
    num_heads = num_heads[::-1]
    window_size = window_size[::-1]
    
    # upsampling begins at the deepest available tensor
    X = X_skip[0]
    
    # other tensors are preserved for concatenation
    X_decode = X_skip[1:]
    
    depth_decode = len(X_decode)
    
    for i in range(depth_decode):
        
        # Patch expanding
        X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                               embed_dim=embed_dim, 
                                               upsample_rate=2, 
                                               return_vector=True)(X)
        

        # update token shape info
        embed_dim = embed_dim//2
        num_patch_x = num_patch_x*2
        num_patch_y = num_patch_y*2
        
        # Concatenation and linear projection
        X = tf.keras.layers.concatenate([X, X_decode[i]], axis=-1, name='{}_concat_{}'.format(name, i))
        X = tf.keras.layers.Dense(embed_dim, use_bias=False, name='{}_concat_linear_proj_{}'.format(name, i))(X)
        
        # Swin Transformer stacks
        X = swin_transformer_stack(X, 
                                   stack_num=stack_num_up, 
                                   embed_dim=embed_dim, 
                                   num_patch=(num_patch_x, num_patch_y), 
                                   num_heads=num_heads[i], 
                                   window_size=window_size[i], 
                                   num_mlp=num_mlp, 
                                   shift_window=shift_window, 
                                   name='{}_swin_up{}'.format(name, i))
        
    # The last expanding layer; it produces full-size feature maps based on the patch size
    # !!! <--- "patch_size[0]" is used; it assumes patch_size = (size, size)
    
    X = transformer_layers.patch_expanding(num_patch=(num_patch_x, num_patch_y), 
                                           embed_dim=embed_dim, 
                                           upsample_rate=patch_size[0], 
                                           return_vector=False)(X)
    
    return X

# %% [markdown]
# ### Hyperparameters

# %%
filter_num_begin = 128     # number of channels in the first downsampling block; it is also the number of embedded dimensions
depth = 4                  # the depth of SwinUNET; depth=4 means three down/upsampling levels and a bottom level 
stack_num_down = 2         # number of Swin Transformers per downsampling level
stack_num_up = 2           # number of Swin Transformers per upsampling level
patch_size = (4, 4)        # Extract 4-by-4 patches from the input image. Height and width of the patch must be equal.
num_heads = [4, 8, 8, 8]   # number of attention heads per down/upsampling level
window_size = [4, 2, 2, 2] # the size of attention window per down/upsampling level
num_mlp = 512              # number of MLP nodes within the Transformer
shift_window=True          # Apply window shifting, i.e., Swin-MSA

# %% [markdown]
# ### Model configuration

# %%
# Input section
IN = tf.keras.layers.Input((WIDTH, HEIGHT, 3))

# Base architecture
X = swin_unet_2d_base(IN, filter_num_begin, depth, stack_num_down, stack_num_up, 
                      patch_size, num_heads, window_size, num_mlp, 
                      shift_window=shift_window, name='swin_unet')



# Output section
n_labels = 13
OUT = tf.keras.layers.Conv2D(n_labels, kernel_size=1, use_bias=False, activation='softmax')(X)

# Model configuration
swin_transformer = tf.keras.models.Model(inputs=[IN,], outputs=[OUT,])
# Optimization
# <---- !!! gradient clipping is important
swin_transformer.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4, clipvalue=0.5), 
    loss=sm.losses.cce_dice_loss,
    metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
)
swin_transformer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  patch_extract (patch_extract)  (None, 256, 48)      0           ['input_1[0][0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 128)    39040       ['patch_extract[0][0]']
#  ng)
#
#  swin_transformer_block (SwinTr  (None, 256, 128)    198724      ['patch_embedding[0][0]']
#  ansformerBlock)
#
#  swin_transformer_block_1 (Swin  (None, 256, 128)    202820      ['swin_transformer_block[0][0]']
#  TransformerBlock)
#
#  patch_merging (patch_merging)  (None, 64, 256)      131072      ['swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_transformer_block_2 (Swin  (None, 64, 256)     527192      ['patch_merging[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_3 (Swin  (None, 64, 256)     527448      ['swin_transformer_block_2[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_1 (patch_merging  (None, 16, 512)     524288      ['swin_transformer_block_3[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_4 (Swin  (None, 16, 512)     1578072     ['patch_merging_1[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_5 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_4[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_merging_2 (patch_merging  (None, 4, 1024)     2097152     ['swin_transformer_block_5[0][0]'
#  )                                                               ]
#
#  swin_transformer_block_6 (Swin  (None, 4, 1024)     5252696     ['patch_merging_2[0][0]']
#  TransformerBlock)
#
#  swin_transformer_block_7 (Swin  (None, 4, 1024)     5252712     ['swin_transformer_block_6[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding (patch_expandi  (None, 16, 512)     2097152     ['swin_transformer_block_7[0][0]'
#  ng)                                                             ]
#
#  swin_unet_concat_0 (Concatenat  (None, 16, 1024)    0           ['patch_expanding[0][0]',
#  e)                                                               'swin_transformer_block_5[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_0  (None, 16, 512)     524288      ['swin_unet_concat_0[0][0]']
#   (Dense)
#
#  swin_transformer_block_8 (Swin  (None, 16, 512)     1578072     ['swin_unet_concat_linear_proj_0[
#  TransformerBlock)                                               0][0]']
#
#  swin_transformer_block_9 (Swin  (None, 16, 512)     1578136     ['swin_transformer_block_8[0][0]'
#  TransformerBlock)                                               ]
#
#  patch_expanding_1 (patch_expan  (None, 64, 256)     524288      ['swin_transformer_block_9[0][0]'
#  ding)                                                           ]
#
#  swin_unet_concat_1 (Concatenat  (None, 64, 512)     0           ['patch_expanding_1[0][0]',
#  e)                                                               'swin_transformer_block_3[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_1  (None, 64, 256)     131072      ['swin_unet_concat_1[0][0]']
#   (Dense)
#
#  swin_transformer_block_10 (Swi  (None, 64, 256)     527192      ['swin_unet_concat_linear_proj_1[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_11 (Swi  (None, 64, 256)     527448      ['swin_transformer_block_10[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_2 (patch_expan  (None, 256, 128)    131072      ['swin_transformer_block_11[0][0]
#  ding)                                                           ']
#
#  swin_unet_concat_2 (Concatenat  (None, 256, 256)    0           ['patch_expanding_2[0][0]',
#  e)                                                               'swin_transformer_block_1[0][0]'
#                                                                  ]
#
#  swin_unet_concat_linear_proj_2  (None, 256, 128)    32768       ['swin_unet_concat_2[0][0]']
#   (Dense)
#
#  swin_transformer_block_12 (Swi  (None, 256, 128)    198360      ['swin_unet_concat_linear_proj_2[
#  nTransformerBlock)                                              0][0]']
#
#  swin_transformer_block_13 (Swi  (None, 256, 128)    199384      ['swin_transformer_block_12[0][0]
#  nTransformerBlock)                                              ']
#
#  patch_expanding_3 (patch_expan  (None, 64, 64, 32)  65536       ['swin_transformer_block_13[0][0]
#  ding)                                                           ']
#
#  conv2d (Conv2D)                (None, 64, 64, 13)   416         ['patch_expanding_3[0][0]']
#
# ==================================================================================================
# Total params: 26,024,536
# Trainable params: 26,018,056
# Non-trainable params: 6,480
# __________________________________________________________________________________________________

# %%
# print('\n\t EVALUATION\n')
# swin_transformer.evaluate(
#     X_test, 
#     y_test,
#     batch_size=32
# )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '../models/swin-unet_train_Weights.hdf5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto'
)

# tf.keras.backend.clear_session()
print('\n\t TRAINING\n')

model_history = swin_transformer.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=128,
    validation_data=(X_test, y_test),
    use_multiprocessing=True,
    callbacks=[checkpoint],
    verbose=1
)

swin_transformer.save_weights('../models/swin-unet_Weights.hdf5')
# Out:
# 	 TRAINING
#
# Epoch 1/100
# 51/51 [==============================] - ETA: 0s - loss: 0.9005 - mean_io_u: 0.4615 - dice_coeficient: 0.4950
# Epoch 1: val_loss improved from inf to 0.70207, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 76s 446ms/step - loss: 0.9005 - mean_io_u: 0.4615 - dice_coeficient: 0.4950 - val_loss: 0.7021 - val_mean_io_u: 0.4615 - val_dice_coeficient: 0.7382
# Epoch 2/100
# 51/51 [==============================] - ETA: 0s - loss: 0.5634 - mean_io_u: 0.4616 - dice_coeficient: 0.8042
# Epoch 2: val_loss improved from 0.70207 to 0.42097, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 316ms/step - loss: 0.5634 - mean_io_u: 0.4616 - dice_coeficient: 0.8042 - val_loss: 0.4210 - val_mean_io_u: 0.4618 - val_dice_coeficient: 0.8500
# Epoch 3/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3350 - mean_io_u: 0.4681 - dice_coeficient: 0.8709
# Epoch 3: val_loss improved from 0.42097 to 0.27627, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 22s 438ms/step - loss: 0.3350 - mean_io_u: 0.4681 - dice_coeficient: 0.8709 - val_loss: 0.2763 - val_mean_io_u: 0.4773 - val_dice_coeficient: 0.8863
# Epoch 4/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2501 - mean_io_u: 0.4848 - dice_coeficient: 0.8974
# Epoch 4: val_loss improved from 0.27627 to 0.23066, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 20s 387ms/step - loss: 0.2501 - mean_io_u: 0.4848 - dice_coeficient: 0.8974 - val_loss: 0.2307 - val_mean_io_u: 0.4939 - val_dice_coeficient: 0.9042
# Epoch 5/100
# 51/51 [==============================] - ETA: 0s - loss: 0.2206 - mean_io_u: 0.5028 - dice_coeficient: 0.9101
# Epoch 5: val_loss improved from 0.23066 to 0.21066, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 50s 992ms/step - loss: 0.2206 - mean_io_u: 0.5028 - dice_coeficient: 0.9101 - val_loss: 0.2107 - val_mean_io_u: 0.5075 - val_dice_coeficient: 0.9142
# Epoch 6/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1902 - mean_io_u: 0.5195 - dice_coeficient: 0.9214
# Epoch 6: val_loss improved from 0.21066 to 0.19104, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 36s 710ms/step - loss: 0.1902 - mean_io_u: 0.5195 - dice_coeficient: 0.9214 - val_loss: 0.1910 - val_mean_io_u: 0.5277 - val_dice_coeficient: 0.9232
# Epoch 7/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1793 - mean_io_u: 0.5367 - dice_coeficient: 0.9287
# Epoch 7: val_loss improved from 0.19104 to 0.17990, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 60s 1s/step - loss: 0.1793 - mean_io_u: 0.5367 - dice_coeficient: 0.9287 - val_loss: 0.1799 - val_mean_io_u: 0.5458 - val_dice_coeficient: 0.9290
# Epoch 8/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1668 - mean_io_u: 0.5539 - dice_coeficient: 0.9333
# Epoch 8: val_loss improved from 0.17990 to 0.17247, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 36s 713ms/step - loss: 0.1668 - mean_io_u: 0.5539 - dice_coeficient: 0.9333 - val_loss: 0.1725 - val_mean_io_u: 0.5614 - val_dice_coeficient: 0.9311
# Epoch 9/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1633 - mean_io_u: 0.5693 - dice_coeficient: 0.9374
# Epoch 9: val_loss improved from 0.17247 to 0.15630, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 31s 613ms/step - loss: 0.1633 - mean_io_u: 0.5693 - dice_coeficient: 0.9374 - val_loss: 0.1563 - val_mean_io_u: 0.5797 - val_dice_coeficient: 0.9382
# Epoch 10/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1468 - mean_io_u: 0.5852 - dice_coeficient: 0.9423
# Epoch 10: val_loss improved from 0.15630 to 0.14953, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 56s 1s/step - loss: 0.1468 - mean_io_u: 0.5852 - dice_coeficient: 0.9423 - val_loss: 0.1495 - val_mean_io_u: 0.5914 - val_dice_coeficient: 0.9412
# Epoch 11/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1426 - mean_io_u: 0.5997 - dice_coeficient: 0.9452
# Epoch 11: val_loss improved from 0.14953 to 0.14473, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 16s 307ms/step - loss: 0.1426 - mean_io_u: 0.5997 - dice_coeficient: 0.9452 - val_loss: 0.1447 - val_mean_io_u: 0.6041 - val_dice_coeficient: 0.9440
# Epoch 12/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1423 - mean_io_u: 0.6114 - dice_coeficient: 0.9477
# Epoch 12: val_loss improved from 0.14473 to 0.14226, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 29s 572ms/step - loss: 0.1423 - mean_io_u: 0.6114 - dice_coeficient: 0.9477 - val_loss: 0.1423 - val_mean_io_u: 0.6137 - val_dice_coeficient: 0.9458
# Epoch 13/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1331 - mean_io_u: 0.6215 - dice_coeficient: 0.9503
# Epoch 13: val_loss improved from 0.14226 to 0.13715, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 331ms/step - loss: 0.1331 - mean_io_u: 0.6215 - dice_coeficient: 0.9503 - val_loss: 0.1372 - val_mean_io_u: 0.6300 - val_dice_coeficient: 0.9482
# Epoch 14/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1303 - mean_io_u: 0.6339 - dice_coeficient: 0.9523
# Epoch 14: val_loss improved from 0.13715 to 0.13405, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 51s 1s/step - loss: 0.1303 - mean_io_u: 0.6339 - dice_coeficient: 0.9523 - val_loss: 0.1341 - val_mean_io_u: 0.6381 - val_dice_coeficient: 0.9501
# Epoch 15/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1277 - mean_io_u: 0.6434 - dice_coeficient: 0.9541
# Epoch 15: val_loss improved from 0.13405 to 0.12833, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 53s 1s/step - loss: 0.1277 - mean_io_u: 0.6434 - dice_coeficient: 0.9541 - val_loss: 0.1283 - val_mean_io_u: 0.6477 - val_dice_coeficient: 0.9521
# Epoch 16/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1245 - mean_io_u: 0.6533 - dice_coeficient: 0.9559
# Epoch 16: val_loss improved from 0.12833 to 0.12770, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 27s 536ms/step - loss: 0.1245 - mean_io_u: 0.6533 - dice_coeficient: 0.9559 - val_loss: 0.1277 - val_mean_io_u: 0.6590 - val_dice_coeficient: 0.9529
# Epoch 17/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1226 - mean_io_u: 0.6615 - dice_coeficient: 0.9564
# Epoch 17: val_loss did not improve from 0.12770
# 51/51 [==============================] - 16s 305ms/step - loss: 0.1226 - mean_io_u: 0.6615 - dice_coeficient: 0.9564 - val_loss: 0.1314 - val_mean_io_u: 0.6589 - val_dice_coeficient: 0.9513
# Epoch 18/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1212 - mean_io_u: 0.6662 - dice_coeficient: 0.9570
# Epoch 18: val_loss improved from 0.12770 to 0.12561, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 35s 704ms/step - loss: 0.1212 - mean_io_u: 0.6662 - dice_coeficient: 0.9570 - val_loss: 0.1256 - val_mean_io_u: 0.6662 - val_dice_coeficient: 0.9549
# Epoch 19/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1143 - mean_io_u: 0.6730 - dice_coeficient: 0.9588
# Epoch 19: val_loss improved from 0.12561 to 0.12089, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 60s 1s/step - loss: 0.1143 - mean_io_u: 0.6730 - dice_coeficient: 0.9588 - val_loss: 0.1209 - val_mean_io_u: 0.6791 - val_dice_coeficient: 0.9564
# Epoch 20/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1078 - mean_io_u: 0.6807 - dice_coeficient: 0.9606
# Epoch 20: val_loss improved from 0.12089 to 0.11953, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 28s 562ms/step - loss: 0.1078 - mean_io_u: 0.6807 - dice_coeficient: 0.9606 - val_loss: 0.1195 - val_mean_io_u: 0.6878 - val_dice_coeficient: 0.9570
# Epoch 21/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1139 - mean_io_u: 0.6842 - dice_coeficient: 0.9598
# Epoch 21: val_loss did not improve from 0.11953
# 51/51 [==============================] - 16s 306ms/step - loss: 0.1139 - mean_io_u: 0.6842 - dice_coeficient: 0.9598 - val_loss: 0.1236 - val_mean_io_u: 0.6840 - val_dice_coeficient: 0.9559
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1089 - mean_io_u: 0.6930 - dice_coeficient: 0.9616
# Epoch 22: val_loss improved from 0.11953 to 0.11763, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 53s 1s/step - loss: 0.1089 - mean_io_u: 0.6930 - dice_coeficient: 0.9616 - val_loss: 0.1176 - val_mean_io_u: 0.6912 - val_dice_coeficient: 0.9586
# Epoch 23/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1040 - mean_io_u: 0.7003 - dice_coeficient: 0.9630
# Epoch 23: val_loss improved from 0.11763 to 0.11390, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 43s 844ms/step - loss: 0.1040 - mean_io_u: 0.7003 - dice_coeficient: 0.9630 - val_loss: 0.1139 - val_mean_io_u: 0.7045 - val_dice_coeficient: 0.9599
# Epoch 24/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1062 - mean_io_u: 0.7057 - dice_coeficient: 0.9643
# Epoch 24: val_loss did not improve from 0.11390
# 51/51 [==============================] - 16s 304ms/step - loss: 0.1062 - mean_io_u: 0.7057 - dice_coeficient: 0.9643 - val_loss: 0.1165 - val_mean_io_u: 0.7018 - val_dice_coeficient: 0.9588
# Epoch 25/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1067 - mean_io_u: 0.7107 - dice_coeficient: 0.9642
# Epoch 25: val_loss did not improve from 0.11390
# 51/51 [==============================] - 16s 314ms/step - loss: 0.1067 - mean_io_u: 0.7107 - dice_coeficient: 0.9642 - val_loss: 0.1145 - val_mean_io_u: 0.7104 - val_dice_coeficient: 0.9594
# Epoch 26/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1036 - mean_io_u: 0.7152 - dice_coeficient: 0.9649
# Epoch 26: val_loss improved from 0.11390 to 0.11138, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 32s 635ms/step - loss: 0.1036 - mean_io_u: 0.7152 - dice_coeficient: 0.9649 - val_loss: 0.1114 - val_mean_io_u: 0.7157 - val_dice_coeficient: 0.9615
# Epoch 27/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1017 - mean_io_u: 0.7201 - dice_coeficient: 0.9657
# Epoch 27: val_loss did not improve from 0.11138
# 51/51 [==============================] - 16s 317ms/step - loss: 0.1017 - mean_io_u: 0.7201 - dice_coeficient: 0.9657 - val_loss: 0.1117 - val_mean_io_u: 0.7158 - val_dice_coeficient: 0.9611
# Epoch 28/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0946 - mean_io_u: 0.7222 - dice_coeficient: 0.9665
# Epoch 28: val_loss did not improve from 0.11138
# 51/51 [==============================] - 17s 326ms/step - loss: 0.0946 - mean_io_u: 0.7222 - dice_coeficient: 0.9665 - val_loss: 0.1120 - val_mean_io_u: 0.7198 - val_dice_coeficient: 0.9620
# Epoch 29/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1007 - mean_io_u: 0.7280 - dice_coeficient: 0.9672
# Epoch 29: val_loss improved from 0.11138 to 0.11066, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 337ms/step - loss: 0.1007 - mean_io_u: 0.7280 - dice_coeficient: 0.9672 - val_loss: 0.1107 - val_mean_io_u: 0.7239 - val_dice_coeficient: 0.9631
# Epoch 30/100
# 51/51 [==============================] - ETA: 0s - loss: 0.1065 - mean_io_u: 0.7241 - dice_coeficient: 0.9625
# Epoch 30: val_loss improved from 0.11066 to 0.11064, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 338ms/step - loss: 0.1065 - mean_io_u: 0.7241 - dice_coeficient: 0.9625 - val_loss: 0.1106 - val_mean_io_u: 0.7308 - val_dice_coeficient: 0.9621
# Epoch 31/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0971 - mean_io_u: 0.7336 - dice_coeficient: 0.9671
# Epoch 31: val_loss improved from 0.11064 to 0.10860, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 17s 341ms/step - loss: 0.0971 - mean_io_u: 0.7336 - dice_coeficient: 0.9671 - val_loss: 0.1086 - val_mean_io_u: 0.7328 - val_dice_coeficient: 0.9628
# Epoch 32/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0976 - mean_io_u: 0.7379 - dice_coeficient: 0.9683
# Epoch 32: val_loss did not improve from 0.10860
# 51/51 [==============================] - 17s 339ms/step - loss: 0.0976 - mean_io_u: 0.7379 - dice_coeficient: 0.9683 - val_loss: 0.1096 - val_mean_io_u: 0.7378 - val_dice_coeficient: 0.9630
# Epoch 33/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0952 - mean_io_u: 0.7409 - dice_coeficient: 0.9675
# Epoch 33: val_loss did not improve from 0.10860
# 51/51 [==============================] - 17s 340ms/step - loss: 0.0952 - mean_io_u: 0.7409 - dice_coeficient: 0.9675 - val_loss: 0.1096 - val_mean_io_u: 0.7344 - val_dice_coeficient: 0.9628
# Epoch 34/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0982 - mean_io_u: 0.7440 - dice_coeficient: 0.9691
# Epoch 34: val_loss improved from 0.10860 to 0.10684, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 344ms/step - loss: 0.0982 - mean_io_u: 0.7440 - dice_coeficient: 0.9691 - val_loss: 0.1068 - val_mean_io_u: 0.7472 - val_dice_coeficient: 0.9651
# Epoch 35/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0963 - mean_io_u: 0.7492 - dice_coeficient: 0.9702
# Epoch 35: val_loss improved from 0.10684 to 0.10597, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 352ms/step - loss: 0.0963 - mean_io_u: 0.7492 - dice_coeficient: 0.9702 - val_loss: 0.1060 - val_mean_io_u: 0.7458 - val_dice_coeficient: 0.9650
# Epoch 36/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0916 - mean_io_u: 0.7517 - dice_coeficient: 0.9704
# Epoch 36: val_loss did not improve from 0.10597
# 51/51 [==============================] - 17s 342ms/step - loss: 0.0916 - mean_io_u: 0.7517 - dice_coeficient: 0.9704 - val_loss: 0.1084 - val_mean_io_u: 0.7506 - val_dice_coeficient: 0.9650
# Epoch 37/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0927 - mean_io_u: 0.7566 - dice_coeficient: 0.9707
# Epoch 37: val_loss improved from 0.10597 to 0.10376, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 350ms/step - loss: 0.0927 - mean_io_u: 0.7566 - dice_coeficient: 0.9707 - val_loss: 0.1038 - val_mean_io_u: 0.7575 - val_dice_coeficient: 0.9657
# Epoch 38/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0915 - mean_io_u: 0.7582 - dice_coeficient: 0.9709
# Epoch 38: val_loss did not improve from 0.10376
# 51/51 [==============================] - 18s 346ms/step - loss: 0.0915 - mean_io_u: 0.7582 - dice_coeficient: 0.9709 - val_loss: 0.1069 - val_mean_io_u: 0.7506 - val_dice_coeficient: 0.9645
# Epoch 39/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0906 - mean_io_u: 0.7604 - dice_coeficient: 0.9711
# Epoch 39: val_loss did not improve from 0.10376
# 51/51 [==============================] - 18s 349ms/step - loss: 0.0906 - mean_io_u: 0.7604 - dice_coeficient: 0.9711 - val_loss: 0.1045 - val_mean_io_u: 0.7546 - val_dice_coeficient: 0.9660
# Epoch 40/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0874 - mean_io_u: 0.7631 - dice_coeficient: 0.9718
# Epoch 40: val_loss did not improve from 0.10376
# 51/51 [==============================] - 18s 348ms/step - loss: 0.0874 - mean_io_u: 0.7631 - dice_coeficient: 0.9718 - val_loss: 0.1052 - val_mean_io_u: 0.7604 - val_dice_coeficient: 0.9658
# Epoch 41/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0917 - mean_io_u: 0.7646 - dice_coeficient: 0.9719
# Epoch 41: val_loss did not improve from 0.10376
# 51/51 [==============================] - 18s 349ms/step - loss: 0.0917 - mean_io_u: 0.7646 - dice_coeficient: 0.9719 - val_loss: 0.1049 - val_mean_io_u: 0.7633 - val_dice_coeficient: 0.9668
# Epoch 42/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0868 - mean_io_u: 0.7664 - dice_coeficient: 0.9726
# Epoch 42: val_loss did not improve from 0.10376
# 51/51 [==============================] - 18s 350ms/step - loss: 0.0868 - mean_io_u: 0.7664 - dice_coeficient: 0.9726 - val_loss: 0.1043 - val_mean_io_u: 0.7652 - val_dice_coeficient: 0.9672
# Epoch 43/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0893 - mean_io_u: 0.7709 - dice_coeficient: 0.9728
# Epoch 43: val_loss improved from 0.10376 to 0.10288, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 356ms/step - loss: 0.0893 - mean_io_u: 0.7709 - dice_coeficient: 0.9728 - val_loss: 0.1029 - val_mean_io_u: 0.7676 - val_dice_coeficient: 0.9672
# Epoch 44/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0860 - mean_io_u: 0.7753 - dice_coeficient: 0.9732
# Epoch 44: val_loss improved from 0.10288 to 0.10159, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 354ms/step - loss: 0.0860 - mean_io_u: 0.7753 - dice_coeficient: 0.9732 - val_loss: 0.1016 - val_mean_io_u: 0.7766 - val_dice_coeficient: 0.9679
# Epoch 45/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0925 - mean_io_u: 0.7767 - dice_coeficient: 0.9737
# Epoch 45: val_loss improved from 0.10159 to 0.10069, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 18s 354ms/step - loss: 0.0925 - mean_io_u: 0.7767 - dice_coeficient: 0.9737 - val_loss: 0.1007 - val_mean_io_u: 0.7746 - val_dice_coeficient: 0.9677
# Epoch 46/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0883 - mean_io_u: 0.7770 - dice_coeficient: 0.9739
# Epoch 46: val_loss did not improve from 0.10069
# 51/51 [==============================] - 18s 352ms/step - loss: 0.0883 - mean_io_u: 0.7770 - dice_coeficient: 0.9739 - val_loss: 0.1023 - val_mean_io_u: 0.7787 - val_dice_coeficient: 0.9681
# Epoch 47/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0867 - mean_io_u: 0.7793 - dice_coeficient: 0.9740
# Epoch 47: val_loss did not improve from 0.10069
# 51/51 [==============================] - 18s 353ms/step - loss: 0.0867 - mean_io_u: 0.7793 - dice_coeficient: 0.9740 - val_loss: 0.1028 - val_mean_io_u: 0.7794 - val_dice_coeficient: 0.9680
# Epoch 48/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0843 - mean_io_u: 0.7821 - dice_coeficient: 0.9741
# Epoch 48: val_loss did not improve from 0.10069
# 51/51 [==============================] - 18s 353ms/step - loss: 0.0843 - mean_io_u: 0.7821 - dice_coeficient: 0.9741 - val_loss: 0.1056 - val_mean_io_u: 0.7778 - val_dice_coeficient: 0.9671
# Epoch 49/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0884 - mean_io_u: 0.7821 - dice_coeficient: 0.9734
# Epoch 49: val_loss did not improve from 0.10069
# 51/51 [==============================] - 18s 355ms/step - loss: 0.0884 - mean_io_u: 0.7821 - dice_coeficient: 0.9734 - val_loss: 0.1029 - val_mean_io_u: 0.7872 - val_dice_coeficient: 0.9676
# Epoch 50/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0846 - mean_io_u: 0.7865 - dice_coeficient: 0.9741
# Epoch 50: val_loss did not improve from 0.10069
# 51/51 [==============================] - 18s 354ms/step - loss: 0.0846 - mean_io_u: 0.7865 - dice_coeficient: 0.9741 - val_loss: 0.1008 - val_mean_io_u: 0.7878 - val_dice_coeficient: 0.9686
# Epoch 51/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0801 - mean_io_u: 0.7880 - dice_coeficient: 0.9744
# Epoch 51: val_loss did not improve from 0.10069
# 51/51 [==============================] - 18s 357ms/step - loss: 0.0801 - mean_io_u: 0.7880 - dice_coeficient: 0.9744 - val_loss: 0.1008 - val_mean_io_u: 0.7818 - val_dice_coeficient: 0.9682
# Epoch 52/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0819 - mean_io_u: 0.7872 - dice_coeficient: 0.9746
# Epoch 52: val_loss improved from 0.10069 to 0.09977, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.0819 - mean_io_u: 0.7872 - dice_coeficient: 0.9746 - val_loss: 0.0998 - val_mean_io_u: 0.7854 - val_dice_coeficient: 0.9684
# Epoch 53/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0787 - mean_io_u: 0.7917 - dice_coeficient: 0.9751
# Epoch 53: val_loss did not improve from 0.09977
# 51/51 [==============================] - 18s 360ms/step - loss: 0.0787 - mean_io_u: 0.7917 - dice_coeficient: 0.9751 - val_loss: 0.1028 - val_mean_io_u: 0.7872 - val_dice_coeficient: 0.9683
# Epoch 54/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0827 - mean_io_u: 0.7904 - dice_coeficient: 0.9748
# Epoch 54: val_loss did not improve from 0.09977
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0827 - mean_io_u: 0.7904 - dice_coeficient: 0.9748 - val_loss: 0.0999 - val_mean_io_u: 0.7916 - val_dice_coeficient: 0.9687
# Epoch 55/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0740 - mean_io_u: 0.7938 - dice_coeficient: 0.9758
# Epoch 55: val_loss improved from 0.09977 to 0.09868, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.0740 - mean_io_u: 0.7938 - dice_coeficient: 0.9758 - val_loss: 0.0987 - val_mean_io_u: 0.7888 - val_dice_coeficient: 0.9688
# Epoch 56/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0799 - mean_io_u: 0.7975 - dice_coeficient: 0.9763
# Epoch 56: val_loss improved from 0.09868 to 0.09786, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 364ms/step - loss: 0.0799 - mean_io_u: 0.7975 - dice_coeficient: 0.9763 - val_loss: 0.0979 - val_mean_io_u: 0.7966 - val_dice_coeficient: 0.9699
# Epoch 57/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0774 - mean_io_u: 0.7987 - dice_coeficient: 0.9766
# Epoch 57: val_loss did not improve from 0.09786
# 51/51 [==============================] - 18s 360ms/step - loss: 0.0774 - mean_io_u: 0.7987 - dice_coeficient: 0.9766 - val_loss: 0.0991 - val_mean_io_u: 0.7985 - val_dice_coeficient: 0.9693
# Epoch 58/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0759 - mean_io_u: 0.7988 - dice_coeficient: 0.9765
# Epoch 58: val_loss did not improve from 0.09786
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0759 - mean_io_u: 0.7988 - dice_coeficient: 0.9765 - val_loss: 0.1008 - val_mean_io_u: 0.7979 - val_dice_coeficient: 0.9696
# Epoch 59/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0828 - mean_io_u: 0.7963 - dice_coeficient: 0.9739
# Epoch 59: val_loss did not improve from 0.09786
# 51/51 [==============================] - 18s 358ms/step - loss: 0.0828 - mean_io_u: 0.7963 - dice_coeficient: 0.9739 - val_loss: 0.1190 - val_mean_io_u: 0.7735 - val_dice_coeficient: 0.9575
# Epoch 60/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0842 - mean_io_u: 0.7939 - dice_coeficient: 0.9711
# Epoch 60: val_loss did not improve from 0.09786
# 51/51 [==============================] - 18s 360ms/step - loss: 0.0842 - mean_io_u: 0.7939 - dice_coeficient: 0.9711 - val_loss: 0.1010 - val_mean_io_u: 0.7949 - val_dice_coeficient: 0.9677
# Epoch 61/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0817 - mean_io_u: 0.8010 - dice_coeficient: 0.9750
# Epoch 61: val_loss did not improve from 0.09786
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0817 - mean_io_u: 0.8010 - dice_coeficient: 0.9750 - val_loss: 0.1014 - val_mean_io_u: 0.8004 - val_dice_coeficient: 0.9690
# Epoch 62/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0835 - mean_io_u: 0.8025 - dice_coeficient: 0.9754
# Epoch 62: val_loss did not improve from 0.09786
# 51/51 [==============================] - 18s 359ms/step - loss: 0.0835 - mean_io_u: 0.8025 - dice_coeficient: 0.9754 - val_loss: 0.0989 - val_mean_io_u: 0.7994 - val_dice_coeficient: 0.9691
# Epoch 63/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0759 - mean_io_u: 0.8058 - dice_coeficient: 0.9766
# Epoch 63: val_loss improved from 0.09786 to 0.09708, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.0759 - mean_io_u: 0.8058 - dice_coeficient: 0.9766 - val_loss: 0.0971 - val_mean_io_u: 0.8074 - val_dice_coeficient: 0.9699
# Epoch 64/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0762 - mean_io_u: 0.8038 - dice_coeficient: 0.9751
# Epoch 64: val_loss did not improve from 0.09708
# 51/51 [==============================] - 18s 362ms/step - loss: 0.0762 - mean_io_u: 0.8038 - dice_coeficient: 0.9751 - val_loss: 0.0995 - val_mean_io_u: 0.8020 - val_dice_coeficient: 0.9690
# Epoch 65/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0810 - mean_io_u: 0.8064 - dice_coeficient: 0.9770
# Epoch 65: val_loss did not improve from 0.09708
# 51/51 [==============================] - 19s 365ms/step - loss: 0.0810 - mean_io_u: 0.8064 - dice_coeficient: 0.9770 - val_loss: 0.0998 - val_mean_io_u: 0.8097 - val_dice_coeficient: 0.9702
# Epoch 66/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0786 - mean_io_u: 0.8077 - dice_coeficient: 0.9759
# Epoch 66: val_loss improved from 0.09708 to 0.09670, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 366ms/step - loss: 0.0786 - mean_io_u: 0.8077 - dice_coeficient: 0.9759 - val_loss: 0.0967 - val_mean_io_u: 0.8080 - val_dice_coeficient: 0.9701
# Epoch 67/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0773 - mean_io_u: 0.8109 - dice_coeficient: 0.9771
# Epoch 67: val_loss did not improve from 0.09670
# 51/51 [==============================] - 18s 362ms/step - loss: 0.0773 - mean_io_u: 0.8109 - dice_coeficient: 0.9771 - val_loss: 0.1004 - val_mean_io_u: 0.8081 - val_dice_coeficient: 0.9696
# Epoch 68/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0738 - mean_io_u: 0.8123 - dice_coeficient: 0.9775
# Epoch 68: val_loss did not improve from 0.09670
# 51/51 [==============================] - 19s 367ms/step - loss: 0.0738 - mean_io_u: 0.8123 - dice_coeficient: 0.9775 - val_loss: 0.0998 - val_mean_io_u: 0.8103 - val_dice_coeficient: 0.9697
# Epoch 69/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0692 - mean_io_u: 0.8138 - dice_coeficient: 0.9774
# Epoch 69: val_loss did not improve from 0.09670
# 51/51 [==============================] - 19s 364ms/step - loss: 0.0692 - mean_io_u: 0.8138 - dice_coeficient: 0.9774 - val_loss: 0.0981 - val_mean_io_u: 0.8190 - val_dice_coeficient: 0.9703
# Epoch 70/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0732 - mean_io_u: 0.8179 - dice_coeficient: 0.9783
# Epoch 70: val_loss improved from 0.09670 to 0.09660, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0732 - mean_io_u: 0.8179 - dice_coeficient: 0.9783 - val_loss: 0.0966 - val_mean_io_u: 0.8114 - val_dice_coeficient: 0.9705
# Epoch 71/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0706 - mean_io_u: 0.8178 - dice_coeficient: 0.9792
# Epoch 71: val_loss did not improve from 0.09660
# 51/51 [==============================] - 19s 366ms/step - loss: 0.0706 - mean_io_u: 0.8178 - dice_coeficient: 0.9792 - val_loss: 0.0967 - val_mean_io_u: 0.8201 - val_dice_coeficient: 0.9713
# Epoch 72/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0688 - mean_io_u: 0.8202 - dice_coeficient: 0.9793
# Epoch 72: val_loss improved from 0.09660 to 0.09546, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 370ms/step - loss: 0.0688 - mean_io_u: 0.8202 - dice_coeficient: 0.9793 - val_loss: 0.0955 - val_mean_io_u: 0.8191 - val_dice_coeficient: 0.9712
# Epoch 73/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0650 - mean_io_u: 0.8221 - dice_coeficient: 0.9797
# Epoch 73: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 369ms/step - loss: 0.0650 - mean_io_u: 0.8221 - dice_coeficient: 0.9797 - val_loss: 0.0962 - val_mean_io_u: 0.8191 - val_dice_coeficient: 0.9712
# Epoch 74/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0730 - mean_io_u: 0.8232 - dice_coeficient: 0.9796
# Epoch 74: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0730 - mean_io_u: 0.8232 - dice_coeficient: 0.9796 - val_loss: 0.0959 - val_mean_io_u: 0.8210 - val_dice_coeficient: 0.9710
# Epoch 75/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0778 - mean_io_u: 0.8143 - dice_coeficient: 0.9747
# Epoch 75: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0778 - mean_io_u: 0.8143 - dice_coeficient: 0.9747 - val_loss: 0.1014 - val_mean_io_u: 0.8156 - val_dice_coeficient: 0.9686
# Epoch 76/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0787 - mean_io_u: 0.8216 - dice_coeficient: 0.9775
# Epoch 76: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 364ms/step - loss: 0.0787 - mean_io_u: 0.8216 - dice_coeficient: 0.9775 - val_loss: 0.0992 - val_mean_io_u: 0.8207 - val_dice_coeficient: 0.9700
# Epoch 77/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0694 - mean_io_u: 0.8247 - dice_coeficient: 0.9780
# Epoch 77: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0694 - mean_io_u: 0.8247 - dice_coeficient: 0.9780 - val_loss: 0.0981 - val_mean_io_u: 0.8227 - val_dice_coeficient: 0.9702
# Epoch 78/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0668 - mean_io_u: 0.8256 - dice_coeficient: 0.9790
# Epoch 78: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 365ms/step - loss: 0.0668 - mean_io_u: 0.8256 - dice_coeficient: 0.9790 - val_loss: 0.0992 - val_mean_io_u: 0.8277 - val_dice_coeficient: 0.9709
# Epoch 79/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0718 - mean_io_u: 0.8265 - dice_coeficient: 0.9797
# Epoch 79: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 368ms/step - loss: 0.0718 - mean_io_u: 0.8265 - dice_coeficient: 0.9797 - val_loss: 0.0957 - val_mean_io_u: 0.8244 - val_dice_coeficient: 0.9717
# Epoch 80/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0673 - mean_io_u: 0.8289 - dice_coeficient: 0.9800
# Epoch 80: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 367ms/step - loss: 0.0673 - mean_io_u: 0.8289 - dice_coeficient: 0.9800 - val_loss: 0.0984 - val_mean_io_u: 0.8259 - val_dice_coeficient: 0.9715
# Epoch 81/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0684 - mean_io_u: 0.8292 - dice_coeficient: 0.9801
# Epoch 81: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0684 - mean_io_u: 0.8292 - dice_coeficient: 0.9801 - val_loss: 0.0955 - val_mean_io_u: 0.8319 - val_dice_coeficient: 0.9719
# Epoch 82/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0692 - mean_io_u: 0.8325 - dice_coeficient: 0.9804
# Epoch 82: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 367ms/step - loss: 0.0692 - mean_io_u: 0.8325 - dice_coeficient: 0.9804 - val_loss: 0.0957 - val_mean_io_u: 0.8314 - val_dice_coeficient: 0.9716
# Epoch 83/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0669 - mean_io_u: 0.8339 - dice_coeficient: 0.9806
# Epoch 83: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 370ms/step - loss: 0.0669 - mean_io_u: 0.8339 - dice_coeficient: 0.9806 - val_loss: 0.0956 - val_mean_io_u: 0.8318 - val_dice_coeficient: 0.9719
# Epoch 84/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0648 - mean_io_u: 0.8350 - dice_coeficient: 0.9809
# Epoch 84: val_loss did not improve from 0.09546
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0648 - mean_io_u: 0.8350 - dice_coeficient: 0.9809 - val_loss: 0.0963 - val_mean_io_u: 0.8311 - val_dice_coeficient: 0.9716
# Epoch 85/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0643 - mean_io_u: 0.8343 - dice_coeficient: 0.9809
# Epoch 85: val_loss improved from 0.09546 to 0.09454, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0643 - mean_io_u: 0.8343 - dice_coeficient: 0.9809 - val_loss: 0.0945 - val_mean_io_u: 0.8349 - val_dice_coeficient: 0.9715
# Epoch 86/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0636 - mean_io_u: 0.8367 - dice_coeficient: 0.9807
# Epoch 86: val_loss did not improve from 0.09454
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0636 - mean_io_u: 0.8367 - dice_coeficient: 0.9807 - val_loss: 0.0958 - val_mean_io_u: 0.8374 - val_dice_coeficient: 0.9720
# Epoch 87/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0702 - mean_io_u: 0.8364 - dice_coeficient: 0.9802
# Epoch 87: val_loss did not improve from 0.09454
# 51/51 [==============================] - 19s 370ms/step - loss: 0.0702 - mean_io_u: 0.8364 - dice_coeficient: 0.9802 - val_loss: 0.0981 - val_mean_io_u: 0.8340 - val_dice_coeficient: 0.9716
# Epoch 88/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0692 - mean_io_u: 0.8361 - dice_coeficient: 0.9805
# Epoch 88: val_loss did not improve from 0.09454
# 51/51 [==============================] - 19s 371ms/step - loss: 0.0692 - mean_io_u: 0.8361 - dice_coeficient: 0.9805 - val_loss: 0.0955 - val_mean_io_u: 0.8340 - val_dice_coeficient: 0.9717
# Epoch 89/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0665 - mean_io_u: 0.8392 - dice_coeficient: 0.9812
# Epoch 89: val_loss did not improve from 0.09454
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0665 - mean_io_u: 0.8392 - dice_coeficient: 0.9812 - val_loss: 0.0958 - val_mean_io_u: 0.8350 - val_dice_coeficient: 0.9714
# Epoch 90/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0664 - mean_io_u: 0.8394 - dice_coeficient: 0.9806
# Epoch 90: val_loss did not improve from 0.09454
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0664 - mean_io_u: 0.8394 - dice_coeficient: 0.9806 - val_loss: 0.0959 - val_mean_io_u: 0.8367 - val_dice_coeficient: 0.9714
# Epoch 91/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0661 - mean_io_u: 0.8407 - dice_coeficient: 0.9816
# Epoch 91: val_loss improved from 0.09454 to 0.09308, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 376ms/step - loss: 0.0661 - mean_io_u: 0.8407 - dice_coeficient: 0.9816 - val_loss: 0.0931 - val_mean_io_u: 0.8385 - val_dice_coeficient: 0.9724
# Epoch 92/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0666 - mean_io_u: 0.8421 - dice_coeficient: 0.9823
# Epoch 92: val_loss did not improve from 0.09308
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0666 - mean_io_u: 0.8421 - dice_coeficient: 0.9823 - val_loss: 0.0931 - val_mean_io_u: 0.8412 - val_dice_coeficient: 0.9723
# Epoch 93/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0665 - mean_io_u: 0.8403 - dice_coeficient: 0.9809
# Epoch 93: val_loss did not improve from 0.09308
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0665 - mean_io_u: 0.8403 - dice_coeficient: 0.9809 - val_loss: 0.0944 - val_mean_io_u: 0.8399 - val_dice_coeficient: 0.9717
# Epoch 94/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0677 - mean_io_u: 0.8461 - dice_coeficient: 0.9815
# Epoch 94: val_loss did not improve from 0.09308
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0677 - mean_io_u: 0.8461 - dice_coeficient: 0.9815 - val_loss: 0.0936 - val_mean_io_u: 0.8407 - val_dice_coeficient: 0.9720
# Epoch 95/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0643 - mean_io_u: 0.8435 - dice_coeficient: 0.9816
# Epoch 95: val_loss did not improve from 0.09308
# 51/51 [==============================] - 19s 372ms/step - loss: 0.0643 - mean_io_u: 0.8435 - dice_coeficient: 0.9816 - val_loss: 0.0963 - val_mean_io_u: 0.8416 - val_dice_coeficient: 0.9720
# Epoch 96/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0670 - mean_io_u: 0.8469 - dice_coeficient: 0.9817
# Epoch 96: val_loss did not improve from 0.09308
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0670 - mean_io_u: 0.8469 - dice_coeficient: 0.9817 - val_loss: 0.0941 - val_mean_io_u: 0.8440 - val_dice_coeficient: 0.9722
# Epoch 97/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0636 - mean_io_u: 0.8488 - dice_coeficient: 0.9825
# Epoch 97: val_loss did not improve from 0.09308
# 51/51 [==============================] - 19s 374ms/step - loss: 0.0636 - mean_io_u: 0.8488 - dice_coeficient: 0.9825 - val_loss: 0.0943 - val_mean_io_u: 0.8483 - val_dice_coeficient: 0.9726
# Epoch 98/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0658 - mean_io_u: 0.8492 - dice_coeficient: 0.9825
# Epoch 98: val_loss did not improve from 0.09308
# 51/51 [==============================] - 19s 375ms/step - loss: 0.0658 - mean_io_u: 0.8492 - dice_coeficient: 0.9825 - val_loss: 0.0936 - val_mean_io_u: 0.8432 - val_dice_coeficient: 0.9726
# Epoch 99/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0603 - mean_io_u: 0.8493 - dice_coeficient: 0.9829
# Epoch 99: val_loss improved from 0.09308 to 0.09264, saving model to ../models\swin-unet_train_Weights.hdf5
# 51/51 [==============================] - 19s 377ms/step - loss: 0.0603 - mean_io_u: 0.8493 - dice_coeficient: 0.9829 - val_loss: 0.0926 - val_mean_io_u: 0.8472 - val_dice_coeficient: 0.9728
# Epoch 100/100
# 51/51 [==============================] - ETA: 0s - loss: 0.0654 - mean_io_u: 0.8511 - dice_coeficient: 0.9829
# Epoch 100: val_loss did not improve from 0.09264
# 51/51 [==============================] - 19s 373ms/step - loss: 0.0654 - mean_io_u: 0.8511 - dice_coeficient: 0.9829 - val_loss: 0.0945 - val_mean_io_u: 0.8426 - val_dice_coeficient: 0.9722

# %%
plt.figure(figsize=(12,4))

plt.subplot(121)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(model_history.history['mean_io_u'])
plt.plot(model_history.history['val_mean_io_u'])
plt.plot(model_history.history['dice_coeficient'])
plt.plot(model_history.history['val_dice_coeficient'])
plt.title('Model meanIOU')
plt.ylabel('mean IOU')
plt.xlabel('epoch')
# plt.yticks(np.arange(0, 1.1, 0.1))

plt.legend(['train IoU', 'val IoU', 'train dice', 'val_dice'], loc='upper left')

plt.show()

# %%
# unet_model = build_unet_model(n_filters=32, n_classes=13)
# unet_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0e-4), 
#     loss=dice_loss,
#     metrics=[tf.metrics.MeanIoU(num_classes=13), dice_coeficient]
# )

# unet_model.load_weights('../models/swin-unet_Weights.hdf5')

# %%
pred = swin_transformer.predict(X_test)
pred = np.array(pred)
pred = tf.argmax(pred, axis=-1)
# Out:
# 51/51 [==============================] - 5s 54ms/step

# %%
plt.figure(figsize=(10,10))
for i in range(3):    
    idx = random.randint(0, len(pred)-1)

    plt.subplot(331 + 3*i)
    plt.imshow(X_test[idx])
    plt.title('Image')
    plt.axis("off")

    plt.subplot(332 + 3*i)
    plt.imshow(tf.argmax(y_test[idx], axis=-1))
    plt.title('Mask')
    plt.axis("off")

    plt.subplot(333 + 3*i)
    plt.imshow(pred[idx])
    plt.title('Prediction')
    plt.axis("off")

plt.show()

# %% [markdown]
#  ---
#  TFG - Alejandro García Mota
